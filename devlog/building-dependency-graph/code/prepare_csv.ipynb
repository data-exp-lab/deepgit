# %% [markdown]
# # Getting the Nodes
#
# - Targets are from this though some doesn't have dependency graph: https://docs.google.com/spreadsheets/d/1CBkyMUawShZdeaRSPp3DMu9-HZriGFb9Uy6NE-Ea36k/edit?gid=0#gid=0
# - There are some repos that don't have dependency or dependents shown.
#   - `samuelmtimbo/unit` doesn't have dependencies shown.
#   - some others have no dependents.

# %% [markdown]
# ## Target Repos

# %%
target_repos_csv_filename = "target_repos.csv"
target_repos = [
    "comfyanonymous/ComfyUI",
    "FlowiseAI/Flowise", 
    "jagenjo/litegraph.js", 
    "biolab/orange3",
    "jerosoler/Drawflow",
    "chaiNNer-org/chaiNNer",
    "samuelmtimbo/unit",
    "Ironclad/rivet",
    "wonderworks-software/PyFlow",
    "ianarawjo/ChainForge",
    "flydelabs/flyde",
    "laudspeaker/laudspeaker",
    "google/visualblocks",
    "enso-org/enso",
    "GraphiteEditor/Graphite",
    "node-red/node-red",
    "JacquesLucke/animation_nodes",
    "Nelarius/imnodes"
]

properties = {
    "name": "full_name",
    "starsCount": "stargazers_count",
    "forksCount": "forks",
    "watchersCount": "subscribers_count",
    "createdAt": "created_at",
    "description": "description",
    "githubPage": "html_url",
    "ownedByOrg": "organization",
    "owner": "owner",
    "language": "language"
}

# %%
import requests
from pprint import pprint
import base64
from github import Github
import datetime

def get_repo_info_from_full_name(repo_full_name: str, prop: dict) -> dict:
    # get the repo
    g = Github()
    repo_info = g.get_repo(full_name_or_id=repo_full_name)
    
    # get properties
    output = {}
    for key in prop.keys():
        output[key] = getattr(repo_info, prop[key])
        
        # make datetime YYYY-MM-DD
        if key == "createdAt":
            output[key] = output[key].strftime("%Y-%m-%d")
        
        # enclose description with ""
        if key == "description":
            output[key] = "\"" + output[key].replace("\"", "'") + "\""
            
        # make ownedByOrg to "True" or "False"
        if key == "ownedByOrg":
            if output[key] is None:
                output[key] = "False"
            else:
                output[key] = "True"
                
        # make owner to string
        if key == "owner":
            output[key] = output[key].login
        
    return output

def get_repo_info_from_repo(repo_info, prop) -> dict:
    # get properties
    output = {}
    for key in prop.keys():
        output[key] = getattr(repo_info, prop[key])
        
        # make datetime YYYY-MM-DD
        if key == "createdAt":
            output[key] = output[key].strftime("%Y-%m-%d")
        
        # enclose description with ""
        if key == "description" and type(output[key]) is str:
            output[key] = "\"" + output[key].replace("\"", "'") + "\""
            
        # make ownedByOrg to "True" or "False"
        if key == "ownedByOrg":
            if output[key] is None:
                output[key] = "False"
            else:
                output[key] = "True"
                
        # make owner to string
        if key == "owner":
            output[key] = output[key].login
        
    return output

# %%
get_repo_info(target_repos[0], properties)
# Out:
# {'name': 'comfyanonymous/ComfyUI',
#  'starsCount': 55993,
#  'forksCount': 5909,
#  'watchersCount': 405,
#  'createdAt': '2023-01-17',
#  'description': '"The most powerful and modular diffusion model GUI, api and backend with a graph/nodes interface."',
#  'githubPage': 'https://github.com/comfyanonymous/ComfyUI',
#  'ownedByOrg': 'False',
#  'owner': 'comfyanonymous',
#  'language': 'Python'}

# %%
# write headers
full_file_name = "csv/{}".format(target_repos_csv_filename)
with open(full_file_name, "w") as f:
    for key in properties.keys():
        f.write(key)
        f.write(",")
    f.write("\n")
    
# call and write data
with open(full_file_name, "a") as f:
    for repo in target_repos:
        data = get_repo_info(repo, properties)
        for key in properties.keys():
            f.write(str(data[key]))
            f.write(",")
        f.write("\n")

print("output to file ...", full_file_name)
# Out:
# output to file ... csv/target_repos.csv

# %% [markdown]
# ## License
# - The license are unique and formatted when get, so I can first output all, and then use CQL `MERGE`.

# %%
license_filename = "license.csv"

license_properties = {
    "id": "spdx_id",
    "name": "name",
    "url": "url"
}

# %%
import requests
from pprint import pprint
import base64
from github import Github
import datetime

def get_license_info(repo_full_name: str, prop: dict) -> dict:
    # get the repo
    g = Github()
    repo_info = g.get_repo(full_name_or_id=repo_full_name)
    
    # get the license
    output = {}
    for key in prop.keys():
        output[key] = getattr(repo_info.license, prop[key])
    
    return output

# %%
# write headers
def write_headers(full_filename: str, prop: dict):
    with open(full_file_name, "w") as f:
        for key in prop.keys():
            f.write(key)
            f.write(",")
        f.write("\n")

# %%
# call and write data
full_file_name = "csv/{}".format(license_filename)
write_headers(full_file_name, license_properties)

with open(full_file_name, "a") as f:
    for repo in target_repos:
        data = get_license_info(repo, license_properties)
        for key in license_properties.keys():
            f.write(str(data[key]))
            f.write(",")
        f.write("\n")

print("output to file ...", full_file_name)
# Out:
# output to file ... csv/license.csv

# %% [markdown]
# ## Topic

# %%
all_topics = [
 '2d-graphics',
 'ai',
 'ai',
 'animation-nodes',
 'art',
 'artificial-intelligence',
 'blender',
 'blueprints',
 'canvas2d',
 'chatbot',
 'chatgpt',
 'checklist-guides',
 'classification',
 'clustering',
 'compiler',
 'compositor',
 'cpp',
 'customer-engagement',
 'customer-journey',
 'data-mining',
 'data-science',
 'data-visualization',
 'dataflow',
 'dataflow-programming',
 'dataflow-programming',
 'dataflow-programming',
 'decision-trees',
 'design',
 'drawflow',
 'editor',
 'editor',
 'email-marketing',
 'enso',
 'evaluation',
 'finite-state-machine',
 'flow',
 'flow-based',
 'flow-based-programming',
 'flow-based-programming',
 'flow-based-programming',
 'flowchart',
 'framework',
 'functional',
 'functional-programming',
 'gamedev',
 'graalvm',
 'graph',
 'graph-editor',
 'graphic-design',
 'graphics-editor',
 'graphs',
 'growth-eng',
 'hacktoberfest',
 'hybrid',
 'image-generation',
 'image-manipulation',
 'image-processing',
 'imgui',
 'interpreter',
 'javascript',
 'javascript',
 'javascript',
 'javascript',
 'javascript-library',
 'jit',
 'langchain',
 'language',
 'large-language-models',
 'large-language-models',
 'live-programming',
 'llamaindex',
 'llm',
 'llmops',
 'llms',
 'low-code',
 'low-code',
 'machine-learning',
 'modular',
 'nestjs',
 'no-code',
 'nocode',
 'node-editor',
 'node-editor',
 'node-graph',
 'node-graph',
 'node-red',
 'nodebased',
 'nodejs',
 'nodejs',
 'nodes',
 'numpy',
 'omnichannel',
 'onboarding',
 'openai',
 'openai',
 'openjs-foundation',
 'orange',
 'orange3',
 'pandas',
 'photo-editing',
 'photo-editor',
 'plotting',
 'polyglot',
 'procedural',
 'procedural-art',
 'procedural-drawing',
 'product-adoption',
 'programming',
 'programming-language',
 'prompt-engineering',
 'push-notifications',
 'pushnotifications',
 'pyflow',
 'pyside2',
 'python',
 'python',
 'python',
 'pytorch',
 'qt',
 'rag',
 'random-forest',
 'react',
 'react',
 'reactive-programming',
 'reactive-programming',
 'regression',
 'rts',
 'scikit-learn',
 'scipy',
 'setup-wizard',
 'sms-marketing',
 'stable-diffusion',
 'state-machine',
 'state-machines',
 'subgraphs',
 'svg-editor',
 'textual',
 'tool',
 'typescript',
 'typescript',
 'typescript',
 'ui',
 'unit',
 'user-onboarding',
 'vector-editor',
 'visual',
 'visual',
 'visual',
 'visual-programming',
 'visual-programming',
 'visual-programming',
 'visual-programming',
 'visual-programming',
 'visual-programming',
 'visual-programming-editor',
 'visual-programming-language',
 'visual-studio-code',
 'visualization',
 'vscode',
 'vscode-extension',
 'vue',
 'workflow',
 'workflow-automation'
]

topics_properties = {
    "id": "id"
}

topics_filename = "topics.csv"

# %%
def get_repo_topics(repo_full_name: str) -> list:
    # get the repo
    g = Github()
    repo_info = g.get_repo(full_name_or_id=repo_full_name)
    
    # get the topic
    return repo_info.topics

# %%
for repo in target_repos:
    all_topics += get_repo_topics(repo)
# Out:
# Request GET /repos/jerosoler/Drawflow failed with 403: rate limit exceeded
# Setting next backoff to 2022.880504s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[43], line 2
#       1 for repo in target_repos:
# ----> 2     all_topics += get_repo_topics(repo)
#
# Cell In[42], line 4, in get_repo_topics(repo_full_name)
#       1 def get_repo_topics(repo_full_name: str) -> list:
#       2     # get the repo
#       3     g = Github()
# ----> 4     repo_info = g.get_repo(full_name_or_id=repo_full_name)
#       6     # get the topic
#       7     return repo_info.topics
#
# File ~/Softwares/python/python3.9/lib/python3.9/site-packages/github/MainClass.py:445, in Github.get_repo(self, full_name_or_id, lazy)
#     443 if lazy:
#     444     return github.Repository.Repository(self.__requester, {}, {"url": url}, completed=False)
# --> 445 headers, data = self.__requester.requestJsonAndCheck("GET", url)
#     446 return github.Repository.Repository(self.__requester, headers, data, completed=True)
#
# File ~/Softwares/python/python3.9/lib/python3.9/site-packages/github/Requester.py:586, in Requester.requestJsonAndCheck(self, verb, url, parameters, headers, input)
#     569 def requestJsonAndCheck(
#     570     self,
#     571     verb: str,
#    (...)
#     575     input: Optional[Any] = None,
#     576 ) -> Tuple[Dict[str, Any], Any]:
#     577     """
#     578     Send a request with JSON body.
#     579
#    (...)
#     584
#     585     """
# --> 586     return self.__check(*self.requestJson(verb, url, parameters, headers, input, self.__customConnection(url)))
#
# File ~/Softwares/python/python3.9/lib/python3.9/site-packages/github/Requester.py:856, in Requester.requestJson(self, verb, url, parameters, headers, input, cnx)
#     853 def encode(input: Any) -> Tuple[str, str]:
#     854     return "application/json", json.dumps(input)
# --> 856 return self.__requestEncode(cnx, verb, url, parameters, headers, input, encode)
#
# File ~/Softwares/python/python3.9/lib/python3.9/site-packages/github/Requester.py:977, in Requester.__requestEncode(self, cnx, verb, url, parameters, requestHeaders, input, encode)
#     973     requestHeaders["Content-Type"], encoded_input = encode(input)
#     975 self.NEW_DEBUG_FRAME(requestHeaders)
# --> 977 status, responseHeaders, output = self.__requestRaw(cnx, verb, url, requestHeaders, encoded_input)
#     979 if Consts.headerRateRemaining in responseHeaders and Consts.headerRateLimit in responseHeaders:
#     980     self.rate_limiting = (
#     981         # ints expected but sometimes floats returned: https://github.com/PyGithub/PyGithub/pull/2697
#     982         int(float(responseHeaders[Consts.headerRateRemaining])),
#     983         int(float(responseHeaders[Consts.headerRateLimit])),
#     984     )
#
# File ~/Softwares/python/python3.9/lib/python3.9/site-packages/github/Requester.py:1011, in Requester.__requestRaw(self, cnx, verb, url, requestHeaders, input)
#    1009     cnx = self.__createConnection()
#    1010 cnx.request(verb, url, input, requestHeaders)
# -> 1011 response = cnx.getresponse()
#    1013 status = response.status
#    1014 responseHeaders = {k.lower(): v for k, v in response.getheaders()}
#
# File ~/Softwares/python/python3.9/lib/python3.9/site-packages/github/Requester.py:202, in HTTPSRequestsConnectionClass.getresponse(self)
#     200 verb = getattr(self.session, self.verb.lower())
#     201 url = f"{self.protocol}://{self.host}:{self.port}{self.url}"
# --> 202 r = verb(
#     203     url,
#     204     headers=self.headers,
#     205     data=self.input,
#     206     timeout=self.timeout,
#     207     verify=self.verify,
#     208     allow_redirects=False,
#     209 )
#     210 return RequestsResponse(r)
#
# File ~/Softwares/python/python3.9/lib/python3.9/site-packages/requests/sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File ~/Softwares/python/python3.9/lib/python3.9/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Softwares/python/python3.9/lib/python3.9/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/Softwares/python/python3.9/lib/python3.9/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/Softwares/python/python3.9/lib/python3.9/site-packages/urllib3/connectionpool.py:876, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     873     return response
#     875 response.drain_conn()
# --> 876 retries.sleep(response)
#     877 log.debug("Retry: %s", url)
#     878 return self.urlopen(
#     879     method,
#     880     url,
#    (...)
#     891     **response_kw
#     892 )
#
# File ~/Softwares/python/python3.9/lib/python3.9/site-packages/urllib3/util/retry.py:432, in Retry.sleep(self, response)
#     429     if slept:
#     430         return
# --> 432 self._sleep_backoff()
#
# File ~/Softwares/python/python3.9/lib/python3.9/site-packages/urllib3/util/retry.py:416, in Retry._sleep_backoff(self)
#     414 if backoff <= 0:
#     415     return
# --> 416 time.sleep(backoff)
#
# KeyboardInterrupt:

# %%
unique_all_topics = []

# sort the topics and do union
all_topics.sort()

# remove spaces and "-" and then do set again.
# for example: nocode, no-code, no code; keep the nocode, the others are alias
for topic in all_topics:
    temp = topic.replace(" ", "").replace("-", "")
    unique_all_topics.append(temp)
    
unique_all_topics = set(unique_all_topics)

# %%
# call and write data
full_file_name = "csv/{}".format(topics_filename)
write_headers(full_file_name, topics_properties)

with open(full_file_name, "a") as f:
    for topic in sorted(unique_all_topics):
        f.write(topic)
        f.write(",")
        f.write("\n")

print("output to file ...", full_file_name)
# Out:
# output to file ... csv/topics.csv

# %% [markdown]
# ## Dependencies -- Repo and DEPENDS_ON

# %% [markdown]
# ### Step 1 -- Querying Dependencies Repo
# - Do union to all target repos' dependency.

# %%
import json

# %%
dependency_file_suffix = "-dependencies.json"
dependent_file_suffix = "-dependents.json"

# split by "/" and lower the case
target_repos_info_raw_filename = []
for full_repo_name in target_repos:
    name = full_repo_name.split("/")[1]
    name = name.lower()
    target_repos_info_raw_filename.append(name)

# %%
# Prepare a list of dependency repo names then do set()
all_target_repo_dependencies = []

for repo in target_repos_info_raw_filename:
    try:
        with open("raw/{}".format(repo + dependency_file_suffix)) as f:
            raw_repo_dep = json.load(f)
        for dep in range(len(raw_repo_dep["packages"])):
            all_target_repo_dependencies.append(raw_repo_dep["packages"][dep]["name"])
    except OSError as e:
        print(repo, "doesn't exist dependencies graph ... ")

# Do set() to make every dep repo unique
unique_all_target_repo_dependencies = set(all_target_repo_dependencies)
unique_all_target_repo_dependencies = sorted(list(unique_all_target_repo_dependencies))
print("all target repos dependency count        =" , len(all_target_repo_dependencies))
print("unique all target repos dependency count =", len(unique_all_target_repo_dependencies))

# If the dependency starts with npm:, remove it
for index, repo in enumerate(unique_all_target_repo_dependencies):
    if repo.startswith("npm:"):
        unique_all_target_repo_dependencies[index] = repo.replace("npm:", "")
# Out:
# unit doesn't exist dependencies graph ...
# all target repos dependency count        = 22771
# unique all target repos dependency count = 6909

# %%
for _ in unique_all_target_repo_dependencies:
    print(_)
# Out:
# 7zip-bin
# @4tw/cypress-drag-drop
# @aashutoshrathi/word-wrap
# @acuminous/bitsyntax
# @adobe/css-tools
# @ag-grid-community/client-side-row-model
# @ag-grid-community/core
# @ag-grid-community/styles
# @ag-grid-enterprise/core
# @ag-grid-enterprise/range-selection
# @ai-sdk/provider
# @ai-sdk/provider-utils
# @ai-sdk/react
# @ai-sdk/solid
# @ai-sdk/svelte
# @ai-sdk/ui-utils
# @ai-sdk/vue
# @akryum/tinypool
# @algolia/autocomplete-core
# @algolia/autocomplete-plugin-algolia-insights
# @algolia/autocomplete-preset-algolia
# @algolia/autocomplete-shared
# @algolia/cache-browser-local-storage
# @algolia/cache-common
# @algolia/cache-in-memory
# @algolia/client-account
# @algolia/client-analytics
# @algolia/client-common
# @algolia/client-personalization
# @algolia/client-search
# @algolia/events
# @algolia/logger-common
# @algolia/logger-console
# @algolia/requester-browser-xhr
# @algolia/requester-common
# @algolia/requester-node-http
# @algolia/transporter
# @alloc/quick-lru
# @ampproject/remapping
# @angular-devkit/core
# @angular-devkit/schematics
# @angular-devkit/schematics-cli
# @ant-design/colors
# @ant-design/cssinjs
# @ant-design/icons
# @ant-design/icons-svg
# @ant-design/react-slick
# @antfu/utils
# @anthropic-ai/sdk
# @apideck/better-ajv-errors
# @apidevtools/json-schema-ref-parser
# @apidevtools/openapi-schemas
# @apidevtools/swagger-methods
# @apidevtools/swagger-parser
# @apify/consts
# @apify/log
# @atlaskit/analytics-next
# @atlaskit/analytics-next-stable-react-context
# @atlaskit/banner
# @atlaskit/blanket
# @atlaskit/button
# @atlaskit/checkbox
# @atlaskit/codemod-utils
# @atlaskit/css-reset
# @atlaskit/dropdown-menu
# @atlaskit/ds-explorations
# @atlaskit/ds-lib
# @atlaskit/focus-ring
# @atlaskit/form
# @atlaskit/icon
# @atlaskit/in-product-testing
# @atlaskit/inline-dialog
# @atlaskit/inline-edit
# @atlaskit/interaction-context
# @atlaskit/layering
# @atlaskit/menu
# @atlaskit/modal-dialog
# @atlaskit/motion
# @atlaskit/platform-feature-flags
# @atlaskit/popper
# @atlaskit/popup
# @atlaskit/portal
# @atlaskit/primitives
# @atlaskit/range
# @atlaskit/select
# @atlaskit/side-navigation
# @atlaskit/spinner
# @atlaskit/tabs
# @atlaskit/textarea
# @atlaskit/textfield
# @atlaskit/theme
# @atlaskit/toggle
# @atlaskit/tokens
# @atlaskit/visually-hidden
# @auth/core
# @aws-amplify/auth
# @aws-amplify/core
# @aws-crypto/crc32
# @aws-crypto/crc32c
# @aws-crypto/ie11-detection
# @aws-crypto/sha1-browser
# @aws-crypto/sha256-browser
# @aws-crypto/sha256-js
# @aws-crypto/supports-web-crypto
# @aws-crypto/util
# @aws-sdk/abort-controller
# @aws-sdk/client-bedrock-agent-runtime
# @aws-sdk/client-bedrock-runtime
# @aws-sdk/client-cloudwatch-logs
# @aws-sdk/client-cognito-identity
# @aws-sdk/client-dynamodb
# @aws-sdk/client-kendra
# @aws-sdk/client-s3
# @aws-sdk/client-sso
# @aws-sdk/client-sso-oidc
# @aws-sdk/client-sts
# @aws-sdk/config-resolver
# @aws-sdk/core
# @aws-sdk/credential-provider-cognito-identity
# @aws-sdk/credential-provider-env
# @aws-sdk/credential-provider-http
# @aws-sdk/credential-provider-imds
# @aws-sdk/credential-provider-ini
# @aws-sdk/credential-provider-node
# @aws-sdk/credential-provider-process
# @aws-sdk/credential-provider-sso
# @aws-sdk/credential-provider-web-identity
# @aws-sdk/credential-providers
# @aws-sdk/endpoint-cache
# @aws-sdk/fetch-http-handler
# @aws-sdk/hash-node
# @aws-sdk/invalid-dependency
# @aws-sdk/is-array-buffer
# @aws-sdk/middleware-bucket-endpoint
# @aws-sdk/middleware-content-length
# @aws-sdk/middleware-endpoint-discovery
# @aws-sdk/middleware-expect-continue
# @aws-sdk/middleware-flexible-checksums
# @aws-sdk/middleware-host-header
# @aws-sdk/middleware-location-constraint
# @aws-sdk/middleware-logger
# @aws-sdk/middleware-recursion-detection
# @aws-sdk/middleware-retry
# @aws-sdk/middleware-sdk-s3
# @aws-sdk/middleware-sdk-sts
# @aws-sdk/middleware-serde
# @aws-sdk/middleware-signing
# @aws-sdk/middleware-ssec
# @aws-sdk/middleware-stack
# @aws-sdk/middleware-user-agent
# @aws-sdk/node-config-provider
# @aws-sdk/node-http-handler
# @aws-sdk/property-provider
# @aws-sdk/protocol-http
# @aws-sdk/querystring-builder
# @aws-sdk/querystring-parser
# @aws-sdk/region-config-resolver
# @aws-sdk/service-error-classification
# @aws-sdk/shared-ini-file-loader
# @aws-sdk/signature-v4
# @aws-sdk/signature-v4-multi-region
# @aws-sdk/smithy-client
# @aws-sdk/token-providers
# @aws-sdk/types
# @aws-sdk/url-parser
# @aws-sdk/url-parser-native
# @aws-sdk/util-arn-parser
# @aws-sdk/util-base64-browser
# @aws-sdk/util-base64-node
# @aws-sdk/util-body-length-browser
# @aws-sdk/util-body-length-node
# @aws-sdk/util-buffer-from
# @aws-sdk/util-endpoints
# @aws-sdk/util-hex-encoding
# @aws-sdk/util-locate-window
# @aws-sdk/util-uri-escape
# @aws-sdk/util-user-agent-browser
# @aws-sdk/util-user-agent-node
# @aws-sdk/util-utf8-browser
# @aws-sdk/util-utf8-node
# @aws-sdk/xml-builder
# @azure-rest/core-client
# @azure/abort-controller
# @azure/core-auth
# @azure/core-client
# @azure/core-lro
# @azure/core-rest-pipeline
# @azure/core-sse
# @azure/core-tracing
# @azure/core-util
# @azure/identity
# @azure/logger
# @azure/msal-browser
# @azure/msal-common
# @azure/msal-node
# @azure/openai
# @babel/code-frame
# @babel/compat-data
# @babel/core
# @babel/eslint-parser
# @babel/generator
# @babel/helper-annotate-as-pure
# @babel/helper-builder-binary-assignment-operator-visitor
# @babel/helper-compilation-targets
# @babel/helper-create-class-features-plugin
# @babel/helper-create-regexp-features-plugin
# @babel/helper-define-polyfill-provider
# @babel/helper-environment-visitor
# @babel/helper-explode-assignable-expression
# @babel/helper-function-name
# @babel/helper-hoist-variables
# @babel/helper-member-expression-to-functions
# @babel/helper-module-imports
# @babel/helper-module-transforms
# @babel/helper-optimise-call-expression
# @babel/helper-plugin-utils
# @babel/helper-remap-async-to-generator
# @babel/helper-replace-supers
# @babel/helper-simple-access
# @babel/helper-skip-transparent-expression-wrappers
# @babel/helper-split-export-declaration
# @babel/helper-string-parser
# @babel/helper-validator-identifier
# @babel/helper-validator-option
# @babel/helper-wrap-function
# @babel/helpers
# @babel/highlight
# @babel/parser
# @babel/plugin-bugfix-firefox-class-in-computed-class-key
# @babel/plugin-bugfix-safari-class-field-initializer-scope
# @babel/plugin-bugfix-safari-id-destructuring-collision-in-function-expression
# @babel/plugin-bugfix-v8-spread-parameters-in-optional-chaining
# @babel/plugin-bugfix-v8-static-class-fields-redefine-readonly
# @babel/plugin-proposal-async-generator-functions
# @babel/plugin-proposal-class-properties
# @babel/plugin-proposal-class-static-block
# @babel/plugin-proposal-decorators
# @babel/plugin-proposal-dynamic-import
# @babel/plugin-proposal-export-namespace-from
# @babel/plugin-proposal-json-strings
# @babel/plugin-proposal-logical-assignment-operators
# @babel/plugin-proposal-nullish-coalescing-operator
# @babel/plugin-proposal-numeric-separator
# @babel/plugin-proposal-object-rest-spread
# @babel/plugin-proposal-optional-catch-binding
# @babel/plugin-proposal-optional-chaining
# @babel/plugin-proposal-private-methods
# @babel/plugin-proposal-private-property-in-object
# @babel/plugin-proposal-unicode-property-regex
# @babel/plugin-syntax-async-generators
# @babel/plugin-syntax-bigint
# @babel/plugin-syntax-class-properties
# @babel/plugin-syntax-class-static-block
# @babel/plugin-syntax-decorators
# @babel/plugin-syntax-dynamic-import
# @babel/plugin-syntax-export-namespace-from
# @babel/plugin-syntax-flow
# @babel/plugin-syntax-import-assertions
# @babel/plugin-syntax-import-attributes
# @babel/plugin-syntax-import-meta
# @babel/plugin-syntax-json-strings
# @babel/plugin-syntax-jsx
# @babel/plugin-syntax-logical-assignment-operators
# @babel/plugin-syntax-nullish-coalescing-operator
# @babel/plugin-syntax-numeric-separator
# @babel/plugin-syntax-object-rest-spread
# @babel/plugin-syntax-optional-catch-binding
# @babel/plugin-syntax-optional-chaining
# @babel/plugin-syntax-private-property-in-object
# @babel/plugin-syntax-top-level-await
# @babel/plugin-syntax-typescript
# @babel/plugin-syntax-unicode-sets-regex
# @babel/plugin-transform-arrow-functions
# @babel/plugin-transform-async-generator-functions
# @babel/plugin-transform-async-to-generator
# @babel/plugin-transform-block-scoped-functions
# @babel/plugin-transform-block-scoping
# @babel/plugin-transform-class-properties
# @babel/plugin-transform-class-static-block
# @babel/plugin-transform-classes
# @babel/plugin-transform-computed-properties
# @babel/plugin-transform-destructuring
# @babel/plugin-transform-dotall-regex
# @babel/plugin-transform-duplicate-keys
# @babel/plugin-transform-duplicate-named-capturing-groups-regex
# @babel/plugin-transform-dynamic-import
# @babel/plugin-transform-exponentiation-operator
# @babel/plugin-transform-export-namespace-from
# @babel/plugin-transform-flow-strip-types
# @babel/plugin-transform-for-of
# @babel/plugin-transform-function-name
# @babel/plugin-transform-json-strings
# @babel/plugin-transform-literals
# @babel/plugin-transform-logical-assignment-operators
# @babel/plugin-transform-member-expression-literals
# @babel/plugin-transform-modules-amd
# @babel/plugin-transform-modules-commonjs
# @babel/plugin-transform-modules-systemjs
# @babel/plugin-transform-modules-umd
# @babel/plugin-transform-named-capturing-groups-regex
# @babel/plugin-transform-new-target
# @babel/plugin-transform-nullish-coalescing-operator
# @babel/plugin-transform-numeric-separator
# @babel/plugin-transform-object-rest-spread
# @babel/plugin-transform-object-super
# @babel/plugin-transform-optional-catch-binding
# @babel/plugin-transform-optional-chaining
# @babel/plugin-transform-parameters
# @babel/plugin-transform-private-methods
# @babel/plugin-transform-private-property-in-object
# @babel/plugin-transform-property-literals
# @babel/plugin-transform-react-constant-elements
# @babel/plugin-transform-react-display-name
# @babel/plugin-transform-react-jsx
# @babel/plugin-transform-react-jsx-development
# @babel/plugin-transform-react-jsx-self
# @babel/plugin-transform-react-jsx-source
# @babel/plugin-transform-react-pure-annotations
# @babel/plugin-transform-regenerator
# @babel/plugin-transform-reserved-words
# @babel/plugin-transform-runtime
# @babel/plugin-transform-shorthand-properties
# @babel/plugin-transform-spread
# @babel/plugin-transform-sticky-regex
# @babel/plugin-transform-template-literals
# @babel/plugin-transform-typeof-symbol
# @babel/plugin-transform-typescript
# @babel/plugin-transform-unicode-escapes
# @babel/plugin-transform-unicode-property-regex
# @babel/plugin-transform-unicode-regex
# @babel/plugin-transform-unicode-sets-regex
# @babel/preset-env
# @babel/preset-flow
# @babel/preset-modules
# @babel/preset-react
# @babel/preset-typescript
# @babel/register
# @babel/regjsgen
# @babel/runtime
# @babel/runtime-corejs3
# @babel/template
# @babel/traverse
# @babel/types
# @bcoe/v8-coverage
# @blueprintjs/colors
# @blueprintjs/core
# @blueprintjs/icons
# @blueprintjs/select
# @chainner/navi
# @chainner/node-path
# @chakra-ui/accordion
# @chakra-ui/alert
# @chakra-ui/anatomy
# @chakra-ui/avatar
# @chakra-ui/breadcrumb
# @chakra-ui/breakpoint-utils
# @chakra-ui/button
# @chakra-ui/card
# @chakra-ui/checkbox
# @chakra-ui/clickable
# @chakra-ui/close-button
# @chakra-ui/color-mode
# @chakra-ui/control-box
# @chakra-ui/counter
# @chakra-ui/css-reset
# @chakra-ui/descendant
# @chakra-ui/dom-utils
# @chakra-ui/editable
# @chakra-ui/event-utils
# @chakra-ui/focus-lock
# @chakra-ui/form-control
# @chakra-ui/hooks
# @chakra-ui/icon
# @chakra-ui/icons
# @chakra-ui/image
# @chakra-ui/input
# @chakra-ui/layout
# @chakra-ui/lazy-utils
# @chakra-ui/live-region
# @chakra-ui/media-query
# @chakra-ui/menu
# @chakra-ui/modal
# @chakra-ui/number-input
# @chakra-ui/number-utils
# @chakra-ui/object-utils
# @chakra-ui/pin-input
# @chakra-ui/popover
# @chakra-ui/popper
# @chakra-ui/portal
# @chakra-ui/progress
# @chakra-ui/provider
# @chakra-ui/radio
# @chakra-ui/react
# @chakra-ui/react-children-utils
# @chakra-ui/react-context
# @chakra-ui/react-env
# @chakra-ui/react-types
# @chakra-ui/react-use-animation-state
# @chakra-ui/react-use-callback-ref
# @chakra-ui/react-use-controllable-state
# @chakra-ui/react-use-disclosure
# @chakra-ui/react-use-event-listener
# @chakra-ui/react-use-focus-effect
# @chakra-ui/react-use-focus-on-pointer-down
# @chakra-ui/react-use-interval
# @chakra-ui/react-use-latest-ref
# @chakra-ui/react-use-merge-refs
# @chakra-ui/react-use-outside-click
# @chakra-ui/react-use-pan-event
# @chakra-ui/react-use-previous
# @chakra-ui/react-use-safe-layout-effect
# @chakra-ui/react-use-size
# @chakra-ui/react-use-timeout
# @chakra-ui/react-use-update-effect
# @chakra-ui/react-utils
# @chakra-ui/select
# @chakra-ui/shared-utils
# @chakra-ui/skeleton
# @chakra-ui/skip-nav
# @chakra-ui/slider
# @chakra-ui/spinner
# @chakra-ui/stat
# @chakra-ui/stepper
# @chakra-ui/styled-system
# @chakra-ui/switch
# @chakra-ui/system
# @chakra-ui/table
# @chakra-ui/tabs
# @chakra-ui/tag
# @chakra-ui/textarea
# @chakra-ui/theme
# @chakra-ui/theme-tools
# @chakra-ui/theme-utils
# @chakra-ui/toast
# @chakra-ui/tooltip
# @chakra-ui/transition
# @chakra-ui/utils
# @chakra-ui/visually-hidden
# @changesets/apply-release-plan
# @changesets/assemble-release-plan
# @changesets/changelog-git
# @changesets/cli
# @changesets/config
# @changesets/errors
# @changesets/get-dependents-graph
# @changesets/get-release-plan
# @changesets/get-version-range-type
# @changesets/git
# @changesets/logger
# @changesets/parse
# @changesets/pre
# @changesets/read
# @changesets/should-skip-package
# @changesets/types
# @changesets/write
# @choojs/findup
# @clickhouse/client
# @clickhouse/client-common
# @codemirror/autocomplete
# @codemirror/commands
# @codemirror/lang-css
# @codemirror/lang-html
# @codemirror/lang-javascript
# @codemirror/lang-json
# @codemirror/lang-markdown
# @codemirror/lang-python
# @codemirror/language
# @codemirror/lint
# @codemirror/search
# @codemirror/state
# @codemirror/theme-one-dark
# @codemirror/view
# @colors/colors
# @couchbase/couchbase-darwin-arm64-napi
# @couchbase/couchbase-darwin-x64-napi
# @couchbase/couchbase-linux-arm64-napi
# @couchbase/couchbase-linux-x64-napi
# @couchbase/couchbase-linuxmusl-x64-napi
# @couchbase/couchbase-win32-x64-napi
# @craco/craco
# @crawlee/types
# @cspotcode/source-map-support
# @csstools/normalize.css
# @csstools/postcss-cascade-layers
# @csstools/postcss-color-function
# @csstools/postcss-font-format-keywords
# @csstools/postcss-hwb-function
# @csstools/postcss-ic-unit
# @csstools/postcss-is-pseudo-class
# @csstools/postcss-nested-calc
# @csstools/postcss-normalize-display-values
# @csstools/postcss-oklab-function
# @csstools/postcss-progressive-custom-properties
# @csstools/postcss-stepped-value-functions
# @csstools/postcss-text-decoration-shorthand
# @csstools/postcss-trigonometric-functions
# @csstools/postcss-unset-value
# @csstools/selector-resolve-nested
# @csstools/selector-specificity
# @ctrl/tinycolor
# @cypress/request
# @cypress/xvfb
# @dabh/diagnostics
# @dagrejs/graphlib
# @danmarshall/deckgl-typings
# @databricks/sql
# @datastax/astra-db-ts
# @date-io/core
# @date-io/date-fns
# @date-io/dayjs
# @date-io/luxon
# @date-io/moment
# @develar/schema-utils
# @discordjs/builders
# @discordjs/collection
# @discordjs/formatters
# @discordjs/rest
# @discordjs/util
# @discordjs/ws
# @discoveryjs/json-ext
# @dnd-kit/accessibility
# @dnd-kit/core
# @dnd-kit/sortable
# @dnd-kit/utilities
# @docsearch/css
# @docsearch/react
# @docusaurus/core
# @docusaurus/cssnano-preset
# @docusaurus/logger
# @docusaurus/mdx-loader
# @docusaurus/module-type-aliases
# @docusaurus/plugin-content-blog
# @docusaurus/plugin-content-docs
# @docusaurus/plugin-content-pages
# @docusaurus/plugin-debug
# @docusaurus/plugin-google-analytics
# @docusaurus/plugin-google-gtag
# @docusaurus/plugin-google-tag-manager
# @docusaurus/plugin-sitemap
# @docusaurus/preset-classic
# @docusaurus/react-loadable
# @docusaurus/theme-classic
# @docusaurus/theme-common
# @docusaurus/theme-search-algolia
# @docusaurus/theme-translations
# @docusaurus/types
# @docusaurus/utils
# @docusaurus/utils-common
# @docusaurus/utils-validation
# @dqbd/tiktoken
# @e2b/code-interpreter
# @elastic/elasticsearch
# @elastic/transport
# @electron-forge/cli
# @electron-forge/core
# @electron-forge/core-utils
# @electron-forge/maker-base
# @electron-forge/maker-deb
# @electron-forge/maker-dmg
# @electron-forge/maker-flatpak
# @electron-forge/maker-rpm
# @electron-forge/maker-squirrel
# @electron-forge/maker-zip
# @electron-forge/plugin-auto-unpack-natives
# @electron-forge/plugin-base
# @electron-forge/plugin-fuses
# @electron-forge/plugin-vite
# @electron-forge/publisher-base
# @electron-forge/publisher-github
# @electron-forge/shared-types
# @electron-forge/template-base
# @electron-forge/template-vite
# @electron-forge/template-vite-typescript
# @electron-forge/template-webpack
# @electron-forge/template-webpack-typescript
# @electron-forge/tracer
# @electron-forge/web-multi-logger
# @electron/asar
# @electron/fuses
# @electron/get
# @electron/notarize
# @electron/osx-sign
# @electron/packager
# @electron/rebuild
# @electron/universal
# @electron/windows-sign
# @emoji-mart/data
# @emoji-mart/react
# @emotion/babel-plugin
# @emotion/cache
# @emotion/eslint-plugin
# @emotion/hash
# @emotion/is-prop-valid
# @emotion/memoize
# @emotion/react
# @emotion/serialize
# @emotion/sheet
# @emotion/styled
# @emotion/stylis
# @emotion/unitless
# @emotion/use-insertion-effect-with-fallbacks
# @emotion/utils
# @emotion/weak-memoize
# @es-joy/jsdoccomment
# @esbuild-kit/cjs-loader
# @esbuild-kit/core-utils
# @esbuild-kit/esm-loader
# @esbuild/aix-ppc64
# @esbuild/android-arm
# @esbuild/android-arm64
# @esbuild/android-x64
# @esbuild/darwin-arm64
# @esbuild/darwin-x64
# @esbuild/freebsd-arm64
# @esbuild/freebsd-x64
# @esbuild/linux-arm
# @esbuild/linux-arm64
# @esbuild/linux-ia32
# @esbuild/linux-loong64
# @esbuild/linux-mips64el
# @esbuild/linux-ppc64
# @esbuild/linux-riscv64
# @esbuild/linux-s390x
# @esbuild/linux-x64
# @esbuild/netbsd-x64
# @esbuild/openbsd-arm64
# @esbuild/openbsd-x64
# @esbuild/sunos-x64
# @esbuild/win32-arm64
# @esbuild/win32-ia32
# @esbuild/win32-x64
# @eslint-community/eslint-utils
# @eslint-community/regexpp
# @eslint/config-array
# @eslint/core
# @eslint/eslintrc
# @eslint/js
# @eslint/object-schema
# @eslint/plugin-kit
# @fal-works/esbuild-plugin-global-externals
# @fast-check/vitest
# @fast-csv/format
# @fast-csv/parse
# @fastify/busboy
# @firebase/app-types
# @firebase/auth-interop-types
# @firebase/component
# @firebase/database
# @firebase/database-compat
# @firebase/database-types
# @firebase/logger
# @firebase/util
# @floating-ui/core
# @floating-ui/dom
# @floating-ui/react
# @floating-ui/react-dom
# @floating-ui/utils
# @floating-ui/vue
# @flowiseai/nodevm
# @flyde/core
# @flyde/dev-server
# @flyde/editor
# @flyde/flow-editor
# @flyde/remote-debugger
# @flyde/resolver
# @flyde/runtime
# @flyde/stdlib
# @fontsource/geist-mono
# @fontsource/open-sans
# @formatjs/ecma402-abstract
# @formatjs/fast-memoize
# @formatjs/icu-messageformat-parser
# @formatjs/icu-skeleton-parser
# @formatjs/intl-localematcher
# @fortaine/fetch-event-source
# @fortawesome/fontawesome-common-types
# @fortawesome/fontawesome-svg-core
# @fortawesome/free-brands-svg-icons
# @fortawesome/free-solid-svg-icons
# @fortawesome/react-fontawesome
# @gar/promisify
# @gentrace/core
# @getzep/zep-cloud
# @getzep/zep-js
# @gilbarbara/deep-equal
# @gilbarbara/helpers
# @gilbarbara/types
# @golevelup/ts-jest
# @gomomento/generated-types
# @gomomento/sdk
# @gomomento/sdk-core
# @good-ghosting/random-name-generator
# @google-ai/generativelanguage
# @google-cloud/firestore
# @google-cloud/paginator
# @google-cloud/projectify
# @google-cloud/promisify
# @google-cloud/storage
# @google-cloud/vertexai
# @google/generative-ai
# @graphql-tools/merge
# @graphql-tools/schema
# @graphql-tools/utils
# @graphql-typed-document-node/core
# @grpc/grpc-js
# @grpc/proto-loader
# @hapi/hoek
# @hapi/topo
# @headlessui/react
# @heroicons/react
# @histoire/app
# @histoire/controls
# @histoire/plugin-vue
# @histoire/shared
# @histoire/vendors
# @hookform/resolvers
# @huggingface/inference
# @huggingface/jinja
# @huggingface/tasks
# @humanfs/core
# @humanfs/node
# @humanwhocodes/config-array
# @humanwhocodes/module-importer
# @humanwhocodes/object-schema
# @humanwhocodes/retry
# @ianvs/prettier-plugin-sort-imports
# @icons/material
# @internationalized/date
# @internationalized/message
# @internationalized/number
# @internationalized/string
# @ioredis/commands
# @isaacs/cliui
# @isaacs/string-locale-compare
# @istanbuljs/load-nyc-config
# @istanbuljs/schema
# @jest/console
# @jest/core
# @jest/environment
# @jest/expect-utils
# @jest/fake-timers
# @jest/globals
# @jest/reporters
# @jest/schemas
# @jest/source-map
# @jest/test-result
# @jest/test-sequencer
# @jest/transform
# @jest/types
# @jridgewell/gen-mapping
# @jridgewell/resolve-uri
# @jridgewell/set-array
# @jridgewell/source-map
# @jridgewell/sourcemap-codec
# @jridgewell/trace-mapping
# @js-sdsl/ordered-map
# @js-temporal/polyfill
# @jsdevtools/ono
# @jsdoc/salty
# @json-schema-spec/json-pointer
# @json-schema-tools/dereferencer
# @json-schema-tools/meta-schema
# @json-schema-tools/reference-resolver
# @json-schema-tools/traverse
# @juggle/resize-observer
# @koa/cors
# @ladle/react
# @ladle/react-context
# @langchain/anthropic
# @langchain/aws
# @langchain/cohere
# @langchain/community
# @langchain/core
# @langchain/exa
# @langchain/google-common
# @langchain/google-gauth
# @langchain/google-genai
# @langchain/google-vertexai
# @langchain/groq
# @langchain/langgraph
# @langchain/mistralai
# @langchain/mongodb
# @langchain/ollama
# @langchain/openai
# @langchain/pinecone
# @langchain/qdrant
# @langchain/textsplitters
# @langchain/weaviate
# @laudspeaker/clickhouse-migrations
# @laudspeaker/core
# @laudspeaker/laudspeaker-js
# @laudspeaker/react
# @leichtgewicht/ip-codec
# @lexical/clipboard
# @lexical/html
# @lexical/link
# @lexical/list
# @lexical/plain-text
# @lexical/selection
# @lexical/table
# @lexical/utils
# @lezer/common
# @lezer/css
# @lezer/highlight
# @lezer/html
# @lezer/javascript
# @lezer/json
# @lezer/lr
# @lezer/markdown
# @lezer/python
# @liaoliaots/nestjs-redis
# @lit-labs/ssr-dom-shim
# @lit/reactive-element
# @llamaindex/cloud
# @llamaindex/env
# @lottiefiles/react-lottie-player
# @lukeed/csprng
# @malept/cross-spawn-promise
# @malept/electron-installer-flatpak
# @malept/flatpak-bundler
# @mantine/core
# @mantine/dates
# @mantine/dropzone
# @mantine/form
# @mantine/hooks
# @mantine/prism
# @mantine/styles
# @mantine/utils
# @manypkg/find-root
# @manypkg/get-packages
# @mapbox/geojson-rewind
# @mapbox/geojson-types
# @mapbox/jsonlint-lines-primitives
# @mapbox/mapbox-gl-supported
# @mapbox/node-pre-gyp
# @mapbox/point-geometry
# @mapbox/tiny-sdf
# @mapbox/unitbezier
# @mapbox/vector-tile
# @mapbox/whoots-js
# @material-tailwind/react
# @mdx-js/mdx
# @mdx-js/react
# @mdx-js/util
# @mendable/firecrawl-js
# @microsoft/1ds-core-js
# @microsoft/1ds-post-js
# @microsoft/applicationinsights-channel-js
# @microsoft/applicationinsights-common
# @microsoft/applicationinsights-core-js
# @microsoft/applicationinsights-shims
# @microsoft/applicationinsights-web-basic
# @microsoft/applicationinsights-web-snippet
# @microsoft/dynamicproto-js
# @microsoft/fetch-event-source
# @mirai73/bedrock-fm
# @mistralai/mistralai
# @modyfi/vite-plugin-yaml
# @monaco-editor/loader
# @monaco-editor/react
# @mongodb-js/saslprep
# @motionone/animation
# @motionone/dom
# @motionone/easing
# @motionone/generators
# @motionone/types
# @motionone/utils
# @msgpackr-extract/msgpackr-extract-win32-x64
# @mui/base
# @mui/core-downloads-tracker
# @mui/icons-material
# @mui/lab
# @mui/material
# @mui/private-theming
# @mui/styled-engine
# @mui/system
# @mui/types
# @mui/utils
# @mui/x-data-grid
# @mui/x-date-pickers
# @mui/x-tree-view
# @nestjs/bull-shared
# @nestjs/bullmq
# @nestjs/cache-manager
# @nestjs/cli
# @nestjs/common
# @nestjs/config
# @nestjs/core
# @nestjs/graphql
# @nestjs/jwt
# @nestjs/mapped-types
# @nestjs/mongoose
# @nestjs/passport
# @nestjs/platform-express
# @nestjs/platform-socket.io
# @nestjs/schedule
# @nestjs/schematics
# @nestjs/serve-static
# @nestjs/testing
# @nestjs/typeorm
# @nestjs/websockets
# @next/env
# @next/eslint-plugin-next
# @next/swc-darwin-arm64
# @next/swc-darwin-x64
# @next/swc-linux-arm64-gnu
# @next/swc-linux-arm64-musl
# @next/swc-linux-x64-gnu
# @next/swc-linux-x64-musl
# @next/swc-win32-arm64-msvc
# @next/swc-win32-ia32-msvc
# @next/swc-win32-x64-msvc
# @nicolo-ribaudo/eslint-scope-5-internals
# @noble/hashes
# @nodelib/fs.scandir
# @nodelib/fs.stat
# @nodelib/fs.walk
# @nolyfill/is-core-module
# @notionhq/client
# @npmcli/arborist
# @npmcli/fs
# @npmcli/git
# @npmcli/installed-package-contents
# @npmcli/map-workspaces
# @npmcli/metavuln-calculator
# @npmcli/move-file
# @npmcli/name-from-folder
# @npmcli/node-gyp
# @npmcli/package-json
# @npmcli/promise-spawn
# @npmcli/run-script
# @nuxtjs/opencollective
# @oclif/core
# @oclif/linewrap
# @oclif/plugin-help
# @oclif/plugin-not-found
# @oclif/plugin-warn-if-update-available
# @oclif/screen
# @octokit/app
# @octokit/auth-app
# @octokit/auth-oauth-app
# @octokit/auth-oauth-device
# @octokit/auth-oauth-user
# @octokit/auth-token
# @octokit/auth-unauthenticated
# @octokit/core
# @octokit/endpoint
# @octokit/graphql
# @octokit/oauth-app
# @octokit/oauth-authorization-url
# @octokit/oauth-methods
# @octokit/openapi-types
# @octokit/plugin-paginate-graphql
# @octokit/plugin-paginate-rest
# @octokit/plugin-request-log
# @octokit/plugin-rest-endpoint-methods
# @octokit/plugin-retry
# @octokit/plugin-throttling
# @octokit/request
# @octokit/request-error
# @octokit/rest
# @octokit/tsconfig
# @octokit/types
# @octokit/webhooks
# @octokit/webhooks-methods
# @octokit/webhooks-types
# @one-ini/wasm
# @open-rpc/client-js
# @open-rpc/meta-schema
# @open-rpc/schema-utils-js
# @open-rpc/server-js
# @open-wc/building-utils
# @opensearch-project/opensearch
# @opentelemetry/api
# @opentelemetry/auto-instrumentations-node
# @opentelemetry/core
# @opentelemetry/exporter-metrics-otlp-grpc
# @opentelemetry/exporter-metrics-otlp-http
# @opentelemetry/exporter-metrics-otlp-proto
# @opentelemetry/exporter-trace-otlp-grpc
# @opentelemetry/exporter-trace-otlp-http
# @opentelemetry/exporter-trace-otlp-proto
# @opentelemetry/resources
# @opentelemetry/sdk-metrics
# @opentelemetry/sdk-node
# @opentelemetry/sdk-trace-base
# @opentelemetry/semantic-conventions
# @panva/hkdf
# @paralleldrive/cuid2
# @petamoriken/float16
# @pinecone-database/pinecone
# @pkgjs/parseargs
# @pkgr/core
# @playwright/test
# @plotly/d3
# @plotly/d3-sankey
# @plotly/d3-sankey-circular
# @plotly/point-cluster
# @pmmmwh/react-refresh-webpack-plugin
# @polka/url
# @popperjs/core
# @protobufjs/aspromise
# @protobufjs/base64
# @protobufjs/codegen
# @protobufjs/eventemitter
# @protobufjs/fetch
# @protobufjs/float
# @protobufjs/inquire
# @protobufjs/path
# @protobufjs/pool
# @protobufjs/utf8
# @puppeteer/browsers
# @qdrant/js-client-rest
# @qdrant/openapi-typescript-fetch
# @radix-ui/number
# @radix-ui/primitive
# @radix-ui/react-compose-refs
# @radix-ui/react-context
# @radix-ui/react-direction
# @radix-ui/react-presence
# @radix-ui/react-primitive
# @radix-ui/react-scroll-area
# @radix-ui/react-slot
# @radix-ui/react-use-callback-ref
# @radix-ui/react-use-layout-effect
# @rc-component/color-picker
# @rc-component/context
# @rc-component/mini-decimal
# @rc-component/mutate-observer
# @rc-component/portal
# @rc-component/tour
# @rc-component/trigger
# @react-aria/breadcrumbs
# @react-aria/button
# @react-aria/calendar
# @react-aria/checkbox
# @react-aria/collections
# @react-aria/color
# @react-aria/combobox
# @react-aria/datepicker
# @react-aria/dialog
# @react-aria/dnd
# @react-aria/focus
# @react-aria/form
# @react-aria/grid
# @react-aria/gridlist
# @react-aria/i18n
# @react-aria/interactions
# @react-aria/label
# @react-aria/link
# @react-aria/listbox
# @react-aria/live-announcer
# @react-aria/menu
# @react-aria/meter
# @react-aria/numberfield
# @react-aria/overlays
# @react-aria/progress
# @react-aria/radio
# @react-aria/searchfield
# @react-aria/select
# @react-aria/selection
# @react-aria/separator
# @react-aria/slider
# @react-aria/spinbutton
# @react-aria/ssr
# @react-aria/switch
# @react-aria/table
# @react-aria/tabs
# @react-aria/tag
# @react-aria/textfield
# @react-aria/toggle
# @react-aria/toolbar
# @react-aria/tooltip
# @react-aria/tree
# @react-aria/utils
# @react-aria/virtualizer
# @react-aria/visually-hidden
# @react-dnd/asap
# @react-dnd/invariant
# @react-dnd/shallowequal
# @react-email/render
# @react-hook/latest
# @react-hook/passive-layout-effect
# @react-hook/resize-observer
# @react-hook/size
# @react-nano/use-event-source
# @react-oauth/google
# @react-stately/calendar
# @react-stately/checkbox
# @react-stately/collections
# @react-stately/color
# @react-stately/combobox
# @react-stately/data
# @react-stately/datepicker
# @react-stately/dnd
# @react-stately/flags
# @react-stately/form
# @react-stately/grid
# @react-stately/layout
# @react-stately/list
# @react-stately/menu
# @react-stately/numberfield
# @react-stately/overlays
# @react-stately/radio
# @react-stately/searchfield
# @react-stately/select
# @react-stately/selection
# @react-stately/slider
# @react-stately/table
# @react-stately/tabs
# @react-stately/toggle
# @react-stately/tooltip
# @react-stately/tree
# @react-stately/utils
# @react-stately/virtualizer
# @react-types/breadcrumbs
# @react-types/button
# @react-types/calendar
# @react-types/checkbox
# @react-types/color
# @react-types/combobox
# @react-types/datepicker
# @react-types/dialog
# @react-types/form
# @react-types/grid
# @react-types/link
# @react-types/listbox
# @react-types/menu
# @react-types/meter
# @react-types/numberfield
# @react-types/overlays
# @react-types/progress
# @react-types/radio
# @react-types/searchfield
# @react-types/select
# @react-types/shared
# @react-types/slider
# @react-types/switch
# @react-types/table
# @react-types/tabs
# @react-types/textfield
# @react-types/tooltip
# @reactflow/background
# @reactflow/controls
# @reactflow/core
# @reactflow/minimap
# @reactflow/node-resizer
# @reactflow/node-toolbar
# @recoiljs/refine
# @redis/bloom
# @redis/client
# @redis/graph
# @redis/json
# @redis/search
# @redis/time-series
# @reduxjs/toolkit
# @rehooks/component-size
# @remix-run/router
# @rjsf/core
# @rjsf/utils
# @rjsf/validator-ajv8
# @rollup/plugin-babel
# @rollup/plugin-node-resolve
# @rollup/plugin-replace
# @rollup/plugin-virtual
# @rollup/pluginutils
# @rollup/rollup-android-arm-eabi
# @rollup/rollup-android-arm64
# @rollup/rollup-darwin-arm64
# @rollup/rollup-darwin-x64
# @rollup/rollup-linux-arm-gnueabihf
# @rollup/rollup-linux-arm-musleabihf
# @rollup/rollup-linux-arm64-gnu
# @rollup/rollup-linux-arm64-musl
# @rollup/rollup-linux-powerpc64le-gnu
# @rollup/rollup-linux-riscv64-gnu
# @rollup/rollup-linux-s390x-gnu
# @rollup/rollup-linux-x64-gnu
# @rollup/rollup-linux-x64-musl
# @rollup/rollup-win32-arm64-msvc
# @rollup/rollup-win32-ia32-msvc
# @rollup/rollup-win32-x64-msvc
# @rtsao/scc
# @rushstack/eslint-patch
# @sapphire/async-queue
# @sapphire/shapeshift
# @sapphire/snowflake
# @selderee/plugin-htmlparser2
# @sendgrid/client
# @sendgrid/eventwebhook
# @sendgrid/helpers
# @sendgrid/mail
# @sentry-internal/feedback
# @sentry-internal/replay-canvas
# @sentry-internal/tracing
# @sentry/browser
# @sentry/cli
# @sentry/core
# @sentry/hub
# @sentry/integrations
# @sentry/node
# @sentry/profiling-node
# @sentry/react
# @sentry/replay
# @sentry/tracing
# @sentry/types
# @sentry/utils
# @sevinf/maybe
# @shaderfrog/glsl-parser
# @sideway/address
# @sideway/formula
# @sideway/pinpoint
# @sigstore/bundle
# @sigstore/protobuf-specs
# @sigstore/sign
# @sigstore/tuf
# @simbathesailor/use-what-changed
# @sinclair/typebox
# @sindresorhus/is
# @sinonjs/commons
# @sinonjs/fake-timers
# @sinonjs/formatio
# @sinonjs/samsam
# @sinonjs/text-encoding
# @slack/logger
# @slack/oauth
# @slack/types
# @slack/web-api
# @slorber/static-site-generator-webpack-plugin
# @smithy/abort-controller
# @smithy/chunked-blob-reader
# @smithy/chunked-blob-reader-native
# @smithy/config-resolver
# @smithy/core
# @smithy/credential-provider-imds
# @smithy/eventstream-codec
# @smithy/eventstream-serde-browser
# @smithy/eventstream-serde-config-resolver
# @smithy/eventstream-serde-node
# @smithy/eventstream-serde-universal
# @smithy/fetch-http-handler
# @smithy/hash-blob-browser
# @smithy/hash-node
# @smithy/hash-stream-node
# @smithy/invalid-dependency
# @smithy/is-array-buffer
# @smithy/md5-js
# @smithy/middleware-content-length
# @smithy/middleware-endpoint
# @smithy/middleware-retry
# @smithy/middleware-serde
# @smithy/middleware-stack
# @smithy/node-config-provider
# @smithy/node-http-handler
# @smithy/property-provider
# @smithy/protocol-http
# @smithy/querystring-builder
# @smithy/querystring-parser
# @smithy/service-error-classification
# @smithy/shared-ini-file-loader
# @smithy/signature-v4
# @smithy/smithy-client
# @smithy/types
# @smithy/url-parser
# @smithy/util-base64
# @smithy/util-body-length-browser
# @smithy/util-body-length-node
# @smithy/util-buffer-from
# @smithy/util-config-provider
# @smithy/util-defaults-mode-browser
# @smithy/util-defaults-mode-node
# @smithy/util-endpoints
# @smithy/util-hex-encoding
# @smithy/util-middleware
# @smithy/util-retry
# @smithy/util-stream
# @smithy/util-uri-escape
# @smithy/util-utf8
# @smithy/util-waiter
# @snyk/github-codeowners
# @socket.io/admin-ui
# @socket.io/component-emitter
# @sqltools/formatter
# @stablelib/base64
# @stripe/react-stripe-js
# @stripe/stripe-js
# @supabase/auth-helpers-nextjs
# @supabase/auth-helpers-shared
# @supabase/functions-js
# @supabase/gotrue-js
# @supabase/node-fetch
# @supabase/postgrest-js
# @supabase/realtime-js
# @supabase/storage-js
# @supabase/supabase-js
# @supercharge/promise-pool
# @surma/rollup-plugin-off-main-thread
# @sveltejs/vite-plugin-svelte
# @sveltejs/vite-plugin-svelte-inspector
# @svgr/babel-plugin-add-jsx-attribute
# @svgr/babel-plugin-remove-jsx-attribute
# @svgr/babel-plugin-remove-jsx-empty-expression
# @svgr/babel-plugin-replace-jsx-attribute-value
# @svgr/babel-plugin-svg-dynamic-title
# @svgr/babel-plugin-svg-em-dimensions
# @svgr/babel-plugin-transform-react-native-svg
# @svgr/babel-plugin-transform-svg-component
# @svgr/babel-preset
# @svgr/core
# @svgr/hast-util-to-babel-ast
# @svgr/plugin-jsx
# @svgr/plugin-svgo
# @svgr/webpack
# @swc/core
# @swc/core-darwin-arm64
# @swc/core-darwin-x64
# @swc/core-linux-arm-gnueabihf
# @swc/core-linux-arm64-gnu
# @swc/core-linux-arm64-musl
# @swc/core-linux-x64-gnu
# @swc/core-linux-x64-musl
# @swc/core-win32-arm64-msvc
# @swc/core-win32-ia32-msvc
# @swc/core-win32-x64-msvc
# @swc/counter
# @swc/helpers
# @swc/types
# @szmarczak/http-timer
# @tabler/icons
# @tabler/icons-react
# @tailwindcss/forms
# @tanstack/match-sorter-utils
# @tanstack/query-core
# @tanstack/query-devtools
# @tanstack/query-persist-client-core
# @tanstack/react-query
# @tanstack/react-query-devtools
# @tanstack/react-table
# @tanstack/react-virtual
# @tanstack/table-core
# @tanstack/virtual-core
# @tanstack/vue-query
# @tauri-apps/api
# @tauri-apps/cli
# @tauri-apps/cli-darwin-arm64
# @tauri-apps/cli-darwin-x64
# @tauri-apps/cli-linux-arm-gnueabihf
# @tauri-apps/cli-linux-arm64-gnu
# @tauri-apps/cli-linux-arm64-musl
# @tauri-apps/cli-linux-x64-gnu
# @tauri-apps/cli-linux-x64-musl
# @tauri-apps/cli-win32-arm64-msvc
# @tauri-apps/cli-win32-ia32-msvc
# @tauri-apps/cli-win32-x64-msvc
# @testing-library/dom
# @testing-library/jest-dom
# @testing-library/react
# @testing-library/user-event
# @tisoap/react-flow-smart-edge
# @tootallnate/once
# @tootallnate/quickjs-emscripten
# @trysound/sax
# @ts-stack/markdown
# @tsconfig/docusaurus
# @tsconfig/node10
# @tsconfig/node12
# @tsconfig/node14
# @tsconfig/node16
# @tsconfig/node20
# @tufjs/canonical-json
# @tufjs/models
# @turf/area
# @turf/bbox
# @turf/centroid
# @turf/helpers
# @turf/meta
# @types/accepts
# @types/argparse
# @types/args
# @types/aria-query
# @types/aws-lambda
# @types/babel__core
# @types/babel__generator
# @types/babel__template
# @types/babel__traverse
# @types/bcrypt
# @types/bcryptjs
# @types/bezier-js
# @types/body-parser
# @types/bonjour
# @types/browserslist
# @types/browserslist-useragent
# @types/btoa-lite
# @types/cacheable-request
# @types/callsite
# @types/caniuse-api
# @types/caseless
# @types/chai
# @types/cli-progress
# @types/command-line-args
# @types/command-line-usage
# @types/component-emitter
# @types/connect
# @types/connect-history-api-fallback
# @types/content-disposition
# @types/cookie
# @types/cookiejar
# @types/cookies
# @types/cors
# @types/cron
# @types/crypto-js
# @types/css.escape
# @types/cuid
# @types/culori
# @types/d3
# @types/d3-array
# @types/d3-axis
# @types/d3-brush
# @types/d3-chord
# @types/d3-color
# @types/d3-contour
# @types/d3-delaunay
# @types/d3-dispatch
# @types/d3-drag
# @types/d3-dsv
# @types/d3-ease
# @types/d3-fetch
# @types/d3-force
# @types/d3-format
# @types/d3-geo
# @types/d3-hierarchy
# @types/d3-interpolate
# @types/d3-path
# @types/d3-polygon
# @types/d3-quadtree
# @types/d3-random
# @types/d3-scale
# @types/d3-scale-chromatic
# @types/d3-selection
# @types/d3-shape
# @types/d3-time
# @types/d3-time-format
# @types/d3-timer
# @types/d3-transition
# @types/d3-zoom
# @types/debounce
# @types/debug
# @types/decompress
# @types/detect-indent
# @types/diff-match-patch
# @types/electron-squirrel-startup
# @types/eslint
# @types/eslint-scope
# @types/estree
# @types/etag
# @types/events
# @types/eventsource
# @types/expect
# @types/express
# @types/express-serve-static-core
# @types/file-saver
# @types/filesystem
# @types/filewriter
# @types/find-root
# @types/flexsearch
# @types/fs-extra
# @types/geojson
# @types/glob
# @types/glob-stream
# @types/google-protobuf
# @types/graceful-fs
# @types/gulp
# @types/hammerjs
# @types/hash-sum
# @types/hast
# @types/history
# @types/hoist-non-react-statics
# @types/html-minifier-terser
# @types/http-assert
# @types/http-cache-semantics
# @types/http-errors
# @types/http-proxy
# @types/is-stream
# @types/istanbul-lib-coverage
# @types/istanbul-lib-report
# @types/istanbul-reports
# @types/jest
# @types/js-cookie
# @types/js-yaml
# @types/jscodeshift
# @types/jsdom
# @types/jsdom-global
# @types/json-schema
# @types/json5
# @types/jsonfile
# @types/jsonpath-plus
# @types/jsonwebtoken
# @types/katex
# @types/keygrip
# @types/keyv
# @types/koa
# @types/koa-compose
# @types/koa-compress
# @types/koa-etag
# @types/koa-send
# @types/koa-static
# @types/koa__cors
# @types/linkify-it
# @types/lodash
# @types/lodash-es
# @types/lodash.mergewith
# @types/lokijs
# @types/long
# @types/lru-cache
# @types/luxon
# @types/mapbox-gl
# @types/markdown-it
# @types/marked
# @types/mathjax
# @types/md5
# @types/mdast
# @types/mdurl
# @types/mime
# @types/mime-types
# @types/minimatch
# @types/minimist
# @types/mkdirp
# @types/mocha
# @types/ms
# @types/multer
# @types/node
# @types/node-fetch
# @types/node-forge
# @types/node-localstorage
# @types/normalize-package-data
# @types/nprogress
# @types/object-hash
# @types/opener
# @types/os-utils
# @types/papaparse
# @types/parse-json
# @types/parse5
# @types/passport
# @types/passport-jwt
# @types/passport-strategy
# @types/path-is-inside
# @types/pg
# @types/pg-cursor
# @types/phoenix
# @types/picomatch
# @types/plist
# @types/plotly.js
# @types/prettier
# @types/prismjs
# @types/prop-types
# @types/ps-tree
# @types/q
# @types/qs
# @types/range-parser
# @types/react
# @types/react-beautiful-dnd
# @types/react-calendar
# @types/react-color
# @types/react-custom-scrollbars
# @types/react-dom
# @types/react-edit-text
# @types/react-google-recaptcha
# @types/react-helmet
# @types/react-is
# @types/react-lines-ellipsis
# @types/react-plotly.js
# @types/react-redux
# @types/react-resizable
# @types/react-router
# @types/react-router-config
# @types/react-router-dom
# @types/react-slider
# @types/react-tagsinput
# @types/react-transition-group
# @types/react-window
# @types/reactcss
# @types/request
# @types/require-from-string
# @types/resolve
# @types/responselike
# @types/retry
# @types/rimraf
# @types/sanitize-html
# @types/sax
# @types/scheduler
# @types/semver
# @types/send
# @types/serve-index
# @types/serve-static
# @types/sharp
# @types/shuffle-seed
# @types/sinon
# @types/sinonjs__fake-timers
# @types/sizzle
# @types/socket.io
# @types/sockjs
# @types/stack-utils
# @types/streamx
# @types/strip-bom
# @types/strip-json-comments
# @types/styled-components
# @types/superagent
# @types/supertest
# @types/swagger-jsdoc
# @types/swagger-ui-express
# @types/tar
# @types/testing-library__jest-dom
# @types/to-ico
# @types/tough-cookie
# @types/triple-beam
# @types/trusted-types
# @types/undertaker
# @types/undertaker-registry
# @types/unist
# @types/use-sync-external-store
# @types/uuid
# @types/validator
# @types/verror
# @types/vinyl
# @types/vinyl-fs
# @types/vscode
# @types/wcag-contrast
# @types/web-bluetooth
# @types/webidl-conversions
# @types/whatwg-url
# @types/which
# @types/wicg-file-system-access
# @types/ws
# @types/xml2js
# @types/yaml
# @types/yargs
# @types/yargs-parser
# @types/yauzl
# @typescript-eslint/eslint-plugin
# @typescript-eslint/experimental-utils
# @typescript-eslint/parser
# @typescript-eslint/scope-manager
# @typescript-eslint/type-utils
# @typescript-eslint/types
# @typescript-eslint/typescript-estree
# @typescript-eslint/utils
# @typescript-eslint/visitor-keys
# @uidotdev/usehooks
# @uiw/codemirror-extensions-basic-setup
# @uiw/codemirror-theme-material
# @uiw/codemirror-theme-noctis-lilac
# @uiw/codemirror-theme-okaidia
# @uiw/codemirror-theme-solarized
# @uiw/codemirror-theme-sublime
# @uiw/codemirror-theme-vscode
# @uiw/codemirror-theme-xcode
# @uiw/codemirror-themes
# @uiw/react-codemirror
# @ungap/structured-clone
# @upstash/redis
# @upstash/vector
# @vercel/blob
# @vercel/kv
# @visualblocks/custom-node-types
# @visualblocks/eslint-config
# @visualblocks/gemini
# @visualblocks/node-utils
# @visualblocks/scripts
# @visualblocks/tsconfig
# @visualblocks/utility-nodes
# @vitejs/plugin-react
# @vitejs/plugin-react-swc
# @vitejs/plugin-vue
# @vitest/coverage-v8
# @vitest/expect
# @vitest/runner
# @vitest/snapshot
# @vitest/spy
# @vitest/utils
# @vladfrangu/async_event_emitter
# @volar/language-core
# @volar/source-map
# @volar/typescript
# @vscode/extension-telemetry
# @vscode/test-electron
# @vscode/vsce
# @vue/babel-helper-vue-transform-on
# @vue/babel-plugin-jsx
# @vue/babel-plugin-resolve-type
# @vue/compiler-core
# @vue/compiler-dom
# @vue/compiler-sfc
# @vue/compiler-ssr
# @vue/devtools-api
# @vue/devtools-core
# @vue/devtools-kit
# @vue/devtools-shared
# @vue/eslint-config-typescript
# @vue/language-core
# @vue/reactivity
# @vue/runtime-core
# @vue/runtime-dom
# @vue/server-renderer
# @vue/shared
# @vue/test-utils
# @vue/tsconfig
# @vueuse/core
# @vueuse/gesture
# @vueuse/metadata
# @vueuse/shared
# @web-std/blob
# @web-std/file
# @web-std/stream
# @webassemblyjs/ast
# @webassemblyjs/floating-point-hex-parser
# @webassemblyjs/helper-api-error
# @webassemblyjs/helper-buffer
# @webassemblyjs/helper-code-frame
# @webassemblyjs/helper-fsm
# @webassemblyjs/helper-module-context
# @webassemblyjs/helper-numbers
# @webassemblyjs/helper-wasm-bytecode
# @webassemblyjs/helper-wasm-section
# @webassemblyjs/ieee754
# @webassemblyjs/leb128
# @webassemblyjs/utf8
# @webassemblyjs/wasm-edit
# @webassemblyjs/wasm-gen
# @webassemblyjs/wasm-opt
# @webassemblyjs/wasm-parser
# @webassemblyjs/wast-parser
# @webassemblyjs/wast-printer
# @webcomponents/shadycss
# @webcomponents/webcomponentsjs
# @webpack-cli/configtest
# @webpack-cli/info
# @webpack-cli/serve
# @wojtekmaj/date-utils
# @wojtekmaj/react-daterange-picker
# @xenova/transformers
# @xmldom/xmldom
# @xobotyi/scrollbar-width
# @xtuc/ieee754
# @xtuc/long
# @yarnpkg/lockfile
# @zag-js/dom-query
# @zag-js/element-size
# @zag-js/focus-visible
# @zilliz/milvus2-sdk-node
# @zxing/text-encoding
# EmbarkStudios/cargo-deny-action
# Inflector
# JSONStream
# ab_glyph
# ab_glyph_rasterizer
# abab
# abbrev
# abort-controller
# abortcontroller-polyfill
# abs-svg-path
# abstract-leveldown
# accepts
# ace-builds
# acorn
# acorn-globals
# acorn-import-assertions
# acorn-import-attributes
# acorn-jsx
# acorn-node
# acorn-walk
# actions-rs/toolchain
# actions/cache
# actions/cache/restore
# actions/cache/save
# actions/checkout
# actions/download-artifact
# actions/github-script
# actions/setup-node
# actions/setup-python
# actions/stale
# actions/upload-artifact
# add-px-to-style
# addr2line
# address
# adjust-sourcemap-loader
# adler
# adler-32
# adler2
# adm-zip
# afl
# ag-charts-community
# ag-grid-community
# ag-grid-enterprise
# ag-grid-vue3
# agent-base
# agentkeepalive
# aggregate-error
# ahash
# aho-corasick
# ahooks
# ahooks-v3-count
# ai
# aiohttp
# ajv
# ajv-errors
# ajv-formats
# ajv-keywords
# algoliasearch
# algoliasearch-helper
# aligned-vec
# alloc-no-stdlib
# alloc-stdlib
# allocator-api2
# almost-equal
# already
# amazon-cognito-identity-js
# amdefine
# amqplib
# anafanafo
# android-activity
# android-properties
# android-tzdata
# android_system_properties
# anes
# ansi-align
# ansi-colors
# ansi-escapes
# ansi-gray
# ansi-html-community
# ansi-regex
# ansi-sequence-parser
# ansi-styles
# ansi-wrap
# ansicolors
# anstream
# anstyle
# anstyle-parse
# anstyle-query
# anstyle-wincon
# antd
# anthropic
# any-promise
# anyhow
# anymatch
# anyqt
# apify-client
# app-builder-bin
# app-builder-lib
# app-root-path
# appdata-path
# appdirs
# appdmg
# append-buffer
# append-field
# append-transform
# applicationinsights
# apps/devserver
# aproba
# ar
# arbitrary
# arboard
# arc-swap
# arch
# archiver
# archiver-utils
# archy
# are-docs-informative
# are-we-there-yet
# arg
# arg_enum_proc_macro
# argparse
# args
# aria-hidden
# aria-query
# arr-diff
# arr-filter
# arr-flatten
# arr-map
# arr-union
# array-back
# array-bounds
# array-buffer-byte-length
# array-differ
# array-each
# array-equal
# array-find-index
# array-flatten
# array-from
# array-includes
# array-initial
# array-last
# array-normalize
# array-range
# array-rearrange
# array-slice
# array-sort
# array-tree-filter
# array-union
# array-uniq
# array-unique
# array.prototype.filter
# array.prototype.findlast
# array.prototype.findlastindex
# array.prototype.flat
# array.prototype.flatmap
# array.prototype.reduce
# array.prototype.toreversed
# array.prototype.tosorted
# arraybuffer.prototype.slice
# arrayref
# arrayvec
# arrify
# as-raw-xcb-connection
# asap
# asar
# ash
# asn1
# asn1.js
# assemblyai
# assert
# assert-json-diff
# assert-plus
# assertion-error
# assign-symbols
# ast-types
# ast-types-flow
# astral-regex
# async
# async-broadcast
# async-channel
# async-compression
# async-dash
# async-done
# async-each
# async-executor
# async-exit-hook
# async-fs
# async-hook-jl
# async-io
# async-limiter
# async-listener
# async-lock
# async-mutex
# async-process
# async-recursion
# async-retry
# async-settle
# async-signal
# async-task
# async-trait
# async-validator
# asynciterator.prototype
# asynckit
# at-least-node
# atk
# atk-sys
# atob
# atomic-waker
# attr-accept
# atty
# author-regex
# autocfg
# autoevals
# autoprefixer
# av1-grain
# available-typed-arrays
# avif-serialize
# aws-config
# aws-endpoint
# aws-http
# aws-sdk
# aws-sdk-ecr
# aws-sdk-s3
# aws-sdk-sso
# aws-sdk-sts
# aws-sig-auth
# aws-sign2
# aws-sigv4
# aws-smithy-async
# aws-smithy-checksums
# aws-smithy-client
# aws-smithy-eventstream
# aws-smithy-http
# aws-smithy-http-tower
# aws-smithy-json
# aws-smithy-query
# aws-smithy-types
# aws-smithy-xml
# aws-types
# aws4
# axe-core
# axios
# axobject-query
# axum
# axum-core
# azure-devops-node-api
# azure/setup-helm
# b4a
# babel-code-frame
# babel-core
# babel-generator
# babel-helper-call-delegate
# babel-helper-define-map
# babel-helper-function-name
# babel-helper-get-function-arity
# babel-helper-hoist-variables
# babel-helper-optimise-call-expression
# babel-helper-regex
# babel-helper-replace-supers
# babel-helpers
# babel-jest
# babel-loader
# babel-messages
# babel-plugin-apply-mdx-type-prop
# babel-plugin-check-es2015-constants
# babel-plugin-dynamic-import-node
# babel-plugin-extract-import-names
# babel-plugin-istanbul
# babel-plugin-jest-hoist
# babel-plugin-macros
# babel-plugin-named-asset-import
# babel-plugin-polyfill-corejs2
# babel-plugin-polyfill-corejs3
# babel-plugin-polyfill-regenerator
# babel-plugin-react-compiler
# babel-plugin-styled-components
# babel-plugin-transform-es2015-arrow-functions
# babel-plugin-transform-es2015-block-scoped-functions
# babel-plugin-transform-es2015-block-scoping
# babel-plugin-transform-es2015-classes
# babel-plugin-transform-es2015-computed-properties
# babel-plugin-transform-es2015-destructuring
# babel-plugin-transform-es2015-duplicate-keys
# babel-plugin-transform-es2015-for-of
# babel-plugin-transform-es2015-function-name
# babel-plugin-transform-es2015-literals
# babel-plugin-transform-es2015-modules-amd
# babel-plugin-transform-es2015-modules-commonjs
# babel-plugin-transform-es2015-modules-systemjs
# babel-plugin-transform-es2015-modules-umd
# babel-plugin-transform-es2015-object-super
# babel-plugin-transform-es2015-parameters
# babel-plugin-transform-es2015-shorthand-properties
# babel-plugin-transform-es2015-spread
# babel-plugin-transform-es2015-sticky-regex
# babel-plugin-transform-es2015-template-literals
# babel-plugin-transform-es2015-typeof-symbol
# babel-plugin-transform-es2015-unicode-regex
# babel-plugin-transform-react-remove-prop-types
# babel-plugin-transform-regenerator
# babel-plugin-transform-strict-mode
# babel-polyfill
# babel-preset-current-node-syntax
# babel-preset-es2015
# babel-preset-jest
# babel-preset-react-app
# babel-register
# babel-runtime
# babel-template
# babel-traverse
# babel-types
# babylon
# bach
# backbone
# backbone-undo
# backo2
# backtrace
# badge-maker
# bail
# balanced-match
# bare-events
# bare-fs
# bare-os
# bare-path
# base
# base-64
# base16
# base32-encode
# base64
# base64-js
# base64id
# basic-auth
# basic-ftp
# batch
# baycomp
# bcrypt
# bcrypt-pbkdf
# bcryptjs
# beef
# beeper
# before-after-hook
# better-path-resolve
# better-sqlite3
# bezier-js
# bfj
# big-integer
# big.js
# bignumber.js
# bin-links
# binary-extensions
# binary-search
# binary-search-bounds
# binaryextensions
# bincode
# bind-event-listener
# bindings
# biolab/orange-ci-cd/.github/workflows/test-translations.yml
# birpc
# bit-set
# bit-twiddle
# bit-vec
# bit_field
# bitflags
# bitmap-sdf
# bitstream-io
# bl
# blinker
# blob-util
# block
# block-buffer
# block-sys
# block2
# blocking
# bluebird
# bluebird-lst
# blueimp-canvas-to-blob
# bmp-js
# bn.js
# body-parser
# bonjour
# bonjour-service
# boolbase
# boolean
# boolinator
# bootstrap
# bottleneck
# bowser
# boxen
# bplist-creator
# bplist-parser
# brace-expansion
# braces
# broadcast-channel
# broadway
# brorand
# brotli
# brotli-decompressor
# browser-or-node
# browser-process-hrtime
# browser-stdout
# browserify-aes
# browserify-cipher
# browserify-des
# browserify-rsa
# browserify-sign
# browserify-zlib
# browserslist
# browserslist-useragent
# bs-logger
# bser
# bson
# bson-objectid
# bstr
# btoa-lite
# buffer
# buffer-alloc
# buffer-alloc-unsafe
# buffer-crc32
# buffer-equal
# buffer-equal-constant-time
# buffer-fill
# buffer-from
# buffer-indexof
# buffer-more-ints
# buffer-writer
# buffer-xor
# bufferstreams
# bufferutil
# builder-util
# builder-util-runtime
# built
# builtin-modules
# builtin-status-codes
# builtins
# bull
# bullmq
# bumpalo
# bundle-name
# bundle-require
# busboy
# bytemuck
# bytemuck_derive
# byteorder
# byteorder-lite
# bytes
# bytes-utils
# bytesize
# cac
# cacache
# cache-base
# cache-content-type
# cache-manager
# cache-manager-ioredis-yet
# cache-manager-redis-store
# cache-manager-redis-yet
# cacheable-lookup
# ...
# remark-mdx
# remark-parse
# remark-rehype
# remark-squeeze-paragraphs
# remove-accents
# remove-bom-buffer
# remove-bom-stream
# remove-trailing-separator
# renderdoc-sys
# renderkid
# repeat-element
# repeat-string
# repeating
# replace-ext
# replace-homedir
# replacestream
# replicate
# request
# request-progress
# request-promise-core
# request-promise-native
# requests
# require-directory
# require-from-string
# require-like
# require-main-filename
# require-reload
# requires-port
# requizzle
# reqwest
# resedit
# reselect
# resend
# resize-img
# resize-observer-polyfill
# resolve
# resolve-alpn
# resolve-cwd
# resolve-dir
# resolve-from
# resolve-options
# resolve-package
# resolve-package-path
# resolve-path
# resolve-pathname
# resolve-pkg-maps
# resolve-protobuf-schema
# resolve-url
# resolve-url-loader
# resolve.exports
# responselike
# restore-cursor
# resvg
# ret
# retain_mut
# retry
# retry-request
# reusify
# revalidator
# rfc4648
# rfd
# rfdc
# rgb
# rifm
# right-now
# rimraf
# ring
# ripemd160
# roarr
# robust-predicates
# rollup
# rollup-plugin-ignore
# rollup-plugin-license
# rollup-plugin-terser
# rollup-plugin-visualizer
# ron
# rooks
# rootpath
# roxmltree
# rregex
# rrweb-cssom
# rspirv
# rtl-css-js
# rtl-detect
# rtlcss
# ruff
# run-applescript
# run-async
# run-parallel
# run-queue
# run-script-os
# rusha
# rustc-demangle
# rustc-hash
# rustc_codegen_spirv
# rustc_codegen_spirv-types
# rustc_version
# rustix
# rustls
# rustls-native-certs
# rustls-pemfile
# rustls-pki-types
# rustls-webpki
# rustversion
# rustybuzz
# rw
# rxjs
# ryu
# sade
# safe-array-concat
# safe-buffer
# safe-regex
# safe-regex-test
# safe-stable-stringify
# safemem
# safer-buffer
# safetensors
# same-file
# sanitize-filename
# sanitize-html
# sanitize.css
# sass
# sass-loader
# sax
# saxes
# schannel
# scheduler
# schema-utils
# scikit-learn
# scipy
# scmp
# scoped-regex
# scoped-tls
# scopeguard
# screenfull
# scriptjs
# scroll
# scroll-into-view-if-needed
# scroll_derive
# scrollparent
# scslre
# sct
# sctk-adwaita
# search-insights
# secrecy
# section-matter
# secure-json-parse
# secure-keys
# security-framework
# security-framework-sys
# seedrandom
# seek-bzip
# selderee
# select
# select-hose
# selectors
# self-replace
# selfsigned
# semver
# semver-compare
# semver-diff
# semver-greatest-satisfied-range
# send
# sentence-case
# sentencepiece
# seq-queue
# serde
# serde-wasm-bindgen
# serde_derive
# serde_json
# serde_path_to_error
# serde_qs
# serde_repr
# serde_spanned
# serde_urlencoded
# serde_with
# serde_with_macros
# serde_yaml
# serialize-error
# serialize-javascript
# serialize-query-params
# serialize-to-javascript
# serialize-to-javascript-impl
# seroval
# serve-handler
# serve-index
# serve-static
# server-destroy
# serverfiles
# servo_arc
# set-blocking
# set-cookie-parser
# set-function-length
# set-function-name
# set-harmonic-interval
# set-value
# setimmediate
# setprototypeof
# sha.js
# sha1
# sha1_smol
# sha2
# shady-css-scoped-element
# shallow-clone
# shallow-copy
# shallow-equal
# shallowequal
# sharded-slab
# shared_child
# sharp
# shebang-command
# shebang-regex
# shell-exec
# shell-quote
# shelljs
# shiki
# shiki-es
# shimmer
# shlex
# shogo82148/actions-upload-release-asset
# should
# shuffle-seed
# shush
# shx
# side-channel
# sift
# siginfo
# signal-exit
# signal-hook-registry
# signum
# sigstore
# simd-adler32
# simd_helpers
# simple-concat
# simple-get
# simple-swizzle
# simple-update-notifier
# simple_asn1
# simplecss
# sinon
# siphasher
# sirv
# sister
# sisteransi
# sitemap
# skim
# skrifa
# slab
# slash
# slashes
# slice-ansi
# slick
# slide
# slotmap
# slug
# smallvec
# smart-buffer
# smithay-client-toolkit
# smol-toml
# smol_str
# snafu
# snafu-derive
# snake-case
# snapdragon
# snapdragon-node
# snapdragon-util
# socket.io
# socket.io-adapter
# socket.io-client
# socket.io-parser
# socket2
# sockjs
# sockjs-client
# socks
# socks-proxy-agent
# solid-element
# solid-js
# sort-css-media-queries
# sort-keys
# soundfile
# soup2
# soup2-sys
# source-list-map
# source-map
# source-map-js
# source-map-loader
# source-map-resolve
# source-map-support
# source-map-url
# sourcemap-codec
# space-separated-tokens
# spandrel
# sparkles
# sparse-bitfield
# spawn-command
# spawn-wrap
# spawndamnit
# spdx-compare
# spdx-correct
# spdx-exceptions
# spdx-expression-parse
# spdx-expression-validate
# spdx-license-ids
# spdx-ranges
# spdx-satisfies
# spdy
# spdy-transport
# speakingurl
# specta
# specta-macros
# spectorjs
# speech-rule-engine
# sphinx
# sphinx-multiproject
# sphinx-rtd-theme
# spin
# spirt
# spirv
# spirv-builder
# spirv-std
# spirv-std-macros
# spirv-std-types
# spirv-tools
# spirv-tools-sys
# split
# split-on-first
# split-string
# split2
# sprintf-js
# sql-formatter
# sqlalchemy
# sqlite3
# sqlstring
# srggrs/assign-one-project-github-action
# srt-parser-2
# ssf
# sshpk
# ssri
# sswr
# stable
# stable_deref_trait
# stack-chain
# stack-generator
# stack-trace
# stack-utils
# stackback
# stackframe
# stacktrace-gps
# stacktrace-js
# standard
# standard-as-callback
# standard-engine
# starkbank-ecdsa
# start-server-and-test
# stat-mode
# state
# state-local
# state-toggle
# static-eval
# static-extend
# static_assertions
# statuses
# std-env
# stdin-discarder
# stealthy-require
# steno
# stop-iteration-iterator
# stoppable
# stream-browserify
# stream-buffers
# stream-combiner
# stream-each
# stream-events
# stream-exhaust
# stream-http
# stream-meter
# stream-parser
# stream-shift
# stream-to
# stream-to-buffer
# stream2asynciter
# streamsearch
# streamx
# stretch
# strict-event-emitter-types
# strict-num
# strict-uri-encode
# string-argv
# string-collapse-leading-whitespace
# string-convert
# string-left-right
# string-length
# string-natural-compare
# string-split-by
# string-strip-html
# string-trim-spaces-only
# string-width
# string-width-cjs
# string.prototype.matchall
# string.prototype.padend
# string.prototype.repeat
# string.prototype.trim
# string.prototype.trimend
# string.prototype.trimstart
# string_cache
# string_cache_codegen
# string_decoder
# stringify-object
# strip-ansi
# strip-ansi-cjs
# strip-ansi-escapes
# strip-bom
# strip-bom-buf
# strip-bom-stream
# strip-bom-string
# strip-comments
# strip-dirs
# strip-eof
# strip-final-newline
# strip-indent
# strip-json-comments
# strip-literal
# strip-outer
# stripe
# strnum
# strongly-connected-components
# strsim
# strum
# strum_macros
# stubs
# styfle/cancel-workflow-action
# style-loader
# style-mod
# style-search
# style-to-js
# style-to-object
# style-value-types
# styled-components
# styled-jsx
# styled-tools
# stylehacks
# stylelint
# stylelint-config-prettier
# stylelint-config-prettier-scss
# stylelint-config-recommended
# stylelint-config-recommended-scss
# stylelint-config-standard
# stylelint-config-standard-scss
# stylelint-prettier
# stylelint-scss
# stylis
# subscriptions-transport-ws
# subtle
# sucrase
# sudo-prompt
# sumchecker
# summary
# superagent
# supercluster
# superjson
# superscript-text
# supertest
# supports-color
# supports-hyperlinks
# supports-preserve-symlinks-flag
# svelte
# svelte-eslint-parser
# svelte-hmr
# svelte-preprocess
# svenstaro/upload-release-action
# sver-compat
# svg
# svg-arc-to-cubic-bezier
# svg-parser
# svg-path-bounds
# svg-path-sdf
# svg-tags
# svg_fmt
# svgo
# svgtypes
# svix
# svix-fetch
# swagger-jsdoc
# swagger-parser
# swagger-ui-dist
# swagger-ui-express
# swr
# swrev
# swrv
# symbol-observable
# symbol-tree
# symlink
# syn
# sync-fetch
# sync_wrapper
# synckit
# sys-locale
# sysinfo
# system-configuration
# system-configuration-sys
# system-deps
# systeminformation
# systemjs
# tabbable
# table
# table-layout
# taiki-e/install-action
# tailwind-merge
# tailwind-variants
# tailwindcss
# tailwindcss-animate
# tailwindcss-react-aria-components
# tao
# tao-macros
# tapable
# tar
# tar-fs
# tar-stream
# target-lexicon
# taskforce-connector
# tauri
# tauri-apps/tauri-action
# tauri-build
# tauri-codegen
# tauri-macros
# tauri-plugin-persisted-scope
# tauri-plugin-window-state
# tauri-runtime
# tauri-runtime-wry
# tauri-utils
# tauri-winres
# tauri-winrt-notification
# teeny-request
# temp
# temp-dir
# temp-file
# tempfile
# tempy
# tendril
# tera
# term
# term-size
# termcolor
# terminal-link
# terminal_size
# terser
# terser-webpack-plugin
# test-exclude
# text-decoding
# text-hex
# text-table
# textextensions
# textwrap
# theming
# thenify
# thenify-all
# thin-slice
# thiserror
# thiserror-impl
# thread_local
# thrift
# throat
# throttle-debounce
# throttleit
# through
# through2
# through2-filter
# thunky
# tiff
# tiktoken
# time
# time-core
# time-macros
# time-stamp
# timer
# timers-browserify
# tiny-each-async
# tiny-emitter
# tiny-invariant
# tiny-skia
# tiny-skia-path
# tiny-warning
# tinybench
# tinycolor
# tinycolor2
# tinypool
# tinyqueue
# tinyrainbow
# tinyspy
# tinytemplate
# tinyvec
# tinyvec_macros
# titleize
# tls
# tmp
# tmp-promise
# tmpl
# tn1150
# to-absolute-glob
# to-arraybuffer
# to-buffer
# to-camel-case
# to-data-view
# to-fast-properties
# to-float32
# to-ico
# to-no-case
# to-object-path
# to-px
# to-readable-stream
# to-regex
# to-regex-range
# to-space-case
# to-through
# toggle-selection
# toidentifier
# tokenizers
# tokio
# tokio-macros
# tokio-native-tls
# tokio-rustls
# tokio-stream
# tokio-util
# toml
# toml_datetime
# toml_edit
# topojson-client
# toposort
# torch
# torchaudio
# torchsde
# torchvision
# tosource
# totalist
# touch
# tough-cookie
# tower
# tower-http
# tower-layer
# tower-service
# tqdm
# tr-nestjs-clickhouse
# tr46
# tracing
# tracing-attributes
# tracing-core
# tracing-log
# tracing-subscriber
# transformers
# traverse
# tree-changes
# tree-kill
# tree_magic_mini
# treediff
# treeverse
# trim
# trim-lines
# trim-newlines
# trim-repeated
# trim-right
# trim-trailing-lines
# triple-beam
# trough
# trubar
# truncate-utf8-bytes
# try-lock
# tryer
# ts-api-utils
# ts-dedent
# ts-easing
# ts-interface-checker
# ts-jest
# ts-loader
# ts-mixer
# ts-node
# ts-node-dev
# ts-pattern
# ts-results
# tsc-watch
# tsconfck
# tsconfig
# tsconfig-paths
# tsconfig-paths-webpack-plugin
# tslib
# tslint
# tsscmp
# tst-reflect
# tst-reflect-transformer
# tsup
# tsutils
# tsv
# tsx
# ttf-parser
# tty-browserify
# ttypescript
# tuf-js
# tuikit
# tunnel
# tunnel-agent
# turbo
# turbo-darwin-64
# turbo-darwin-arm64
# turbo-linux-64
# turbo-linux-arm64
# turbo-windows-64
# turbo-windows-arm64
# tweetnacl
# twilio
# type
# type-check
# type-detect
# type-fest
# type-is
# typed-array-buffer
# typed-array-byte-length
# typed-array-byte-offset
# typed-array-length
# typed-emitter
# typed-function
# typed-rest-client
# typedarray
# typedarray-pool
# typedarray-to-buffer
# typedoc
# typedoc-plugin-markdown
# typenum
# typeorm
# typescript
# typescript-eslint
# typical
# ua-parser-js
# uc.micro
# ucd-trie
# uds_windows
# ufo
# uglify-js
# uid
# uk.co.bithatch:svg-rasterizer-maven-plugin
# unbox-primitive
# unbzip2-stream
# unc-path-regex
# unctx
# undefsafe
# underscore
# undertaker
# undertaker-registry
# undici
# undici-types
# unfetch
# unherit
# unic-char-property
# unic-char-range
# unic-common
# unic-segment
# unic-ucd-segment
# unic-ucd-version
# unicase
# unicode-bidi
# unicode-bidi-mirroring
# unicode-canonical-property-names-ecmascript
# unicode-ccc
# unicode-ident
# unicode-match-property-ecmascript
# unicode-match-property-value-ecmascript
# unicode-normalization
# unicode-properties
# unicode-property-aliases-ecmascript
# unicode-script
# unicode-segmentation
# unicode-vo
# unicode-width
# unicode-xid
# unified
# union-value
# unique-filename
# unique-slug
# unique-stream
# unique-string
# unist-builder
# unist-util-find-after
# unist-util-generated
# unist-util-is
# unist-util-position
# unist-util-remove
# unist-util-remove-position
# unist-util-stringify-position
# unist-util-visit
# unist-util-visit-parents
# universal-cookie
# universal-github-app-jwt
# universal-user-agent
# universalify
# unix-dgram
# unload
# unorm
# unpipe
# unplugin
# unquote
# unsafe-libyaml
# unset-value
# untildify
# untrusted
# upath
# update-browserslist-db
# update-diff
# update-input-width
# update-notifier
# upper-case
# upper-case-first
# uri-js
# urix
# url
# url-join
# url-loader
# url-parse
# url-parse-lax
# url-regex
# urlencoding
# urllib3
# use
# use-async-effect
# use-callback-ref
# use-composed-ref
# use-context-selector
# use-debounce
# use-error-boundary
# use-isomorphic-layout-effect
# use-latest
# use-memo-one
# use-query-params
# use-sidecar
# use-sync-external-store
# usehooks-ts
# useragent
# username
# usvg
# utf-8
# utf-8-validate
# utf8-byte-length
# utf8parse
# util
# util-deprecate
# util.promisify
# utila
# utile
# utility-types
# utils-merge
# uuid
# uuidv4
# uuidv7
# uvu
# v8-compile-cache
# v8-compile-cache-lib
# v8-to-istanbul
# v8flags
# v_frame
# vali-date
# valid-data-url
# valid-url
# validate-npm-package-license
# validate-npm-package-name
# validate-peer-dependencies
# validate.io-array
# validate.io-function
# validate.io-integer
# validate.io-integer-array
# validate.io-number
# validator
# valuable
# value-equal
# value-or-function
# value-or-promise
# vary
# vbtest-custom-node-types
# vcpkg
# veaury
# vello
# vello_encoding
# vello_shaders
# verror
# version-compare
# version-guard
# version_check
# vfile
# vfile-location
# vfile-message
# victory
# victory-area
# victory-axis
# victory-bar
# victory-box-plot
# victory-brush-container
# victory-brush-line
# victory-candlestick
# victory-canvas
# victory-chart
# victory-core
# victory-create-container
# victory-cursor-container
# victory-errorbar
# victory-group
# victory-histogram
# victory-legend
# victory-line
# victory-pie
# victory-polar-axis
# victory-scatter
# victory-selection-container
# victory-shared-events
# victory-stack
# victory-tooltip
# victory-vendor
# victory-voronoi
# victory-voronoi-container
# victory-zoom-container
# vinyl
# vinyl-bufferstream
# vinyl-file
# vinyl-fs
# vinyl-sourcemap
# vinyl-sourcemaps-apply
# vite
# vite-hot-client
# vite-multiple-assets
# vite-node
# vite-plugin-inspect
# vite-plugin-monaco-editor
# vite-plugin-pwa
# vite-plugin-react-js-support
# vite-plugin-svgr
# vite-plugin-top-level-await
# vite-plugin-vue-devtools
# vite-plugin-vue-inspector
# vite-plugin-wasm
# vite-tsconfig-paths
# vitefu
# vitest
# viztracer
# vm-browserify
# vm2
# void-elements
# vsce
# vscode-oniguruma
# vscode-textmate
# vscode-uri
# vswhom
# vswhom-sys
# vt-pbf
# vte
# vte_generate_state_changes
# vue
# vue-component-type-helpers
# vue-demi
# vue-eslint-parser
# vue-react-wrapper
# vue-resize
# vue-template-compiler
# vue-tsc
# w3c-hr-time
# w3c-keyname
# w3c-xmlserializer
# wait-on
# waker-fn
# walk-up-path
# walkdir
# walker
# want
# warning
# wasi
# wasm-bindgen
# wasm-bindgen-backend
# wasm-bindgen-futures
# wasm-bindgen-macro
# wasm-bindgen-macro-support
# wasm-bindgen-shared
# wasm-bindgen-test
# wasm-bindgen-test-macro
# wasm-streams
# watchpack
# watchpack-chokidar2
# wayland-backend
# wayland-client
# wayland-csd-frame
# wayland-cursor
# wayland-protocols
# wayland-protocols-plasma
# wayland-protocols-wlr
# wayland-scanner
# wayland-sys
# wbuf
# wcag-contrast
# wcwidth
# weak-map
# weaviate-ts-client
# web-encoding
# web-namespaces
# web-resource-inliner
# web-streams-polyfill
# web-sys
# web-time
# web-vitals
# web-worker
# webgl-context
# webidl-conversions
# webkit2gtk
# webkit2gtk-sys
# webpack
# webpack-bundle-analyzer
# webpack-cli
# webpack-dev-middleware
# webpack-dev-server
# webpack-log
# webpack-manifest-plugin
# webpack-merge
# webpack-node-externals
# webpack-sources
# webpack-virtual-modules
# webpackbar
# webpki
# webpki-roots
# webpod
# websocket-codec
# websocket-driver
# websocket-extensions
# websocket-lite
# webview2-com
# webview2-com-macros
# webview2-com-sys
# weezl
# wgpu
# wgpu-core
# wgpu-hal
# wgpu-types
# whatwg-encoding
# whatwg-fetch
# whatwg-mimetype
# whatwg-url
# which
# which-boxed-primitive
# which-builtin-type
# which-collection
# which-module
# which-pm
# which-typed-array
# why-is-node-running
# wicked-good-xpath
# wide-align
# widest-line
# widestring
# wikipedia
# wildcard
# winapi
# winapi-build
# winapi-i686-pc-windows-gnu
# winapi-util
# winapi-x86_64-pc-windows-gnu
# window-size
# windows
# windows-bindgen
# windows-core
# windows-implement
# windows-interface
# windows-metadata
# windows-registry
# windows-release
# windows-result
# windows-strings
# windows-sys
# windows-targets
# windows-tokens
# windows-version
# windows_aarch64_gnullvm
# windows_aarch64_msvc
# windows_i686_gnu
# windows_i686_gnullvm
# windows_i686_msvc
# windows_x86_64_gnu
# windows_x86_64_gnullvm
# windows_x86_64_msvc
# winit
# wink-nlp
# winnow
# winreg
# winston
# winston-papertrail
# winston-syslog
# winston-transport
# wiremock
# wl-clipboard-rs
# wmf
# word
# word-wrap
# wordwrap
# wordwrapjs
# workbox-background-sync
# workbox-broadcast-update
# workbox-build
# workbox-cacheable-response
# workbox-core
# workbox-expiration
# workbox-google-analytics
# workbox-navigation-preload
# workbox-precaching
# workbox-range-requests
# workbox-recipes
# workbox-routing
# workbox-strategies
# workbox-streams
# workbox-sw
# workbox-webpack-plugin
# workbox-window
# worker-farm
# worker-loader
# workerpool
# world-calendars
# wrap-ansi
# wrap-ansi-cjs
# wrappy
# write-file-atomic
# wry
# ws
# wtfnode
# x11
# x11-dl
# x11rb
# x11rb-protocol
# xattr
# xcursor
# xdg
# xdg-basedir
# xdg-default-browser
# xdg-home
# xgboost
# xhr
# xkbcommon-dl
# xkeysym
# xlrd
# xlsx
# xlsxwriter
# xml-js
# xml-name-validator
# xml-parse-from-string
# xml-rs
# xml2js
# xmlbuilder
# xmlchars
# xmlcreate
# xmldom-sre
# xmlhttprequest-ssl
# xmlparser
# xmlwriter
# xtend
# xterm
# xterm-addon-fit
# xterm-addon-search
# y-codemirror.next
# y-leveldb
# y-protocols
# y-textarea
# y-websocket
# y18n
# yallist
# yaml
# yamlparser
# yargs
# yargs-parser
# yargs-unparser
# yarn-or-npm
# yauzl
# yazl
# yeoman-environment
# yeoman-generator
# yjs
# ylru
# yn
# yocto-queue
# youtube-player
# yup
# z-schema
# zbus
# zbus_macros
# zbus_names
# zen-observable
# zen-observable-ts
# zerocopy
# zerocopy-derive
# zeroize
# zip
# zip-stream
# zod
# zod-to-json-schema
# zod-validation-error
# zune-core
# zune-inflate
# zune-jpeg
# zustand
# zvariant
# zvariant_derive
# zvariant_utils
# zwitch
# zx

# %%
### DON'T TOUCH

# Write headers
unique_all_target_repo_dependencies_filename = "target_repo_dependencies.csv"
full_file_name = "csv/{}".format(unique_all_target_repo_dependencies_filename)
write_headers(full_file_name, properties)

# %%
### DON'T TOUCH

# Keep dependencies full name, because we might also want to create topics and licenses csv.
unique_all_target_repo_dependencies_full_name = []   # only contain those that can be identify, and is written to csv file
unique_all_target_repo_dependencies_failed = {"CannotFind": [], "MultiSuggestion": []}

# %%
### DON'T TOUCH

map_target_repo_dependencies_to_full_name = {}

for index, repo in enumerate(sorted(unique_all_target_repo_dependencies)):
    if index == len(unique_all_target_repo_dependencies_full_name):
        break
    map_target_repo_dependencies_to_full_name[repo] = unique_all_target_repo_dependencies_full_name[index]

# %%
len(map_target_repo_dependencies_to_full_name)
# Out:
# 56

# %%
import requests
import json
from github import Github
from github import Auth
from github import GithubException

auth = Auth.Token("YOUR_TOKEN")

g = Github(auth=auth)

# %%
from bs4 import BeautifulSoup

def search_pypi(repo_full_name: str):
    """Search pypi and return Repository() obj"""
    global g
    
    # get html
    url = "https://pypi.org/project/"
    page = requests.get(url + repo_full_name)
    
    soup = BeautifulSoup(page.content, 'html.parser')
    
    # parsing
    # <a class="vertical-tabs__tab vertical-tabs__tab--with-icon vertical-tabs__tab--condensed" href="https://github.com/data-exp-lab/yt_libyt" rel="nofollow">
    #    <i aria-hidden="true" class="fas fa-home">
    #    </i>
    #    Homepage
    # </a>
    
    github_url_prefix = "https://github.com/"
    find_all_a = soup.find_all("a")
    candidate = []
    for a in find_all_a:
        if "Homepage" in a.get_text():
            github_url = a.get("href")
            candidate.append(github_url[len(github_url_prefix):])
    candidate = list(set(candidate))
    
    if len(candidate) != 1:
        return None, "MultiSuggestion"
    else:
        repo_info = g.get_repo(full_name_or_id=candidate[0])
        return repo_info, "ok"

# %%
def search_npm_io(repo_full_name: str):
    """Search npm and return Repository() obj"""
    global g
    
    url = "https://api.npms.io/v2/search"
    query = "?q=" + repo_full_name
    
    # query using npm.io API
    respond = requests.get(url + query)
    search_npm_results = json.loads(respond.content)
    
    # get the first result based on its search, and return GitHub repo full name
    github_url_prefix = "https://github.com/"
    if search_npm_results["total"] > 0:
        try:
            if search_npm_results["results"][0]["package"]["name"] == repo_full_name:
                repo_url = search_npm_results["results"][0]["package"]["links"]["repository"]
                if github_url_prefix in repo_url:
                    temp = repo_url[len(github_url_prefix):].split("/")
                    github_repo_full_name = temp[0] + "/" + temp[1]
                    try:
                        repo_info = g.get_repo(full_name_or_id=github_repo_full_name)
                        return repo_info, "ok"
                    except GithubException as e:
                        if e.status == 404:
                            return None, "CannotFind"
                        else:
                            raise(e)
                    except Exception as e:
                        print(e)
                        return None, "CannotFind"
                else:
                    return None, "CannotFind"
            else:
                return None, "CannotFind"
        except KeyError:
            return None, "CannotFind"
    else:
        return None, "CannotFind"

# %%
def scratch_npm_html(repo_full_name):
    """Scratch npm html webpage and return Repository() obj"""
    global g
    
    # get html
    url = "https://www.npmjs.com/package/"
    query = repo_full_name
    page = requests.get(url + query)
    html = page.content.decode("utf-8")
    
    span_open_tag = "<span id=\"repository-link\">"
    span_close_tag = "</span>"
    repo_link_start = html.find(span_open_tag)
    
    if repo_link_start > 0:
        repo_link_end = html.find("</span>", repo_link_start)
        repo_full_name = html[len(span_open_tag) + repo_link_start : repo_link_end]
        repo_full_name = repo_full_name[repo_full_name.find("/") + 1:]
    
    try:
        repo_info = g.get_repo(full_name_or_id=repo_full_name)
        return repo_info, "ok"
    except:
        return None, "CannotFind"

# %%
def search_github(repo_full_name: str):
    """Search github and return Repository() obj"""
    global g
    
    # search the repo, sort by stars
    try:
        search_rank0_starcount = -1
        search_rank1_starcount = -1
        for s, search in enumerate(g.search_repositories(query=repo_full_name, sort="stars")):
            if search.full_name.split("/")[1] == repo_full_name:
                if s == 0:
                    search_rank0 = search
                    search_rank0_starcount = search.stargazers_count
                else:
                    search_rank1 = search
                    search_rank1_starcount = search.stargazers_count
                    break

        # pick the one that has largest star count
        # if there are two or more repo, then raise error
        if search_rank0_starcount == -1:
            return None, "CannotFind"

        if search_rank0_starcount <= search_rank1_starcount:
            return None, "MultiSuggestion"

        return search_rank0, "ok"
    except:
        return None, "CannotFind"

# %%
def write_to_csv_file(filename : str, row : list):
    with open(filename, "a") as f:
        for elem in row:
            f.write(elem)
            f.write(",")
        f.write("\n")

# %%
# Search and write repo results in csv
start_at = 6902
for index, repo in enumerate(sorted(unique_all_target_repo_dependencies)):
    if index < start_at:
        print("* ignoring #", index, repo, " ...")
        continue
    else:
        print("* searching #", index, repo, " ...")
    
    # try npm then try github
    find_in = {
        "npm.io": search_npm_io,
        "npm": scratch_npm_html,
        "github": search_github
    }
    for method in find_in.keys():
        repo_info = find_in[method](repo)
        if repo_info[0] is not None:
            print("    find #", index, repo, " in", method, ":", repo_info)
            break
        
    # if unable to identify in npm and github, then mark it
    if repo_info[0] is None:
        print("    cannot find #", index, repo)
        unique_all_target_repo_dependencies_failed[repo_info[1]].append(repo)
        write_to_csv_file("csv/map_sbom_name_failed.csv", [repo, repo_info[1]])
        continue
    
    # get repo info
    output = get_repo_info(repo_info[0], properties)
    map_target_repo_dependencies_to_full_name[repo] = output["name"]
    write_to_csv_file("csv/map_sbom_name_to_repo_full_name.csv", [repo, output["name"], method])
    
    # just in case (I think it's no use, since there are package not found)
    unique_all_target_repo_dependencies_full_name.append(output["name"])
    
    with open(full_file_name, "a") as f:
        for key in properties.keys():
            f.write(str(output[key]))
            f.write(",")
        f.write("\n")
# Out:
# * ignoring # 0 7zip-bin  ...
# * ignoring # 1 @4tw/cypress-drag-drop  ...
# * ignoring # 2 @aashutoshrathi/word-wrap  ...
# * ignoring # 3 @acuminous/bitsyntax  ...
# * ignoring # 4 @adobe/css-tools  ...
# * ignoring # 5 @ag-grid-community/client-side-row-model  ...
# * ignoring # 6 @ag-grid-community/core  ...
# * ignoring # 7 @ag-grid-community/styles  ...
# * ignoring # 8 @ag-grid-enterprise/core  ...
# * ignoring # 9 @ag-grid-enterprise/range-selection  ...
# * ignoring # 10 @ai-sdk/provider  ...
# * ignoring # 11 @ai-sdk/provider-utils  ...
# * ignoring # 12 @ai-sdk/react  ...
# * ignoring # 13 @ai-sdk/solid  ...
# * ignoring # 14 @ai-sdk/svelte  ...
# * ignoring # 15 @ai-sdk/ui-utils  ...
# * ignoring # 16 @ai-sdk/vue  ...
# * ignoring # 17 @akryum/tinypool  ...
# * ignoring # 18 @algolia/autocomplete-core  ...
# * ignoring # 19 @algolia/autocomplete-plugin-algolia-insights  ...
# * ignoring # 20 @algolia/autocomplete-preset-algolia  ...
# * ignoring # 21 @algolia/autocomplete-shared  ...
# * ignoring # 22 @algolia/cache-browser-local-storage  ...
# * ignoring # 23 @algolia/cache-common  ...
# * ignoring # 24 @algolia/cache-in-memory  ...
# * ignoring # 25 @algolia/client-account  ...
# * ignoring # 26 @algolia/client-analytics  ...
# * ignoring # 27 @algolia/client-common  ...
# * ignoring # 28 @algolia/client-personalization  ...
# * ignoring # 29 @algolia/client-search  ...
# * ignoring # 30 @algolia/events  ...
# * ignoring # 31 @algolia/logger-common  ...
# * ignoring # 32 @algolia/logger-console  ...
# * ignoring # 33 @algolia/requester-browser-xhr  ...
# * ignoring # 34 @algolia/requester-common  ...
# * ignoring # 35 @algolia/requester-node-http  ...
# * ignoring # 36 @algolia/transporter  ...
# * ignoring # 37 @alloc/quick-lru  ...
# * ignoring # 38 @ampproject/remapping  ...
# * ignoring # 39 @ampproject/remapping  ...
# * ignoring # 40 @angular-devkit/core  ...
# * ignoring # 41 @angular-devkit/schematics  ...
# * ignoring # 42 @angular-devkit/schematics-cli  ...
# * ignoring # 43 @ant-design/colors  ...
# * ignoring # 44 @ant-design/cssinjs  ...
# * ignoring # 45 @ant-design/icons  ...
# * ignoring # 46 @ant-design/icons-svg  ...
# * ignoring # 47 @ant-design/react-slick  ...
# * ignoring # 48 @antfu/utils  ...
# * ignoring # 49 @anthropic-ai/sdk  ...
# * ignoring # 50 @apideck/better-ajv-errors  ...
# * ignoring # 51 @apidevtools/json-schema-ref-parser  ...
# * ignoring # 52 @apidevtools/openapi-schemas  ...
# * ignoring # 53 @apidevtools/swagger-methods  ...
# * ignoring # 54 @apidevtools/swagger-parser  ...
# * ignoring # 55 @apify/consts  ...
# * ignoring # 56 @apify/log  ...
# * ignoring # 57 @atlaskit/analytics-next  ...
# * ignoring # 58 @atlaskit/analytics-next-stable-react-context  ...
# * ignoring # 59 @atlaskit/banner  ...
# * ignoring # 60 @atlaskit/blanket  ...
# * ignoring # 61 @atlaskit/button  ...
# * ignoring # 62 @atlaskit/checkbox  ...
# * ignoring # 63 @atlaskit/codemod-utils  ...
# * ignoring # 64 @atlaskit/css-reset  ...
# * ignoring # 65 @atlaskit/dropdown-menu  ...
# * ignoring # 66 @atlaskit/ds-explorations  ...
# * ignoring # 67 @atlaskit/ds-lib  ...
# * ignoring # 68 @atlaskit/focus-ring  ...
# * ignoring # 69 @atlaskit/form  ...
# * ignoring # 70 @atlaskit/icon  ...
# * ignoring # 71 @atlaskit/in-product-testing  ...
# * ignoring # 72 @atlaskit/inline-dialog  ...
# * ignoring # 73 @atlaskit/inline-edit  ...
# * ignoring # 74 @atlaskit/interaction-context  ...
# * ignoring # 75 @atlaskit/layering  ...
# * ignoring # 76 @atlaskit/menu  ...
# * ignoring # 77 @atlaskit/modal-dialog  ...
# * ignoring # 78 @atlaskit/motion  ...
# * ignoring # 79 @atlaskit/platform-feature-flags  ...
# * ignoring # 80 @atlaskit/popper  ...
# * ignoring # 81 @atlaskit/popup  ...
# * ignoring # 82 @atlaskit/portal  ...
# * ignoring # 83 @atlaskit/primitives  ...
# * ignoring # 84 @atlaskit/range  ...
# * ignoring # 85 @atlaskit/select  ...
# * ignoring # 86 @atlaskit/side-navigation  ...
# * ignoring # 87 @atlaskit/spinner  ...
# * ignoring # 88 @atlaskit/tabs  ...
# * ignoring # 89 @atlaskit/textarea  ...
# * ignoring # 90 @atlaskit/textfield  ...
# * ignoring # 91 @atlaskit/theme  ...
# * ignoring # 92 @atlaskit/toggle  ...
# * ignoring # 93 @atlaskit/tokens  ...
# * ignoring # 94 @atlaskit/visually-hidden  ...
# * ignoring # 95 @auth/core  ...
# * ignoring # 96 @aws-amplify/auth  ...
# * ignoring # 97 @aws-amplify/core  ...
# * ignoring # 98 @aws-crypto/crc32  ...
# * ignoring # 99 @aws-crypto/crc32c  ...
# * ignoring # 100 @aws-crypto/ie11-detection  ...
# * ignoring # 101 @aws-crypto/sha1-browser  ...
# * ignoring # 102 @aws-crypto/sha256-browser  ...
# * ignoring # 103 @aws-crypto/sha256-js  ...
# * ignoring # 104 @aws-crypto/supports-web-crypto  ...
# * ignoring # 105 @aws-crypto/util  ...
# * ignoring # 106 @aws-sdk/abort-controller  ...
# * ignoring # 107 @aws-sdk/client-bedrock-agent-runtime  ...
# * ignoring # 108 @aws-sdk/client-bedrock-runtime  ...
# * ignoring # 109 @aws-sdk/client-cloudwatch-logs  ...
# * ignoring # 110 @aws-sdk/client-cognito-identity  ...
# * ignoring # 111 @aws-sdk/client-dynamodb  ...
# * ignoring # 112 @aws-sdk/client-kendra  ...
# * ignoring # 113 @aws-sdk/client-s3  ...
# * ignoring # 114 @aws-sdk/client-sso  ...
# * ignoring # 115 @aws-sdk/client-sso-oidc  ...
# * ignoring # 116 @aws-sdk/client-sts  ...
# * ignoring # 117 @aws-sdk/config-resolver  ...
# * ignoring # 118 @aws-sdk/core  ...
# * ignoring # 119 @aws-sdk/credential-provider-cognito-identity  ...
# * ignoring # 120 @aws-sdk/credential-provider-env  ...
# * ignoring # 121 @aws-sdk/credential-provider-http  ...
# * ignoring # 122 @aws-sdk/credential-provider-imds  ...
# * ignoring # 123 @aws-sdk/credential-provider-ini  ...
# * ignoring # 124 @aws-sdk/credential-provider-node  ...
# * ignoring # 125 @aws-sdk/credential-provider-process  ...
# * ignoring # 126 @aws-sdk/credential-provider-sso  ...
# * ignoring # 127 @aws-sdk/credential-provider-web-identity  ...
# * ignoring # 128 @aws-sdk/credential-providers  ...
# * ignoring # 129 @aws-sdk/endpoint-cache  ...
# * ignoring # 130 @aws-sdk/fetch-http-handler  ...
# * ignoring # 131 @aws-sdk/hash-node  ...
# * ignoring # 132 @aws-sdk/invalid-dependency  ...
# * ignoring # 133 @aws-sdk/is-array-buffer  ...
# * ignoring # 134 @aws-sdk/middleware-bucket-endpoint  ...
# * ignoring # 135 @aws-sdk/middleware-content-length  ...
# * ignoring # 136 @aws-sdk/middleware-endpoint-discovery  ...
# * ignoring # 137 @aws-sdk/middleware-expect-continue  ...
# * ignoring # 138 @aws-sdk/middleware-flexible-checksums  ...
# * ignoring # 139 @aws-sdk/middleware-host-header  ...
# * ignoring # 140 @aws-sdk/middleware-location-constraint  ...
# * ignoring # 141 @aws-sdk/middleware-logger  ...
# * ignoring # 142 @aws-sdk/middleware-recursion-detection  ...
# * ignoring # 143 @aws-sdk/middleware-retry  ...
# * ignoring # 144 @aws-sdk/middleware-sdk-s3  ...
# * ignoring # 145 @aws-sdk/middleware-sdk-sts  ...
# * ignoring # 146 @aws-sdk/middleware-serde  ...
# * ignoring # 147 @aws-sdk/middleware-signing  ...
# * ignoring # 148 @aws-sdk/middleware-ssec  ...
# * ignoring # 149 @aws-sdk/middleware-stack  ...
# * ignoring # 150 @aws-sdk/middleware-user-agent  ...
# * ignoring # 151 @aws-sdk/node-config-provider  ...
# * ignoring # 152 @aws-sdk/node-http-handler  ...
# * ignoring # 153 @aws-sdk/property-provider  ...
# * ignoring # 154 @aws-sdk/protocol-http  ...
# * ignoring # 155 @aws-sdk/querystring-builder  ...
# * ignoring # 156 @aws-sdk/querystring-parser  ...
# * ignoring # 157 @aws-sdk/region-config-resolver  ...
# * ignoring # 158 @aws-sdk/service-error-classification  ...
# * ignoring # 159 @aws-sdk/shared-ini-file-loader  ...
# * ignoring # 160 @aws-sdk/signature-v4  ...
# * ignoring # 161 @aws-sdk/signature-v4-multi-region  ...
# * ignoring # 162 @aws-sdk/smithy-client  ...
# * ignoring # 163 @aws-sdk/token-providers  ...
# * ignoring # 164 @aws-sdk/types  ...
# * ignoring # 165 @aws-sdk/url-parser  ...
# * ignoring # 166 @aws-sdk/url-parser-native  ...
# * ignoring # 167 @aws-sdk/util-arn-parser  ...
# * ignoring # 168 @aws-sdk/util-base64-browser  ...
# * ignoring # 169 @aws-sdk/util-base64-node  ...
# * ignoring # 170 @aws-sdk/util-body-length-browser  ...
# * ignoring # 171 @aws-sdk/util-body-length-node  ...
# * ignoring # 172 @aws-sdk/util-buffer-from  ...
# * ignoring # 173 @aws-sdk/util-endpoints  ...
# * ignoring # 174 @aws-sdk/util-hex-encoding  ...
# * ignoring # 175 @aws-sdk/util-locate-window  ...
# * ignoring # 176 @aws-sdk/util-uri-escape  ...
# * ignoring # 177 @aws-sdk/util-user-agent-browser  ...
# * ignoring # 178 @aws-sdk/util-user-agent-node  ...
# * ignoring # 179 @aws-sdk/util-utf8-browser  ...
# * ignoring # 180 @aws-sdk/util-utf8-node  ...
# * ignoring # 181 @aws-sdk/xml-builder  ...
# * ignoring # 182 @azure-rest/core-client  ...
# * ignoring # 183 @azure/abort-controller  ...
# * ignoring # 184 @azure/core-auth  ...
# * ignoring # 185 @azure/core-client  ...
# * ignoring # 186 @azure/core-lro  ...
# * ignoring # 187 @azure/core-rest-pipeline  ...
# * ignoring # 188 @azure/core-sse  ...
# * ignoring # 189 @azure/core-tracing  ...
# * ignoring # 190 @azure/core-util  ...
# * ignoring # 191 @azure/identity  ...
# * ignoring # 192 @azure/logger  ...
# * ignoring # 193 @azure/msal-browser  ...
# * ignoring # 194 @azure/msal-common  ...
# * ignoring # 195 @azure/msal-node  ...
# * ignoring # 196 @azure/openai  ...
# * ignoring # 197 @babel/code-frame  ...
# * ignoring # 198 @babel/code-frame  ...
# * ignoring # 199 @babel/compat-data  ...
# * ignoring # 200 @babel/compat-data  ...
# * ignoring # 201 @babel/core  ...
# * ignoring # 202 @babel/core  ...
# * ignoring # 203 @babel/eslint-parser  ...
# * ignoring # 204 @babel/generator  ...
# * ignoring # 205 @babel/generator  ...
# * ignoring # 206 @babel/helper-annotate-as-pure  ...
# * ignoring # 207 @babel/helper-builder-binary-assignment-operator-visitor  ...
# * ignoring # 208 @babel/helper-compilation-targets  ...
# * ignoring # 209 @babel/helper-compilation-targets  ...
# * ignoring # 210 @babel/helper-create-class-features-plugin  ...
# * ignoring # 211 @babel/helper-create-regexp-features-plugin  ...
# * ignoring # 212 @babel/helper-define-polyfill-provider  ...
# * ignoring # 213 @babel/helper-environment-visitor  ...
# * ignoring # 214 @babel/helper-environment-visitor  ...
# * ignoring # 215 @babel/helper-explode-assignable-expression  ...
# * ignoring # 216 @babel/helper-function-name  ...
# * ignoring # 217 @babel/helper-function-name  ...
# * ignoring # 218 @babel/helper-hoist-variables  ...
# * ignoring # 219 @babel/helper-hoist-variables  ...
# * ignoring # 220 @babel/helper-member-expression-to-functions  ...
# * ignoring # 221 @babel/helper-module-imports  ...
# * ignoring # 222 @babel/helper-module-imports  ...
# * ignoring # 223 @babel/helper-module-transforms  ...
# * ignoring # 224 @babel/helper-module-transforms  ...
# * ignoring # 225 @babel/helper-optimise-call-expression  ...
# * ignoring # 226 @babel/helper-plugin-utils  ...
# * ignoring # 227 @babel/helper-plugin-utils  ...
# * ignoring # 228 @babel/helper-remap-async-to-generator  ...
# * ignoring # 229 @babel/helper-replace-supers  ...
# * ignoring # 230 @babel/helper-simple-access  ...
# * ignoring # 231 @babel/helper-simple-access  ...
# * ignoring # 232 @babel/helper-skip-transparent-expression-wrappers  ...
# * ignoring # 233 @babel/helper-split-export-declaration  ...
# * ignoring # 234 @babel/helper-split-export-declaration  ...
# * ignoring # 235 @babel/helper-string-parser  ...
# * ignoring # 236 @babel/helper-string-parser  ...
# * ignoring # 237 @babel/helper-validator-identifier  ...
# * ignoring # 238 @babel/helper-validator-identifier  ...
# * ignoring # 239 @babel/helper-validator-option  ...
# * ignoring # 240 @babel/helper-validator-option  ...
# * ignoring # 241 @babel/helper-wrap-function  ...
# * ignoring # 242 @babel/helpers  ...
# * ignoring # 243 @babel/helpers  ...
# * ignoring # 244 @babel/highlight  ...
# * ignoring # 245 @babel/highlight  ...
# * ignoring # 246 @babel/parser  ...
# * ignoring # 247 @babel/parser  ...
# * ignoring # 248 @babel/plugin-bugfix-firefox-class-in-computed-class-key  ...
# * ignoring # 249 @babel/plugin-bugfix-safari-class-field-initializer-scope  ...
# * ignoring # 250 @babel/plugin-bugfix-safari-id-destructuring-collision-in-function-expression  ...
# * ignoring # 251 @babel/plugin-bugfix-v8-spread-parameters-in-optional-chaining  ...
# * ignoring # 252 @babel/plugin-bugfix-v8-static-class-fields-redefine-readonly  ...
# * ignoring # 253 @babel/plugin-proposal-async-generator-functions  ...
# * ignoring # 254 @babel/plugin-proposal-class-properties  ...
# * ignoring # 255 @babel/plugin-proposal-class-static-block  ...
# * ignoring # 256 @babel/plugin-proposal-decorators  ...
# * ignoring # 257 @babel/plugin-proposal-dynamic-import  ...
# * ignoring # 258 @babel/plugin-proposal-export-namespace-from  ...
# * ignoring # 259 @babel/plugin-proposal-json-strings  ...
# * ignoring # 260 @babel/plugin-proposal-logical-assignment-operators  ...
# * ignoring # 261 @babel/plugin-proposal-nullish-coalescing-operator  ...
# * ignoring # 262 @babel/plugin-proposal-numeric-separator  ...
# * ignoring # 263 @babel/plugin-proposal-object-rest-spread  ...
# * ignoring # 264 @babel/plugin-proposal-optional-catch-binding  ...
# * ignoring # 265 @babel/plugin-proposal-optional-chaining  ...
# * ignoring # 266 @babel/plugin-proposal-private-methods  ...
# * ignoring # 267 @babel/plugin-proposal-private-property-in-object  ...
# * ignoring # 268 @babel/plugin-proposal-unicode-property-regex  ...
# * ignoring # 269 @babel/plugin-syntax-async-generators  ...
# * ignoring # 270 @babel/plugin-syntax-async-generators  ...
# * ignoring # 271 @babel/plugin-syntax-bigint  ...
# * ignoring # 272 @babel/plugin-syntax-bigint  ...
# * ignoring # 273 @babel/plugin-syntax-class-properties  ...
# * ignoring # 274 @babel/plugin-syntax-class-properties  ...
# * ignoring # 275 @babel/plugin-syntax-class-static-block  ...
# * ignoring # 276 @babel/plugin-syntax-decorators  ...
# * ignoring # 277 @babel/plugin-syntax-dynamic-import  ...
# * ignoring # 278 @babel/plugin-syntax-export-namespace-from  ...
# * ignoring # 279 @babel/plugin-syntax-flow  ...
# * ignoring # 280 @babel/plugin-syntax-import-assertions  ...
# * ignoring # 281 @babel/plugin-syntax-import-attributes  ...
# * ignoring # 282 @babel/plugin-syntax-import-meta  ...
# * ignoring # 283 @babel/plugin-syntax-import-meta  ...
# * ignoring # 284 @babel/plugin-syntax-json-strings  ...
# * ignoring # 285 @babel/plugin-syntax-json-strings  ...
# * ignoring # 286 @babel/plugin-syntax-jsx  ...
# * ignoring # 287 @babel/plugin-syntax-logical-assignment-operators  ...
# * ignoring # 288 @babel/plugin-syntax-logical-assignment-operators  ...
# * ignoring # 289 @babel/plugin-syntax-nullish-coalescing-operator  ...
# * ignoring # 290 @babel/plugin-syntax-nullish-coalescing-operator  ...
# * ignoring # 291 @babel/plugin-syntax-numeric-separator  ...
# * ignoring # 292 @babel/plugin-syntax-numeric-separator  ...
# * ignoring # 293 @babel/plugin-syntax-object-rest-spread  ...
# * ignoring # 294 @babel/plugin-syntax-object-rest-spread  ...
# * ignoring # 295 @babel/plugin-syntax-optional-catch-binding  ...
# * ignoring # 296 @babel/plugin-syntax-optional-catch-binding  ...
# * ignoring # 297 @babel/plugin-syntax-optional-chaining  ...
# * ignoring # 298 @babel/plugin-syntax-optional-chaining  ...
# * ignoring # 299 @babel/plugin-syntax-private-property-in-object  ...
# * ignoring # 300 @babel/plugin-syntax-top-level-await  ...
# * ignoring # 301 @babel/plugin-syntax-top-level-await  ...
# * ignoring # 302 @babel/plugin-syntax-typescript  ...
# * ignoring # 303 @babel/plugin-syntax-typescript  ...
# * ignoring # 304 @babel/plugin-syntax-unicode-sets-regex  ...
# * ignoring # 305 @babel/plugin-transform-arrow-functions  ...
# * ignoring # 306 @babel/plugin-transform-async-generator-functions  ...
# * ignoring # 307 @babel/plugin-transform-async-to-generator  ...
# * ignoring # 308 @babel/plugin-transform-block-scoped-functions  ...
# * ignoring # 309 @babel/plugin-transform-block-scoping  ...
# * ignoring # 310 @babel/plugin-transform-class-properties  ...
# * ignoring # 311 @babel/plugin-transform-class-static-block  ...
# * ignoring # 312 @babel/plugin-transform-classes  ...
# * ignoring # 313 @babel/plugin-transform-computed-properties  ...
# * ignoring # 314 @babel/plugin-transform-destructuring  ...
# * ignoring # 315 @babel/plugin-transform-dotall-regex  ...
# * ignoring # 316 @babel/plugin-transform-duplicate-keys  ...
# * ignoring # 317 @babel/plugin-transform-duplicate-named-capturing-groups-regex  ...
# * ignoring # 318 @babel/plugin-transform-dynamic-import  ...
# * ignoring # 319 @babel/plugin-transform-exponentiation-operator  ...
# * ignoring # 320 @babel/plugin-transform-export-namespace-from  ...
# * ignoring # 321 @babel/plugin-transform-flow-strip-types  ...
# * ignoring # 322 @babel/plugin-transform-for-of  ...
# * ignoring # 323 @babel/plugin-transform-function-name  ...
# * ignoring # 324 @babel/plugin-transform-json-strings  ...
# * ignoring # 325 @babel/plugin-transform-literals  ...
# * ignoring # 326 @babel/plugin-transform-logical-assignment-operators  ...
# * ignoring # 327 @babel/plugin-transform-member-expression-literals  ...
# * ignoring # 328 @babel/plugin-transform-modules-amd  ...
# * ignoring # 329 @babel/plugin-transform-modules-commonjs  ...
# * ignoring # 330 @babel/plugin-transform-modules-systemjs  ...
# * ignoring # 331 @babel/plugin-transform-modules-umd  ...
# * ignoring # 332 @babel/plugin-transform-named-capturing-groups-regex  ...
# * ignoring # 333 @babel/plugin-transform-new-target  ...
# * ignoring # 334 @babel/plugin-transform-nullish-coalescing-operator  ...
# * ignoring # 335 @babel/plugin-transform-numeric-separator  ...
# * ignoring # 336 @babel/plugin-transform-object-rest-spread  ...
# * ignoring # 337 @babel/plugin-transform-object-super  ...
# * ignoring # 338 @babel/plugin-transform-optional-catch-binding  ...
# * ignoring # 339 @babel/plugin-transform-optional-chaining  ...
# * ignoring # 340 @babel/plugin-transform-parameters  ...
# * ignoring # 341 @babel/plugin-transform-private-methods  ...
# * ignoring # 342 @babel/plugin-transform-private-property-in-object  ...
# * ignoring # 343 @babel/plugin-transform-property-literals  ...
# * ignoring # 344 @babel/plugin-transform-react-constant-elements  ...
# * ignoring # 345 @babel/plugin-transform-react-display-name  ...
# * ignoring # 346 @babel/plugin-transform-react-jsx  ...
# * ignoring # 347 @babel/plugin-transform-react-jsx-development  ...
# * ignoring # 348 @babel/plugin-transform-react-jsx-self  ...
# * ignoring # 349 @babel/plugin-transform-react-jsx-source  ...
# * ignoring # 350 @babel/plugin-transform-react-pure-annotations  ...
# * ignoring # 351 @babel/plugin-transform-regenerator  ...
# * ignoring # 352 @babel/plugin-transform-reserved-words  ...
# * ignoring # 353 @babel/plugin-transform-runtime  ...
# * ignoring # 354 @babel/plugin-transform-shorthand-properties  ...
# * ignoring # 355 @babel/plugin-transform-spread  ...
# * ignoring # 356 @babel/plugin-transform-sticky-regex  ...
# * ignoring # 357 @babel/plugin-transform-template-literals  ...
# * ignoring # 358 @babel/plugin-transform-typeof-symbol  ...
# * ignoring # 359 @babel/plugin-transform-typescript  ...
# * ignoring # 360 @babel/plugin-transform-unicode-escapes  ...
# * ignoring # 361 @babel/plugin-transform-unicode-property-regex  ...
# * ignoring # 362 @babel/plugin-transform-unicode-regex  ...
# * ignoring # 363 @babel/plugin-transform-unicode-sets-regex  ...
# * ignoring # 364 @babel/preset-env  ...
# * ignoring # 365 @babel/preset-flow  ...
# * ignoring # 366 @babel/preset-modules  ...
# * ignoring # 367 @babel/preset-react  ...
# * ignoring # 368 @babel/preset-typescript  ...
# * ignoring # 369 @babel/register  ...
# * ignoring # 370 @babel/regjsgen  ...
# * ignoring # 371 @babel/runtime  ...
# * ignoring # 372 @babel/runtime-corejs3  ...
# * ignoring # 373 @babel/template  ...
# * ignoring # 374 @babel/template  ...
# * ignoring # 375 @babel/traverse  ...
# * ignoring # 376 @babel/traverse  ...
# * ignoring # 377 @babel/types  ...
# * ignoring # 378 @babel/types  ...
# * ignoring # 379 @bcoe/v8-coverage  ...
# * ignoring # 380 @bcoe/v8-coverage  ...
# * ignoring # 381 @blueprintjs/colors  ...
# * ignoring # 382 @blueprintjs/core  ...
# * ignoring # 383 @blueprintjs/icons  ...
# * ignoring # 384 @blueprintjs/select  ...
# * ignoring # 385 @chainner/navi  ...
# * ignoring # 386 @chainner/node-path  ...
# * ignoring # 387 @chakra-ui/accordion  ...
# * ignoring # 388 @chakra-ui/alert  ...
# * ignoring # 389 @chakra-ui/anatomy  ...
# * ignoring # 390 @chakra-ui/avatar  ...
# * ignoring # 391 @chakra-ui/breadcrumb  ...
# * ignoring # 392 @chakra-ui/breakpoint-utils  ...
# * ignoring # 393 @chakra-ui/button  ...
# * ignoring # 394 @chakra-ui/card  ...
# * ignoring # 395 @chakra-ui/checkbox  ...
# * ignoring # 396 @chakra-ui/clickable  ...
# * ignoring # 397 @chakra-ui/close-button  ...
# * ignoring # 398 @chakra-ui/color-mode  ...
# * ignoring # 399 @chakra-ui/control-box  ...
# * ignoring # 400 @chakra-ui/counter  ...
# * ignoring # 401 @chakra-ui/css-reset  ...
# * ignoring # 402 @chakra-ui/descendant  ...
# * ignoring # 403 @chakra-ui/dom-utils  ...
# * ignoring # 404 @chakra-ui/editable  ...
# * ignoring # 405 @chakra-ui/event-utils  ...
# * ignoring # 406 @chakra-ui/focus-lock  ...
# * ignoring # 407 @chakra-ui/form-control  ...
# * ignoring # 408 @chakra-ui/hooks  ...
# * ignoring # 409 @chakra-ui/icon  ...
# * ignoring # 410 @chakra-ui/icons  ...
# * ignoring # 411 @chakra-ui/image  ...
# * ignoring # 412 @chakra-ui/input  ...
# * ignoring # 413 @chakra-ui/layout  ...
# * ignoring # 414 @chakra-ui/lazy-utils  ...
# * ignoring # 415 @chakra-ui/live-region  ...
# * ignoring # 416 @chakra-ui/media-query  ...
# * ignoring # 417 @chakra-ui/menu  ...
# * ignoring # 418 @chakra-ui/modal  ...
# * ignoring # 419 @chakra-ui/number-input  ...
# * ignoring # 420 @chakra-ui/number-utils  ...
# * ignoring # 421 @chakra-ui/object-utils  ...
# * ignoring # 422 @chakra-ui/pin-input  ...
# * ignoring # 423 @chakra-ui/popover  ...
# * ignoring # 424 @chakra-ui/popper  ...
# * ignoring # 425 @chakra-ui/portal  ...
# * ignoring # 426 @chakra-ui/progress  ...
# * ignoring # 427 @chakra-ui/provider  ...
# * ignoring # 428 @chakra-ui/radio  ...
# * ignoring # 429 @chakra-ui/react  ...
# * ignoring # 430 @chakra-ui/react-children-utils  ...
# * ignoring # 431 @chakra-ui/react-context  ...
# * ignoring # 432 @chakra-ui/react-env  ...
# * ignoring # 433 @chakra-ui/react-types  ...
# * ignoring # 434 @chakra-ui/react-use-animation-state  ...
# * ignoring # 435 @chakra-ui/react-use-callback-ref  ...
# * ignoring # 436 @chakra-ui/react-use-controllable-state  ...
# * ignoring # 437 @chakra-ui/react-use-disclosure  ...
# * ignoring # 438 @chakra-ui/react-use-event-listener  ...
# * ignoring # 439 @chakra-ui/react-use-focus-effect  ...
# * ignoring # 440 @chakra-ui/react-use-focus-on-pointer-down  ...
# * ignoring # 441 @chakra-ui/react-use-interval  ...
# * ignoring # 442 @chakra-ui/react-use-latest-ref  ...
# * ignoring # 443 @chakra-ui/react-use-merge-refs  ...
# * ignoring # 444 @chakra-ui/react-use-outside-click  ...
# * ignoring # 445 @chakra-ui/react-use-pan-event  ...
# * ignoring # 446 @chakra-ui/react-use-previous  ...
# * ignoring # 447 @chakra-ui/react-use-safe-layout-effect  ...
# * ignoring # 448 @chakra-ui/react-use-size  ...
# * ignoring # 449 @chakra-ui/react-use-timeout  ...
# * ignoring # 450 @chakra-ui/react-use-update-effect  ...
# * ignoring # 451 @chakra-ui/react-utils  ...
# * ignoring # 452 @chakra-ui/select  ...
# * ignoring # 453 @chakra-ui/shared-utils  ...
# * ignoring # 454 @chakra-ui/skeleton  ...
# * ignoring # 455 @chakra-ui/skip-nav  ...
# * ignoring # 456 @chakra-ui/slider  ...
# * ignoring # 457 @chakra-ui/spinner  ...
# * ignoring # 458 @chakra-ui/stat  ...
# * ignoring # 459 @chakra-ui/stepper  ...
# * ignoring # 460 @chakra-ui/styled-system  ...
# * ignoring # 461 @chakra-ui/switch  ...
# * ignoring # 462 @chakra-ui/system  ...
# * ignoring # 463 @chakra-ui/table  ...
# * ignoring # 464 @chakra-ui/tabs  ...
# * ignoring # 465 @chakra-ui/tag  ...
# * ignoring # 466 @chakra-ui/textarea  ...
# * ignoring # 467 @chakra-ui/theme  ...
# * ignoring # 468 @chakra-ui/theme-tools  ...
# * ignoring # 469 @chakra-ui/theme-utils  ...
# * ignoring # 470 @chakra-ui/toast  ...
# * ignoring # 471 @chakra-ui/tooltip  ...
# * ignoring # 472 @chakra-ui/transition  ...
# * ignoring # 473 @chakra-ui/utils  ...
# * ignoring # 474 @chakra-ui/visually-hidden  ...
# * ignoring # 475 @changesets/apply-release-plan  ...
# * ignoring # 476 @changesets/assemble-release-plan  ...
# * ignoring # 477 @changesets/changelog-git  ...
# * ignoring # 478 @changesets/cli  ...
# * ignoring # 479 @changesets/config  ...
# * ignoring # 480 @changesets/errors  ...
# * ignoring # 481 @changesets/get-dependents-graph  ...
# * ignoring # 482 @changesets/get-release-plan  ...
# * ignoring # 483 @changesets/get-version-range-type  ...
# * ignoring # 484 @changesets/git  ...
# * ignoring # 485 @changesets/logger  ...
# * ignoring # 486 @changesets/parse  ...
# * ignoring # 487 @changesets/pre  ...
# * ignoring # 488 @changesets/read  ...
# * ignoring # 489 @changesets/should-skip-package  ...
# * ignoring # 490 @changesets/types  ...
# * ignoring # 491 @changesets/write  ...
# * ignoring # 492 @choojs/findup  ...
# * ignoring # 493 @clickhouse/client  ...
# * ignoring # 494 @clickhouse/client-common  ...
# * ignoring # 495 @codemirror/autocomplete  ...
# * ignoring # 496 @codemirror/commands  ...
# * ignoring # 497 @codemirror/lang-css  ...
# * ignoring # 498 @codemirror/lang-html  ...
# * ignoring # 499 @codemirror/lang-javascript  ...
# * ignoring # 500 @codemirror/lang-json  ...
# * ignoring # 501 @codemirror/lang-markdown  ...
# * ignoring # 502 @codemirror/lang-python  ...
# * ignoring # 503 @codemirror/language  ...
# * ignoring # 504 @codemirror/lint  ...
# * ignoring # 505 @codemirror/search  ...
# * ignoring # 506 @codemirror/state  ...
# * ignoring # 507 @codemirror/theme-one-dark  ...
# * ignoring # 508 @codemirror/view  ...
# * ignoring # 509 @colors/colors  ...
# * ignoring # 510 @couchbase/couchbase-darwin-arm64-napi  ...
# * ignoring # 511 @couchbase/couchbase-darwin-x64-napi  ...
# * ignoring # 512 @couchbase/couchbase-linux-arm64-napi  ...
# * ignoring # 513 @couchbase/couchbase-linux-x64-napi  ...
# * ignoring # 514 @couchbase/couchbase-linuxmusl-x64-napi  ...
# * ignoring # 515 @couchbase/couchbase-win32-x64-napi  ...
# * ignoring # 516 @craco/craco  ...
# * ignoring # 517 @crawlee/types  ...
# * ignoring # 518 @cspotcode/source-map-support  ...
# * ignoring # 519 @csstools/normalize.css  ...
# * ignoring # 520 @csstools/postcss-cascade-layers  ...
# * ignoring # 521 @csstools/postcss-color-function  ...
# * ignoring # 522 @csstools/postcss-font-format-keywords  ...
# * ignoring # 523 @csstools/postcss-hwb-function  ...
# * ignoring # 524 @csstools/postcss-ic-unit  ...
# * ignoring # 525 @csstools/postcss-is-pseudo-class  ...
# * ignoring # 526 @csstools/postcss-nested-calc  ...
# * ignoring # 527 @csstools/postcss-normalize-display-values  ...
# * ignoring # 528 @csstools/postcss-oklab-function  ...
# * ignoring # 529 @csstools/postcss-progressive-custom-properties  ...
# * ignoring # 530 @csstools/postcss-stepped-value-functions  ...
# * ignoring # 531 @csstools/postcss-text-decoration-shorthand  ...
# * ignoring # 532 @csstools/postcss-trigonometric-functions  ...
# * ignoring # 533 @csstools/postcss-unset-value  ...
# * ignoring # 534 @csstools/selector-resolve-nested  ...
# * ignoring # 535 @csstools/selector-specificity  ...
# * ignoring # 536 @ctrl/tinycolor  ...
# * ignoring # 537 @cypress/request  ...
# * ignoring # 538 @cypress/xvfb  ...
# * ignoring # 539 @dabh/diagnostics  ...
# * ignoring # 540 @dagrejs/graphlib  ...
# * ignoring # 541 @danmarshall/deckgl-typings  ...
# * ignoring # 542 @databricks/sql  ...
# * ignoring # 543 @datastax/astra-db-ts  ...
# * ignoring # 544 @date-io/core  ...
# * ignoring # 545 @date-io/date-fns  ...
# * ignoring # 546 @date-io/dayjs  ...
# * ignoring # 547 @date-io/luxon  ...
# * ignoring # 548 @date-io/moment  ...
# * ignoring # 549 @develar/schema-utils  ...
# * ignoring # 550 @discordjs/builders  ...
# * ignoring # 551 @discordjs/collection  ...
# * ignoring # 552 @discordjs/formatters  ...
# * ignoring # 553 @discordjs/rest  ...
# * ignoring # 554 @discordjs/util  ...
# * ignoring # 555 @discordjs/ws  ...
# * ignoring # 556 @discoveryjs/json-ext  ...
# * ignoring # 557 @dnd-kit/accessibility  ...
# * ignoring # 558 @dnd-kit/core  ...
# * ignoring # 559 @dnd-kit/sortable  ...
# * ignoring # 560 @dnd-kit/utilities  ...
# * ignoring # 561 @docsearch/css  ...
# * ignoring # 562 @docsearch/react  ...
# * ignoring # 563 @docusaurus/core  ...
# * ignoring # 564 @docusaurus/cssnano-preset  ...
# * ignoring # 565 @docusaurus/logger  ...
# * ignoring # 566 @docusaurus/mdx-loader  ...
# * ignoring # 567 @docusaurus/module-type-aliases  ...
# * ignoring # 568 @docusaurus/plugin-content-blog  ...
# * ignoring # 569 @docusaurus/plugin-content-docs  ...
# * ignoring # 570 @docusaurus/plugin-content-pages  ...
# * ignoring # 571 @docusaurus/plugin-debug  ...
# * ignoring # 572 @docusaurus/plugin-google-analytics  ...
# * ignoring # 573 @docusaurus/plugin-google-gtag  ...
# * ignoring # 574 @docusaurus/plugin-google-tag-manager  ...
# * ignoring # 575 @docusaurus/plugin-sitemap  ...
# * ignoring # 576 @docusaurus/preset-classic  ...
# * ignoring # 577 @docusaurus/react-loadable  ...
# * ignoring # 578 @docusaurus/theme-classic  ...
# * ignoring # 579 @docusaurus/theme-common  ...
# * ignoring # 580 @docusaurus/theme-search-algolia  ...
# * ignoring # 581 @docusaurus/theme-translations  ...
# * ignoring # 582 @docusaurus/types  ...
# * ignoring # 583 @docusaurus/utils  ...
# * ignoring # 584 @docusaurus/utils-common  ...
# * ignoring # 585 @docusaurus/utils-validation  ...
# * ignoring # 586 @dqbd/tiktoken  ...
# * ignoring # 587 @e2b/code-interpreter  ...
# * ignoring # 588 @elastic/elasticsearch  ...
# * ignoring # 589 @elastic/transport  ...
# * ignoring # 590 @electron-forge/cli  ...
# * ignoring # 591 @electron-forge/core  ...
# * ignoring # 592 @electron-forge/core-utils  ...
# * ignoring # 593 @electron-forge/maker-base  ...
# * ignoring # 594 @electron-forge/maker-deb  ...
# * ignoring # 595 @electron-forge/maker-dmg  ...
# * ignoring # 596 @electron-forge/maker-flatpak  ...
# * ignoring # 597 @electron-forge/maker-rpm  ...
# * ignoring # 598 @electron-forge/maker-squirrel  ...
# * ignoring # 599 @electron-forge/maker-zip  ...
# * ignoring # 600 @electron-forge/plugin-auto-unpack-natives  ...
# * ignoring # 601 @electron-forge/plugin-base  ...
# * ignoring # 602 @electron-forge/plugin-fuses  ...
# * ignoring # 603 @electron-forge/plugin-vite  ...
# * ignoring # 604 @electron-forge/publisher-base  ...
# * ignoring # 605 @electron-forge/publisher-github  ...
# * ignoring # 606 @electron-forge/shared-types  ...
# * ignoring # 607 @electron-forge/template-base  ...
# * ignoring # 608 @electron-forge/template-vite  ...
# * ignoring # 609 @electron-forge/template-vite-typescript  ...
# * ignoring # 610 @electron-forge/template-webpack  ...
# * ignoring # 611 @electron-forge/template-webpack-typescript  ...
# * ignoring # 612 @electron-forge/tracer  ...
# * ignoring # 613 @electron-forge/web-multi-logger  ...
# * ignoring # 614 @electron/asar  ...
# * ignoring # 615 @electron/fuses  ...
# * ignoring # 616 @electron/get  ...
# * ignoring # 617 @electron/notarize  ...
# * ignoring # 618 @electron/osx-sign  ...
# * ignoring # 619 @electron/packager  ...
# * ignoring # 620 @electron/rebuild  ...
# * ignoring # 621 @electron/universal  ...
# * ignoring # 622 @electron/windows-sign  ...
# * ignoring # 623 @emoji-mart/data  ...
# * ignoring # 624 @emoji-mart/react  ...
# * ignoring # 625 @emotion/babel-plugin  ...
# * ignoring # 626 @emotion/cache  ...
# * ignoring # 627 @emotion/eslint-plugin  ...
# * ignoring # 628 @emotion/hash  ...
# * ignoring # 629 @emotion/is-prop-valid  ...
# * ignoring # 630 @emotion/memoize  ...
# * ignoring # 631 @emotion/react  ...
# * ignoring # 632 @emotion/serialize  ...
# * ignoring # 633 @emotion/sheet  ...
# * ignoring # 634 @emotion/styled  ...
# * ignoring # 635 @emotion/stylis  ...
# * ignoring # 636 @emotion/unitless  ...
# * ignoring # 637 @emotion/use-insertion-effect-with-fallbacks  ...
# * ignoring # 638 @emotion/utils  ...
# * ignoring # 639 @emotion/weak-memoize  ...
# * ignoring # 640 @es-joy/jsdoccomment  ...
# * ignoring # 641 @esbuild-kit/cjs-loader  ...
# * ignoring # 642 @esbuild-kit/core-utils  ...
# * ignoring # 643 @esbuild-kit/esm-loader  ...
# * ignoring # 644 @esbuild/aix-ppc64  ...
# * ignoring # 645 @esbuild/android-arm  ...
# * ignoring # 646 @esbuild/android-arm64  ...
# * ignoring # 647 @esbuild/android-x64  ...
# * ignoring # 648 @esbuild/darwin-arm64  ...
# * ignoring # 649 @esbuild/darwin-x64  ...
# * ignoring # 650 @esbuild/freebsd-arm64  ...
# * ignoring # 651 @esbuild/freebsd-x64  ...
# * ignoring # 652 @esbuild/linux-arm  ...
# * ignoring # 653 @esbuild/linux-arm64  ...
# * ignoring # 654 @esbuild/linux-ia32  ...
# * ignoring # 655 @esbuild/linux-loong64  ...
# * ignoring # 656 @esbuild/linux-mips64el  ...
# * ignoring # 657 @esbuild/linux-ppc64  ...
# * ignoring # 658 @esbuild/linux-riscv64  ...
# * ignoring # 659 @esbuild/linux-s390x  ...
# * ignoring # 660 @esbuild/linux-x64  ...
# * ignoring # 661 @esbuild/netbsd-x64  ...
# * ignoring # 662 @esbuild/openbsd-arm64  ...
# * ignoring # 663 @esbuild/openbsd-x64  ...
# * ignoring # 664 @esbuild/sunos-x64  ...
# * ignoring # 665 @esbuild/win32-arm64  ...
# * ignoring # 666 @esbuild/win32-ia32  ...
# * ignoring # 667 @esbuild/win32-x64  ...
# * ignoring # 668 @eslint-community/eslint-utils  ...
# * ignoring # 669 @eslint-community/eslint-utils  ...
# * ignoring # 670 @eslint-community/regexpp  ...
# * ignoring # 671 @eslint-community/regexpp  ...
# * ignoring # 672 @eslint/config-array  ...
# * ignoring # 673 @eslint/core  ...
# * ignoring # 674 @eslint/eslintrc  ...
# * ignoring # 675 @eslint/eslintrc  ...
# * ignoring # 676 @eslint/js  ...
# * ignoring # 677 @eslint/js  ...
# * ignoring # 678 @eslint/object-schema  ...
# * ignoring # 679 @eslint/plugin-kit  ...
# * ignoring # 680 @fal-works/esbuild-plugin-global-externals  ...
# * ignoring # 681 @fast-check/vitest  ...
# * ignoring # 682 @fast-csv/format  ...
# * ignoring # 683 @fast-csv/parse  ...
# * ignoring # 684 @fastify/busboy  ...
# * ignoring # 685 @firebase/app-types  ...
# * ignoring # 686 @firebase/auth-interop-types  ...
# * ignoring # 687 @firebase/component  ...
# * ignoring # 688 @firebase/database  ...
# * ignoring # 689 @firebase/database-compat  ...
# * ignoring # 690 @firebase/database-types  ...
# * ignoring # 691 @firebase/logger  ...
# * ignoring # 692 @firebase/util  ...
# * ignoring # 693 @floating-ui/core  ...
# * ignoring # 694 @floating-ui/dom  ...
# * ignoring # 695 @floating-ui/react  ...
# * ignoring # 696 @floating-ui/react-dom  ...
# * ignoring # 697 @floating-ui/utils  ...
# * ignoring # 698 @floating-ui/vue  ...
# * ignoring # 699 @flowiseai/nodevm  ...
# * ignoring # 700 @flyde/core  ...
# * ignoring # 701 @flyde/dev-server  ...
# * ignoring # 702 @flyde/editor  ...
# * ignoring # 703 @flyde/flow-editor  ...
# * ignoring # 704 @flyde/remote-debugger  ...
# * ignoring # 705 @flyde/resolver  ...
# * ignoring # 706 @flyde/runtime  ...
# * ignoring # 707 @flyde/stdlib  ...
# * ignoring # 708 @fontsource/geist-mono  ...
# * ignoring # 709 @fontsource/open-sans  ...
# * ignoring # 710 @formatjs/ecma402-abstract  ...
# * ignoring # 711 @formatjs/fast-memoize  ...
# * ignoring # 712 @formatjs/icu-messageformat-parser  ...
# * ignoring # 713 @formatjs/icu-skeleton-parser  ...
# * ignoring # 714 @formatjs/intl-localematcher  ...
# * ignoring # 715 @fortaine/fetch-event-source  ...
# * ignoring # 716 @fortawesome/fontawesome-common-types  ...
# * ignoring # 717 @fortawesome/fontawesome-svg-core  ...
# * ignoring # 718 @fortawesome/free-brands-svg-icons  ...
# * ignoring # 719 @fortawesome/free-solid-svg-icons  ...
# * ignoring # 720 @fortawesome/react-fontawesome  ...
# * ignoring # 721 @gar/promisify  ...
# * ignoring # 722 @gentrace/core  ...
# * ignoring # 723 @getzep/zep-cloud  ...
# * ignoring # 724 @getzep/zep-js  ...
# * ignoring # 725 @gilbarbara/deep-equal  ...
# * ignoring # 726 @gilbarbara/helpers  ...
# * ignoring # 727 @gilbarbara/types  ...
# * ignoring # 728 @golevelup/ts-jest  ...
# * ignoring # 729 @gomomento/generated-types  ...
# * ignoring # 730 @gomomento/sdk  ...
# * ignoring # 731 @gomomento/sdk-core  ...
# * ignoring # 732 @good-ghosting/random-name-generator  ...
# * ignoring # 733 @google-ai/generativelanguage  ...
# * ignoring # 734 @google-cloud/firestore  ...
# * ignoring # 735 @google-cloud/paginator  ...
# * ignoring # 736 @google-cloud/projectify  ...
# * ignoring # 737 @google-cloud/promisify  ...
# * ignoring # 738 @google-cloud/storage  ...
# * ignoring # 739 @google-cloud/vertexai  ...
# * ignoring # 740 @google/generative-ai  ...
# * ignoring # 741 @graphql-tools/merge  ...
# * ignoring # 742 @graphql-tools/schema  ...
# * ignoring # 743 @graphql-tools/utils  ...
# * ignoring # 744 @graphql-typed-document-node/core  ...
# * ignoring # 745 @grpc/grpc-js  ...
# * ignoring # 746 @grpc/proto-loader  ...
# * ignoring # 747 @hapi/hoek  ...
# * ignoring # 748 @hapi/topo  ...
# * ignoring # 749 @headlessui/react  ...
# * ignoring # 750 @heroicons/react  ...
# * ignoring # 751 @histoire/app  ...
# * ignoring # 752 @histoire/controls  ...
# * ignoring # 753 @histoire/plugin-vue  ...
# * ignoring # 754 @histoire/shared  ...
# * ignoring # 755 @histoire/vendors  ...
# * ignoring # 756 @hookform/resolvers  ...
# * ignoring # 757 @huggingface/inference  ...
# * ignoring # 758 @huggingface/jinja  ...
# * ignoring # 759 @huggingface/tasks  ...
# * ignoring # 760 @humanfs/core  ...
# * ignoring # 761 @humanfs/node  ...
# * ignoring # 762 @humanwhocodes/config-array  ...
# * ignoring # 763 @humanwhocodes/config-array  ...
# * ignoring # 764 @humanwhocodes/module-importer  ...
# * ignoring # 765 @humanwhocodes/module-importer  ...
# * ignoring # 766 @humanwhocodes/object-schema  ...
# * ignoring # 767 @humanwhocodes/object-schema  ...
# * ignoring # 768 @humanwhocodes/retry  ...
# * ignoring # 769 @ianvs/prettier-plugin-sort-imports  ...
# * ignoring # 770 @icons/material  ...
# * ignoring # 771 @internationalized/date  ...
# * ignoring # 772 @internationalized/message  ...
# * ignoring # 773 @internationalized/number  ...
# * ignoring # 774 @internationalized/string  ...
# * ignoring # 775 @ioredis/commands  ...
# * ignoring # 776 @isaacs/cliui  ...
# * ignoring # 777 @isaacs/string-locale-compare  ...
# * ignoring # 778 @istanbuljs/load-nyc-config  ...
# * ignoring # 779 @istanbuljs/load-nyc-config  ...
# * ignoring # 780 @istanbuljs/schema  ...
# * ignoring # 781 @istanbuljs/schema  ...
# * ignoring # 782 @jest/console  ...
# * ignoring # 783 @jest/console  ...
# * ignoring # 784 @jest/core  ...
# * ignoring # 785 @jest/core  ...
# * ignoring # 786 @jest/environment  ...
# * ignoring # 787 @jest/environment  ...
# * ignoring # 788 @jest/expect  ...
# * ignoring # 789 @jest/expect-utils  ...
# * ignoring # 790 @jest/expect-utils  ...
# * ignoring # 791 @jest/fake-timers  ...
# * ignoring # 792 @jest/fake-timers  ...
# * ignoring # 793 @jest/globals  ...
# * ignoring # 794 @jest/globals  ...
# * ignoring # 795 @jest/reporters  ...
# * ignoring # 796 @jest/reporters  ...
# * ignoring # 797 @jest/schemas  ...
# * ignoring # 798 @jest/schemas  ...
# * ignoring # 799 @jest/source-map  ...
# * ignoring # 800 @jest/source-map  ...
# * ignoring # 801 @jest/test-result  ...
# * ignoring # 802 @jest/test-result  ...
# * ignoring # 803 @jest/test-sequencer  ...
# * ignoring # 804 @jest/test-sequencer  ...
# * ignoring # 805 @jest/transform  ...
# * ignoring # 806 @jest/transform  ...
# * ignoring # 807 @jest/types  ...
# * ignoring # 808 @jest/types  ...
# * ignoring # 809 @jridgewell/gen-mapping  ...
# * ignoring # 810 @jridgewell/gen-mapping  ...
# * ignoring # 811 @jridgewell/resolve-uri  ...
# * ignoring # 812 @jridgewell/resolve-uri  ...
# * ignoring # 813 @jridgewell/set-array  ...
# * ignoring # 814 @jridgewell/set-array  ...
# * ignoring # 815 @jridgewell/source-map  ...
# * ignoring # 816 @jridgewell/sourcemap-codec  ...
# * ignoring # 817 @jridgewell/sourcemap-codec  ...
# * ignoring # 818 @jridgewell/trace-mapping  ...
# * ignoring # 819 @jridgewell/trace-mapping  ...
# * ignoring # 820 @js-sdsl/ordered-map  ...
# * ignoring # 821 @js-temporal/polyfill  ...
# * ignoring # 822 @jsdevtools/ono  ...
# * ignoring # 823 @jsdoc/salty  ...
# * ignoring # 824 @json-schema-spec/json-pointer  ...
# * ignoring # 825 @json-schema-tools/dereferencer  ...
# * ignoring # 826 @json-schema-tools/meta-schema  ...
# * ignoring # 827 @json-schema-tools/reference-resolver  ...
# * ignoring # 828 @json-schema-tools/traverse  ...
# * ignoring # 829 @juggle/resize-observer  ...
# * ignoring # 830 @koa/cors  ...
# * ignoring # 831 @ladle/react  ...
# * ignoring # 832 @ladle/react-context  ...
# * ignoring # 833 @langchain/anthropic  ...
# * ignoring # 834 @langchain/aws  ...
# * ignoring # 835 @langchain/cohere  ...
# * ignoring # 836 @langchain/community  ...
# * ignoring # 837 @langchain/core  ...
# * ignoring # 838 @langchain/exa  ...
# * ignoring # 839 @langchain/google-common  ...
# * ignoring # 840 @langchain/google-gauth  ...
# * ignoring # 841 @langchain/google-genai  ...
# * ignoring # 842 @langchain/google-vertexai  ...
# * ignoring # 843 @langchain/groq  ...
# * ignoring # 844 @langchain/langgraph  ...
# * ignoring # 845 @langchain/mistralai  ...
# * ignoring # 846 @langchain/mongodb  ...
# * ignoring # 847 @langchain/ollama  ...
# * ignoring # 848 @langchain/openai  ...
# * ignoring # 849 @langchain/pinecone  ...
# * ignoring # 850 @langchain/qdrant  ...
# * ignoring # 851 @langchain/textsplitters  ...
# * ignoring # 852 @langchain/weaviate  ...
# * ignoring # 853 @laudspeaker/clickhouse-migrations  ...
# * ignoring # 854 @laudspeaker/core  ...
# * ignoring # 855 @laudspeaker/laudspeaker-js  ...
# * ignoring # 856 @laudspeaker/react  ...
# * ignoring # 857 @leichtgewicht/ip-codec  ...
# * ignoring # 858 @lexical/clipboard  ...
# * ignoring # 859 @lexical/html  ...
# * ignoring # 860 @lexical/link  ...
# * ignoring # 861 @lexical/list  ...
# * ignoring # 862 @lexical/plain-text  ...
# * ignoring # 863 @lexical/selection  ...
# * ignoring # 864 @lexical/table  ...
# * ignoring # 865 @lexical/utils  ...
# * ignoring # 866 @lezer/common  ...
# * ignoring # 867 @lezer/css  ...
# * ignoring # 868 @lezer/highlight  ...
# * ignoring # 869 @lezer/html  ...
# * ignoring # 870 @lezer/javascript  ...
# * ignoring # 871 @lezer/json  ...
# * ignoring # 872 @lezer/lr  ...
# * ignoring # 873 @lezer/markdown  ...
# * ignoring # 874 @lezer/python  ...
# * ignoring # 875 @liaoliaots/nestjs-redis  ...
# * ignoring # 876 @lit-labs/ssr-dom-shim  ...
# * ignoring # 877 @lit/reactive-element  ...
# * ignoring # 878 @llamaindex/cloud  ...
# * ignoring # 879 @llamaindex/env  ...
# * ignoring # 880 @lottiefiles/react-lottie-player  ...
# * ignoring # 881 @lukeed/csprng  ...
# * ignoring # 882 @malept/cross-spawn-promise  ...
# * ignoring # 883 @malept/electron-installer-flatpak  ...
# * ignoring # 884 @malept/flatpak-bundler  ...
# * ignoring # 885 @mantine/core  ...
# * ignoring # 886 @mantine/dates  ...
# * ignoring # 887 @mantine/dropzone  ...
# * ignoring # 888 @mantine/form  ...
# * ignoring # 889 @mantine/hooks  ...
# * ignoring # 890 @mantine/prism  ...
# * ignoring # 891 @mantine/styles  ...
# * ignoring # 892 @mantine/utils  ...
# * ignoring # 893 @manypkg/find-root  ...
# * ignoring # 894 @manypkg/get-packages  ...
# * ignoring # 895 @mapbox/geojson-rewind  ...
# * ignoring # 896 @mapbox/geojson-types  ...
# * ignoring # 897 @mapbox/jsonlint-lines-primitives  ...
# * ignoring # 898 @mapbox/mapbox-gl-supported  ...
# * ignoring # 899 @mapbox/node-pre-gyp  ...
# * ignoring # 900 @mapbox/point-geometry  ...
# * ignoring # 901 @mapbox/tiny-sdf  ...
# * ignoring # 902 @mapbox/unitbezier  ...
# * ignoring # 903 @mapbox/vector-tile  ...
# * ignoring # 904 @mapbox/whoots-js  ...
# * ignoring # 905 @material-tailwind/react  ...
# * ignoring # 906 @mdx-js/mdx  ...
# * ignoring # 907 @mdx-js/react  ...
# * ignoring # 908 @mdx-js/util  ...
# * ignoring # 909 @mendable/firecrawl-js  ...
# * ignoring # 910 @microsoft/1ds-core-js  ...
# * ignoring # 911 @microsoft/1ds-post-js  ...
# * ignoring # 912 @microsoft/applicationinsights-channel-js  ...
# * ignoring # 913 @microsoft/applicationinsights-common  ...
# * ignoring # 914 @microsoft/applicationinsights-core-js  ...
# * ignoring # 915 @microsoft/applicationinsights-shims  ...
# * ignoring # 916 @microsoft/applicationinsights-web-basic  ...
# * ignoring # 917 @microsoft/applicationinsights-web-snippet  ...
# * ignoring # 918 @microsoft/dynamicproto-js  ...
# * ignoring # 919 @microsoft/fetch-event-source  ...
# * ignoring # 920 @mirai73/bedrock-fm  ...
# * ignoring # 921 @mistralai/mistralai  ...
# * ignoring # 922 @modyfi/vite-plugin-yaml  ...
# * ignoring # 923 @monaco-editor/loader  ...
# * ignoring # 924 @monaco-editor/react  ...
# * ignoring # 925 @mongodb-js/saslprep  ...
# * ignoring # 926 @motionone/animation  ...
# * ignoring # 927 @motionone/dom  ...
# * ignoring # 928 @motionone/easing  ...
# * ignoring # 929 @motionone/generators  ...
# * ignoring # 930 @motionone/types  ...
# * ignoring # 931 @motionone/utils  ...
# * ignoring # 932 @msgpackr-extract/msgpackr-extract-win32-x64  ...
# * ignoring # 933 @mui/base  ...
# * ignoring # 934 @mui/core-downloads-tracker  ...
# * ignoring # 935 @mui/icons-material  ...
# * ignoring # 936 @mui/lab  ...
# * ignoring # 937 @mui/material  ...
# * ignoring # 938 @mui/private-theming  ...
# * ignoring # 939 @mui/styled-engine  ...
# * ignoring # 940 @mui/system  ...
# * ignoring # 941 @mui/types  ...
# * ignoring # 942 @mui/utils  ...
# * ignoring # 943 @mui/x-data-grid  ...
# * ignoring # 944 @mui/x-date-pickers  ...
# * ignoring # 945 @mui/x-tree-view  ...
# * ignoring # 946 @nestjs/bull-shared  ...
# * ignoring # 947 @nestjs/bullmq  ...
# * ignoring # 948 @nestjs/cache-manager  ...
# * ignoring # 949 @nestjs/cli  ...
# * ignoring # 950 @nestjs/common  ...
# * ignoring # 951 @nestjs/config  ...
# * ignoring # 952 @nestjs/core  ...
# * ignoring # 953 @nestjs/graphql  ...
# * ignoring # 954 @nestjs/jwt  ...
# * ignoring # 955 @nestjs/mapped-types  ...
# * ignoring # 956 @nestjs/mongoose  ...
# * ignoring # 957 @nestjs/passport  ...
# * ignoring # 958 @nestjs/platform-express  ...
# * ignoring # 959 @nestjs/platform-socket.io  ...
# * ignoring # 960 @nestjs/schedule  ...
# * ignoring # 961 @nestjs/schematics  ...
# * ignoring # 962 @nestjs/serve-static  ...
# * ignoring # 963 @nestjs/testing  ...
# * ignoring # 964 @nestjs/typeorm  ...
# * ignoring # 965 @nestjs/websockets  ...
# * ignoring # 966 @next/env  ...
# * ignoring # 967 @next/eslint-plugin-next  ...
# * ignoring # 968 @next/swc-darwin-arm64  ...
# * ignoring # 969 @next/swc-darwin-x64  ...
# * ignoring # 970 @next/swc-linux-arm64-gnu  ...
# * ignoring # 971 @next/swc-linux-arm64-musl  ...
# * ignoring # 972 @next/swc-linux-x64-gnu  ...
# * ignoring # 973 @next/swc-linux-x64-musl  ...
# * ignoring # 974 @next/swc-win32-arm64-msvc  ...
# * ignoring # 975 @next/swc-win32-ia32-msvc  ...
# * ignoring # 976 @next/swc-win32-x64-msvc  ...
# * ignoring # 977 @nicolo-ribaudo/eslint-scope-5-internals  ...
# * ignoring # 978 @noble/hashes  ...
# * ignoring # 979 @nodelib/fs.scandir  ...
# * ignoring # 980 @nodelib/fs.scandir  ...
# * ignoring # 981 @nodelib/fs.stat  ...
# * ignoring # 982 @nodelib/fs.stat  ...
# * ignoring # 983 @nodelib/fs.walk  ...
# * ignoring # 984 @nodelib/fs.walk  ...
# * ignoring # 985 @nolyfill/is-core-module  ...
# * ignoring # 986 @notionhq/client  ...
# * ignoring # 987 @npmcli/arborist  ...
# * ignoring # 988 @npmcli/fs  ...
# * ignoring # 989 @npmcli/git  ...
# * ignoring # 990 @npmcli/installed-package-contents  ...
# * ignoring # 991 @npmcli/map-workspaces  ...
# * ignoring # 992 @npmcli/metavuln-calculator  ...
# * ignoring # 993 @npmcli/move-file  ...
# * ignoring # 994 @npmcli/name-from-folder  ...
# * ignoring # 995 @npmcli/node-gyp  ...
# * ignoring # 996 @npmcli/package-json  ...
# * ignoring # 997 @npmcli/promise-spawn  ...
# * ignoring # 998 @npmcli/run-script  ...
# * ignoring # 999 @nuxtjs/opencollective  ...
# * ignoring # 1000 @oclif/core  ...
# * ignoring # 1001 @oclif/linewrap  ...
# * ignoring # 1002 @oclif/plugin-help  ...
# * ignoring # 1003 @oclif/plugin-not-found  ...
# * ignoring # 1004 @oclif/plugin-warn-if-update-available  ...
# * ignoring # 1005 @oclif/screen  ...
# * ignoring # 1006 @octokit/app  ...
# * ignoring # 1007 @octokit/auth-app  ...
# * ignoring # 1008 @octokit/auth-oauth-app  ...
# * ignoring # 1009 @octokit/auth-oauth-device  ...
# * ignoring # 1010 @octokit/auth-oauth-user  ...
# * ignoring # 1011 @octokit/auth-token  ...
# * ignoring # 1012 @octokit/auth-unauthenticated  ...
# * ignoring # 1013 @octokit/core  ...
# * ignoring # 1014 @octokit/endpoint  ...
# * ignoring # 1015 @octokit/graphql  ...
# * ignoring # 1016 @octokit/oauth-app  ...
# * ignoring # 1017 @octokit/oauth-authorization-url  ...
# * ignoring # 1018 @octokit/oauth-methods  ...
# * ignoring # 1019 @octokit/openapi-types  ...
# ...
# * ignoring # 6484 upath  ...
# * ignoring # 6485 update-browserslist-db  ...
# * ignoring # 6486 update-browserslist-db  ...
# * ignoring # 6487 update-diff  ...
# * ignoring # 6488 update-input-width  ...
# * ignoring # 6489 update-notifier  ...
# * ignoring # 6490 update-notifier  ...
# * ignoring # 6491 upper-case  ...
# * ignoring # 6492 upper-case-first  ...
# * ignoring # 6493 uri-js  ...
# * ignoring # 6494 uri-js  ...
# * ignoring # 6495 urix  ...
# * ignoring # 6496 urix  ...
# * ignoring # 6497 url  ...
# * ignoring # 6498 url-join  ...
# * ignoring # 6499 url-loader  ...
# * ignoring # 6500 url-parse  ...
# * ignoring # 6501 url-parse-lax  ...
# * ignoring # 6502 url-parse-lax  ...
# * ignoring # 6503 url-regex  ...
# * ignoring # 6504 urlencoding  ...
# * ignoring # 6505 urllib3  ...
# * ignoring # 6506 use  ...
# * ignoring # 6507 use  ...
# * ignoring # 6508 use-async-effect  ...
# * ignoring # 6509 use-callback-ref  ...
# * ignoring # 6510 use-composed-ref  ...
# * ignoring # 6511 use-context-selector  ...
# * ignoring # 6512 use-debounce  ...
# * ignoring # 6513 use-error-boundary  ...
# * ignoring # 6514 use-isomorphic-layout-effect  ...
# * ignoring # 6515 use-latest  ...
# * ignoring # 6516 use-memo-one  ...
# * ignoring # 6517 use-query-params  ...
# * ignoring # 6518 use-sidecar  ...
# * ignoring # 6519 use-sync-external-store  ...
# * ignoring # 6520 usehooks-ts  ...
# * ignoring # 6521 useragent  ...
# * ignoring # 6522 username  ...
# * ignoring # 6523 usvg  ...
# * ignoring # 6524 utf-8  ...
# * ignoring # 6525 utf-8-validate  ...
# * ignoring # 6526 utf8-byte-length  ...
# * ignoring # 6527 utf8parse  ...
# * ignoring # 6528 util  ...
# * ignoring # 6529 util-deprecate  ...
# * ignoring # 6530 util-deprecate  ...
# * ignoring # 6531 util.promisify  ...
# * ignoring # 6532 utila  ...
# * ignoring # 6533 utile  ...
# * ignoring # 6534 utility-types  ...
# * ignoring # 6535 utils-merge  ...
# * ignoring # 6536 utils-merge  ...
# * ignoring # 6537 uuid  ...
# * ignoring # 6538 uuidv4  ...
# * ignoring # 6539 uuidv7  ...
# * ignoring # 6540 uvu  ...
# * ignoring # 6541 v8-compile-cache  ...
# * ignoring # 6542 v8-compile-cache-lib  ...
# * ignoring # 6543 v8-to-istanbul  ...
# * ignoring # 6544 v8-to-istanbul  ...
# * ignoring # 6545 v8flags  ...
# * ignoring # 6546 v8flags  ...
# * ignoring # 6547 v_frame  ...
# * ignoring # 6548 vali-date  ...
# * ignoring # 6549 valid-data-url  ...
# * ignoring # 6550 valid-url  ...
# * ignoring # 6551 validate-npm-package-license  ...
# * ignoring # 6552 validate-npm-package-name  ...
# * ignoring # 6553 validate-peer-dependencies  ...
# * ignoring # 6554 validate.io-array  ...
# * ignoring # 6555 validate.io-function  ...
# * ignoring # 6556 validate.io-integer  ...
# * ignoring # 6557 validate.io-integer-array  ...
# * ignoring # 6558 validate.io-number  ...
# * ignoring # 6559 validator  ...
# * ignoring # 6560 valuable  ...
# * ignoring # 6561 value-equal  ...
# * ignoring # 6562 value-or-function  ...
# * ignoring # 6563 value-or-promise  ...
# * ignoring # 6564 vary  ...
# * ignoring # 6565 vary  ...
# * ignoring # 6566 vbtest-custom-node-types  ...
# * ignoring # 6567 vcpkg  ...
# * ignoring # 6568 veaury  ...
# * ignoring # 6569 vello  ...
# * ignoring # 6570 vello_encoding  ...
# * ignoring # 6571 vello_shaders  ...
# * ignoring # 6572 verror  ...
# * ignoring # 6573 version-compare  ...
# * ignoring # 6574 version-guard  ...
# * ignoring # 6575 version_check  ...
# * ignoring # 6576 vfile  ...
# * ignoring # 6577 vfile-location  ...
# * ignoring # 6578 vfile-message  ...
# * ignoring # 6579 victory  ...
# * ignoring # 6580 victory-area  ...
# * ignoring # 6581 victory-axis  ...
# * ignoring # 6582 victory-bar  ...
# * ignoring # 6583 victory-box-plot  ...
# * ignoring # 6584 victory-brush-container  ...
# * ignoring # 6585 victory-brush-line  ...
# * ignoring # 6586 victory-candlestick  ...
# * ignoring # 6587 victory-canvas  ...
# * ignoring # 6588 victory-chart  ...
# * ignoring # 6589 victory-core  ...
# * ignoring # 6590 victory-create-container  ...
# * ignoring # 6591 victory-cursor-container  ...
# * ignoring # 6592 victory-errorbar  ...
# * ignoring # 6593 victory-group  ...
# * ignoring # 6594 victory-histogram  ...
# * ignoring # 6595 victory-legend  ...
# * ignoring # 6596 victory-line  ...
# * ignoring # 6597 victory-pie  ...
# * ignoring # 6598 victory-polar-axis  ...
# * ignoring # 6599 victory-scatter  ...
# * ignoring # 6600 victory-selection-container  ...
# * ignoring # 6601 victory-shared-events  ...
# * ignoring # 6602 victory-stack  ...
# * ignoring # 6603 victory-tooltip  ...
# * ignoring # 6604 victory-vendor  ...
# * ignoring # 6605 victory-voronoi  ...
# * ignoring # 6606 victory-voronoi-container  ...
# * ignoring # 6607 victory-zoom-container  ...
# * ignoring # 6608 vinyl  ...
# * ignoring # 6609 vinyl  ...
# * ignoring # 6610 vinyl-bufferstream  ...
# * ignoring # 6611 vinyl-file  ...
# * ignoring # 6612 vinyl-fs  ...
# * ignoring # 6613 vinyl-sourcemap  ...
# * ignoring # 6614 vinyl-sourcemaps-apply  ...
# * ignoring # 6615 vinyl-sourcemaps-apply  ...
# * ignoring # 6616 vite  ...
# * ignoring # 6617 vite-hot-client  ...
# * ignoring # 6618 vite-multiple-assets  ...
# * ignoring # 6619 vite-node  ...
# * ignoring # 6620 vite-plugin-inspect  ...
# * ignoring # 6621 vite-plugin-monaco-editor  ...
# * ignoring # 6622 vite-plugin-pwa  ...
# * ignoring # 6623 vite-plugin-react-js-support  ...
# * ignoring # 6624 vite-plugin-svgr  ...
# * ignoring # 6625 vite-plugin-top-level-await  ...
# * ignoring # 6626 vite-plugin-vue-devtools  ...
# * ignoring # 6627 vite-plugin-vue-inspector  ...
# * ignoring # 6628 vite-plugin-wasm  ...
# * ignoring # 6629 vite-tsconfig-paths  ...
# * ignoring # 6630 vitefu  ...
# * ignoring # 6631 vitest  ...
# * ignoring # 6632 viztracer  ...
# * ignoring # 6633 vm-browserify  ...
# * ignoring # 6634 vm2  ...
# * ignoring # 6635 void-elements  ...
# * ignoring # 6636 vsce  ...
# * ignoring # 6637 vscode-oniguruma  ...
# * ignoring # 6638 vscode-textmate  ...
# * ignoring # 6639 vscode-uri  ...
# * ignoring # 6640 vswhom  ...
# * ignoring # 6641 vswhom-sys  ...
# * ignoring # 6642 vt-pbf  ...
# * ignoring # 6643 vte  ...
# * ignoring # 6644 vte_generate_state_changes  ...
# * ignoring # 6645 vue  ...
# * ignoring # 6646 vue-component-type-helpers  ...
# * ignoring # 6647 vue-demi  ...
# * ignoring # 6648 vue-eslint-parser  ...
# * ignoring # 6649 vue-react-wrapper  ...
# * ignoring # 6650 vue-resize  ...
# * ignoring # 6651 vue-template-compiler  ...
# * ignoring # 6652 vue-tsc  ...
# * ignoring # 6653 w3c-hr-time  ...
# * ignoring # 6654 w3c-keyname  ...
# * ignoring # 6655 w3c-xmlserializer  ...
# * ignoring # 6656 wait-on  ...
# * ignoring # 6657 waker-fn  ...
# * ignoring # 6658 walk-up-path  ...
# * ignoring # 6659 walkdir  ...
# * ignoring # 6660 walker  ...
# * ignoring # 6661 walker  ...
# * ignoring # 6662 want  ...
# * ignoring # 6663 warning  ...
# * ignoring # 6664 wasi  ...
# * ignoring # 6665 wasm-bindgen  ...
# * ignoring # 6666 wasm-bindgen-backend  ...
# * ignoring # 6667 wasm-bindgen-futures  ...
# * ignoring # 6668 wasm-bindgen-macro  ...
# * ignoring # 6669 wasm-bindgen-macro-support  ...
# * ignoring # 6670 wasm-bindgen-shared  ...
# * ignoring # 6671 wasm-bindgen-test  ...
# * ignoring # 6672 wasm-bindgen-test-macro  ...
# * ignoring # 6673 wasm-streams  ...
# * ignoring # 6674 watchpack  ...
# * ignoring # 6675 watchpack-chokidar2  ...
# * ignoring # 6676 wayland-backend  ...
# * ignoring # 6677 wayland-client  ...
# * ignoring # 6678 wayland-csd-frame  ...
# * ignoring # 6679 wayland-cursor  ...
# * ignoring # 6680 wayland-protocols  ...
# * ignoring # 6681 wayland-protocols-plasma  ...
# * ignoring # 6682 wayland-protocols-wlr  ...
# * ignoring # 6683 wayland-scanner  ...
# * ignoring # 6684 wayland-sys  ...
# * ignoring # 6685 wbuf  ...
# * ignoring # 6686 wcag-contrast  ...
# * ignoring # 6687 wcwidth  ...
# * ignoring # 6688 weak-map  ...
# * ignoring # 6689 weaviate-ts-client  ...
# * ignoring # 6690 web-encoding  ...
# * ignoring # 6691 web-namespaces  ...
# * ignoring # 6692 web-resource-inliner  ...
# * ignoring # 6693 web-streams-polyfill  ...
# * ignoring # 6694 web-sys  ...
# * ignoring # 6695 web-time  ...
# * ignoring # 6696 web-vitals  ...
# * ignoring # 6697 web-worker  ...
# * ignoring # 6698 webgl-context  ...
# * ignoring # 6699 webidl-conversions  ...
# * ignoring # 6700 webkit2gtk  ...
# * ignoring # 6701 webkit2gtk-sys  ...
# * ignoring # 6702 webpack  ...
# * ignoring # 6703 webpack-bundle-analyzer  ...
# * ignoring # 6704 webpack-cli  ...
# * ignoring # 6705 webpack-dev-middleware  ...
# * ignoring # 6706 webpack-dev-server  ...
# * ignoring # 6707 webpack-log  ...
# * ignoring # 6708 webpack-manifest-plugin  ...
# * ignoring # 6709 webpack-merge  ...
# * ignoring # 6710 webpack-node-externals  ...
# * ignoring # 6711 webpack-sources  ...
# * ignoring # 6712 webpack-virtual-modules  ...
# * ignoring # 6713 webpackbar  ...
# * ignoring # 6714 webpki  ...
# * ignoring # 6715 webpki-roots  ...
# * ignoring # 6716 webpod  ...
# * ignoring # 6717 websocket-codec  ...
# * ignoring # 6718 websocket-driver  ...
# * ignoring # 6719 websocket-extensions  ...
# * ignoring # 6720 websocket-lite  ...
# * ignoring # 6721 webview2-com  ...
# * ignoring # 6722 webview2-com-macros  ...
# * ignoring # 6723 webview2-com-sys  ...
# * ignoring # 6724 weezl  ...
# * ignoring # 6725 wgpu  ...
# * ignoring # 6726 wgpu-core  ...
# * ignoring # 6727 wgpu-hal  ...
# * ignoring # 6728 wgpu-types  ...
# * ignoring # 6729 whatwg-encoding  ...
# * ignoring # 6730 whatwg-fetch  ...
# * ignoring # 6731 whatwg-mimetype  ...
# * ignoring # 6732 whatwg-url  ...
# * ignoring # 6733 which  ...
# * ignoring # 6734 which  ...
# * ignoring # 6735 which-boxed-primitive  ...
# * ignoring # 6736 which-builtin-type  ...
# * ignoring # 6737 which-collection  ...
# * ignoring # 6738 which-module  ...
# * ignoring # 6739 which-pm  ...
# * ignoring # 6740 which-typed-array  ...
# * ignoring # 6741 why-is-node-running  ...
# * ignoring # 6742 wicked-good-xpath  ...
# * ignoring # 6743 wide-align  ...
# * ignoring # 6744 widest-line  ...
# * ignoring # 6745 widest-line  ...
# * ignoring # 6746 widestring  ...
# * ignoring # 6747 wikipedia  ...
# * ignoring # 6748 wildcard  ...
# * ignoring # 6749 winapi  ...
# * ignoring # 6750 winapi-build  ...
# * ignoring # 6751 winapi-i686-pc-windows-gnu  ...
# * ignoring # 6752 winapi-util  ...
# * ignoring # 6753 winapi-x86_64-pc-windows-gnu  ...
# * ignoring # 6754 window-size  ...
# * ignoring # 6755 windows  ...
# * ignoring # 6756 windows-bindgen  ...
# * ignoring # 6757 windows-core  ...
# * ignoring # 6758 windows-implement  ...
# * ignoring # 6759 windows-interface  ...
# * ignoring # 6760 windows-metadata  ...
# * ignoring # 6761 windows-registry  ...
# * ignoring # 6762 windows-release  ...
# * ignoring # 6763 windows-result  ...
# * ignoring # 6764 windows-strings  ...
# * ignoring # 6765 windows-sys  ...
# * ignoring # 6766 windows-targets  ...
# * ignoring # 6767 windows-tokens  ...
# * ignoring # 6768 windows-version  ...
# * ignoring # 6769 windows_aarch64_gnullvm  ...
# * ignoring # 6770 windows_aarch64_msvc  ...
# * ignoring # 6771 windows_i686_gnu  ...
# * ignoring # 6772 windows_i686_gnullvm  ...
# * ignoring # 6773 windows_i686_msvc  ...
# * ignoring # 6774 windows_x86_64_gnu  ...
# * ignoring # 6775 windows_x86_64_gnullvm  ...
# * ignoring # 6776 windows_x86_64_msvc  ...
# * ignoring # 6777 winit  ...
# * ignoring # 6778 wink-nlp  ...
# * ignoring # 6779 winnow  ...
# * ignoring # 6780 winreg  ...
# * ignoring # 6781 winston  ...
# * ignoring # 6782 winston-papertrail  ...
# * ignoring # 6783 winston-syslog  ...
# * ignoring # 6784 winston-transport  ...
# * ignoring # 6785 wiremock  ...
# * ignoring # 6786 wl-clipboard-rs  ...
# * ignoring # 6787 wmf  ...
# * ignoring # 6788 word  ...
# * ignoring # 6789 word-wrap  ...
# * ignoring # 6790 word-wrap  ...
# * ignoring # 6791 wordwrap  ...
# * ignoring # 6792 wordwrapjs  ...
# * ignoring # 6793 workbox-background-sync  ...
# * ignoring # 6794 workbox-broadcast-update  ...
# * ignoring # 6795 workbox-build  ...
# * ignoring # 6796 workbox-cacheable-response  ...
# * ignoring # 6797 workbox-core  ...
# * ignoring # 6798 workbox-expiration  ...
# * ignoring # 6799 workbox-google-analytics  ...
# * ignoring # 6800 workbox-navigation-preload  ...
# * ignoring # 6801 workbox-precaching  ...
# * ignoring # 6802 workbox-range-requests  ...
# * ignoring # 6803 workbox-recipes  ...
# * ignoring # 6804 workbox-routing  ...
# * ignoring # 6805 workbox-strategies  ...
# * ignoring # 6806 workbox-streams  ...
# * ignoring # 6807 workbox-sw  ...
# * ignoring # 6808 workbox-webpack-plugin  ...
# * ignoring # 6809 workbox-window  ...
# * ignoring # 6810 worker-farm  ...
# * ignoring # 6811 worker-loader  ...
# * ignoring # 6812 workerpool  ...
# * ignoring # 6813 world-calendars  ...
# * ignoring # 6814 wrap-ansi  ...
# * ignoring # 6815 wrap-ansi  ...
# * ignoring # 6816 wrap-ansi-cjs  ...
# * ignoring # 6817 wrappy  ...
# * ignoring # 6818 wrappy  ...
# * ignoring # 6819 write-file-atomic  ...
# * ignoring # 6820 write-file-atomic  ...
# * ignoring # 6821 wry  ...
# * ignoring # 6822 ws  ...
# * ignoring # 6823 wtfnode  ...
# * ignoring # 6824 x11  ...
# * ignoring # 6825 x11-dl  ...
# * ignoring # 6826 x11rb  ...
# * ignoring # 6827 x11rb-protocol  ...
# * ignoring # 6828 xattr  ...
# * ignoring # 6829 xcursor  ...
# * ignoring # 6830 xdg  ...
# * ignoring # 6831 xdg-basedir  ...
# * ignoring # 6832 xdg-basedir  ...
# * ignoring # 6833 xdg-default-browser  ...
# * ignoring # 6834 xdg-home  ...
# * ignoring # 6835 xgboost  ...
# * ignoring # 6836 xhr  ...
# * ignoring # 6837 xkbcommon-dl  ...
# * ignoring # 6838 xkeysym  ...
# * ignoring # 6839 xlrd  ...
# * ignoring # 6840 xlsx  ...
# * ignoring # 6841 xlsxwriter  ...
# * ignoring # 6842 xml-js  ...
# * ignoring # 6843 xml-name-validator  ...
# * ignoring # 6844 xml-parse-from-string  ...
# * ignoring # 6845 xml-rs  ...
# * ignoring # 6846 xml2js  ...
# * ignoring # 6847 xmlbuilder  ...
# * ignoring # 6848 xmlchars  ...
# * ignoring # 6849 xmlcreate  ...
# * ignoring # 6850 xmldom-sre  ...
# * ignoring # 6851 xmlhttprequest-ssl  ...
# * ignoring # 6852 xmlparser  ...
# * ignoring # 6853 xmlwriter  ...
# * ignoring # 6854 xtend  ...
# * ignoring # 6855 xterm  ...
# * ignoring # 6856 xterm-addon-fit  ...
# * ignoring # 6857 xterm-addon-search  ...
# * ignoring # 6858 y-codemirror.next  ...
# * ignoring # 6859 y-leveldb  ...
# * ignoring # 6860 y-protocols  ...
# * ignoring # 6861 y-textarea  ...
# * ignoring # 6862 y-websocket  ...
# * ignoring # 6863 y18n  ...
# * ignoring # 6864 y18n  ...
# * ignoring # 6865 yallist  ...
# * ignoring # 6866 yallist  ...
# * ignoring # 6867 yaml  ...
# * ignoring # 6868 yamlparser  ...
# * ignoring # 6869 yargs  ...
# * ignoring # 6870 yargs  ...
# * ignoring # 6871 yargs-parser  ...
# * ignoring # 6872 yargs-parser  ...
# * ignoring # 6873 yargs-unparser  ...
# * ignoring # 6874 yarn-or-npm  ...
# * ignoring # 6875 yauzl  ...
# * ignoring # 6876 yazl  ...
# * ignoring # 6877 yeoman-environment  ...
# * ignoring # 6878 yeoman-generator  ...
# * ignoring # 6879 yjs  ...
# * ignoring # 6880 ylru  ...
# * ignoring # 6881 yn  ...
# * ignoring # 6882 yocto-queue  ...
# * ignoring # 6883 yocto-queue  ...
# * ignoring # 6884 youtube-player  ...
# * ignoring # 6885 yup  ...
# * ignoring # 6886 z-schema  ...
# * ignoring # 6887 zbus  ...
# * ignoring # 6888 zbus_macros  ...
# * ignoring # 6889 zbus_names  ...
# * ignoring # 6890 zen-observable  ...
# * ignoring # 6891 zen-observable-ts  ...
# * ignoring # 6892 zerocopy  ...
# * ignoring # 6893 zerocopy-derive  ...
# * ignoring # 6894 zeroize  ...
# * ignoring # 6895 zip  ...
# * ignoring # 6896 zip-stream  ...
# * ignoring # 6897 zod  ...
# * ignoring # 6898 zod-to-json-schema  ...
# * ignoring # 6899 zod-validation-error  ...
# * ignoring # 6900 zune-core  ...
# * ignoring # 6901 zune-inflate  ...
# * searching # 6902 zune-jpeg  ...
#     find # 6902 zune-jpeg  in github : (Repository(full_name="Shnatsel/zune-jpeg"), 'ok')
# * searching # 6903 zustand  ...
#     find # 6903 zustand  in npm.io : (Repository(full_name="pmndrs/zustand"), 'ok')
# * searching # 6904 zvariant  ...
#     cannot find # 6904 zvariant
# * searching # 6905 zvariant_derive  ...
#     cannot find # 6905 zvariant_derive
# * searching # 6906 zvariant_utils  ...
#     cannot find # 6906 zvariant_utils
# * searching # 6907 zwitch  ...
#     find # 6907 zwitch  in npm.io : (Repository(full_name="wooorm/zwitch"), 'ok')
# * searching # 6908 zx  ...
#     find # 6908 zx  in npm.io : (Repository(full_name="google/zx"), 'ok')

# %%
unique_all_target_repo_dependencies_failed
# Out:
# {'CannotFind': ['@atlaskit/analytics-next',
#   '@atlaskit/analytics-next-stable-react-context',
#   '@atlaskit/banner',
#   '@atlaskit/blanket',
#   '@atlaskit/button',
#   '@atlaskit/checkbox',
#   '@atlaskit/codemod-utils',
#   '@atlaskit/css-reset',
#   '@atlaskit/dropdown-menu',
#   '@atlaskit/ds-explorations',
#   '@atlaskit/ds-lib',
#   '@atlaskit/focus-ring',
#   '@atlaskit/form',
#   '@atlaskit/icon',
#   '@atlaskit/in-product-testing',
#   '@atlaskit/inline-dialog',
#   '@atlaskit/inline-edit',
#   '@atlaskit/interaction-context',
#   '@atlaskit/layering',
#   '@atlaskit/menu',
#   '@atlaskit/modal-dialog',
#   '@atlaskit/motion',
#   '@atlaskit/platform-feature-flags',
#   '@atlaskit/popper',
#   '@atlaskit/popup',
#   '@atlaskit/portal',
#   '@atlaskit/primitives',
#   '@atlaskit/range',
#   '@atlaskit/select',
#   '@atlaskit/side-navigation',
#   '@atlaskit/spinner',
#   '@atlaskit/tabs',
#   '@atlaskit/textarea',
#   '@atlaskit/textfield',
#   '@atlaskit/theme',
#   '@atlaskit/toggle',
#   '@atlaskit/tokens',
#   '@atlaskit/visually-hidden',
#   '@azure/core-sse',
#   '@azure/openai',
#   '@babel/plugin-bugfix-safari-id-destructuring-collision-in-function-expression',
#   '@babel/plugin-bugfix-v8-spread-parameters-in-optional-chaining',
#   '@babel/plugin-transform-class-properties',
#   '@babel/plugin-transform-class-static-block',
#   '@babel/plugin-transform-logical-assignment-operators',
#   '@babel/runtime',
#   '@chakra-ui/react-children-utils',
#   '@chakra-ui/react-context',
#   '@chakra-ui/react-use-focus-effect',
#   '@chakra-ui/react-use-focus-on-pointer-down',
#   '@chakra-ui/react-use-interval',
#   '@chakra-ui/react-use-latest-ref',
#   '@chakra-ui/react-use-merge-refs',
#   '@chakra-ui/react-use-outside-click',
#   '@chakra-ui/react-use-pan-event',
#   '@chakra-ui/react-use-previous',
#   '@chakra-ui/react-use-safe-layout-effect',
#   '@chakra-ui/react-use-size',
#   '@chakra-ui/react-use-timeout',
#   '@changesets/should-skip-package',
#   '@couchbase/couchbase-win32-x64-napi',
#   '@csstools/postcss-nested-calc',
#   '@csstools/postcss-text-decoration-shorthand',
#   '@csstools/selector-resolve-nested',
#   '@databricks/sql',
#   '@datastax/astra-db-ts'],
#  'MultiSuggestion': []}

# %%
# DON'T TOUCH
# creating csv file for mapping sbom name to github repo full name

with open("csv/map_sbom_name_to_repo_full_name.csv", "w") as f:
    # write header
    f.write("sbom_name, repo, \n")

    for key in map_target_repo_dependencies_to_full_name.keys():
        f.write(key)
        f.write(",")
        f.write(map_target_repo_dependencies_to_full_name[key])
        f.write(",\n")
        
# creating csv file for sbom name that failed to match to github repo full name

with open("csv/map_sbom_name_failed.csv", "w") as f:
    # write header
    f.write("sbom_name, problem, \n")
    
    for problem in unique_all_target_repo_dependencies_failed.keys():
        for sbom in unique_all_target_repo_dependencies_failed[problem]:
            f.write(sbom)
            f.write(",")
            f.write(problem)
            f.write(",\n")

# %% [markdown]
# ### Step 2 -- Map SBOM Name to Repo
#
# - Might need to be careful about how I get the github repo. Some are in PyPI, but it turns out that I can also find it in npm. So match the package manager in sbom file to how I map the github repo.
# - See step 3

# %%
import pandas as pd

map_sbom_name_to_repo_full_name_raw = pd.read_csv("csv/metastep/map_sbom_name_to_repo_full_name.csv", 
                                              header=0, names=["sbom_name", "repo", "map_by", ""])

# because I map_by is added much more later, so NaN is set to npm
for i, _ in enumerate(map_sbom_name_to_repo_full_name_raw["map_by"]):
    if not isinstance(_, str):
        map_sbom_name_to_repo_full_name_raw.loc[i, "map_by"] = "npm"
        
sbom_name2repo_full_name = {}
for i, row in map_sbom_name_to_repo_full_name_raw.iterrows():
    sbom_name2repo_full_name[row["sbom_name"]] = {"repo": row["repo"], "map_by": row["map_by"], "index": i}
    
sbom_name2repo_full_name
# Out:
# {'7zip-bin': {'repo': 'develar/7zip-bin', 'map_by': 'npm', 'index': 0},
#  '@4tw/cypress-drag-drop': {'repo': '4teamwork/cypress-drag-drop',
#   'map_by': 'npm',
#   'index': 1},
#  '@aashutoshrathi/word-wrap': {'repo': 'aashutoshrathi/word-wrap',
#   'map_by': 'npm',
#   'index': 2},
#  '@acuminous/bitsyntax': {'repo': 'acuminous/bitsyntax-js',
#   'map_by': 'npm',
#   'index': 3},
#  '@adobe/css-tools': {'repo': 'adobe/css-tools', 'map_by': 'npm', 'index': 4},
#  '@ag-grid-community/client-side-row-model': {'repo': 'ag-grid/ag-grid',
#   'map_by': 'npm',
#   'index': 5},
#  '@ag-grid-community/core': {'repo': 'ag-grid/ag-grid',
#   'map_by': 'npm',
#   'index': 6},
#  '@ag-grid-community/styles': {'repo': 'ag-grid/ag-grid',
#   'map_by': 'npm',
#   'index': 7},
#  '@ag-grid-enterprise/core': {'repo': 'ag-grid/ag-grid',
#   'map_by': 'npm',
#   'index': 8},
#  '@ag-grid-enterprise/range-selection': {'repo': 'ag-grid/ag-grid',
#   'map_by': 'npm',
#   'index': 9},
#  '@ai-sdk/provider': {'repo': 'vercel/ai', 'map_by': 'npm', 'index': 10},
#  '@ai-sdk/provider-utils': {'repo': 'vercel/ai', 'map_by': 'npm', 'index': 11},
#  '@ai-sdk/react': {'repo': 'vercel/ai', 'map_by': 'npm', 'index': 12},
#  '@ai-sdk/solid': {'repo': 'vercel/ai', 'map_by': 'npm', 'index': 13},
#  '@ai-sdk/svelte': {'repo': 'vercel/ai', 'map_by': 'npm', 'index': 14},
#  '@ai-sdk/ui-utils': {'repo': 'vercel/ai', 'map_by': 'npm', 'index': 15},
#  '@ai-sdk/vue': {'repo': 'vercel/ai', 'map_by': 'npm', 'index': 16},
#  '@akryum/tinypool': {'repo': 'tinylibs/tinypool',
#   'map_by': 'npm',
#   'index': 17},
#  '@algolia/autocomplete-core': {'repo': 'algolia/autocomplete',
#   'map_by': 'npm',
#   'index': 18},
#  '@algolia/autocomplete-plugin-algolia-insights': {'repo': 'algolia/autocomplete',
#   'map_by': 'npm',
#   'index': 19},
#  '@algolia/autocomplete-preset-algolia': {'repo': 'algolia/autocomplete',
#   'map_by': 'npm',
#   'index': 20},
#  '@algolia/autocomplete-shared': {'repo': 'algolia/autocomplete',
#   'map_by': 'npm',
#   'index': 21},
#  '@algolia/cache-browser-local-storage': {'repo': 'algolia/algoliasearch-client-javascript',
#   'map_by': 'npm',
#   'index': 22},
#  '@algolia/cache-common': {'repo': 'algolia/algoliasearch-client-javascript',
#   'map_by': 'npm',
#   'index': 23},
#  '@algolia/cache-in-memory': {'repo': 'algolia/algoliasearch-client-javascript',
#   'map_by': 'npm',
#   'index': 24},
#  '@algolia/client-account': {'repo': 'algolia/algoliasearch-client-javascript',
#   'map_by': 'npm',
#   'index': 25},
#  '@algolia/client-analytics': {'repo': 'algolia/algoliasearch-client-javascript',
#   'map_by': 'npm',
#   'index': 26},
#  '@algolia/client-common': {'repo': 'algolia/algoliasearch-client-javascript',
#   'map_by': 'npm',
#   'index': 27},
#  '@algolia/client-personalization': {'repo': 'algolia/algoliasearch-client-javascript',
#   'map_by': 'npm',
#   'index': 28},
#  '@algolia/client-search': {'repo': 'algolia/algoliasearch-client-javascript',
#   'map_by': 'npm',
#   'index': 29},
#  '@algolia/events': {'repo': 'algolia/events', 'map_by': 'npm', 'index': 30},
#  '@algolia/logger-common': {'repo': 'algolia/algoliasearch-client-javascript',
#   'map_by': 'npm',
#   'index': 31},
#  '@algolia/logger-console': {'repo': 'algolia/algoliasearch-client-javascript',
#   'map_by': 'npm',
#   'index': 32},
#  '@algolia/requester-browser-xhr': {'repo': 'algolia/algoliasearch-client-javascript',
#   'map_by': 'npm',
#   'index': 33},
#  '@algolia/requester-common': {'repo': 'algolia/algoliasearch-client-javascript',
#   'map_by': 'npm',
#   'index': 34},
#  '@algolia/requester-node-http': {'repo': 'algolia/algoliasearch-client-javascript',
#   'map_by': 'npm',
#   'index': 35},
#  '@algolia/transporter': {'repo': 'algolia/algoliasearch-client-javascript',
#   'map_by': 'npm',
#   'index': 36},
#  '@alloc/quick-lru': {'repo': 'sindresorhus/quick-lru',
#   'map_by': 'npm',
#   'index': 37},
#  '@ampproject/remapping': {'repo': 'ampproject/remapping',
#   'map_by': 'npm',
#   'index': 38},
#  '@angular-devkit/core': {'repo': 'angular/angular-cli',
#   'map_by': 'npm',
#   'index': 39},
#  '@angular-devkit/schematics': {'repo': 'angular/angular-cli',
#   'map_by': 'npm',
#   'index': 40},
#  '@angular-devkit/schematics-cli': {'repo': 'angular/angular-cli',
#   'map_by': 'npm',
#   'index': 41},
#  '@ant-design/colors': {'repo': 'ant-design/ant-design-colors',
#   'map_by': 'npm',
#   'index': 42},
#  '@ant-design/cssinjs': {'repo': 'ant-design/cssinjs',
#   'map_by': 'npm',
#   'index': 43},
#  '@ant-design/icons': {'repo': 'ant-design/ant-design-icons',
#   'map_by': 'npm',
#   'index': 44},
#  '@ant-design/icons-svg': {'repo': 'ant-design/ant-design-icons',
#   'map_by': 'npm',
#   'index': 45},
#  '@ant-design/react-slick': {'repo': 'ant-design/react-slick',
#   'map_by': 'npm',
#   'index': 46},
#  '@antfu/utils': {'repo': 'antfu/utils', 'map_by': 'npm', 'index': 47},
#  '@anthropic-ai/sdk': {'repo': 'anthropics/anthropic-sdk-typescript',
#   'map_by': 'npm',
#   'index': 48},
#  '@apideck/better-ajv-errors': {'repo': 'apideck-libraries/better-ajv-errors',
#   'map_by': 'npm',
#   'index': 49},
#  '@apidevtools/json-schema-ref-parser': {'repo': 'APIDevTools/json-schema-ref-parser',
#   'map_by': 'npm',
#   'index': 50},
#  '@apidevtools/openapi-schemas': {'repo': 'APIDevTools/openapi-schemas',
#   'map_by': 'npm',
#   'index': 51},
#  '@apidevtools/swagger-methods': {'repo': 'APIDevTools/swagger-methods',
#   'map_by': 'npm',
#   'index': 52},
#  '@apidevtools/swagger-parser': {'repo': 'APIDevTools/swagger-parser',
#   'map_by': 'npm',
#   'index': 53},
#  '@apify/consts': {'repo': 'apify/apify-shared-js',
#   'map_by': 'npm',
#   'index': 54},
#  '@apify/log': {'repo': 'apify/apify-shared-js', 'map_by': 'npm', 'index': 55},
#  '@auth/core': {'repo': 'nextauthjs/next-auth', 'map_by': 'npm', 'index': 56},
#  '@aws-amplify/auth': {'repo': 'aws-amplify/amplify-js',
#   'map_by': 'npm',
#   'index': 57},
#  '@aws-amplify/core': {'repo': 'aws-amplify/amplify-js',
#   'map_by': 'npm',
#   'index': 58},
#  '@aws-crypto/crc32': {'repo': 'aws/aws-sdk-js-crypto-helpers',
#   'map_by': 'npm',
#   'index': 59},
#  '@aws-crypto/crc32c': {'repo': 'aws/aws-sdk-js-crypto-helpers',
#   'map_by': 'npm',
#   'index': 60},
#  '@aws-crypto/ie11-detection': {'repo': 'aws/aws-sdk-js-crypto-helpers',
#   'map_by': 'npm',
#   'index': 61},
#  '@aws-crypto/sha1-browser': {'repo': 'aws/aws-sdk-js-crypto-helpers',
#   'map_by': 'npm',
#   'index': 62},
#  '@aws-crypto/sha256-browser': {'repo': 'aws/aws-sdk-js-crypto-helpers',
#   'map_by': 'npm',
#   'index': 63},
#  '@aws-crypto/sha256-js': {'repo': 'aws/aws-sdk-js-crypto-helpers',
#   'map_by': 'npm',
#   'index': 64},
#  '@aws-crypto/supports-web-crypto': {'repo': 'aws/aws-sdk-js-crypto-helpers',
#   'map_by': 'npm',
#   'index': 65},
#  '@aws-crypto/util': {'repo': 'aws/aws-sdk-js-crypto-helpers',
#   'map_by': 'npm',
#   'index': 66},
#  '@aws-sdk/abort-controller': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 67},
#  '@aws-sdk/client-bedrock-agent-runtime': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 68},
#  '@aws-sdk/client-bedrock-runtime': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 69},
#  '@aws-sdk/client-cloudwatch-logs': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 70},
#  '@aws-sdk/client-cognito-identity': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 71},
#  '@aws-sdk/client-dynamodb': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 72},
#  '@aws-sdk/client-kendra': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 73},
#  '@aws-sdk/client-s3': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 74},
#  '@aws-sdk/client-sso': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 75},
#  '@aws-sdk/client-sso-oidc': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 76},
#  '@aws-sdk/client-sts': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 77},
#  '@aws-sdk/config-resolver': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 78},
#  '@aws-sdk/core': {'repo': 'aws/aws-sdk-js-v3', 'map_by': 'npm', 'index': 79},
#  '@aws-sdk/credential-provider-cognito-identity': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 80},
#  '@aws-sdk/credential-provider-env': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 81},
#  '@aws-sdk/credential-provider-http': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 82},
#  '@aws-sdk/credential-provider-imds': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 83},
#  '@aws-sdk/credential-provider-ini': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 84},
#  '@aws-sdk/credential-provider-node': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 85},
#  '@aws-sdk/credential-provider-process': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 86},
#  '@aws-sdk/credential-provider-sso': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 87},
#  '@aws-sdk/credential-provider-web-identity': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 88},
#  '@aws-sdk/credential-providers': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 89},
#  '@aws-sdk/endpoint-cache': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 90},
#  '@aws-sdk/fetch-http-handler': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 91},
#  '@aws-sdk/hash-node': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 92},
#  '@aws-sdk/invalid-dependency': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 93},
#  '@aws-sdk/is-array-buffer': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 94},
#  '@aws-sdk/middleware-bucket-endpoint': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 95},
#  '@aws-sdk/middleware-content-length': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 96},
#  '@aws-sdk/middleware-endpoint-discovery': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 97},
#  '@aws-sdk/middleware-expect-continue': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 98},
#  '@aws-sdk/middleware-flexible-checksums': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 99},
#  '@aws-sdk/middleware-host-header': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 100},
#  '@aws-sdk/middleware-location-constraint': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 101},
#  '@aws-sdk/middleware-logger': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 102},
#  '@aws-sdk/middleware-recursion-detection': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 103},
#  '@aws-sdk/middleware-retry': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 104},
#  '@aws-sdk/middleware-sdk-s3': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 105},
#  '@aws-sdk/middleware-sdk-sts': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 106},
#  '@aws-sdk/middleware-serde': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 107},
#  '@aws-sdk/middleware-signing': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 108},
#  '@aws-sdk/middleware-ssec': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 109},
#  '@aws-sdk/middleware-stack': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 110},
#  '@aws-sdk/middleware-user-agent': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 111},
#  '@aws-sdk/node-config-provider': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 112},
#  '@aws-sdk/node-http-handler': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 113},
#  '@aws-sdk/property-provider': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 114},
#  '@aws-sdk/protocol-http': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 115},
#  '@aws-sdk/querystring-builder': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 116},
#  '@aws-sdk/querystring-parser': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 117},
#  '@aws-sdk/region-config-resolver': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 118},
#  '@aws-sdk/service-error-classification': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 119},
#  '@aws-sdk/shared-ini-file-loader': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 120},
#  '@aws-sdk/signature-v4': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 121},
#  '@aws-sdk/signature-v4-multi-region': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 122},
#  '@aws-sdk/smithy-client': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 123},
#  '@aws-sdk/token-providers': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 124},
#  '@aws-sdk/types': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 125},
#  '@aws-sdk/url-parser': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 126},
#  '@aws-sdk/url-parser-native': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 127},
#  '@aws-sdk/util-arn-parser': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 128},
#  '@aws-sdk/util-base64-browser': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 129},
#  '@aws-sdk/util-base64-node': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 130},
#  '@aws-sdk/util-body-length-browser': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 131},
#  '@aws-sdk/util-body-length-node': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 132},
#  '@aws-sdk/util-buffer-from': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 133},
#  '@aws-sdk/util-endpoints': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 134},
#  '@aws-sdk/util-hex-encoding': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 135},
#  '@aws-sdk/util-locate-window': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 136},
#  '@aws-sdk/util-uri-escape': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 137},
#  '@aws-sdk/util-user-agent-browser': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 138},
#  '@aws-sdk/util-user-agent-node': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 139},
#  '@aws-sdk/util-utf8-browser': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 140},
#  '@aws-sdk/util-utf8-node': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 141},
#  '@aws-sdk/xml-builder': {'repo': 'aws/aws-sdk-js-v3',
#   'map_by': 'npm',
#   'index': 142},
#  '@azure-rest/core-client': {'repo': 'Azure/azure-sdk-for-js',
#   'map_by': 'npm',
#   'index': 143},
#  '@azure/abort-controller': {'repo': 'Azure/azure-sdk-for-js',
#   'map_by': 'npm',
#   'index': 144},
#  '@azure/core-auth': {'repo': 'Azure/azure-sdk-for-js',
#   'map_by': 'npm',
#   'index': 145},
#  '@azure/core-client': {'repo': 'Azure/azure-sdk-for-js',
#   'map_by': 'npm',
#   'index': 146},
#  '@azure/core-lro': {'repo': 'Azure/azure-sdk-for-js',
#   'map_by': 'npm',
#   'index': 147},
#  '@azure/core-rest-pipeline': {'repo': 'Azure/azure-sdk-for-js',
#   'map_by': 'npm',
#   'index': 148},
#  '@azure/core-tracing': {'repo': 'Azure/azure-sdk-for-js',
#   'map_by': 'npm',
#   'index': 149},
#  '@azure/core-util': {'repo': 'Azure/azure-sdk-for-js',
#   'map_by': 'npm',
#   'index': 150},
#  '@azure/identity': {'repo': 'Azure/azure-sdk-for-js',
#   'map_by': 'npm',
#   'index': 151},
#  '@azure/logger': {'repo': 'Azure/azure-sdk-for-js',
#   'map_by': 'npm',
#   'index': 152},
#  '@azure/msal-browser': {'repo': 'AzureAD/microsoft-authentication-library-for-js',
#   'map_by': 'npm',
#   'index': 153},
#  '@azure/msal-common': {'repo': 'AzureAD/microsoft-authentication-library-for-js',
#   'map_by': 'npm',
#   'index': 154},
#  '@azure/msal-node': {'repo': 'AzureAD/microsoft-authentication-library-for-js',
#   'map_by': 'npm',
#   'index': 155},
#  '@babel/code-frame': {'repo': 'babel/babel', 'map_by': 'npm', 'index': 156},
#  '@babel/compat-data': {'repo': 'babel/babel', 'map_by': 'npm', 'index': 157},
#  '@babel/core': {'repo': 'babel/babel', 'map_by': 'npm', 'index': 158},
#  '@babel/eslint-parser': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 159},
#  '@babel/generator': {'repo': 'babel/babel', 'map_by': 'npm', 'index': 160},
#  '@babel/helper-annotate-as-pure': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 161},
#  '@babel/helper-builder-binary-assignment-operator-visitor': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 162},
#  '@babel/helper-compilation-targets': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 163},
#  '@babel/helper-create-class-features-plugin': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 164},
#  '@babel/helper-create-regexp-features-plugin': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 165},
#  '@babel/helper-define-polyfill-provider': {'repo': 'babel/babel-polyfills',
#   'map_by': 'npm',
#   'index': 166},
#  '@babel/helper-environment-visitor': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 167},
#  '@babel/helper-explode-assignable-expression': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 168},
#  '@babel/helper-function-name': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 169},
#  '@babel/helper-hoist-variables': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 170},
#  '@babel/helper-member-expression-to-functions': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 171},
#  '@babel/helper-module-imports': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 172},
#  '@babel/helper-module-transforms': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 173},
#  '@babel/helper-optimise-call-expression': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 174},
#  '@babel/helper-plugin-utils': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 175},
#  '@babel/helper-remap-async-to-generator': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 176},
#  '@babel/helper-replace-supers': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 177},
#  '@babel/helper-simple-access': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 178},
#  '@babel/helper-skip-transparent-expression-wrappers': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 179},
#  '@babel/helper-split-export-declaration': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 180},
#  '@babel/helper-string-parser': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 181},
#  '@babel/helper-validator-identifier': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 182},
#  '@babel/helper-validator-option': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 183},
#  '@babel/helper-wrap-function': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 184},
#  '@babel/helpers': {'repo': 'babel/babel', 'map_by': 'npm', 'index': 185},
#  '@babel/highlight': {'repo': 'babel/babel', 'map_by': 'npm', 'index': 186},
#  '@babel/parser': {'repo': 'babel/babel', 'map_by': 'npm', 'index': 187},
#  '@babel/plugin-bugfix-firefox-class-in-computed-class-key': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 188},
#  '@babel/plugin-bugfix-safari-class-field-initializer-scope': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 189},
#  '@babel/plugin-bugfix-v8-static-class-fields-redefine-readonly': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 190},
#  '@babel/plugin-proposal-async-generator-functions': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 191},
#  '@babel/plugin-proposal-class-properties': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 192},
#  '@babel/plugin-proposal-class-static-block': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 193},
#  '@babel/plugin-proposal-decorators': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 194},
#  '@babel/plugin-proposal-dynamic-import': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 195},
#  '@babel/plugin-proposal-export-namespace-from': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 196},
#  '@babel/plugin-proposal-json-strings': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 197},
#  '@babel/plugin-proposal-logical-assignment-operators': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 198},
#  '@babel/plugin-proposal-nullish-coalescing-operator': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 199},
#  '@babel/plugin-proposal-numeric-separator': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 200},
#  '@babel/plugin-proposal-object-rest-spread': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 201},
#  '@babel/plugin-proposal-optional-catch-binding': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 202},
#  '@babel/plugin-proposal-optional-chaining': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 203},
#  '@babel/plugin-proposal-private-methods': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 204},
#  '@babel/plugin-proposal-private-property-in-object': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 205},
#  '@babel/plugin-proposal-unicode-property-regex': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 206},
#  '@babel/plugin-syntax-async-generators': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 207},
#  '@babel/plugin-syntax-bigint': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 208},
#  '@babel/plugin-syntax-class-properties': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 209},
#  '@babel/plugin-syntax-class-static-block': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 210},
#  '@babel/plugin-syntax-decorators': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 211},
#  '@babel/plugin-syntax-dynamic-import': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 212},
#  '@babel/plugin-syntax-export-namespace-from': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 213},
#  '@babel/plugin-syntax-flow': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 214},
#  '@babel/plugin-syntax-import-assertions': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 215},
#  '@babel/plugin-syntax-import-attributes': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 216},
#  '@babel/plugin-syntax-import-meta': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 217},
#  '@babel/plugin-syntax-json-strings': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 218},
#  '@babel/plugin-syntax-jsx': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 219},
#  '@babel/plugin-syntax-logical-assignment-operators': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 220},
#  '@babel/plugin-syntax-nullish-coalescing-operator': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 221},
#  '@babel/plugin-syntax-numeric-separator': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 222},
#  '@babel/plugin-syntax-object-rest-spread': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 223},
#  '@babel/plugin-syntax-optional-catch-binding': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 224},
#  '@babel/plugin-syntax-optional-chaining': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 225},
#  '@babel/plugin-syntax-private-property-in-object': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 226},
#  '@babel/plugin-syntax-top-level-await': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 227},
#  '@babel/plugin-syntax-typescript': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 228},
#  '@babel/plugin-syntax-unicode-sets-regex': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 229},
#  '@babel/plugin-transform-arrow-functions': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 230},
#  '@babel/plugin-transform-async-generator-functions': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 231},
#  '@babel/plugin-transform-async-to-generator': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 232},
#  '@babel/plugin-transform-block-scoped-functions': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 233},
#  '@babel/plugin-transform-block-scoping': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 234},
#  '@babel/plugin-transform-classes': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 235},
#  '@babel/plugin-transform-computed-properties': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 236},
#  '@babel/plugin-transform-destructuring': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 237},
#  '@babel/plugin-transform-dotall-regex': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 238},
#  '@babel/plugin-transform-duplicate-keys': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 239},
#  '@babel/plugin-transform-duplicate-named-capturing-groups-regex': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 240},
#  '@babel/plugin-transform-dynamic-import': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 241},
#  '@babel/plugin-transform-exponentiation-operator': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 242},
#  '@babel/plugin-transform-export-namespace-from': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 243},
#  '@babel/plugin-transform-flow-strip-types': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 244},
#  '@babel/plugin-transform-for-of': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 245},
#  '@babel/plugin-transform-function-name': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 246},
#  '@babel/plugin-transform-json-strings': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 247},
#  '@babel/plugin-transform-literals': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 248},
#  '@babel/plugin-transform-member-expression-literals': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 249},
#  '@babel/plugin-transform-modules-amd': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 250},
#  '@babel/plugin-transform-modules-commonjs': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 251},
#  '@babel/plugin-transform-modules-systemjs': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 252},
#  '@babel/plugin-transform-modules-umd': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 253},
#  '@babel/plugin-transform-named-capturing-groups-regex': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 254},
#  '@babel/plugin-transform-new-target': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 255},
#  '@babel/plugin-transform-nullish-coalescing-operator': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 256},
#  '@babel/plugin-transform-numeric-separator': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 257},
#  '@babel/plugin-transform-object-rest-spread': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 258},
#  '@babel/plugin-transform-object-super': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 259},
#  '@babel/plugin-transform-optional-catch-binding': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 260},
#  '@babel/plugin-transform-optional-chaining': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 261},
#  '@babel/plugin-transform-parameters': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 262},
#  '@babel/plugin-transform-private-methods': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 263},
#  '@babel/plugin-transform-private-property-in-object': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 264},
#  '@babel/plugin-transform-property-literals': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 265},
#  '@babel/plugin-transform-react-constant-elements': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 266},
#  '@babel/plugin-transform-react-display-name': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 267},
#  '@babel/plugin-transform-react-jsx': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 268},
#  '@babel/plugin-transform-react-jsx-development': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 269},
#  '@babel/plugin-transform-react-jsx-self': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 270},
#  '@babel/plugin-transform-react-jsx-source': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 271},
#  '@babel/plugin-transform-react-pure-annotations': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 272},
#  '@babel/plugin-transform-regenerator': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 273},
#  '@babel/plugin-transform-reserved-words': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 274},
#  '@babel/plugin-transform-runtime': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 275},
#  '@babel/plugin-transform-shorthand-properties': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 276},
#  '@babel/plugin-transform-spread': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 277},
#  '@babel/plugin-transform-sticky-regex': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 278},
#  '@babel/plugin-transform-template-literals': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 279},
#  '@babel/plugin-transform-typeof-symbol': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 280},
#  '@babel/plugin-transform-typescript': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 281},
#  '@babel/plugin-transform-unicode-escapes': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 282},
#  '@babel/plugin-transform-unicode-property-regex': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 283},
#  '@babel/plugin-transform-unicode-regex': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 284},
#  '@babel/plugin-transform-unicode-sets-regex': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 285},
#  '@babel/preset-env': {'repo': 'babel/babel', 'map_by': 'npm', 'index': 286},
#  '@babel/preset-flow': {'repo': 'babel/babel', 'map_by': 'npm', 'index': 287},
#  '@babel/preset-modules': {'repo': 'babel/preset-modules',
#   'map_by': 'npm',
#   'index': 288},
#  '@babel/preset-react': {'repo': 'babel/babel', 'map_by': 'npm', 'index': 289},
#  '@babel/preset-typescript': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 290},
#  '@babel/register': {'repo': 'babel/babel', 'map_by': 'npm', 'index': 291},
#  '@babel/regjsgen': {'repo': 'bnjmnt4n/regjsgen',
#   'map_by': 'npm',
#   'index': 292},
#  '@babel/runtime-corejs3': {'repo': 'babel/babel',
#   'map_by': 'npm',
#   'index': 293},
#  '@babel/template': {'repo': 'babel/babel', 'map_by': 'npm', 'index': 294},
#  '@babel/traverse': {'repo': 'babel/babel', 'map_by': 'npm', 'index': 295},
#  '@babel/types': {'repo': 'babel/babel', 'map_by': 'npm', 'index': 296},
#  '@bcoe/v8-coverage': {'repo': 'demurgos/v8-coverage',
#   'map_by': 'npm',
#   'index': 297},
#  '@blueprintjs/colors': {'repo': 'palantir/blueprint',
#   'map_by': 'npm',
#   'index': 298},
#  '@blueprintjs/core': {'repo': 'palantir/blueprint',
#   'map_by': 'npm',
#   'index': 299},
#  '@blueprintjs/icons': {'repo': 'palantir/blueprint',
#   'map_by': 'npm',
#   'index': 300},
#  '@blueprintjs/select': {'repo': 'palantir/blueprint',
#   'map_by': 'npm',
#   'index': 301},
#  '@chainner/navi': {'repo': 'chaiNNer-org/Navi',
#   'map_by': 'npm',
#   'index': 302},
#  '@chainner/node-path': {'repo': 'chaiNNer-org/node-path',
#   'map_by': 'npm',
#   'index': 303},
#  '@chakra-ui/accordion': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 304},
#  '@chakra-ui/alert': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 305},
#  '@chakra-ui/anatomy': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 306},
#  '@chakra-ui/avatar': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 307},
#  '@chakra-ui/breadcrumb': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 308},
#  '@chakra-ui/breakpoint-utils': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 309},
#  '@chakra-ui/button': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 310},
#  '@chakra-ui/card': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 311},
#  '@chakra-ui/checkbox': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 312},
#  '@chakra-ui/clickable': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 313},
#  '@chakra-ui/close-button': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 314},
#  '@chakra-ui/color-mode': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 315},
#  '@chakra-ui/control-box': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 316},
#  '@chakra-ui/counter': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 317},
#  '@chakra-ui/css-reset': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 318},
#  '@chakra-ui/descendant': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 319},
#  '@chakra-ui/dom-utils': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 320},
#  '@chakra-ui/editable': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 321},
#  '@chakra-ui/event-utils': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 322},
#  '@chakra-ui/focus-lock': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 323},
#  '@chakra-ui/form-control': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 324},
#  '@chakra-ui/hooks': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 325},
#  '@chakra-ui/icon': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 326},
#  '@chakra-ui/icons': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 327},
#  '@chakra-ui/image': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 328},
#  '@chakra-ui/input': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 329},
#  '@chakra-ui/layout': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 330},
#  '@chakra-ui/lazy-utils': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 331},
#  '@chakra-ui/live-region': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 332},
#  '@chakra-ui/media-query': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 333},
#  '@chakra-ui/menu': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 334},
#  '@chakra-ui/modal': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 335},
#  '@chakra-ui/number-input': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 336},
#  '@chakra-ui/number-utils': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 337},
#  '@chakra-ui/object-utils': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 338},
#  '@chakra-ui/pin-input': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 339},
#  '@chakra-ui/popover': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 340},
#  '@chakra-ui/popper': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 341},
#  '@chakra-ui/portal': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 342},
#  '@chakra-ui/progress': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 343},
#  '@chakra-ui/provider': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 344},
#  '@chakra-ui/radio': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 345},
#  '@chakra-ui/react': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 346},
#  '@chakra-ui/react-env': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 347},
#  '@chakra-ui/react-types': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 348},
#  '@chakra-ui/react-use-animation-state': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 349},
#  '@chakra-ui/react-use-callback-ref': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 350},
#  '@chakra-ui/react-use-controllable-state': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 351},
#  '@chakra-ui/react-use-disclosure': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 352},
#  '@chakra-ui/react-use-event-listener': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 353},
#  '@chakra-ui/react-use-update-effect': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 354},
#  '@chakra-ui/react-utils': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 355},
#  '@chakra-ui/select': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 356},
#  '@chakra-ui/shared-utils': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 357},
#  '@chakra-ui/skeleton': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 358},
#  '@chakra-ui/skip-nav': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 359},
#  '@chakra-ui/slider': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 360},
#  '@chakra-ui/spinner': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 361},
#  '@chakra-ui/stat': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 362},
#  '@chakra-ui/stepper': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 363},
#  '@chakra-ui/styled-system': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 364},
#  '@chakra-ui/switch': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 365},
#  '@chakra-ui/system': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 366},
#  '@chakra-ui/table': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 367},
#  '@chakra-ui/tabs': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 368},
#  '@chakra-ui/tag': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 369},
#  '@chakra-ui/textarea': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 370},
#  '@chakra-ui/theme': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 371},
#  '@chakra-ui/theme-tools': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 372},
#  '@chakra-ui/theme-utils': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 373},
#  '@chakra-ui/toast': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 374},
#  '@chakra-ui/tooltip': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 375},
#  '@chakra-ui/transition': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 376},
#  '@chakra-ui/utils': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 377},
#  '@chakra-ui/visually-hidden': {'repo': 'chakra-ui/chakra-ui',
#   'map_by': 'npm',
#   'index': 378},
#  '@changesets/apply-release-plan': {'repo': 'changesets/changesets',
#   'map_by': 'npm',
#   'index': 379},
#  '@changesets/assemble-release-plan': {'repo': 'changesets/changesets',
#   'map_by': 'npm',
#   'index': 380},
#  '@changesets/changelog-git': {'repo': 'changesets/changesets',
#   'map_by': 'npm',
#   'index': 381},
#  '@changesets/cli': {'repo': 'changesets/changesets',
#   'map_by': 'npm',
#   'index': 382},
#  '@changesets/config': {'repo': 'changesets/changesets',
#   'map_by': 'npm',
#   'index': 383},
#  '@changesets/errors': {'repo': 'changesets/changesets',
#   'map_by': 'npm',
#   'index': 384},
#  '@changesets/get-dependents-graph': {'repo': 'changesets/changesets',
#   'map_by': 'npm',
#   'index': 385},
#  '@changesets/get-release-plan': {'repo': 'changesets/changesets',
#   'map_by': 'npm',
#   'index': 386},
#  '@changesets/get-version-range-type': {'repo': 'changesets/changesets',
#   'map_by': 'npm',
#   'index': 387},
#  '@changesets/git': {'repo': 'changesets/changesets',
#   'map_by': 'npm',
#   'index': 388},
#  '@changesets/logger': {'repo': 'changesets/changesets',
#   'map_by': 'npm',
#   'index': 389},
#  '@changesets/parse': {'repo': 'changesets/changesets',
#   'map_by': 'npm',
#   'index': 390},
#  '@changesets/pre': {'repo': 'changesets/changesets',
#   'map_by': 'npm',
#   'index': 391},
#  '@changesets/read': {'repo': 'changesets/changesets',
#   'map_by': 'npm',
#   'index': 392},
#  '@changesets/types': {'repo': 'changesets/changesets',
#   'map_by': 'npm',
#   'index': 393},
#  '@changesets/write': {'repo': 'changesets/changesets',
#   'map_by': 'npm',
#   'index': 394},
#  '@choojs/findup': {'repo': 'choojs/findup', 'map_by': 'npm', 'index': 395},
#  '@clickhouse/client': {'repo': 'ClickHouse/clickhouse-js',
#   'map_by': 'npm',
#   'index': 396},
#  '@clickhouse/client-common': {'repo': 'ClickHouse/clickhouse-js',
#   'map_by': 'npm',
#   'index': 397},
#  '@codemirror/autocomplete': {'repo': 'codemirror/autocomplete',
#   'map_by': 'npm',
#   'index': 398},
#  '@codemirror/commands': {'repo': 'codemirror/commands',
#   'map_by': 'npm',
#   'index': 399},
#  '@codemirror/lang-css': {'repo': 'codemirror/lang-css',
#   'map_by': 'npm',
#   'index': 400},
#  '@codemirror/lang-html': {'repo': 'codemirror/lang-html',
#   'map_by': 'npm',
#   'index': 401},
#  '@codemirror/lang-javascript': {'repo': 'codemirror/lang-javascript',
#   'map_by': 'npm',
#   'index': 402},
#  '@codemirror/lang-json': {'repo': 'codemirror/lang-json',
#   'map_by': 'npm',
#   'index': 403},
#  '@codemirror/lang-markdown': {'repo': 'codemirror/lang-markdown',
#   'map_by': 'npm',
#   'index': 404},
#  '@codemirror/lang-python': {'repo': 'codemirror/lang-python',
#   'map_by': 'npm',
#   'index': 405},
#  '@codemirror/language': {'repo': 'codemirror/language',
#   'map_by': 'npm',
#   'index': 406},
#  '@codemirror/lint': {'repo': 'codemirror/lint',
#   'map_by': 'npm',
#   'index': 407},
#  '@codemirror/search': {'repo': 'codemirror/search',
#   'map_by': 'npm',
#   'index': 408},
#  '@codemirror/state': {'repo': 'codemirror/state',
#   'map_by': 'npm',
#   'index': 409},
#  '@codemirror/theme-one-dark': {'repo': 'codemirror/theme-one-dark',
#   'map_by': 'npm',
#   'index': 410},
#  '@codemirror/view': {'repo': 'codemirror/view',
#   'map_by': 'npm',
#   'index': 411},
#  '@colors/colors': {'repo': 'DABH/colors.js', 'map_by': 'npm', 'index': 412},
#  '@couchbase/couchbase-darwin-arm64-napi': {'repo': 'couchbase/couchnode',
#   'map_by': 'npm',
#   'index': 413},
#  '@couchbase/couchbase-darwin-x64-napi': {'repo': 'couchbase/couchnode',
#   'map_by': 'npm',
#   'index': 414},
#  '@couchbase/couchbase-linux-arm64-napi': {'repo': 'couchbase/couchnode',
#   'map_by': 'npm',
#   'index': 415},
#  '@couchbase/couchbase-linux-x64-napi': {'repo': 'couchbase/couchnode',
#   'map_by': 'npm',
#   'index': 416},
#  '@couchbase/couchbase-linuxmusl-x64-napi': {'repo': 'couchbase/couchnode',
#   'map_by': 'npm',
#   'index': 417},
#  '@craco/craco': {'repo': 'dilanx/craco', 'map_by': 'npm', 'index': 418},
#  '@crawlee/types': {'repo': 'apify/crawlee', 'map_by': 'npm', 'index': 419},
#  '@cspotcode/source-map-support': {'repo': 'cspotcode/node-source-map-support',
#   'map_by': 'npm',
#   'index': 420},
#  '@csstools/normalize.css': {'repo': 'csstools/normalize.css',
#   'map_by': 'npm',
#   'index': 421},
#  '@csstools/postcss-cascade-layers': {'repo': 'csstools/postcss-plugins',
#   'map_by': 'npm',
#   'index': 422},
#  '@csstools/postcss-color-function': {'repo': 'csstools/postcss-plugins',
#   'map_by': 'npm',
#   'index': 423},
#  '@csstools/postcss-font-format-keywords': {'repo': 'csstools/postcss-plugins',
#   'map_by': 'npm',
#   'index': 424},
#  '@csstools/postcss-hwb-function': {'repo': 'csstools/postcss-plugins',
#   'map_by': 'npm',
#   'index': 425},
#  '@csstools/postcss-ic-unit': {'repo': 'csstools/postcss-plugins',
#   'map_by': 'npm',
#   'index': 426},
#  '@csstools/postcss-is-pseudo-class': {'repo': 'csstools/postcss-plugins',
#   'map_by': 'npm',
#   'index': 427},
#  '@csstools/postcss-normalize-display-values': {'repo': 'csstools/postcss-plugins',
#   'map_by': 'npm',
#   'index': 428},
#  '@csstools/postcss-oklab-function': {'repo': 'csstools/postcss-plugins',
#   'map_by': 'npm',
#   'index': 429},
#  '@csstools/postcss-progressive-custom-properties': {'repo': 'csstools/postcss-plugins',
#   'map_by': 'npm',
#   'index': 430},
#  '@csstools/postcss-stepped-value-functions': {'repo': 'csstools/postcss-plugins',
#   'map_by': 'npm',
#   'index': 431},
#  '@csstools/postcss-trigonometric-functions': {'repo': 'csstools/postcss-plugins',
#   'map_by': 'npm',
#   'index': 432},
#  '@csstools/postcss-unset-value': {'repo': 'csstools/postcss-plugins',
#   'map_by': 'npm',
#   'index': 433},
#  '@csstools/selector-specificity': {'repo': 'csstools/postcss-plugins',
#   'map_by': 'npm',
#   'index': 434},
#  '@ctrl/tinycolor': {'repo': 'scttcper/tinycolor',
#   'map_by': 'npm',
#   'index': 435},
#  '@cypress/request': {'repo': 'cypress-io/request',
#   'map_by': 'npm',
#   'index': 436},
#  '@cypress/xvfb': {'repo': 'cypress-io/xvfb', 'map_by': 'npm', 'index': 437},
#  '@dabh/diagnostics': {'repo': '3rd-Eden/diagnostics',
#   'map_by': 'npm',
#   'index': 438},
#  '@dagrejs/graphlib': {'repo': 'dagrejs/graphlib',
#   'map_by': 'npm',
#   'index': 439},
#  '@danmarshall/deckgl-typings': {'repo': 'danmarshall/deckgl-typings',
#   'map_by': 'npm',
#   'index': 440},
#  '@date-io/core': {'repo': 'dmtrKovalenko/date-io',
#   'map_by': 'npm',
#   'index': 441},
#  '@date-io/date-fns': {'repo': 'dmtrKovalenko/date-io',
#   'map_by': 'npm',
#   'index': 442},
#  '@date-io/dayjs': {'repo': 'dmtrKovalenko/date-io',
#   'map_by': 'npm',
#   'index': 443},
#  '@date-io/luxon': {'repo': 'dmtrKovalenko/date-io',
#   'map_by': 'npm',
#   'index': 444},
#  '@date-io/moment': {'repo': 'dmtrKovalenko/date-io',
#   'map_by': 'npm',
#   'index': 445},
#  '@develar/schema-utils': {'repo': 'webpack/schema-utils',
#   'map_by': 'npm',
#   'index': 446},
#  '@discordjs/builders': {'repo': 'discordjs/discord.js',
#   'map_by': 'npm',
#   'index': 447},
#  '@discordjs/collection': {'repo': 'discordjs/discord.js',
#   'map_by': 'npm',
#   'index': 448},
#  '@discordjs/formatters': {'repo': 'discordjs/discord.js',
#   'map_by': 'npm',
#   'index': 449},
#  '@discordjs/rest': {'repo': 'discordjs/discord.js',
#   'map_by': 'npm',
#   'index': 450},
#  '@discordjs/util': {'repo': 'discordjs/discord.js',
#   'map_by': 'npm',
#   'index': 451},
#  '@discordjs/ws': {'repo': 'discordjs/discord.js',
#   'map_by': 'npm',
#   'index': 452},
#  '@discoveryjs/json-ext': {'repo': 'discoveryjs/json-ext',
#   'map_by': 'npm',
#   'index': 453},
#  '@dnd-kit/accessibility': {'repo': 'clauderic/dnd-kit',
#   'map_by': 'npm',
#   'index': 454},
#  '@dnd-kit/core': {'repo': 'clauderic/dnd-kit', 'map_by': 'npm', 'index': 455},
#  '@dnd-kit/sortable': {'repo': 'clauderic/dnd-kit',
#   'map_by': 'npm',
#   'index': 456},
#  '@dnd-kit/utilities': {'repo': 'clauderic/dnd-kit',
#   'map_by': 'npm',
#   'index': 457},
#  '@docsearch/css': {'repo': 'algolia/docsearch',
#   'map_by': 'npm',
#   'index': 458},
#  '@docsearch/react': {'repo': 'algolia/docsearch',
#   'map_by': 'npm',
#   'index': 459},
#  '@docusaurus/core': {'repo': 'facebook/docusaurus',
#   'map_by': 'npm',
#   'index': 460},
#  '@docusaurus/cssnano-preset': {'repo': 'facebook/docusaurus',
#   'map_by': 'npm',
#   'index': 461},
#  '@docusaurus/logger': {'repo': 'facebook/docusaurus',
#   'map_by': 'npm',
#   'index': 462},
#  '@docusaurus/mdx-loader': {'repo': 'facebook/docusaurus',
#   'map_by': 'npm',
#   'index': 463},
#  '@docusaurus/module-type-aliases': {'repo': 'facebook/docusaurus',
#   'map_by': 'npm',
#   'index': 464},
#  '@docusaurus/plugin-content-blog': {'repo': 'facebook/docusaurus',
#   'map_by': 'npm',
#   'index': 465},
#  '@docusaurus/plugin-google-gtag': {'repo': 'facebook/docusaurus',
#   'map_by': 'npm',
#   'index': 466},
#  '@docusaurus/plugin-sitemap': {'repo': 'facebook/docusaurus',
#   'map_by': 'npm',
#   'index': 467},
#  '@docusaurus/preset-classic': {'repo': 'facebook/docusaurus',
#   'map_by': 'npm',
#   'index': 468},
#  '@docusaurus/react-loadable': {'repo': 'jamiebuilds/react-loadable',
#   'map_by': 'npm',
#   'index': 469},
#  '@docusaurus/theme-common': {'repo': 'facebook/docusaurus',
#   'map_by': 'npm',
#   'index': 470},
#  '@docusaurus/theme-search-algolia': {'repo': 'facebook/docusaurus',
#   'map_by': 'npm',
#   'index': 471},
#  '@docusaurus/theme-translations': {'repo': 'facebook/docusaurus',
#   'map_by': 'npm',
#   'index': 472},
#  '@docusaurus/types': {'repo': 'facebook/docusaurus',
#   'map_by': 'npm',
#   'index': 473},
#  '@docusaurus/utils': {'repo': 'facebook/docusaurus',
#   'map_by': 'npm',
#   'index': 474},
#  '@docusaurus/utils-common': {'repo': 'facebook/docusaurus',
#   'map_by': 'npm',
#   'index': 475},
#  '@docusaurus/utils-validation': {'repo': 'facebook/docusaurus',
#   'map_by': 'npm',
#   'index': 476},
#  '@dqbd/tiktoken': {'repo': 'dqbd/tiktoken', 'map_by': 'npm', 'index': 477},
#  '@e2b/code-interpreter': {'repo': 'e2b-dev/code-interpreter',
#   'map_by': 'npm',
#   'index': 478},
#  '@elastic/elasticsearch': {'repo': 'elastic/elasticsearch-js',
#   'map_by': 'npm',
#   'index': 479},
#  '@elastic/transport': {'repo': 'elastic/elastic-transport-js',
#   'map_by': 'npm',
#   'index': 480},
#  '@electron-forge/cli': {'repo': 'electron/forge',
#   'map_by': 'npm',
#   'index': 481},
#  '@electron-forge/core': {'repo': 'electron/forge',
#   'map_by': 'npm',
#   'index': 482},
#  '@electron-forge/core-utils': {'repo': 'electron/forge',
#   'map_by': 'npm',
#   'index': 483},
#  '@electron-forge/maker-base': {'repo': 'electron/forge',
#   'map_by': 'npm',
#   'index': 484},
#  '@electron-forge/maker-deb': {'repo': 'electron/forge',
#   'map_by': 'npm',
#   'index': 485},
#  '@electron-forge/maker-dmg': {'repo': 'electron/forge',
#   'map_by': 'npm',
#   'index': 486},
#  '@electron-forge/maker-flatpak': {'repo': 'electron/forge',
#   'map_by': 'npm',
#   'index': 487},
#  '@electron-forge/maker-rpm': {'repo': 'electron/forge',
#   'map_by': 'npm',
#   'index': 488},
#  '@electron-forge/maker-squirrel': {'repo': 'electron/forge',
# ...
#   'map_by': 'npm.io',
#   'index': 860},
#  '@qdrant/js-client-rest': {'repo': 'qdrant/qdrant-js',
#   'map_by': 'npm',
#   'index': 861},
#  '@qdrant/openapi-typescript-fetch': {'repo': 'qdrant/openapi-typescript-fetch',
#   'map_by': 'npm',
#   'index': 862},
#  '@radix-ui/number': {'repo': 'radix-ui/primitives',
#   'map_by': 'npm.io',
#   'index': 863},
#  '@radix-ui/primitive': {'repo': 'radix-ui/primitives',
#   'map_by': 'npm.io',
#   'index': 864},
#  '@radix-ui/react-compose-refs': {'repo': 'radix-ui/primitives',
#   'map_by': 'npm.io',
#   'index': 865},
#  '@radix-ui/react-context': {'repo': 'radix-ui/primitives',
#   'map_by': 'npm.io',
#   'index': 866},
#  '@radix-ui/react-direction': {'repo': 'radix-ui/primitives',
#   'map_by': 'npm.io',
#   'index': 867},
#  '@radix-ui/react-presence': {'repo': 'radix-ui/primitives',
#   'map_by': 'npm.io',
#   'index': 868},
#  '@radix-ui/react-primitive': {'repo': 'radix-ui/primitives',
#   'map_by': 'npm.io',
#   'index': 869},
#  '@radix-ui/react-scroll-area': {'repo': 'radix-ui/primitives',
#   'map_by': 'npm.io',
#   'index': 870},
#  '@radix-ui/react-slot': {'repo': 'radix-ui/primitives',
#   'map_by': 'npm.io',
#   'index': 871},
#  '@radix-ui/react-use-callback-ref': {'repo': 'radix-ui/primitives',
#   'map_by': 'npm.io',
#   'index': 872},
#  '@radix-ui/react-use-layout-effect': {'repo': 'radix-ui/primitives',
#   'map_by': 'npm.io',
#   'index': 873},
#  '@rc-component/color-picker': {'repo': 'react-component/color-picker',
#   'map_by': 'npm',
#   'index': 874},
#  '@rc-component/context': {'repo': 'react-component/context',
#   'map_by': 'npm',
#   'index': 875},
#  '@rc-component/mini-decimal': {'repo': 'react-component/mini-decimal',
#   'map_by': 'npm',
#   'index': 876},
#  '@rc-component/mutate-observer': {'repo': 'react-component/mutate-observer',
#   'map_by': 'npm',
#   'index': 877},
#  '@rc-component/portal': {'repo': 'react-component/portal',
#   'map_by': 'npm',
#   'index': 878},
#  '@react-aria/breadcrumbs': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 879},
#  '@react-aria/button': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 880},
#  '@react-aria/calendar': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 881},
#  '@react-aria/collections': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 882},
#  '@react-aria/combobox': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 883},
#  '@react-aria/datepicker': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 884},
#  '@react-aria/dialog': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 885},
#  '@react-aria/dnd': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 886},
#  '@react-aria/focus': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 887},
#  '@react-aria/grid': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 888},
#  '@react-aria/i18n': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 889},
#  '@react-aria/interactions': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 890},
#  '@react-aria/label': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 891},
#  '@react-aria/link': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 892},
#  '@react-aria/live-announcer': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 893},
#  '@react-aria/menu': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 894},
#  '@react-aria/meter': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 895},
#  '@react-aria/numberfield': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 896},
#  '@react-aria/overlays': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 897},
#  '@react-aria/progress': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 898},
#  '@react-aria/radio': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 899},
#  '@react-aria/searchfield': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm',
#   'index': 900},
#  '@react-aria/select': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 901},
#  '@react-aria/selection': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 902},
#  '@react-aria/separator': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 903},
#  '@react-aria/slider': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 904},
#  '@react-aria/spinbutton': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 905},
#  '@react-aria/ssr': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 906},
#  '@react-aria/switch': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm',
#   'index': 907},
#  '@react-aria/table': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 908},
#  '@react-aria/tabs': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 909},
#  '@react-aria/tag': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm',
#   'index': 910},
#  '@react-aria/textfield': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 911},
#  '@react-aria/toggle': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 912},
#  '@react-aria/toolbar': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm',
#   'index': 913},
#  '@react-aria/tooltip': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm',
#   'index': 914},
#  '@react-aria/tree': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm',
#   'index': 915},
#  '@react-aria/utils': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 916},
#  '@react-aria/virtualizer': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 917},
#  '@react-aria/visually-hidden': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 918},
#  '@react-dnd/asap': {'repo': 'react-dnd/react-dnd',
#   'map_by': 'npm.io',
#   'index': 919},
#  '@react-dnd/invariant': {'repo': 'react-dnd/react-dnd',
#   'map_by': 'npm.io',
#   'index': 920},
#  '@react-dnd/shallowequal': {'repo': 'react-dnd/react-dnd',
#   'map_by': 'npm.io',
#   'index': 921},
#  '@react-email/render': {'repo': 'resend/react-email',
#   'map_by': 'npm',
#   'index': 922},
#  '@react-hook/latest': {'repo': 'jaredLunde/react-hook',
#   'map_by': 'npm.io',
#   'index': 923},
#  '@react-hook/passive-layout-effect': {'repo': 'jaredLunde/react-hook',
#   'map_by': 'npm.io',
#   'index': 924},
#  '@react-hook/resize-observer': {'repo': 'jaredLunde/react-hook',
#   'map_by': 'npm.io',
#   'index': 925},
#  '@react-hook/size': {'repo': 'jaredLunde/react-hook',
#   'map_by': 'npm.io',
#   'index': 926},
#  '@react-nano/use-event-source': {'repo': 'Lusito/react-nano',
#   'map_by': 'npm.io',
#   'index': 927},
#  '@react-oauth/google': {'repo': 'MomenSherif/react-oauth',
#   'map_by': 'npm.io',
#   'index': 928},
#  '@react-stately/calendar': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 929},
#  '@react-stately/checkbox': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 930},
#  '@react-stately/collections': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 931},
#  '@react-stately/color': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 932},
#  '@react-stately/combobox': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm',
#   'index': 933},
#  '@react-stately/data': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 934},
#  '@react-stately/datepicker': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 935},
#  '@react-stately/dnd': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 936},
#  '@react-stately/flags': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm',
#   'index': 937},
#  '@react-stately/form': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm',
#   'index': 938},
#  '@react-stately/grid': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 939},
#  '@react-stately/layout': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 940},
#  '@react-stately/list': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 941},
#  '@react-stately/menu': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 942},
#  '@react-stately/numberfield': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 943},
#  '@react-stately/overlays': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 944},
#  '@react-stately/radio': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 945},
#  '@react-stately/searchfield': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 946},
#  '@react-stately/select': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 947},
#  '@react-stately/selection': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 948},
#  '@react-stately/slider': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 949},
#  '@react-stately/table': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 950},
#  '@react-stately/tabs': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 951},
#  '@react-stately/toggle': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 952},
#  '@react-stately/tooltip': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 953},
#  '@react-stately/tree': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 954},
#  '@react-stately/utils': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 955},
#  '@react-stately/virtualizer': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 956},
#  '@react-types/breadcrumbs': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 957},
#  '@react-types/button': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 958},
#  '@react-types/calendar': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 959},
#  '@react-types/checkbox': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 960},
#  '@react-types/color': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 961},
#  '@react-types/combobox': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 962},
#  '@react-types/datepicker': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 963},
#  '@react-types/dialog': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 964},
#  '@react-types/form': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 965},
#  '@react-types/grid': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 966},
#  '@react-types/link': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 967},
#  '@react-types/listbox': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 968},
#  '@react-types/menu': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 969},
#  '@react-types/meter': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 970},
#  '@react-types/numberfield': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 971},
#  '@react-types/overlays': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 972},
#  '@react-types/progress': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 973},
#  '@react-types/radio': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 974},
#  '@react-types/searchfield': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 975},
#  '@react-types/select': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 976},
#  '@react-types/shared': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 977},
#  '@react-types/slider': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 978},
#  '@react-types/switch': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 979},
#  '@react-types/table': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 980},
#  '@react-types/tabs': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 981},
#  '@react-types/textfield': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 982},
#  '@react-types/tooltip': {'repo': 'adobe/react-spectrum',
#   'map_by': 'npm.io',
#   'index': 983},
#  '@reactflow/background': {'repo': 'xyflow/xyflow',
#   'map_by': 'npm',
#   'index': 984},
#  '@reactflow/controls': {'repo': 'xyflow/xyflow',
#   'map_by': 'npm',
#   'index': 985},
#  '@reactflow/core': {'repo': 'xyflow/xyflow', 'map_by': 'npm', 'index': 986},
#  '@reactflow/minimap': {'repo': 'xyflow/xyflow',
#   'map_by': 'npm',
#   'index': 987},
#  '@reactflow/node-resizer': {'repo': 'xyflow/xyflow',
#   'map_by': 'npm',
#   'index': 988},
#  '@reactflow/node-toolbar': {'repo': 'xyflow/xyflow',
#   'map_by': 'npm',
#   'index': 989},
#  '@recoiljs/refine': {'repo': 'facebookexperimental/Recoil',
#   'map_by': 'npm.io',
#   'index': 990},
#  '@redis/client': {'repo': 'redis/node-redis',
#   'map_by': 'npm.io',
#   'index': 991},
#  '@reduxjs/toolkit': {'repo': 'reduxjs/redux-toolkit',
#   'map_by': 'npm.io',
#   'index': 992},
#  '@rehooks/component-size': {'repo': 'rehooks/component-size',
#   'map_by': 'npm.io',
#   'index': 993},
#  '@remix-run/router': {'repo': 'remix-run/react-router',
#   'map_by': 'npm.io',
#   'index': 994},
#  '@rjsf/core': {'repo': 'rjsf-team/react-jsonschema-form',
#   'map_by': 'npm.io',
#   'index': 995},
#  '@rollup/plugin-babel': {'repo': 'rollup/plugins',
#   'map_by': 'npm.io',
#   'index': 996},
#  '@rollup/plugin-node-resolve': {'repo': 'rollup/plugins',
#   'map_by': 'npm.io',
#   'index': 997},
#  '@rollup/plugin-replace': {'repo': 'rollup/plugins',
#   'map_by': 'npm.io',
#   'index': 998},
#  '@rollup/pluginutils': {'repo': 'rollup/plugins',
#   'map_by': 'npm.io',
#   'index': 999},
#  '@rollup/rollup-linux-arm-musleabihf': {'repo': 'rollup/rollup',
#   'map_by': 'npm',
#   'index': 1000},
#  '@rollup/rollup-linux-arm64-gnu': {'repo': 'rollup/rollup',
#   'map_by': 'npm',
#   'index': 1001},
#  '@rollup/rollup-linux-arm64-musl': {'repo': 'rollup/rollup',
#   'map_by': 'npm',
#   'index': 1002},
#  '@rollup/rollup-linux-powerpc64le-gnu': {'repo': 'rollup/rollup',
#   'map_by': 'npm',
#   'index': 1003},
#  '@rollup/rollup-linux-riscv64-gnu': {'repo': 'rollup/rollup',
#   'map_by': 'npm',
#   'index': 1004},
#  '@rollup/rollup-linux-s390x-gnu': {'repo': 'rollup/rollup',
#   'map_by': 'npm',
#   'index': 1005},
#  '@rollup/rollup-linux-x64-gnu': {'repo': 'rollup/rollup',
#   'map_by': 'npm',
#   'index': 1006},
#  '@rollup/rollup-linux-x64-musl': {'repo': 'rollup/rollup',
#   'map_by': 'npm',
#   'index': 1007},
#  '@rollup/rollup-win32-arm64-msvc': {'repo': 'rollup/rollup',
#   'map_by': 'npm',
#   'index': 1008},
#  '@rtsao/scc': {'repo': 'rtsao/scc', 'map_by': 'npm.io', 'index': 1009},
#  '@rushstack/eslint-patch': {'repo': 'microsoft/rushstack',
#   'map_by': 'npm.io',
#   'index': 1010},
#  '@sapphire/async-queue': {'repo': 'sapphiredev/utilities',
#   'map_by': 'npm.io',
#   'index': 1011},
#  '@sapphire/shapeshift': {'repo': 'sapphiredev/shapeshift',
#   'map_by': 'npm.io',
#   'index': 1012},
#  '@sapphire/snowflake': {'repo': 'sapphiredev/utilities',
#   'map_by': 'npm.io',
#   'index': 1013},
#  '@selderee/plugin-htmlparser2': {'repo': 'mxxii/selderee',
#   'map_by': 'npm.io',
#   'index': 1014},
#  '@sendgrid/client': {'repo': 'sendgrid/sendgrid-nodejs',
#   'map_by': 'npm.io',
#   'index': 1015},
#  '@sendgrid/eventwebhook': {'repo': 'sendgrid/sendgrid-nodejs',
#   'map_by': 'npm.io',
#   'index': 1016},
#  '@sendgrid/helpers': {'repo': 'sendgrid/sendgrid-nodejs',
#   'map_by': 'npm.io',
#   'index': 1017},
#  '@sendgrid/mail': {'repo': 'sendgrid/sendgrid-nodejs',
#   'map_by': 'npm.io',
#   'index': 1018},
#  '@sentry/browser': {'repo': 'getsentry/sentry-javascript',
#   'map_by': 'npm.io',
#   'index': 1019},
#  '@sentry/cli': {'repo': 'getsentry/sentry-cli',
#   'map_by': 'npm.io',
#   'index': 1020},
#  '@sentry/core': {'repo': 'getsentry/sentry-javascript',
#   'map_by': 'npm.io',
#   'index': 1021},
#  '@sentry/hub': {'repo': 'getsentry/sentry-javascript',
#   'map_by': 'npm.io',
#   'index': 1022},
#  '@sentry/integrations': {'repo': 'getsentry/sentry-javascript',
#   'map_by': 'npm.io',
#   'index': 1023},
#  '@sentry/node': {'repo': 'getsentry/sentry-javascript',
#   'map_by': 'npm.io',
#   'index': 1024},
#  ...}

# %%
import json

def get_relationship_from_sbom_file(repo_full_name : str, dep_filename : str):
    """Get relationship from sbom file
    It makes sure raw_json["relationships"][index]["relatedSpdxElement"] is equal to 
    raw_json["packages"][index]["SPDXID"], and then it maps it to sbom name.
    """
    
    output = []
    
    # read json file
    try:
        with open(dep_filename) as f:
            raw = json.load(f)
    except OSError as e:
        print(repo, "doesn't exist dependencies graph ... ")
        return None
    
    # get relationship and package
    relationships = raw["relationships"]
    packages = raw["packages"]
    
    # if not the same, probably should do it manually.
    assert len(relationships) == len(packages), \
           "relationships and packages len not match %d != %d" % (len(relationships), len(packages))
    
    # loop through packages and check package manager, relatedSpdxElement, relationshipType
    for index, rel in enumerate(relationships):
        # make sure the id in relationships and packages matches
        assert rel["relatedSpdxElement"] == packages[index]["SPDXID"], \
               "SpdxID in relationship and package not match"
        
        # # make sure there is only DEPENDS_ON relationship
        # assert rel["relationshipType"] == "DEPENDS_ON", \
        #        "relationship type is not DEPENDS_ON, it is %s" % rel["relationshipType"]
        
        # create dep info
        sbom_repo_relationship = [repo_full_name, "DEPENDS_ON"]
        sbom_name = packages[index]["name"]
        
        if sbom_name.startswith("npm:"):
            sbom_name = sbom_name.replace("npm:", "")
        
        sbom_dep_info = {"sbom_name": sbom_name}
        
        if "licenseConcluded" in packages[index]:
            sbom_dep_info["license"] = packages[index]["licenseConcluded"]
        if "externalRefs" in packages[index]:
            sbom_dep_info["package_manager"] = \
            packages[index]["externalRefs"][0]["referenceLocator"].split("/")[0].replace("pkg:", "")
        
        sbom_repo_relationship.append(sbom_dep_info)
        
        # append to output
        output.append(sbom_repo_relationship)
        
    return output

# %%
def record_sbom_name_failed(repo_full_name: str, sbom_name: str, pkg_manager: str):
    """Record failure to map dependency sbom_name"""
    
    map_sbom_name_failed_new_filename = "csv/metastep/map_sbom_name_failed_new.csv"
    
    failed = pd.read_csv(map_sbom_name_failed_new_filename, header=0,
                         names=["repo_full_name", "relationship", "sbom_name", "pkg_manager", ""])
    
    if any(failed["repo_full_name"][failed["sbom_name"] == sbom_name] == repo_full_name):
        print("(", repo_full_name, ",", sbom_name, ") already in failure record")
        return
    
    with open(map_sbom_name_failed_new_filename, "a") as f:
        f.write(repo_full_name)
        f.write(",")
        f.write("DEPENDS_ON,")
        f.write(sbom_name)
        f.write(",")
        f.write(pkg_manager)
        f.write(",\n")
        
    print("writing", sbom_name, "to", map_sbom_name_failed_new_filename)
        
def record_relationship(repo_full_name: str, relationship: str, dependency: str):
    """Reocrd relationship from repo full name to repo full name"""
    
    relationships_filename = "csv/relationships.csv" # subject, relationship, object
    
    with open(relationships_filename, "a") as f:
        f.write(repo_full_name)
        f.write(",")
        f.write(relationship)
        f.write(",")
        f.write(dependency)
        f.write(",\n")
        
    print("writing", repo_full_name, "-", relationship, "->", dependency, "to", relationships_filename)
    

def map_sbom_name_2_repo_full_name(repo_full_name: str, output: list):
    """Map and record to csv file ready for Neo4j
    dependencies are labeled repo, and relationships point repo to repo
    """
    
    # load the mapping
    global sbom_name2repo_full_name
    
    for rel in output:
        sbom_repo = rel[2]
        
        # make sure sbom_name can be mapped to repo_full_name, or else make sure it is record for failure
        if sbom_repo["sbom_name"] not in sbom_name2repo_full_name:
            record_sbom_name_failed(repo_full_name, sbom_repo["sbom_name"], sbom_repo["package_manager"])
            continue
        
        # make sure the package manager and how we get the repo is matched
        if sbom_repo["package_manager"] in sbom_name2repo_full_name[sbom_repo["sbom_name"]]["map_by"]:
            record_relationship(repo_full_name, rel[1], sbom_name2repo_full_name[sbom_repo["sbom_name"]]["repo"])
        else:
            record_sbom_name_failed(repo_full_name, sbom_repo["sbom_name"], sbom_repo["package_manager"])
            print("package manager not match (", repo_full_name, ",", sbom_repo["sbom_name"], ",", sbom_repo["package_manager"], ")")
            
    print("Dealing with #", len(output), "of records done.")

# %%
litegraph_dep = get_relationship_from_sbom_file("jagenjo/litegraph.js", "raw/litegraph.js-dependencies.json")
litegraph_dep = map_sbom_name_2_repo_full_name("jagenjo/litegraph.js", litegraph_dep)
# Out:
# writing jagenjo/litegraph.js - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> demurgos/v8-coverage to csv/relationships.csv
# writing @humanwhocodes/module-importer to csv/metastep/map_sbom_name_failed_new.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> istanbuljs/load-nyc-config to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> istanbuljs/schema to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jestjs/jest to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jestjs/jest to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jestjs/jest to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jestjs/jest to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jestjs/jest to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jestjs/jest to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jestjs/jest to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jestjs/jest to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jestjs/jest to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jestjs/jest to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jestjs/jest to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jestjs/jest to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jestjs/jest to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jestjs/jest to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jridgewell/resolve-uri to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jridgewell/set-array to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jridgewell/sourcemap-codec to csv/relationships.csv
# writing @nodelib/fs.scandir to csv/metastep/map_sbom_name_failed_new.csv
# writing @nodelib/fs.stat to csv/metastep/map_sbom_name_failed_new.csv
# writing @nodelib/fs.walk to csv/metastep/map_sbom_name_failed_new.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sinclairzx81/typebox to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sinonjs/fake-timers to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> DefinitelyTyped/DefinitelyTyped to csv/relationships.csv
# writing @types/babel__generator to csv/metastep/map_sbom_name_failed_new.csv
# writing @types/babel__template to csv/metastep/map_sbom_name_failed_new.csv
# writing @types/babel__traverse to csv/metastep/map_sbom_name_failed_new.csv
# writing @types/graceful-fs to csv/metastep/map_sbom_name_failed_new.csv
# writing @types/istanbul-lib-coverage to csv/metastep/map_sbom_name_failed_new.csv
# writing @types/istanbul-lib-report to csv/metastep/map_sbom_name_failed_new.csv
# writing @types/istanbul-reports to csv/metastep/map_sbom_name_failed_new.csv
# writing @types/prettier to csv/metastep/map_sbom_name_failed_new.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> DefinitelyTyped/DefinitelyTyped to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> DefinitelyTyped/DefinitelyTyped to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> npm/abbrev-js to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jshttp/accepts to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> acornjs/acorn to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> acornjs/acorn-jsx to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/ansi-escapes to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> chalk/ansi-regex to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> chalk/ansi-styles to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> chalk/ansi-styles to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> chalk/ansi-styles to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> nodeca/argparse to csv/relationships.csv
# writing array-each to csv/metastep/map_sbom_name_failed_new.csv
# writing array-flatten to csv/metastep/map_sbom_name_failed_new.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/array-slice to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/array-union to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> caolan/async to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jestjs/jest to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> istanbuljs/babel-plugin-istanbul to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jestjs/jest to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> nicolo-ribaudo/babel-preset-current-node-syntax to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jestjs/jest to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> expressjs/body-parser to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> juliangruber/brace-expansion to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> micromatch/braces to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> facebook/watchman to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> LinusU/buffer-from to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> visionmedia/bytes.js to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/callsites to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/camelcase to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/camelcase to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> chalk/chalk to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> chalk/chalk to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> Richienb/char-regex to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> watson/ci-info to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> nodejs/cjs-module-lexer to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> yargs/cliui to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> pvorb/clone to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> tj/co to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> SimenB/collect-v8-coverage to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> Qix-/color-convert to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> Qix-/color-convert to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> colorjs/color-name to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> colorjs/color-name to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> ljharb/concat-map to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jshttp/content-disposition to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jshttp/content-type to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jshttp/cookie to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> tj/node-cookie-signature to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> isaacs/core-util-is to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> moxystudio/node-cross-spawn to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> debug-js/debug to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> debug-js/debug to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> debug-js/debug to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> dmnd/dedent to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> TehShrike/deepmerge to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> dougwilson/nodejs-depd to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> stream-utils/destroy to csv/relationships.csv
# writing detect-file to csv/metastep/map_sbom_name_failed_new.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/detect-newline to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jestjs/jest to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> kevva/dir-glob to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> eslint/doctrine to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonathanong/ee-first to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/emittery to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> mathiasbynens/emoji-regex to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> pillarjs/encodeurl to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> lukeed/escalade to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> component/escape-html to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/escape-string-regexp to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/escape-string-regexp to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/escape-string-regexp to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> eslint/eslint-scope to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jquery/esprima to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> estools/esquery to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> estools/esrecurse to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> estools/estraverse to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jshttp/etag to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/execa to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> cowboy/node-exit to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/expand-tilde to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jestjs/jest to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> expressjs/express to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> justmoon/node-extend to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> epoberezkin/fast-deep-equal to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> epoberezkin/fast-json-stable-stringify to csv/relationships.csv
# writing fast-levenshtein to csv/metastep/map_sbom_name_failed_new.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> facebook/watchman to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jaredwray/file-entry-cache to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/fill-range to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> pillarjs/finalhandler to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/find-up to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/find-up to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jaredwray/flat-cache to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/for-in to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/for-own to csv/relationships.csv
# writing forwarded to csv/metastep/map_sbom_name_failed_new.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jshttp/fresh to csv/relationships.csv
# writing fs.realpath to csv/metastep/map_sbom_name_failed_new.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> fsevents/fsevents to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> loganfsmyth/gensync to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> stefanpenner/get-caller-file to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> cfware/get-package-type to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/get-stream to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> gulpjs/glob-parent to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> gulpjs/glob-parent to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/global-modules to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/global-prefix to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/globals to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/globby to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> tarruda/has to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/has-flag to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/has-flag to csv/relationships.csv
# writing has-symbols to csv/metastep/map_sbom_name_failed_new.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> doowb/homedir-polyfill to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> WebReflection/html-escaper to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jshttp/http-errors to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> ehmicky/human-signals to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> ashtuchkin/iconv-lite to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> kaelzhang/node-ignore to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> novemberborn/ignore-by-default to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/import-local to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jensyt/imurmurhash-js to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> isaacs/inflight-DEPRECATED-DO-NOT-USE to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> isaacs/inherits to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> npm/ini to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> whitequark/ipaddr.js to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/is-absolute to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> Qix-/node-is-arrayish to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> micromatch/is-extglob to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/is-fullwidth-code-point to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/is-generator-fn to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> micromatch/is-glob to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/is-number to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/is-path-inside to csv/relationships.csv
# writing is-plain-object to csv/metastep/map_sbom_name_failed_new.csv
# writing is-relative to csv/metastep/map_sbom_name_failed_new.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/is-stream to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/is-unc-path to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/is-windows to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> juliangruber/isarray to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> isaacs/isexe to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/isobject to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> istanbuljs/istanbuljs to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> istanbuljs/istanbuljs to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> istanbuljs/istanbuljs to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jestjs/jest to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jestjs/jest to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jestjs/jest to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jestjs/jest to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jestjs/jest to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jestjs/jest to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jestjs/jest to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jestjs/jest to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jestjs/jest to csv/relationships.csv
# writing jest-get-type to csv/metastep/map_sbom_name_failed_new.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jestjs/jest to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jestjs/jest to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jestjs/jest to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jestjs/jest to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jestjs/jest to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> arcanis/jest-pnp-resolver to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jestjs/jest to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jestjs/jest to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jestjs/jest to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jestjs/jest to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jestjs/jest to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jestjs/jest to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jestjs/jest to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jestjs/jest to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jestjs/jest to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jestjs/jest to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> lydell/js-tokens to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> nodeca/js-yaml to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> mathiasbynens/jsesc to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> npm/json-parse-even-better-errors to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> epoberezkin/json-schema-traverse to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> samn/json-stable-stringify to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> json5/json5 to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/kind-of to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> lukeed/kleur to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/leven to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> gkz/levn to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/locate-path to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/locate-path to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> lodash/lodash to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> lodash/lodash to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> isaacs/node-lru-cache to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> isaacs/node-lru-cache to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/make-dir to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/make-iterator to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> daaku/nodejs-makeerror to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/map-cache to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jshttp/media-typer to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/merge-descriptors to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> grncdr/merge-stream to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> teambition/merge2 to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jshttp/methods to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> micromatch/micromatch to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> broofa/mime to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/mimic-function to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> isaacs/minimatch to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> isaacs/node-mkdirp to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> vercel/ms to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> vercel/ms to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> vercel/ms to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> litejs/natural-compare-lite to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jshttp/negotiator to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> broofa/node-int64 to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> npm/nopt to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/normalize-path to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/npm-run-path to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/object.defaults to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/object.map to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/object.pick to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jshttp/on-finished to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> isaacs/once to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/onetime to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/os-homedir to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/os-tmpdir to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/p-limit to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/p-limit to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/p-locate to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/p-locate to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/p-try to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/parent-module to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/parse-filepath to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/parse-json to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> doowb/parse-passwd to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> pillarjs/parseurl to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/path-exists to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/path-is-absolute to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> domenic/path-is-inside to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/path-key to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/path-key to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jbgutierrez/path-parse to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/path-root to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> regexhq/path-root-regex to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> pillarjs/path-to-regexp to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/path-type to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> alexeyraspopov/picocolors to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> micromatch/picomatch to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/pify to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> danez/pirates to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/pkg-dir to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> gkz/prelude-ls to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jestjs/jest to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> calvinmetcalf/process-nextick-args to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> terkelg/prompts to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jshttp/proxy-addr to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> remy/pstree to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> ljharb/qs to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> feross/queue-microtask to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jshttp/range-parser to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> stream-utils/raw-body to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> facebook/react to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> nodejs/readable-stream to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/repeat-element to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> troygoode/node-require-directory to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/resolve-cwd to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/resolve-dir to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/resolve-from to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/resolve-from to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> lukeed/resolve.exports to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> fent/ret.js to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> mcollina/reusify to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> isaacs/rimraf to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> isaacs/rimraf to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> feross/run-parallel to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> feross/safe-buffer to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> feross/safe-buffer to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> ChALkeR/safer-buffer to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> pillarjs/send to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> expressjs/serve-static to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> wesleytodd/setprototypeof to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> kevva/shebang-command to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> kevva/shebang-command to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/shebang-regex to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/shebang-regex to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> ljharb/side-channel to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> tapjs/signal-exit to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> terkelg/sisteransi to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/slash to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> mozilla/source-map to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> evanw/node-source-map-support to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> alexei/sprintf.js to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> tapjs/stack-utils to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jshttp/statuses to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/string-length to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/string-width to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> nodejs/string_decoder to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> chalk/strip-ansi to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/strip-bom to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/strip-final-newline to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/strip-json-comments to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> chalk/supports-color to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> chalk/supports-color to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> chalk/supports-color to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jamestalmage/supports-hyperlinks to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> inspect-js/node-supports-preserve-symlinks-flag to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/terminal-link to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> istanbuljs/test-exclude to csv/relationships.csv
# writing text-table to csv/metastep/map_sbom_name_failed_new.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> daaku/nodejs-tmpl to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/to-fast-properties to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> micromatch/to-regex-range to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> component/toidentifier to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> isaacs/node-touch to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> microsoft/tslib to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> ajafff/tsutils to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> gkz/type-check to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> chaijs/type-detect to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/type-fest to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/type-fest to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jshttp/type-is to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> regexhq/unc-path-regex to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> remy/undefsafe to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> stream-utils/unpipe to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> TooTallNate/util-deprecate to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jaredhanson/utils-merge to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jshttp/vary to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> daaku/nodejs-walker to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> npm/node-which to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> npm/node-which to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> chalk/wrap-ansi to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> isaacs/wrappy to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> npm/write-file-atomic to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> npm/write-file-atomic to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> yargs/y18n to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> isaacs/yallist to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> isaacs/yallist to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> yargs/yargs to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> yargs/yargs-parser to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/yocto-queue to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> ampproject/remapping to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jridgewell/gen-mapping to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jridgewell/sourcemap-codec to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sinonjs/commons to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> ajv-validator/ajv to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> micromatch/anymatch to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> nodeca/argparse to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> juliangruber/balanced-match to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> thlorenz/convert-source-map to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> thlorenz/deep-is to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> Qix-/node-error-ex to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> estools/estraverse to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> estools/esutils to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> mcollina/fastq to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/import-fresh to csv/relationships.csv
# writing is-obj to csv/metastep/map_sbom_name_failed_new.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> nodeca/js-yaml to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> eventualbuddha/lines-and-columns to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jshttp/mime-db to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jshttp/mime-types to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> anodynos/upath to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> garycourt/uri-js to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> nexdrew/ansi-align to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> chalk/ansi-regex to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> micromatch/anymatch to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/arr-diff to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/arr-flatten to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/arr-union to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/array-unique to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/assign-symbols to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> paulmillr/async-each to csv/relationships.csv
# writing atob to csv/metastep/map_sbom_name_failed_new.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> base/base to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/binary-extensions to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> TooTallNate/node-bindings to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/boxen to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> micromatch/braces to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/cache-base to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> ljharb/call-bind to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/camelcase to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> paulmillr/chokidar to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> watson/ci-info to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/class-utils to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/cli-boxes to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/collection-visit to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/component-emitter to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> yeoman/configstore to csv/relationships.csv
# writing copy-descriptor to csv/metastep/map_sbom_name_failed_new.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> floatdrop/create-error-class to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> moxystudio/node-cross-spawn to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/crypto-random-string to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> unclechu/node-deep-extend to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/define-property to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/define-property to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/define-property to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/dot-prop to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/execa to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> micromatch/expand-brackets to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/extend-shallow to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/extend-shallow to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> micromatch/extglob to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> TooTallNate/file-uri-to-path to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/fill-range to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/fragment-cache to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> fsevents/fsevents to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> Raynos/function-bind to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/get-stream to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/get-value to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> gulpjs/glob-parent to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/global-directory to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/got to csv/relationships.csv
# writing has-value to csv/metastep/map_sbom_name_failed_new.csv
# ( jagenjo/litegraph.js , has-value ) already in failure record
# writing has-values to csv/metastep/map_sbom_name_failed_new.csv
# ( jagenjo/litegraph.js , has-values ) already in failure record
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/import-lazy to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> inspect-js/is-accessor-descriptor to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> inspect-js/is-accessor-descriptor to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/is-binary-path to csv/relationships.csv
# writing is-buffer to csv/metastep/map_sbom_name_failed_new.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> watson/is-ci to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> inspect-js/is-core-module to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> inspect-js/is-data-descriptor to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> inspect-js/is-data-descriptor to csv/relationships.csv
# writing is-descriptor to csv/metastep/map_sbom_name_failed_new.csv
# ( jagenjo/litegraph.js , is-descriptor ) already in failure record
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/is-extendable to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/is-extendable to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/is-fullwidth-code-point to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> micromatch/is-glob to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/is-installed-globally to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/is-npm to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/is-number to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/is-path-inside to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/is-redirect to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/is-retry-allowed to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/is-stream to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/isobject to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> istanbuljs/istanbuljs to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/kind-of to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/kind-of to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/kind-of to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/latest-version to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/lowercase-keys to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> isaacs/node-lru-cache to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/make-dir to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/map-visit to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> micromatch/micromatch to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> minimistjs/minimist to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/mixin-deep to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> micromatch/nanomatch to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> remy/nodemon to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> npm/nopt to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/normalize-path to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/npm-run-path to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/object-copy to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> inspect-js/object-inspect to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/object-visit to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> npm/osenv to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/p-finally to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/package-json to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/pascalcase to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> gulpjs/path-dirname to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> micromatch/posix-character-classes to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/prepend-http to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> isaacs/pseudomap to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> dominictarr/rc to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> paulmillr/readdirp to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/regex-not to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> rexxars/registry-auth-token to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/registry-url to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> darsain/remove-trailing-separator to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/repeat-string to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> browserify/resolve to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> lydell/resolve-url to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> davisjam/safe-regex to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> npm/node-semver to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> npm/node-semver to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/semver-diff to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/set-value to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> here-be/snapdragon to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> here-be/snapdragon-node to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> here-be/snapdragon-util to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> mozilla/source-map to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> lydell/source-map-resolve to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> lydell/source-map-url to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/split-string to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/static-extend to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/string-width to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> chalk/strip-ansi to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> chalk/strip-ansi to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/strip-final-newline to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/strip-json-comments to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/terminal-size to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/timed-out to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/to-object-path to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/to-regex to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> micromatch/to-regex-range to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/union-value to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/unique-string to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/unset-value to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/decompress-response to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> yeoman/update-notifier to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> lydell/urix to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/url-parse-lax to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/use to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/widest-line to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jonschlinkert/word-wrap to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/xdg-basedir to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> isaacs/yallist to csv/relationships.csv
# writing @types/jest to csv/metastep/map_sbom_name_failed_new.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> DefinitelyTyped/DefinitelyTyped to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> WebReflection/flatted to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> mathiasbynens/punycode.js to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> istanbuljs/v8-to-istanbul to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> humanwhocodes/object-schema to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jridgewell/trace-mapping to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> browserslist/browserslist to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> DefinitelyTyped/DefinitelyTyped to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> chicoxyzzy/node-releases to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> isaacs/node-graceful-fs to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> mrmlnc/fast-glob to csv/relationships.csv
# writing update-browserslist-db to csv/metastep/map_sbom_name_failed_new.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> istanbuljs/istanbuljs to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> chalk/ansi-styles to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> chalk/chalk to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/globals to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> chalk/has-ansi to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> chalk/supports-color to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> SamVerschueren/decode-uri-component to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> eslint/eslintrc to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> humanwhocodes/config-array to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> DefinitelyTyped/DefinitelyTyped to csv/relationships.csv
# writing @types/semver to csv/metastep/map_sbom_name_failed_new.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> eslint/eslint-visitor-keys to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> eslint/js to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> ljharb/get-intrinsic to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> orling/grapheme-splitter to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> gkz/optionator to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> npm/node-semver to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> eslint/eslint-scope to csv/relationships.csv
# writing nan to csv/metastep/map_sbom_name_failed_new.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> alexei/sprintf.js to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> chalk/ansi-regex to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> felixge/node-dateformat to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/duplexer3 to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> isaacs/node-glob to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> gulpjs/v8flags to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> gulpjs/findup-sync to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> jest-community/eslint-plugin-jest to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> gulpjs/rechoir to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> gulpjs/replace-ext to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> isaacs/minimatch to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> npm/nopt to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> Marak/colors.js to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> EventEmitter2/EventEmitter2 to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> gulpjs/fined to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> gulpjs/flagged-respawn to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> cowboy/node-getobject to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> gruntjs/grunt-cli to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> gruntjs/grunt-known-options to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> gruntjs/grunt-legacy-log to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> gruntjs/grunt-legacy-log-utils to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> gruntjs/grunt-legacy-util to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> cowboy/javascript-hooker to csv/relationships.csv
# writing interpret to csv/metastep/map_sbom_name_failed_new.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> gruntjs/js-liftup to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> esamattis/underscore.string to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> isaacs/node-glob to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> eslint/eslint to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> eslint/eslint to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> gulpjs/clone-buffer to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> hughsk/clone-stats to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> mcollina/cloneable-readable to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> gulpjs/vinyl to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> ZLY201/js-sdsl to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> eslint-community/regexpp to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> microsoft/TypeScript to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> gulp-sourcemaps/vinyl-sourcemaps-apply to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> sindresorhus/capture-stack-trace to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> typescript-eslint/typescript-eslint to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> typescript-eslint/typescript-eslint to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> typescript-eslint/typescript-eslint to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> eslint-community/eslint-utils to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> gruntjs/grunt to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> gulpjs/findup-sync to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> gruntjs/grunt-contrib-concat to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> typescript-eslint/typescript-eslint to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> Kilian/electron-to-chromium to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> browserslist/caniuse-lite to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> typescript-eslint/typescript-eslint to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> google/closure-compiler-npm to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> thanpolas/grunt-closure-tools to csv/relationships.csv
# writing jagenjo/litegraph.js - DEPENDS_ON -> thanpolas/task-closure-tools to csv/relationships.csv
# Dealing with # 658 of records done.

# %%
target_repos
# Out:
# ['comfyanonymous/ComfyUI',
#  'FlowiseAI/Flowise',
#  'jagenjo/litegraph.js',
#  'biolab/orange3',
#  'jerosoler/Drawflow',
#  'chaiNNer-org/chaiNNer',
#  'samuelmtimbo/unit',
#  'Ironclad/rivet',
#  'wonderworks-software/PyFlow',
#  'ianarawjo/ChainForge',
#  'flydelabs/flyde',
#  'laudspeaker/laudspeaker',
#  'google/visualblocks',
#  'enso-org/enso',
#  'GraphiteEditor/Graphite',
#  'node-red/node-red',
#  'JacquesLucke/animation_nodes',
#  'Nelarius/imnodes']

# %%
dependency_file_suffix = "-dependencies.json"

# split by "/" and lower the case
for full_repo_name in target_repos:
    name = full_repo_name.split("/")[1]
    name = name.lower()
    
    dep_filename = "raw/" + name + dependency_file_suffix
    
    step1 = get_relationship_from_sbom_file(full_repo_name, dep_filename)
    if step1 is None:
        print("************** skipping", full_repo_name, "*************")
        continue
    step2 = map_sbom_name_2_repo_full_name(full_repo_name, step1)
    print("**************", full_repo_name, "is done*************")
# Out:
# writing pillow to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( comfyanonymous/ComfyUI , pillow , pypi )
# writing scipy to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( comfyanonymous/ComfyUI , scipy , pypi )
# writing pyyaml to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( comfyanonymous/ComfyUI , pyyaml , pypi )
# writing tqdm to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( comfyanonymous/ComfyUI , tqdm , pypi )
# writing torch to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( comfyanonymous/ComfyUI , torch , pypi )
# writing torchvision to csv/metastep/map_sbom_name_failed_new.csv
# writing aiohttp to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( comfyanonymous/ComfyUI , aiohttp , pypi )
# writing einops to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( comfyanonymous/ComfyUI , einops , pypi )
# writing psutil to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( comfyanonymous/ComfyUI , psutil , pypi )
# writing soundfile to csv/metastep/map_sbom_name_failed_new.csv
# writing sentencepiece to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( comfyanonymous/ComfyUI , sentencepiece , pypi )
# writing torchaudio to csv/metastep/map_sbom_name_failed_new.csv
# writing torchsde to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( comfyanonymous/ComfyUI , torchsde , pypi )
# writing transformers to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( comfyanonymous/ComfyUI , transformers , pypi )
# writing tokenizers to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( comfyanonymous/ComfyUI , tokenizers , pypi )
# writing kornia to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( comfyanonymous/ComfyUI , kornia , pypi )
# writing spandrel to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( comfyanonymous/ComfyUI , spandrel , pypi )
# writing safetensors to csv/metastep/map_sbom_name_failed_new.csv
# writing pytest-asyncio to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( comfyanonymous/ComfyUI , pytest-asyncio , pypi )
# writing pytest-aiohttp to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( comfyanonymous/ComfyUI , pytest-aiohttp , pypi )
# writing pytest to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( comfyanonymous/ComfyUI , pytest , pypi )
# writing actions/github-script to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( comfyanonymous/ComfyUI , actions/github-script , githubactions )
# writing comfy-org/comfy-action to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( comfyanonymous/ComfyUI , comfy-org/comfy-action , githubactions )
# writing actions/checkout to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( comfyanonymous/ComfyUI , actions/checkout , githubactions )
# writing actions/setup-python to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( comfyanonymous/ComfyUI , actions/setup-python , githubactions )
# writing actions/cache/restore to csv/metastep/map_sbom_name_failed_new.csv
# writing svenstaro/upload-release-action to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( comfyanonymous/ComfyUI , svenstaro/upload-release-action , githubactions )
# writing actions/stale to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( comfyanonymous/ComfyUI , actions/stale , githubactions )
# ( comfyanonymous/ComfyUI , actions/checkout ) already in failure record
# package manager not match ( comfyanonymous/ComfyUI , actions/checkout , githubactions )
# ( comfyanonymous/ComfyUI , actions/setup-python ) already in failure record
# package manager not match ( comfyanonymous/ComfyUI , actions/setup-python , githubactions )
# writing actions/upload-artifact to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( comfyanonymous/ComfyUI , actions/upload-artifact , githubactions )
# ( comfyanonymous/ComfyUI , actions/setup-python ) already in failure record
# package manager not match ( comfyanonymous/ComfyUI , actions/setup-python , githubactions )
# ( comfyanonymous/ComfyUI , actions/setup-python ) already in failure record
# package manager not match ( comfyanonymous/ComfyUI , actions/setup-python , githubactions )
# writing actions/cache/save to csv/metastep/map_sbom_name_failed_new.csv
# writing com.github.comfyanonymous/ComfyUI to csv/metastep/map_sbom_name_failed_new.csv
# Dealing with # 35 of records done.
# ************** comfyanonymous/ComfyUI is done*************
# writing FlowiseAI/Flowise - DEPENDS_ON -> gilamran/tsc-watch to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> DefinitelyTyped/DefinitelyTyped to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> scottie1984/swagger-ui-express to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> Surnet/swagger-jsdoc to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> DefinitelyTyped/DefinitelyTyped to csv/relationships.csv
# writing @types/node-fetch to csv/metastep/map_sbom_name_failed_new.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> colinhacks/zod to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> expressjs/express to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> form-data/form-data to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> html-to-text/node-html-to-text to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> lodash/lodash to csv/relationships.csv
# writing @types/object-hash to csv/metastep/map_sbom_name_failed_new.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> puleos/object-hash to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> axios/axios to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> DefinitelyTyped/DefinitelyTyped to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> jsdom/jsdom to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> isaacs/rimraf to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> crosstype/node-html-markdown to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> redis/ioredis to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> motdotla/dotenv to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> graphql/graphql-js to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> brix/crypto-js to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> microsoft/tslib to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> moment/moment to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> gulpjs/gulp to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> socketio/socket.io to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> winstonjs/winston to csv/relationships.csv
# writing @types/jsdom to csv/metastep/map_sbom_name_failed_new.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> Starcounter-Jack/JSON-Patch to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> cheeriojs/cheerio to csv/relationships.csv
# writing @types/ws to csv/metastep/map_sbom_name_failed_new.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> redis/node-redis to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> parshap/node-sanitize-filename to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> node-fetch/node-fetch to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing @types/crypto-js to csv/metastep/map_sbom_name_failed_new.csv
# writing pdf-parse to csv/metastep/map_sbom_name_failed_new.csv
# writing @types/js-yaml to csv/metastep/map_sbom_name_failed_new.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> brianc/node-postgres to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> elastic/elasticsearch-js to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> dqbd/tiktoken to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> StefanTerdell/zod-to-json-schema to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> nfrasser/linkifyjs to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> mwilliamson/mammoth.js to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> momentohq/client-sdk-javascript to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> typeorm/typeorm to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> fb55/css-what to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> upstash/redis-js to csv/relationships.csv
# writing @types/gulp to csv/metastep/map_sbom_name_failed_new.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> opensearch-project/opensearch-js to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> huggingface/huggingface.js to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> aws/aws-sdk-js-v3 to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> websockets/ws to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> microsoft/playwright to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> 1c7/srt-parser-2 to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> mozilla/pdfjs-dist to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> d3/d3-dsv to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> aws/aws-sdk-js-v3 to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> janl/node-jsonpointer to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> puppeteer/puppeteer to csv/relationships.csv
# writing apify-client to csv/metastep/map_sbom_name_failed_new.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> aws/aws-sdk-js-v3 to csv/relationships.csv
# writing @notionhq/client to csv/metastep/map_sbom_name_failed_new.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> supabase/supabase-js to csv/relationships.csv
# writing @zilliz/milvus2-sdk-node to csv/metastep/map_sbom_name_failed_new.csv
# writing chromadb to csv/metastep/map_sbom_name_failed_new.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> souvikinator/notion-to-md to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> pyodide/pyodide to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> weaviate/typescript-client to csv/relationships.csv
# writing faiss-node to csv/metastep/map_sbom_name_failed_new.csv
# writing @types/lodash to csv/metastep/map_sbom_name_failed_new.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> mongodb/node-mongodb-native to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> swc-project/swc to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> getzep/zep-js to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> momentohq/client-sdk-javascript to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> googleapis/google-auth-library-nodejs to csv/relationships.csv
# writing exa-js to csv/metastep/map_sbom_name_failed_new.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> AssemblyAI/assemblyai-node-sdk to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> cohere-ai/cohere-typescript to csv/relationships.csv
# writing @langchain/pinecone to csv/metastep/map_sbom_name_failed_new.csv
# writing @langchain/weaviate to csv/metastep/map_sbom_name_failed_new.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> langchain-ai/langsmith-sdk to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> microsoft/TypeScript to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> sidorares/node-mysql2 to csv/relationships.csv
# writing @langchain/mongodb to csv/metastep/map_sbom_name_failed_new.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> mistralai/client-ts to csv/relationships.csv
# writing langfuse to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( FlowiseAI/Flowise , langfuse , npm )
# writing langfuse-langchain to csv/metastep/map_sbom_name_failed_new.csv
# writing @langchain/groq to csv/metastep/map_sbom_name_failed_new.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> langchain-ai/langchainjs to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> qdrant/qdrant-js to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> e2b-dev/code-interpreter to csv/relationships.csv
# writing @langchain/openai to csv/metastep/map_sbom_name_failed_new.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> googleapis/google-cloud-node to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> run-llama/LlamaIndexTS to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> langchain-ai/langchainjs to csv/relationships.csv
# writing @langchain/qdrant to csv/metastep/map_sbom_name_failed_new.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> pinecone-io/pinecone-ts-client to csv/relationships.csv
# writing @langchain/langgraph to csv/metastep/map_sbom_name_failed_new.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> langchain-ai/langchainjs to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> mendableai/firecrawl to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> langwatch/langwatch to csv/relationships.csv
# writing @langchain/google-vertexai to csv/metastep/map_sbom_name_failed_new.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> meilisearch/meilisearch-js to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> langchain-ai/langchainjs to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> mikeal/replicate to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> getzep/zep-js to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> google-gemini/generative-ai-js to csv/relationships.csv
# writing @langchain/google-genai to csv/metastep/map_sbom_name_failed_new.csv
# writing @langchain/mistralai to csv/metastep/map_sbom_name_failed_new.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> langchain-ai/langchainjs to csv/relationships.csv
# writing @langchain/ollama to csv/metastep/map_sbom_name_failed_new.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> upstash/vector-js to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> langchain-ai/langchainjs to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> APIDevTools/json-schema-ref-parser to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> langchain-ai/langchainjs to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> couchbase/couchnode to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> openai/openai-node to csv/relationships.csv
# writing @flowiseai/nodevm to csv/metastep/map_sbom_name_failed_new.csv
# writing @datastax/astra-db-ts to csv/metastep/map_sbom_name_failed_new.csv
# writing lunary to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( FlowiseAI/Flowise , lunary , npm )
# writing FlowiseAI/Flowise - DEPENDS_ON -> jshttp/content-disposition to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> TryGhost/node-sqlite3 to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> rbuckton/reflect-metadata to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> expressjs/cors to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> jshttp/http-errors to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> uuidjs/uuid to csv/relationships.csv
# writing @types/content-disposition to csv/metastep/map_sbom_name_failed_new.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> apostrophecms/sanitize-html to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> expressjs/multer to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> moment/moment-timezone to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> prettymuchbryce/http-status-codes to csv/relationships.csv
# writing @types/uuid to csv/metastep/map_sbom_name_failed_new.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> open-cli-tools/concurrently to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> DirtyHairy/async-mutex to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> remy/nodemon to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> TypeStrong/ts-node to csv/relationships.csv
# writing @types/multer to csv/metastep/map_sbom_name_failed_new.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> DefinitelyTyped/DefinitelyTyped to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> shelljs/shx to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> charlesguse/run-script-os to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> oclif/oclif to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> open-telemetry/opentelemetry-js-api to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> LionC/express-basic-auth to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> brianc/node-postgres to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> gajus/global-agent to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> express-rate-limit/express-rate-limit to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> oclif/core to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> bahmutov/start-server-and-test to csv/relationships.csv
# writing @types/sanitize-html to csv/metastep/map_sbom_name_failed_new.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> PostHog/posthog-node to csv/relationships.csv
# writing langchainhub to csv/metastep/map_sbom_name_failed_new.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> siimon/prom-client to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> cypress-io/cypress to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> open-telemetry/opentelemetry-js to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> open-telemetry/opentelemetry-js to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> open-telemetry/opentelemetry-js to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> open-telemetry/opentelemetry-js to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> open-telemetry/opentelemetry-js to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> open-telemetry/opentelemetry-js to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> open-telemetry/opentelemetry-js to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> open-telemetry/opentelemetry-js to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> open-telemetry/opentelemetry-js to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> open-telemetry/opentelemetry-js to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> open-telemetry/opentelemetry-js to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> open-telemetry/opentelemetry-js to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> open-telemetry/opentelemetry-js-contrib to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> facebook/create-react-app to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> remarkjs/remark-gfm to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> facebook/react to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> facebook/react to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> testing-library/user-event to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> emotion-js/emotion to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> Hacker0x01/react-datepicker to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> reduxjs/react-redux to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> testing-library/react-testing-library to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> emotion-js/emotion to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> reduxjs/redux to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> remarkjs/react-markdown to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> react-syntax-highlighter/react-syntax-highlighter to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> facebook/prop-types to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> prettier/pretty-quick to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> remix-run/history to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> casesandberg/react-color to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> lukeed/clsx to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> sass/dart-sass to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> goldenyz/react-perfect-scrollbar to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> codemirror/lang-javascript to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> codemirror/lang-json to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> jaredpalmer/formik to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> jquense/yup to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> xyflow/xyflow to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> remarkjs/remark-math to csv/relationships.csv
# writing react-code-blocks to csv/metastep/map_sbom_name_failed_new.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> iamhosseindhv/notistack to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> rehypejs/rehype-raw to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> socketio/socket.io-client to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> remarkablemark/html-react-parser to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> duskload/react-device-detect to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> mui/mui-x to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> testing-library/jest-dom to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> Azure/fetch-event-source to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> framer/motion to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> remarkjs/remark-math to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> emotion-js/emotion to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> remix-run/react-router to csv/relationships.csv
# writing flowise-embed to csv/metastep/map_sbom_name_failed_new.csv
# writing flowise-embed-react to csv/metastep/map_sbom_name_failed_new.csv
# writing flowise-react-json-view to csv/metastep/map_sbom_name_failed_new.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> remix-run/react-router to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> mui/material-ui to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> dravenww/vite-plugin-react-js-support to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> vitejs/vite to csv/relationships.csv
# writing @mui/material to csv/metastep/map_sbom_name_failed_new.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> uiwjs/react-codemirror to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> vitejs/vite to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> codemirror/view to csv/relationships.csv
# writing @mui/lab to csv/metastep/map_sbom_name_failed_new.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> vite-pwa/vite-plugin-pwa to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> uiwjs/react-codemirror to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> uiwjs/react-codemirror to csv/relationships.csv
# writing @mui/base to csv/metastep/map_sbom_name_failed_new.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> tabler/tabler-icons to csv/relationships.csv
# writing actions/checkout to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( FlowiseAI/Flowise , actions/checkout , githubactions )
# writing peter-evans/repository-dispatch to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( FlowiseAI/Flowise , peter-evans/repository-dispatch , githubactions )
# ( FlowiseAI/Flowise , actions/checkout ) already in failure record
# package manager not match ( FlowiseAI/Flowise , actions/checkout , githubactions )
# ( FlowiseAI/Flowise , actions/checkout ) already in failure record
# package manager not match ( FlowiseAI/Flowise , actions/checkout , githubactions )
# writing docker/setup-buildx-action to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( FlowiseAI/Flowise , docker/setup-buildx-action , githubactions )
# writing docker/setup-qemu-action to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( FlowiseAI/Flowise , docker/setup-qemu-action , githubactions )
# writing docker/login-action to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( FlowiseAI/Flowise , docker/login-action , githubactions )
# writing docker/build-push-action to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( FlowiseAI/Flowise , docker/build-push-action , githubactions )
# writing actions/setup-node to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( FlowiseAI/Flowise , actions/setup-node , githubactions )
# writing pnpm/action-setup to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( FlowiseAI/Flowise , pnpm/action-setup , githubactions )
# writing cypress-io/github-action to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( FlowiseAI/Flowise , cypress-io/github-action , githubactions )
# ( FlowiseAI/Flowise , actions/checkout ) already in failure record
# package manager not match ( FlowiseAI/Flowise , actions/checkout , githubactions )
# writing FlowiseAI/Flowise - DEPENDS_ON -> aashutoshrathi/word-wrap to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> babel/babel to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> babel/preset-modules to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> bnjmnt4n/regjsgen to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> demurgos/v8-coverage to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> codemirror/lang-json to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> cspotcode/node-source-map-support to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> emotion-js/emotion to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> emotion-js/emotion to csv/relationships.csv
# writing @esbuild/linux-x64 to csv/metastep/map_sbom_name_failed_new.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> eslint-community/eslint-utils to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> hapijs/hoek to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> hapijs/topo to csv/relationships.csv
# writing @humanwhocodes/module-importer to csv/metastep/map_sbom_name_failed_new.csv
# writing @isaacs/cliui to csv/metastep/map_sbom_name_failed_new.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> istanbuljs/load-nyc-config to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> istanbuljs/schema to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> jestjs/jest to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> jestjs/jest to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> jestjs/jest to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> jestjs/jest to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> jestjs/jest to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> jestjs/jest to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> jestjs/jest to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> jestjs/jest to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> jridgewell/trace-mapping to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> dnsquery/ip-codec to csv/relationships.csv
# writing @nodelib/fs.scandir to csv/metastep/map_sbom_name_failed_new.csv
# writing @nodelib/fs.stat to csv/metastep/map_sbom_name_failed_new.csv
# writing @nodelib/fs.walk to csv/metastep/map_sbom_name_failed_new.csv
# writing @puppeteer/browsers to csv/metastep/map_sbom_name_failed_new.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> rollup/plugins to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> hapijs/formula to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> hapijs/pinpoint to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> sinclairzx81/typebox to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> sinclairzx81/typebox to csv/relationships.csv
# writing @swc/types to csv/metastep/map_sbom_name_failed_new.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> TooTallNate/once to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> TooTallNate/once to csv/relationships.csv
# writing @tootallnate/quickjs-emscripten to csv/metastep/map_sbom_name_failed_new.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> tsconfig/bases to csv/relationships.csv
# writing @types/cookie to csv/metastep/map_sbom_name_failed_new.csv
# writing @types/estree to csv/metastep/map_sbom_name_failed_new.csv
# writing @types/html-minifier-terser to csv/metastep/map_sbom_name_failed_new.csv
# writing @types/json5 to csv/metastep/map_sbom_name_failed_new.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> DefinitelyTyped/DefinitelyTyped to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> typescript-eslint/typescript-eslint to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> typescript-eslint/typescript-eslint to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> typescript-eslint/typescript-eslint to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> typescript-eslint/typescript-eslint to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> typescript-eslint/typescript-eslint to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> ungap/structured-clone to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> xtuc/webassemblyjs to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> xtuc/webassemblyjs to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> xtuc/webassemblyjs to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> xtuc/webassemblyjs to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> xtuc/webassemblyjs to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> xtuc/webassemblyjs to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> xtuc/webassemblyjs to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> xtuc/webassemblyjs to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> xtuc/webassemblyjs to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> xtuc/webassemblyjs to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> xtuc/webassemblyjs to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> xtuc/webassemblyjs to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> xtuc/webassemblyjs to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> xtuc/webassemblyjs to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> xtuc/webassemblyjs to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> xmldom/xmldom to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> feross/ieee754 to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> dcodeIO/long.js to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> jsdom/abab to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> npm/abbrev-js to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> jshttp/accepts to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> acornjs/acorn to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> ForbesLindesay/acorn-globals to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> xtuc/acorn-import-attributes to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> acornjs/acorn-jsx to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> acornjs/acorn to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> node-modules/address to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> TooTallNate/node-agent-base to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> TooTallNate/node-agent-base to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> sindresorhus/aggregate-error to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> ajv-validator/ajv-formats to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> ajv-validator/ajv-keywords to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> ajv-validator/ajv-keywords to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> doowb/ansi-colors to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> sindresorhus/ansi-escapes to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> mahdyar/ansi-html-community to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> chalk/ansi-regex to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> chalk/ansi-regex to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> chalk/ansi-styles to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> chalk/ansi-styles to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> chalk/ansi-styles to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> chalk/ansi-styles to csv/relationships.csv
# writing archy to csv/metastep/map_sbom_name_failed_new.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> vercel/arg to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> nodeca/argparse to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> A11yance/aria-query to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> A11yance/aria-query to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> sindresorhus/array-differ to csv/relationships.csv
# writing array-each to csv/metastep/map_sbom_name_failed_new.csv
# writing array-flatten to csv/metastep/map_sbom_name_failed_new.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> es-shims/array-includes to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> jonschlinkert/array-slice to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> sindresorhus/array-union to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> es-shims/Array.prototype.flat to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> es-shims/Array.prototype.flatMap to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> sindresorhus/arrify to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> kriskowal/asap to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> benjamn/ast-types to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> kevva/astral-regex to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> ljharb/AsyncIterator.prototype to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> alexindigo/asynckit to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> istanbuljs/babel-plugin-istanbul to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> kentcdodds/babel-plugin-macros to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> nicolo-ribaudo/babel-preset-current-node-syntax to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> wooorm/bail to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> beatgammit/base64-js to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> visionmedia/batch to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> MikeMcl/big.js to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> rvagg/bl to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> fb55/boolbase to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> joeferner/node-bplist-parser to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> juliangruber/brace-expansion to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> juliangruber/brace-expansion to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> micromatch/braces to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> facebook/watchman to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> feross/buffer to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> feross/buffer to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> brianloveswords/buffer-crc32 to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> salesforce/buffer-equal-constant-time to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> LinusU/buffer-from to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> sindresorhus/builtin-modules to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> sindresorhus/bundle-name to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> visionmedia/bytes.js to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> visionmedia/bytes.js to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> sindresorhus/callsites to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> blakeembrey/change-case to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> sindresorhus/camelcase to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> sindresorhus/camelcase to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> Urthen/case-sensitive-paths-webpack-plugin to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> wooorm/ccount to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> chalk/chalk to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> chalk/chalk to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> chalk/chalk to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> Richienb/char-regex to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> Richienb/char-regex to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> wooorm/character-entities to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> wooorm/character-entities to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> wooorm/character-entities-legacy to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> wooorm/character-reference-invalid to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> runk/node-chardet to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> isaacs/chownr to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> isaacs/chownr to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> samccone/chrome-trace-event to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> GoogleChromeLabs/chromium-bidi to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> sindresorhus/clean-stack to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> sindresorhus/cli-cursor to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> sindresorhus/cli-cursor to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> knownasilya/cli-width to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> yargs/cliui to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> yargs/cliui to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> pvorb/clone to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> pvorb/clone to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> lukeed/clsx to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> tj/co to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> Qix-/color-convert to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> Qix-/color-convert to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> colorjs/color-name to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> colorjs/color-name to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> omgovich/colord to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> jorgebucaran/colorette to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> felixge/node-combined-stream to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> wooorm/comma-separated-tokens to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> wooorm/comma-separated-tokens to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> tj/commander.js to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> tj/commander.js to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> tj/commander.js to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> tj/commander.js to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> tj/commander.js to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> tj/commander.js to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> novemberborn/common-path-prefix to csv/relationships.csv
# writing commondir to csv/metastep/map_sbom_name_failed_new.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> jshttp/compressible to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> expressjs/compression to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> ljharb/concat-map to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> max-mapper/concat-stream to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> bripkens/connect-history-api-fallback to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> thlorenz/convert-source-map to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> jshttp/cookie to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> jshttp/cookie to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> tj/node-cookie-signature to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> isaacs/core-util-is to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> cosmiconfig/cosmiconfig to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> cosmiconfig/cosmiconfig to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> cosmiconfig/cosmiconfig to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> unjs/create-require to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> lquixada/cross-fetch to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> moxystudio/node-cross-spawn to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> sindresorhus/crypto-random-string to csv/relationships.csv
# writing css-color-keywords to csv/metastep/map_sbom_name_failed_new.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> fb55/css-select to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> csstree/csstree to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> fb55/css-what to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> mathiasbynens/CSS.escape to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> mathiasbynens/cssesc to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> NV/CSSOM to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> NV/CSSOM to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> jsdom/cssstyle to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> d3/d3-color to csv/relationships.csv
# writing d3-drag to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( FlowiseAI/Flowise , d3-drag , npm )
# writing FlowiseAI/Flowise - DEPENDS_ON -> d3/d3-interpolate to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> d3/d3-selection to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> d3/d3-transition to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> d3/d3-zoom to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> tad-lispy/node-damerau-levenshtein to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> jsdom/data-urls to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> debug-js/debug to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> debug-js/debug to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> debug-js/debug to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> sindresorhus/decamelize to csv/relationships.csv
# writing FlowiseAI/Flowise - DEPENDS_ON -> MikeMcl/decimal.js to csv/relationships.csv
# ...
# ( GraphiteEditor/Graphite , hyper-util ) already in failure record
# ( GraphiteEditor/Graphite , serde_json ) already in failure record
# writing pest to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( GraphiteEditor/Graphite , pest , cargo )
# writing pest_derive to csv/metastep/map_sbom_name_failed_new.csv
# writing pest_generator to csv/metastep/map_sbom_name_failed_new.csv
# writing pest_meta to csv/metastep/map_sbom_name_failed_new.csv
# ( GraphiteEditor/Graphite , ttf-parser ) already in failure record
# package manager not match ( GraphiteEditor/Graphite , ttf-parser , cargo )
# ( GraphiteEditor/Graphite , owned_ttf_parser ) already in failure record
# ( GraphiteEditor/Graphite , rustls-webpki ) already in failure record
# ( GraphiteEditor/Graphite , ab_glyph ) already in failure record
# ( GraphiteEditor/Graphite , serde_derive ) already in failure record
# ( GraphiteEditor/Graphite , serde ) already in failure record
# package manager not match ( GraphiteEditor/Graphite , serde , cargo )
# ( GraphiteEditor/Graphite , rustls ) already in failure record
# package manager not match ( GraphiteEditor/Graphite , rustls , cargo )
# ( GraphiteEditor/Graphite , specta ) already in failure record
# ( GraphiteEditor/Graphite , specta-macros ) already in failure record
# ( GraphiteEditor/Graphite , bytes ) already in failure record
# package manager not match ( GraphiteEditor/Graphite , bytes , cargo )
# ( GraphiteEditor/Graphite , security-framework-sys ) already in failure record
# ( GraphiteEditor/Graphite , redox_syscall ) already in failure record
# ( GraphiteEditor/Graphite , tokio ) already in failure record
# package manager not match ( GraphiteEditor/Graphite , tokio , cargo )
# ( GraphiteEditor/Graphite , wayland-backend ) already in failure record
# ( GraphiteEditor/Graphite , wayland-client ) already in failure record
# ( GraphiteEditor/Graphite , wayland-cursor ) already in failure record
# ( GraphiteEditor/Graphite , wayland-scanner ) already in failure record
# ( GraphiteEditor/Graphite , wayland-sys ) already in failure record
# package manager not match ( GraphiteEditor/Graphite , wayland-sys , cargo )
# ( GraphiteEditor/Graphite , vello ) already in failure record
# package manager not match ( GraphiteEditor/Graphite , vello , cargo )
# ( GraphiteEditor/Graphite , vello_encoding ) already in failure record
# ( GraphiteEditor/Graphite , vello_shaders ) already in failure record
# ( GraphiteEditor/Graphite , thiserror-impl ) already in failure record
# ( GraphiteEditor/Graphite , thiserror ) already in failure record
# package manager not match ( GraphiteEditor/Graphite , thiserror , cargo )
# ( GraphiteEditor/Graphite , xcursor ) already in failure record
# ( GraphiteEditor/Graphite , cc ) already in failure record
# package manager not match ( GraphiteEditor/Graphite , cc , cargo )
# ( GraphiteEditor/Graphite , arrayref ) already in failure record
# package manager not match ( GraphiteEditor/Graphite , arrayref , cargo )
# ( GraphiteEditor/Graphite , syn ) already in failure record
# package manager not match ( GraphiteEditor/Graphite , syn , cargo )
# ( GraphiteEditor/Graphite , quinn-udp ) already in failure record
# writing cloudflare/pages-action to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( GraphiteEditor/Graphite , cloudflare/pages-action , githubactions )
# writing actions/checkout to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( GraphiteEditor/Graphite , actions/checkout , githubactions )
# writing actions/setup-node to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( GraphiteEditor/Graphite , actions/setup-node , githubactions )
# writing EmbarkStudios/cargo-deny-action to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( GraphiteEditor/Graphite , EmbarkStudios/cargo-deny-action , githubactions )
# writing actions/github-script to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( GraphiteEditor/Graphite , actions/github-script , githubactions )
# writing actions-rs/toolchain to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( GraphiteEditor/Graphite , actions-rs/toolchain , githubactions )
# writing actions/cache to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( GraphiteEditor/Graphite , actions/cache , githubactions )
# writing mozilla-actions/sccache-action to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( GraphiteEditor/Graphite , mozilla-actions/sccache-action , githubactions )
# writing actions/cache/restore to csv/metastep/map_sbom_name_failed_new.csv
# writing actions/cache/save to csv/metastep/map_sbom_name_failed_new.csv
# writing dorny/paths-filter to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( GraphiteEditor/Graphite , dorny/paths-filter , githubactions )
# writing taiki-e/install-action to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( GraphiteEditor/Graphite , taiki-e/install-action , githubactions )
# writing com.github.GraphiteEditor/Graphite to csv/metastep/map_sbom_name_failed_new.csv
# Dealing with # 1442 of records done.
# ************** GraphiteEditor/Graphite is done*************
# writing node-red/node-red - DEPENDS_ON -> pvorb/clone to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> form-data/form-data to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> TooTallNate/proxy-agents to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> ashtuchkin/iconv-lite to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> nodeca/js-yaml to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> broofa/mime to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> janl/mustache.js to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> jshttp/on-headers to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> uuidjs/uuid to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> jshttp/content-type to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> jshttp/basic-auth to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> expressjs/cors to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> wayfind/is-utf8 to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> moll/json-stringify-safe to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> npm/nopt to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> Leonidas-from-XIV/node-xml2js to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> invertase/denque to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> mishoo/UglifyJS to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> ladjs/supertest to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> expressjs/multer to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> markedjs/marked to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> bevacqua/hash-sum to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> sass/dart-sass to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> dcodeIO/bcrypt.js to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> sindresorhus/got to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> lodash/lodash to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> cheeriojs/cheerio to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> gruntjs/grunt to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> delvedor/hpagent to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> mochajs/mocha to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> i18next/i18next to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> shouldjs/should.js to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> jshttp/media-typer to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> hunterloftis/stoppable to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> yuanchuan/node-watch to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> jaredhanson/passport-http-bearer to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> gruntjs/grunt-contrib-compress to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> gruntjs/grunt-contrib-copy to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> gruntjs/grunt-contrib-uglify to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> i18next/i18next-http-backend to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> jaredhanson/passport-oauth2-client-password to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> sinonjs/sinon to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> gruntjs/grunt-contrib-clean to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> gruntjs/grunt-contrib-watch to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> gruntjs/grunt-contrib-concat to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> gruntjs/grunt-contrib-jshint to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> nijikokun/minami to csv/relationships.csv
# writing grunt-concurrent to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( node-red/node-red , grunt-concurrent , npm )
# writing node-red/node-red - DEPENDS_ON -> roccomuso/memorystore to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> yaymukund/grunt-simple-mocha to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> jaclarke/cronosjs to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> sindresorhus/grunt-sass to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> TooTallNate/proxy to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> JamesMGreene/grunt-chmod to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> krampstudio/grunt-jsdoc to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> jaredhanson/oauth2orize to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> i18next/jquery-i18next to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> tandrewnichols/grunt-simple-nyc to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> jsdoc2md/grunt-jsdoc-to-markdown to csv/relationships.csv
# writing grunt-mkdir to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( node-red/node-red , grunt-mkdir , npm )
# writing node-red/node-red - DEPENDS_ON -> unindented/grunt-npm-command to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> stream-utils/raw-body to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> moment/moment to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> jprichardson/node-fs-extra to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> jaredhanson/passport to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> node-red/node-red-node-test-helper to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> davidmarkclements/rfdc to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> expressjs/session to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> DirtyHairy/async-mutex to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> expressjs/cookie-parser to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> brandonramirez/grunt-jsonlint to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> jsonata-js/jsonata to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> mqttjs/MQTT.js to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> websockets/ws to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> acornjs/acorn to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> salesforce/tough-cookie to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> ajv-validator/ajv to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> npm/node-semver to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> gruntjs/grunt-cli to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> isaacs/node-tar to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> acornjs/acorn to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> expressjs/body-parser to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> expressjs/express to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> node-red/node-red-admin to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> remy/nodemon to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> cure53/DOMPurify to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> mermaid-js/mermaid to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> moment/moment-timezone to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> jshttp/cookie to csv/relationships.csv
# writing node-red/node-red - DEPENDS_ON -> node-red/node-red-nodes to csv/relationships.csv
# writing cowsay2 to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( node-red/node-red , cowsay2 , npm )
# writing actions/checkout to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( node-red/node-red , actions/checkout , githubactions )
# writing actions/setup-node to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( node-red/node-red , actions/setup-node , githubactions )
# writing peter-evans/create-pull-request to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( node-red/node-red , peter-evans/create-pull-request , githubactions )
# ( node-red/node-red , actions/checkout ) already in failure record
# package manager not match ( node-red/node-red , actions/checkout , githubactions )
# ( node-red/node-red , actions/setup-node ) already in failure record
# package manager not match ( node-red/node-red , actions/setup-node , githubactions )
# writing com.github.node-red/node-red to csv/metastep/map_sbom_name_failed_new.csv
# Dealing with # 97 of records done.
# ************** node-red/node-red is done*************
# writing actions/upload-artifact to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( JacquesLucke/animation_nodes , actions/upload-artifact , githubactions )
# writing actions/checkout to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( JacquesLucke/animation_nodes , actions/checkout , githubactions )
# writing actions/setup-python to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( JacquesLucke/animation_nodes , actions/setup-python , githubactions )
# writing ilammy/msvc-dev-cmd to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( JacquesLucke/animation_nodes , ilammy/msvc-dev-cmd , githubactions )
# writing svenstaro/upload-release-action to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( JacquesLucke/animation_nodes , svenstaro/upload-release-action , githubactions )
# writing actions/download-artifact to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( JacquesLucke/animation_nodes , actions/download-artifact , githubactions )
# writing com.github.JacquesLucke/animation_nodes to csv/metastep/map_sbom_name_failed_new.csv
# Dealing with # 7 of records done.
# ************** JacquesLucke/animation_nodes is done*************
# writing actions/checkout to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( Nelarius/imnodes , actions/checkout , githubactions )
# writing lukka/run-vcpkg to csv/metastep/map_sbom_name_failed_new.csv
# package manager not match ( Nelarius/imnodes , lukka/run-vcpkg , githubactions )
# writing com.github.Nelarius/imnodes to csv/metastep/map_sbom_name_failed_new.csv
# Dealing with # 3 of records done.
# ************** Nelarius/imnodes is done*************

# %% [markdown]
# ### Step 3 -- Fixing and Getting the Right Source
#
# After Step1 and 2, which is to:
# 1. `csv/target_repo_dependencies_raw.csv` has been loaded in Neo4j
# 2. `csv/relationships.csv` has been loaded in Neo4j
# 3. Orphan nodes have been removed
#
# We still need:
#
# **We still need to deal with mapping to repo name failure recorded in `csv/metastep/map_sbom_name_failed-1.csv`.**
# **Remember to also update `csv/metastep/map_sbom_name_to_repo_full_name.csv` when fixing the failure, they are one-to-one relationship for sbom name to repo full name (github).**
#   - First write to independent file and then merge.

# %%
import requests
from pprint import pprint
import base64
from github import Github
import datetime

def get_repo_info_from_repo(repo_info, prop) -> dict:
    # get properties
    output = {}
    for key in prop.keys():
        output[key] = getattr(repo_info, prop[key])
        
        # make datetime YYYY-MM-DD
        if key == "createdAt":
            output[key] = output[key].strftime("%Y-%m-%d")
        
        # enclose description with ""
        if key == "description" and type(output[key]) is str:
            output[key] = "\"" + output[key].replace("\"", "'") + "\""
            
        # make ownedByOrg to "True" or "False"
        if key == "ownedByOrg":
            if output[key] is None:
                output[key] = "False"
            else:
                output[key] = "True"
                
        # make owner to string
        if key == "owner":
            output[key] = output[key].login
        
    return output

# %%
import requests
import json
from github import Github
from github import Auth
from github import GithubException

auth = Auth.Token("YOUR_TOKEN")

g = Github(auth=auth)

# %%
from bs4 import BeautifulSoup

def search_pypi(sbom_name: str):
    """Search pypi and return Repository() obj"""
    global g
    
    # get html
    url = "https://pypi.org/project/"
    page = requests.get(url + sbom_name)
    
    soup = BeautifulSoup(page.content, 'html.parser')
    
    # parsing
    # <a class="vertical-tabs__tab vertical-tabs__tab--with-icon vertical-tabs__tab--condensed" href="https://github.com/data-exp-lab/yt_libyt" rel="nofollow">
    #    <i aria-hidden="true" class="fas fa-home">
    #    </i>
    #    Homepage
    # </a>
    tag_to_find = ["Homepage", "Repository", "Source", "Download"]
    
    github_url_prefix = "https://github.com/"
    find_all_a = soup.find_all("a")
    candidate = []
    for a in find_all_a:
        for tag in tag_to_find:
            if tag in a.get_text():
                url = a.get("href")
                if github_url_prefix in url:
                    # in case urls like owner/repo/tree/master
                    guess_repo_full_name = url[len(github_url_prefix):].split("/")
                    guess_repo_full_name = guess_repo_full_name[0] + "/" + guess_repo_full_name[1]
                    
                    # in case .git is included at the end
                    if guess_repo_full_name[-len(".git"):] == ".git":
                        guess_repo_full_name = guess_repo_full_name[:-len(".git")]
                        
                    candidate.append(guess_repo_full_name)
    candidate = list(set(candidate))
    
    if len(candidate) != 1:
        print("      * more than one suggestions")
        return None, "MultiSuggestion"
    else:
        repo_info = g.get_repo(full_name_or_id=candidate[0])
        return repo_info, "ok"

# %%
def search_npm_io(sbom_name: str):
    """Search npm and return Repository() obj"""
    global g
    
    url = "https://api.npms.io/v2/search"
    query = "?q=" + sbom_name
    
    # query using npm.io API
    respond = requests.get(url + query)
    search_npm_results = json.loads(respond.content)
    
    # get the first result based on its search, and return GitHub repo full name
    github_url_prefix = "https://github.com/"
    if search_npm_results["total"] > 0:
        try:
            if search_npm_results["results"][0]["package"]["name"] == sbom_name:
                repo_url = search_npm_results["results"][0]["package"]["links"]["repository"]
                if github_url_prefix in repo_url:
                    temp = repo_url[len(github_url_prefix):].split("/")
                    github_repo_full_name = temp[0] + "/" + temp[1]
                    try:
                        repo_info = g.get_repo(full_name_or_id=github_repo_full_name)
                        return repo_info, "ok"
                    except GithubException as e:
                        if e.status == 404:
                            print("      * cannot access '", github_repo_full_name, "'")
                            return None, "CannotFind"
                        else:
                            raise(e)
                    except Exception as e:
                        print(e)
                        return None, "CannotFind"
                else:
                    print("      * repo_url doesn't contain", github_url_prefix)
                    return None, "CannotFind"
            else:
                print("      * sbom_name not match to searched package name")
                return None, "CannotFind"
        except KeyError:
            print("      * First search result doesn't contain 'package' or 'repository'")
            return None, "CannotFind"
    else:
        print("      * npm.io search nothing")
        return None, "CannotFind"

# %%
import time

def scratch_npm_html(sbom_name):
    """Scratch npm html webpage and return Repository() obj"""
    global g
    
    # get html
    url = "https://www.npmjs.com/package/"
    query = sbom_name
    time.sleep(2)
    page = requests.get(url + query)
    html = page.content.decode("utf-8")
    
    span_open_tag = "<span id=\"repository-link\">"
    span_close_tag = "</span>"
    repo_link_start = html.find(span_open_tag)
    
    if repo_link_start > 0:
        repo_link_end = html.find("</span>", repo_link_start)
        guess_repo_full_name = html[len(span_open_tag) + repo_link_start : repo_link_end].split("/")
        repo_full_name = guess_repo_full_name[1] + "/" + guess_repo_full_name[2]
    
        try:
            repo_info = g.get_repo(full_name_or_id=repo_full_name)
            return repo_info, "ok"
        except GithubException as e:
            if e.status == 404:
                print("      * cannot access '", repo_full_name, "'")
                return None, "CannotFind"
            else:
                raise(e)
        except:
            raise("Other error or exception occurred.")
    else:
        print("      * Cannot find repository tag")
        return None, "CannotFind"

# %%
def search_github_sort_by_stars(sbom_name: str):
    """Search github and pick the most starrred repo, then return Repository() obj"""
    global g
    
    # search the repo, sort by stars
    try:
        search_rank0_starcount = -1
        search_rank1_starcount = -1
        for s, search in enumerate(g.search_repositories(query=sbom_name, sort="stars")):
            if search.full_name.split("/")[1] == sbom_name:
                if s == 0:
                    search_rank0 = search
                    search_rank0_starcount = search.stargazers_count
                else:
                    search_rank1 = search
                    search_rank1_starcount = search.stargazers_count
                    break

        # pick the one that has largest star count
        # if there are two or more repo, then raise error
        if search_rank0_starcount == -1:
            return None, "CannotFind"

        if search_rank0_starcount <= search_rank1_starcount:
            return None, "MultiSuggestion"

        return search_rank0, "ok"
    except:
        return None, "CannotFind"

# %%
def search_github(sbom_name):
    """Search github using full repo name, then return Repository() obj"""
    global g
    
    try:
        repo_info = g.get_repo(full_name_or_id=sbom_name)
        return repo_info, "ok"
    except GithubException as e:
        if e.status == 404:
            return None, "CannotFind"

# %%
def write_to_csv_file(filename : str, row : list):
    with open(filename, "a") as f:
        for elem in row:
            f.write(str(elem))
            f.write(",")
        f.write("\n")

# %%
import pandas as pd

failed_raw = pd.read_csv("csv/metastep/map_sbom_name_failed-1.csv")

# failed_raw["sbom_name"][330] = str("nan")
# type(failed_raw["sbom_name"][330])
for i, row in failed_raw.iterrows():
    if type(row["sbom_name"]) is float:
        print(i, row["sbom_name"])
        failed_raw["sbom_name"][i] = str("nan")
# Out:
# 330 nan
# 410 nan
# 541 nan
# 671 nan
# 1481 nan
# 1710 nan
# 1914 nan
# /tmp/ipykernel_20070/2636818576.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   failed_raw["sbom_name"][i] = str("nan")
# /tmp/ipykernel_20070/2636818576.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   failed_raw["sbom_name"][i] = str("nan")
# /tmp/ipykernel_20070/2636818576.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   failed_raw["sbom_name"][i] = str("nan")
# /tmp/ipykernel_20070/2636818576.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   failed_raw["sbom_name"][i] = str("nan")
# /tmp/ipykernel_20070/2636818576.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   failed_raw["sbom_name"][i] = str("nan")
# /tmp/ipykernel_20070/2636818576.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   failed_raw["sbom_name"][i] = str("nan")
# /tmp/ipykernel_20070/2636818576.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   failed_raw["sbom_name"][i] = str("nan")
# /tmp/ipykernel_20070/2636818576.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   failed_raw["sbom_name"][i] = str("nan")
# /tmp/ipykernel_20070/2636818576.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   failed_raw["sbom_name"][i] = str("nan")
# /tmp/ipykernel_20070/2636818576.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   failed_raw["sbom_name"][i] = str("nan")
# /tmp/ipykernel_20070/2636818576.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   failed_raw["sbom_name"][i] = str("nan")
# /tmp/ipykernel_20070/2636818576.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   failed_raw["sbom_name"][i] = str("nan")
# /tmp/ipykernel_20070/2636818576.py:10: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   failed_raw["sbom_name"][i] = str("nan")
# /tmp/ipykernel_20070/2636818576.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   failed_raw["sbom_name"][i] = str("nan")

# %%
## find missing dependencies based on file "csv/metastep/map_sbom_name_failed-1.csv"
# 1. Write repo to "csv/target_repo_dependencies_raw-1.csv" (Use `write_to_csv_file`)
# 2. Write relationsip to "csv/relationships-1.csv" (Use `write_to_csv_file`)
# 3. Write "csv/metastep/map_sbom_name_to_repo_full_name-1.csv" (Use `write_to_csv_file`)
# 4. If still failed, write to "csv/metastep/map_sbom_name_failed-2.csv"  (Use `write_to_csv_file`)

find_in = {
    "pypi": search_pypi,
    "npm.io": search_npm_io,
    "npm": scratch_npm_html,
    "github": search_github
}

rep_dep_filename = "csv/target_repo_dependencies_raw-1.csv"
relationship_filename = "csv/relationships-1.csv"
map_sbom_to_repo_filename = "csv/metastep/map_sbom_name_to_repo_full_name-1.csv"
still_fail_filename = "csv/metastep/map_sbom_name_failed-2.csv"

start_at = 595
for index, row in failed_raw.iterrows():
    if index < start_at:
        # print("skipping", index, row["repo_full_name"], row["sbom_name"], row["pkg_manager"])
        continue
        
    # make sure it is DEPENDS_ON relationship
    if row["relationship"] != "DEPENDS_ON":
        print("NotDependsOn#", index, "sbom = ", row["sbom_name"], row["pkg_manager"])
        write_to_csv_file(still_fail_filename, [row["repo_full_name"], row["relationship"], row["sbom_name"], row["pkg_manager"]])
        continue
    
    
    # finding sbom_name's repo based on pkg manager
    repo_info = None, "CannotFind"
    for method in find_in.keys():
        if method in row["pkg_manager"] or row["pkg_manager"] in method:
            repo_info = find_in[method](row["sbom_name"])
            if repo_info[0] is not None:
                break
    
    # output results
    if repo_info[0] is None:
        print("Cannot find #", index, "sbom = ", row["sbom_name"], "(", row["pkg_manager"], ")")
        write_to_csv_file(still_fail_filename, [row["repo_full_name"], row["relationship"], row["sbom_name"], row["pkg_manager"]])
        continue
    else:
        get_repo_info = get_repo_info_from_repo(repo_info[0], properties)
        
        write_to_csv_file(rep_dep_filename, [get_repo_info["name"], get_repo_info["starsCount"], get_repo_info["forksCount"], 
                                             get_repo_info["watchersCount"], get_repo_info["createdAt"], get_repo_info["description"],
                                             get_repo_info["githubPage"], get_repo_info["ownedByOrg"], get_repo_info["owner"], 
                                             get_repo_info["language"]])
        
        write_to_csv_file(relationship_filename, [row["repo_full_name"], row["relationship"], get_repo_info["name"]])
        
        write_to_csv_file(map_sbom_to_repo_filename, [row["sbom_name"], get_repo_info["name"], method])
        
        print("Find        #", index, "sbom = ", row["sbom_name"], "(", row["pkg_manager"], ")", repo_info[0])
# Out:
#       * npm.io search nothing
# Find        # 595 sbom =  @chakra-ui/react-children-utils ( npm ) Repository(full_name="chakra-ui/chakra-ui")
#       * sbom_name not match to searched package name
# Find        # 596 sbom =  @chakra-ui/react-context ( npm ) Repository(full_name="chakra-ui/chakra-ui")
#       * npm.io search nothing
# Find        # 597 sbom =  @chakra-ui/react-use-focus-effect ( npm ) Repository(full_name="chakra-ui/chakra-ui")
#       * npm.io search nothing
# Find        # 598 sbom =  @chakra-ui/react-use-focus-on-pointer-down ( npm ) Repository(full_name="chakra-ui/chakra-ui")
#       * npm.io search nothing
# Find        # 599 sbom =  @chakra-ui/react-use-interval ( npm ) Repository(full_name="chakra-ui/chakra-ui")
#       * npm.io search nothing
# Find        # 600 sbom =  @chakra-ui/react-use-latest-ref ( npm ) Repository(full_name="chakra-ui/chakra-ui")
#       * npm.io search nothing
# Find        # 601 sbom =  @chakra-ui/react-use-merge-refs ( npm ) Repository(full_name="chakra-ui/chakra-ui")
#       * npm.io search nothing
# Find        # 602 sbom =  @chakra-ui/react-use-outside-click ( npm ) Repository(full_name="chakra-ui/chakra-ui")
#       * npm.io search nothing
# Find        # 603 sbom =  @chakra-ui/react-use-pan-event ( npm ) Repository(full_name="chakra-ui/chakra-ui")
#       * npm.io search nothing
# Find        # 604 sbom =  @chakra-ui/react-use-previous ( npm ) Repository(full_name="chakra-ui/chakra-ui")
#       * npm.io search nothing
# Find        # 605 sbom =  @chakra-ui/react-use-safe-layout-effect ( npm ) Repository(full_name="chakra-ui/chakra-ui")
#       * npm.io search nothing
# Find        # 606 sbom =  @chakra-ui/react-use-size ( npm ) Repository(full_name="chakra-ui/chakra-ui")
#       * npm.io search nothing
# Find        # 607 sbom =  @chakra-ui/react-use-timeout ( npm ) Repository(full_name="chakra-ui/chakra-ui")
#       * First search result doesn't contain 'package'
# Find        # 608 sbom =  @types/d3 ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
# Find        # 609 sbom =  @types/d3-format ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
# Find        # 610 sbom =  @types/d3-interpolate ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
# Find        # 611 sbom =  @types/d3-path ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
# Find        # 612 sbom =  @types/d3-polygon ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
# Find        # 613 sbom =  @types/d3-random ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
# Find        # 614 sbom =  @types/d3-scale-chromatic ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
# Find        # 615 sbom =  @types/d3-time ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
# Find        # 616 sbom =  @types/d3-time-format ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
# Find        # 617 sbom =  @types/d3-timer ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
# Find        # 618 sbom =  @types/lodash.mergewith ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * npm.io search nothing
# Find        # 619 sbom =  @zag-js/element-size ( npm ) Repository(full_name="chakra-ui/zag")
#       * First search result doesn't contain 'package'
# Find        # 620 sbom =  d3-dispatch ( npm ) Repository(full_name="d3/d3-dispatch")
#       * First search result doesn't contain 'package'
# Find        # 621 sbom =  generate-function ( npm ) Repository(full_name="mafintosh/generate-function")
#       * npm.io search nothing
# Find        # 622 sbom =  @zag-js/dom-query ( npm ) Repository(full_name="chakra-ui/zag")
#       * repo_url doesn't contain https://github.com/
# Find        # 623 sbom =  javascript-time-ago ( npm ) Repository(full_name="catamphetamine/javascript-time-ago")
#       * First search result doesn't contain 'package'
# Find        # 624 sbom =  @types/http-cache-semantics ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
# Find        # 625 sbom =  @types/hast ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * cannot access ' thenativeweb/boolean '
#       * cannot access ' thenativeweb/boolean '
# Cannot find # 626 sbom =  boolean ( npm )
#       * First search result doesn't contain 'package'
# Find        # 627 sbom =  @types/mdurl ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
# Find        # 628 sbom =  @types/react-dom ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 629 sbom =  @types/cacheable-request ( npm )
#       * First search result doesn't contain 'package'
#       * cannot access ' kevva/compare-version '
# Cannot find # 630 sbom =  compare-version ( npm )
#       * First search result doesn't contain 'package'
# Find        # 631 sbom =  flora-colossus ( npm ) Repository(full_name="MarshallOfSound/flora-colossus")
#       * First search result doesn't contain 'package'
# Find        # 632 sbom =  galactus ( npm ) Repository(full_name="MarshallOfSound/galactus")
#       * cannot access ' substack/parse-color '
#       * cannot access ' substack/parse-color '
# Cannot find # 633 sbom =  parse-color ( npm )
#       * First search result doesn't contain 'package'
# Find        # 634 sbom =  unist-util-generated ( npm ) Repository(full_name="syntax-tree/unist-util-generated")
#       * First search result doesn't contain 'package'
# Find        # 635 sbom =  @types/geojson ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
# Find        # 636 sbom =  @electron/get ( npm ) Repository(full_name="electron/get")
#       * First search result doesn't contain 'package'
# Find        # 637 sbom =  @types/d3-axis ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
# Find        # 638 sbom =  @types/d3-brush ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
# Find        # 639 sbom =  @types/d3-chord ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
# Find        # 640 sbom =  @types/d3-contour ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
# Find        # 641 sbom =  @types/d3-dispatch ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
# Find        # 642 sbom =  @types/d3-drag ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
# Find        # 643 sbom =  @types/d3-dsv ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
# Find        # 644 sbom =  @types/d3-fetch ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
# Find        # 645 sbom =  @types/d3-force ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
# Find        # 646 sbom =  @types/d3-geo ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
# Find        # 647 sbom =  @types/d3-selection ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
# Find        # 648 sbom =  @types/d3-zoom ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
# Find        # 649 sbom =  @types/d3-color ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
# Find        # 650 sbom =  @types/d3-hierarchy ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
# Find        # 651 sbom =  @types/d3-shape ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
# Find        # 652 sbom =  electron-squirrel-startup ( npm ) Repository(full_name="mongodb-js/electron-squirrel-startup")
#       * First search result doesn't contain 'package'
# Find        # 653 sbom =  @types/decompress ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
# Find        # 654 sbom =  @types/d3-delaunay ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
# Find        # 655 sbom =  @types/wcag-contrast ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
# Find        # 656 sbom =  @types/bezier-js ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * sbom_name not match to searched package name
# Find        # 657 sbom =  cross-dirname ( npm ) Repository(full_name="JumpLink/cross-dirname")
#       * First search result doesn't contain 'package'
# Find        # 658 sbom =  @types/node-localstorage ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
# Find        # 659 sbom =  @types/eventsource ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * npm.io search nothing
# Find        # 660 sbom =  @types/electron-squirrel-startup ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
# Find        # 661 sbom =  @types/os-utils ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
# Find        # 662 sbom =  @types/lodash ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * npm.io search nothing
# Find        # 663 sbom =  @vitejs/plugin-react-swc ( npm ) Repository(full_name="vitejs/vite-plugin-react-swc")
#       * npm.io search nothing
# Find        # 664 sbom =  @swc/counter ( npm ) Repository(full_name="swc-project/pkgs")
#       * npm.io search nothing
# Find        # 665 sbom =  es-define-property ( npm ) Repository(full_name="ljharb/es-define-property")
#       * sbom_name not match to searched package name
# Find        # 666 sbom =  define-data-property ( npm ) Repository(full_name="ljharb/define-data-property")
#       * First search result doesn't contain 'package'
# Find        # 667 sbom =  @babel/runtime ( npm ) Repository(full_name="babel/babel")
#       * First search result doesn't contain 'package'
# Find        # 668 sbom =  hasown ( npm ) Repository(full_name="inspect-js/hasOwn")
#       * sbom_name not match to searched package name
# Find        # 669 sbom =  set-function-length ( npm ) Repository(full_name="ljharb/set-function-length")
#       * sbom_name not match to searched package name
# Find        # 670 sbom =  @swc/types ( npm ) Repository(full_name="swc-project/swc")
# Find        # 671 sbom =  nan ( npm ) Repository(full_name="nodejs/nan")
#       * npm.io search nothing
# Find        # 672 sbom =  @vitest/expect ( npm ) Repository(full_name="vitest-dev/vitest")
#       * npm.io search nothing
# Find        # 673 sbom =  @vitest/runner ( npm ) Repository(full_name="vitest-dev/vitest")
#       * npm.io search nothing
# Find        # 674 sbom =  @vitest/snapshot ( npm ) Repository(full_name="vitest-dev/vitest")
#       * npm.io search nothing
# Find        # 675 sbom =  @vitest/spy ( npm ) Repository(full_name="vitest-dev/vitest")
#       * sbom_name not match to searched package name
# Find        # 676 sbom =  @vitest/utils ( npm ) Repository(full_name="vitest-dev/vitest")
#       * sbom_name not match to searched package name
# Find        # 677 sbom =  @electron/asar ( npm ) Repository(full_name="electron/asar")
#       * First search result doesn't contain 'package'
# Find        # 678 sbom =  @electron/fuses ( npm ) Repository(full_name="electron/fuses")
#       * First search result doesn't contain 'package'
# Find        # 679 sbom =  @electron-forge/plugin-auto-unpack-natives ( npm ) Repository(full_name="electron/forge")
#       * First search result doesn't contain 'package'
# Find        # 680 sbom =  @electron-forge/plugin-base ( npm ) Repository(full_name="electron/forge")
#       * First search result doesn't contain 'package'
# Find        # 681 sbom =  @electron-forge/shared-types ( npm ) Repository(full_name="electron/forge")
#       * npm.io search nothing
# Find        # 682 sbom =  @electron-forge/tracer ( npm ) Repository(full_name="electron/forge")
#       * First search result doesn't contain 'package'
# Find        # 683 sbom =  @electron-forge/maker-zip ( npm ) Repository(full_name="electron/forge")
#       * npm.io search nothing
# Find        # 684 sbom =  @electron-forge/plugin-fuses ( npm ) Repository(full_name="electron/forge")
#       * First search result doesn't contain 'package'
# Find        # 685 sbom =  @electron-forge/publisher-base ( npm ) Repository(full_name="electron/forge")
#       * First search result doesn't contain 'package'
# Find        # 686 sbom =  @electron-forge/template-base ( npm ) Repository(full_name="electron/forge")
#       * npm.io search nothing
# Find        # 687 sbom =  @electron-forge/template-vite ( npm ) Repository(full_name="electron/forge")
#       * npm.io search nothing
# Find        # 688 sbom =  @electron-forge/template-vite-typescript ( npm ) Repository(full_name="electron/forge")
#       * First search result doesn't contain 'package'
# Find        # 689 sbom =  @electron-forge/template-webpack ( npm ) Repository(full_name="electron/forge")
#       * sbom_name not match to searched package name
# Find        # 690 sbom =  @electron-forge/template-webpack-typescript ( npm ) Repository(full_name="electron/forge")
#       * First search result doesn't contain 'package'
# Find        # 691 sbom =  @electron-forge/web-multi-logger ( npm ) Repository(full_name="electron/forge")
#       * sbom_name not match to searched package name
# Find        # 692 sbom =  @electron-forge/plugin-vite ( npm ) Repository(full_name="electron/forge")
#       * First search result doesn't contain 'package'
# Find        # 693 sbom =  @electron-forge/publisher-github ( npm ) Repository(full_name="electron/forge")
#       * sbom_name not match to searched package name
# Find        # 694 sbom =  @esbuild/darwin-arm64 ( npm ) Repository(full_name="evanw/esbuild")
#       * sbom_name not match to searched package name
# Find        # 695 sbom =  @esbuild/darwin-x64 ( npm ) Repository(full_name="evanw/esbuild")
#       * sbom_name not match to searched package name
# Find        # 696 sbom =  @esbuild/freebsd-arm64 ( npm ) Repository(full_name="evanw/esbuild")
#       * npm.io search nothing
# Find        # 697 sbom =  @esbuild/freebsd-x64 ( npm ) Repository(full_name="evanw/esbuild")
#       * sbom_name not match to searched package name
# Find        # 698 sbom =  @esbuild/linux-arm ( npm ) Repository(full_name="evanw/esbuild")
#       * sbom_name not match to searched package name
# Find        # 699 sbom =  @esbuild/linux-arm64 ( npm ) Repository(full_name="evanw/esbuild")
#       * npm.io search nothing
# Find        # 700 sbom =  @esbuild/linux-ia32 ( npm ) Repository(full_name="evanw/esbuild")
#       * npm.io search nothing
# Find        # 701 sbom =  @esbuild/linux-loong64 ( npm ) Repository(full_name="evanw/esbuild")
#       * npm.io search nothing
# Find        # 702 sbom =  @esbuild/linux-mips64el ( npm ) Repository(full_name="evanw/esbuild")
#       * npm.io search nothing
#       * Cannot find repository tag
# Cannot find # 703 sbom =  @esbuild/linux-ppc64 ( npm )
#       * sbom_name not match to searched package name
#       * Cannot find repository tag
# Cannot find # 704 sbom =  @esbuild/linux-riscv64 ( npm )
#       * sbom_name not match to searched package name
#       * Cannot find repository tag
# Cannot find # 705 sbom =  @esbuild/linux-s390x ( npm )
#       * sbom_name not match to searched package name
# Find        # 706 sbom =  @esbuild/linux-x64 ( npm ) Repository(full_name="evanw/esbuild")
#       * npm.io search nothing
#       * Cannot find repository tag
# Cannot find # 707 sbom =  @esbuild/netbsd-x64 ( npm )
#       * npm.io search nothing
#       * Cannot find repository tag
# Cannot find # 708 sbom =  @esbuild/openbsd-x64 ( npm )
#       * npm.io search nothing
#       * Cannot find repository tag
# Cannot find # 709 sbom =  @esbuild/sunos-x64 ( npm )
#       * sbom_name not match to searched package name
#       * Cannot find repository tag
# Cannot find # 710 sbom =  @esbuild/win32-arm64 ( npm )
#       * npm.io search nothing
#       * Cannot find repository tag
# Cannot find # 711 sbom =  @esbuild/win32-ia32 ( npm )
#       * npm.io search nothing
#       * Cannot find repository tag
# Cannot find # 712 sbom =  @rollup/rollup-android-arm-eabi ( npm )
#       * sbom_name not match to searched package name
#       * Cannot find repository tag
# Cannot find # 713 sbom =  @rollup/rollup-android-arm64 ( npm )
#       * sbom_name not match to searched package name
#       * Cannot find repository tag
# Cannot find # 714 sbom =  @rollup/rollup-darwin-arm64 ( npm )
#       * sbom_name not match to searched package name
#       * Cannot find repository tag
# Cannot find # 715 sbom =  @rollup/rollup-darwin-x64 ( npm )
#       * sbom_name not match to searched package name
#       * Cannot find repository tag
# Cannot find # 716 sbom =  @rollup/rollup-linux-arm-gnueabihf ( npm )
#       * sbom_name not match to searched package name
#       * Cannot find repository tag
# Cannot find # 717 sbom =  @rollup/rollup-win32-ia32-msvc ( npm )
#       * sbom_name not match to searched package name
#       * Cannot find repository tag
# Cannot find # 718 sbom =  @rollup/rollup-win32-x64-msvc ( npm )
# Find        # 719 sbom =  pytest ( pypi ) Repository(full_name="pytest-dev/pytest")
#       * more than one suggestions
# Cannot find # 720 sbom =  appdirs ( pypi )
# Find        # 721 sbom =  debugpy ( pypi ) Repository(full_name="microsoft/debugpy")
# Find        # 722 sbom =  viztracer ( pypi ) Repository(full_name="gaogaotiantian/viztracer")
# Find        # 723 sbom =  pyright ( pypi ) Repository(full_name="RobertCraigie/pyright-python")
# Find        # 724 sbom =  ruff ( pypi ) Repository(full_name="astral-sh/ruff")
# Find        # 725 sbom =  fjogeleit/http-request-action ( githubactions ) Repository(full_name="fjogeleit/http-request-action")
# Find        # 726 sbom =  actions/checkout ( githubactions ) Repository(full_name="actions/checkout")
# Find        # 727 sbom =  actions/cache ( githubactions ) Repository(full_name="actions/cache")
# Find        # 728 sbom =  actions/setup-python ( githubactions ) Repository(full_name="actions/setup-python")
# Find        # 729 sbom =  actions/setup-node ( githubactions ) Repository(full_name="actions/setup-node")
# Find        # 730 sbom =  actions/upload-artifact ( githubactions ) Repository(full_name="actions/upload-artifact")
# Cannot find # 731 sbom =  com.github.chaiNNer-org/chaiNNer ( github )
#       * First search result doesn't contain 'package'
# Find        # 732 sbom =  @types/react-dom ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * sbom_name not match to searched package name
#       * Cannot find repository tag
# Cannot find # 733 sbom =  @floating-ui/react ( npm )
#       * First search result doesn't contain 'package'
# Find        # 734 sbom =  @types/react-color ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 735 sbom =  @atlaskit/theme ( npm )
#       * First search result doesn't contain 'package'
# Find        # 736 sbom =  @types/semver ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 737 sbom =  @types/marked ( npm )
#       * repo_url doesn't contain https://github.com/
#       * Cannot find repository tag
# Cannot find # 738 sbom =  @atlaskit/tokens ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 739 sbom =  @types/ws ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 740 sbom =  @types/jsonpath-plus ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 741 sbom =  @atlaskit/css-reset ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 742 sbom =  @atlaskit/banner ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 743 sbom =  @atlaskit/checkbox ( npm )
#       * repo_url doesn't contain https://github.com/
#       * Cannot find repository tag
# Cannot find # 744 sbom =  @atlaskit/form ( npm )
#       * repo_url doesn't contain https://github.com/
#       * Cannot find repository tag
# Cannot find # 745 sbom =  @atlaskit/textfield ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 746 sbom =  @atlaskit/tabs ( npm )
#       * repo_url doesn't contain https://github.com/
#       * Cannot find repository tag
# Cannot find # 747 sbom =  @atlaskit/textarea ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 748 sbom =  @atlaskit/toggle ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 749 sbom =  @types/filesystem ( npm )
#       * repo_url doesn't contain https://github.com/
#       * Cannot find repository tag
# Cannot find # 750 sbom =  @atlaskit/range ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 751 sbom =  @atlaskit/button ( npm )
#       * repo_url doesn't contain https://github.com/
#       * Cannot find repository tag
# Cannot find # 752 sbom =  @atlaskit/dropdown-menu ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 753 sbom =  @atlaskit/inline-edit ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 754 sbom =  @atlaskit/modal-dialog ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 755 sbom =  @atlaskit/icon ( npm )
#       * repo_url doesn't contain https://github.com/
#       * Cannot find repository tag
# Cannot find # 756 sbom =  @atlaskit/select ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 757 sbom =  @types/wicg-file-system-access ( npm )
#       * First search result doesn't contain 'package'
#       * cannot access ' atlassian/atlassian-frontend-mirror '
# Cannot find # 758 sbom =  @atlaskit/side-navigation ( npm )
#       * repo_url doesn't contain https://github.com/
#       * Cannot find repository tag
# Cannot find # 759 sbom =  @atlaskit/popup ( npm )
#       * repo_url doesn't contain https://github.com/
#       * Cannot find repository tag
# Cannot find # 760 sbom =  @atlaskit/portal ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 761 sbom =  @atlaskit/menu ( npm )
#       * First search result doesn't contain 'package'
# Find        # 762 sbom =  @types/lodash ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
# Find        # 763 sbom =  @types/eslint ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
# Find        # 764 sbom =  @types/crypto-js ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * npm.io search nothing
#       * Cannot find repository tag
# Cannot find # 765 sbom =  emittery-0-13 ( npm )
#       * npm.io search nothing
#       * Cannot find repository tag
# Cannot find # 766 sbom =  p-queue-6 ( npm )
#       * npm.io search nothing
#       * Cannot find repository tag
# Cannot find # 767 sbom =  p-retry-4 ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 768 sbom =  @docusaurus/theme-classic ( npm )
#       * First search result doesn't contain 'package'
# Find        # 769 sbom =  @types/minimatch ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * sbom_name not match to searched package name
# Find        # 770 sbom =  @babel/plugin-transform-class-properties ( npm ) Repository(full_name="babel/babel")
#       * npm.io search nothing
# Find        # 771 sbom =  @humanwhocodes/module-importer ( npm ) Repository(full_name="humanwhocodes/module-importer")
#       * npm.io search nothing
#       * Cannot find repository tag
# Cannot find # 772 sbom =  @isaacs/cliui ( npm )
#       * First search result doesn't contain 'package'
# Find        # 773 sbom =  @nodelib/fs.scandir ( npm ) Repository(full_name="nodelib/nodelib")
#       * First search result doesn't contain 'package'
# Find        # 774 sbom =  @nodelib/fs.stat ( npm ) Repository(full_name="nodelib/nodelib")
#       * First search result doesn't contain 'package'
# Find        # 775 sbom =  @nodelib/fs.walk ( npm ) Repository(full_name="nodelib/nodelib")
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 776 sbom =  @rollup/plugin-virtual ( npm )
#       * npm.io search nothing
# Find        # 777 sbom =  @swc/counter ( npm ) Repository(full_name="swc-project/pkgs")
#       * sbom_name not match to searched package name
# Find        # 778 sbom =  @swc/types ( npm ) Repository(full_name="swc-project/swc")
#       * First search result doesn't contain 'package'
# Find        # 779 sbom =  @types/body-parser ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 780 sbom =  @types/bonjour ( npm )
#       * First search result doesn't contain 'package'
# Find        # 781 sbom =  @types/connect ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
# Find        # 782 sbom =  @types/express ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 783 sbom =  @types/html-minifier-terser ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 784 sbom =  @types/istanbul-lib-coverage ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 785 sbom =  @types/istanbul-lib-report ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 786 sbom =  @types/istanbul-reports ( npm )
#       * First search result doesn't contain 'package'
# Find        # 787 sbom =  @types/jsdom ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 788 sbom =  @types/json5 ( npm )
#       * First search result doesn't contain 'package'
# Find        # 789 sbom =  @types/minimist ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
# Find        # 790 sbom =  @types/parse-json ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
# Find        # 791 sbom =  @types/range-parser ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 792 sbom =  @types/serve-index ( npm )
#       * First search result doesn't contain 'package'
# Find        # 793 sbom =  @types/unist ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
# Find        # 794 sbom =  array-flatten ( npm ) Repository(full_name="blakeembrey/array-flatten")
#       * cannot access ' substack/node-commondir '
#       * cannot access ' substack/node-commondir '
# Cannot find # 795 sbom =  commondir ( npm )
#       * sbom_name not match to searched package name
# Find        # 796 sbom =  define-data-property ( npm ) Repository(full_name="ljharb/define-data-property")
#       * First search result doesn't contain 'package'
# Find        # 797 sbom =  dns-equal ( npm ) Repository(full_name="watson/dns-equal")
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 798 sbom =  domelementtype ( npm )
#       * First search result doesn't contain 'package'
# Find        # 799 sbom =  domhandler ( npm ) Repository(full_name="fb55/domhandler")
#       * First search result doesn't contain 'package'
# Find        # 800 sbom =  domutils ( npm ) Repository(full_name="fb55/domutils")
#       * npm.io search nothing
#       * Cannot find repository tag
# Cannot find # 801 sbom =  es-iterator-helpers ( npm )
#       * First search result doesn't contain 'package'
# Find        # 802 sbom =  fast-levenshtein ( npm ) Repository(full_name="hiddentao/fast-levenshtein")
#       * First search result doesn't contain 'package'
# Find        # 803 sbom =  forwarded ( npm ) Repository(full_name="jshttp/forwarded")
#       * First search result doesn't contain 'package'
# Find        # 804 sbom =  fs.realpath ( npm ) Repository(full_name="isaacs/fs.realpath")
#       * First search result doesn't contain 'package'
# Find        # 805 sbom =  gzip-size ( npm ) Repository(full_name="sindresorhus/gzip-size")
#       * First search result doesn't contain 'package'
# Find        # 806 sbom =  has-symbols ( npm ) Repository(full_name="inspect-js/has-symbols")
#       * First search result doesn't contain 'package'
# Find        # 807 sbom =  hasown ( npm ) Repository(full_name="inspect-js/hasOwn")
#       * First search result doesn't contain 'package'
# Find        # 808 sbom =  html-webpack-plugin ( npm ) Repository(full_name="jantimon/html-webpack-plugin")
#       * First search result doesn't contain 'package'
# Find        # 809 sbom =  is-boolean-object ( npm ) Repository(full_name="inspect-js/is-boolean-object")
#       * First search result doesn't contain 'package'
# Find        # 810 sbom =  is-buffer ( npm ) Repository(full_name="feross/is-buffer")
#       * First search result doesn't contain 'package'
# Find        # 811 sbom =  is-callable ( npm ) Repository(full_name="inspect-js/is-callable")
#       * First search result doesn't contain 'package'
# Find        # 812 sbom =  is-decimal ( npm ) Repository(full_name="wooorm/is-decimal")
#       * First search result doesn't contain 'package'
# Find        # 813 sbom =  is-hexadecimal ( npm ) Repository(full_name="wooorm/is-hexadecimal")
#       * First search result doesn't contain 'package'
# Find        # 814 sbom =  is-number-object ( npm ) Repository(full_name="inspect-js/is-number-object")
#       * First search result doesn't contain 'package'
# Find        # 815 sbom =  is-plain-obj ( npm ) Repository(full_name="sindresorhus/is-plain-obj")
#       * First search result doesn't contain 'package'
# Find        # 816 sbom =  is-plain-object ( npm ) Repository(full_name="jonschlinkert/is-plain-object")
#       * sbom_name not match to searched package name
#       * Cannot find repository tag
# Cannot find # 817 sbom =  iterator.prototype ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 818 sbom =  jest-get-type ( npm )
#       * npm.io search nothing
#       * Cannot find repository tag
# Cannot find # 819 sbom =  safe-array-concat ( npm )
#       * sbom_name not match to searched package name
# Find        # 820 sbom =  safe-regex-test ( npm ) Repository(full_name="ljharb/safe-regex-test")
#       * sbom_name not match to searched package name
# Find        # 821 sbom =  set-function-length ( npm ) Repository(full_name="ljharb/set-function-length")
#       * cannot access ' substack/text-table '
#       * cannot access ' substack/text-table '
# Cannot find # 822 sbom =  text-table ( npm )
#       * sbom_name not match to searched package name
#       * Cannot find repository tag
# Cannot find # 823 sbom =  typed-array-buffer ( npm )
#       * npm.io search nothing
# Find        # 824 sbom =  typed-array-byte-length ( npm ) Repository(full_name="inspect-js/typed-array-byte-length")
#       * First search result doesn't contain 'package'
# Find        # 825 sbom =  use-sync-external-store ( npm ) Repository(full_name="facebook/react")
#       * First search result doesn't contain 'package'
# Find        # 826 sbom =  @babel/runtime ( npm ) Repository(full_name="babel/babel")
#       * npm.io search nothing
#       * Cannot find repository tag
# Cannot find # 827 sbom =  @nicolo-ribaudo/eslint-scope-5-internals ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 828 sbom =  @types/babel__generator ( npm )
#       * First search result doesn't contain 'package'
# Find        # 829 sbom =  @types/babel__template ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
# Find        # 830 sbom =  @types/babel__traverse ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
# Find        # 831 sbom =  cssnano-preset-default ( npm ) Repository(full_name="cssnano/cssnano")
#       * First search result doesn't contain 'package'
# Find        # 832 sbom =  http-parser-js ( npm ) Repository(full_name="creationix/http-parser-js")
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 833 sbom =  is-obj ( npm )
#       * First search result doesn't contain 'package'
# Find        # 834 sbom =  is-root ( npm ) Repository(full_name="sindresorhus/is-root")
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 835 sbom =  @types/mime ( npm )
#       * First search result doesn't contain 'package'
# Find        # 836 sbom =  has-unicode ( npm ) Repository(full_name="iarna/has-unicode")
#       * First search result doesn't contain 'package'
# Find        # 837 sbom =  is-lambda ( npm ) Repository(full_name="watson/is-lambda")
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 838 sbom =  minipass-pipeline ( npm )
#       * npm.io search nothing
#       * Cannot find repository tag
# Cannot find # 839 sbom =  es-set-tostringtag ( npm )
#       * npm.io search nothing
# Find        # 840 sbom =  update-browserslist-db ( npm ) Repository(full_name="browserslist/update-db")
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 841 sbom =  serve-handler ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 842 sbom =  @types/keyv ( npm )
#       * npm.io search nothing
#       * Cannot find repository tag
# Cannot find # 843 sbom =  @floating-ui/utils ( npm )
#       * First search result doesn't contain 'package'
# Find        # 844 sbom =  @types/scheduler ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * npm.io search nothing
# Find        # 845 sbom =  @emotion/use-insertion-effect-with-fallbacks ( npm ) Repository(full_name="emotion-js/emotion")
#       * First search result doesn't contain 'package'
# Following Github server redirection from /repos/js-n/find-root to /repositories/14966421
# Find        # 846 sbom =  find-root ( npm ) Repository(full_name="junosuarez/find-root")
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 847 sbom =  @types/eslint-scope ( npm )
#       * First search result doesn't contain 'package'
# Find        # 848 sbom =  @types/express-serve-static-core ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 849 sbom =  @types/history ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 850 sbom =  @types/react-router-dom ( npm )
#       * First search result doesn't contain 'package'
# Find        # 851 sbom =  @types/send ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
# Find        # 852 sbom =  @types/serve-static ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * sbom_name not match to searched package name
#       * Cannot find repository tag
# Cannot find # 853 sbom =  client-only ( npm )
#       * First search result doesn't contain 'package'
# Find        # 854 sbom =  interpret ( npm ) Repository(full_name="gulpjs/interpret")
#       * First search result doesn't contain 'package'
# Find        # 855 sbom =  @npmcli/fs ( npm ) Repository(full_name="npm/fs")
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 856 sbom =  @types/connect-history-api-fallback ( npm )
#       * First search result doesn't contain 'package'
# Find        # 857 sbom =  @types/http-proxy ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 858 sbom =  has-yarn ( npm )
#       * First search result doesn't contain 'package'
# Find        # 859 sbom =  @babel/plugin-bugfix-safari-id-destructuring-collision-in-function-expression ( npm ) Repository(full_name="babel/babel")
#       * First search result doesn't contain 'package'
# Find        # 860 sbom =  @babel/plugin-bugfix-v8-spread-parameters-in-optional-chaining ( npm ) Repository(full_name="babel/babel")
#       * npm.io search nothing
# Find        # 861 sbom =  @babel/plugin-transform-class-static-block ( npm ) Repository(full_name="babel/babel")
#       * npm.io search nothing
# Find        # 862 sbom =  @babel/plugin-transform-logical-assignment-operators ( npm ) Repository(full_name="babel/babel")
#       * First search result doesn't contain 'package'
# Find        # 863 sbom =  @types/estree ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 864 sbom =  @next/swc-linux-x64-musl ( npm )
#       * First search result doesn't contain 'package'
# Find        # 865 sbom =  @next/swc-win32-arm64-msvc ( npm ) Repository(full_name="vercel/next.js")
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 866 sbom =  @next/swc-win32-ia32-msvc ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 867 sbom =  @next/swc-win32-x64-msvc ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 868 sbom =  gcp-metadata ( npm )
#       * cannot access ' substack/github-from-package '
#       * Cannot find repository tag
# Cannot find # 869 sbom =  github-from-package ( npm )
#       * sbom_name not match to searched package name
# Find        # 870 sbom =  @esbuild/darwin-arm64 ( npm ) Repository(full_name="evanw/esbuild")
#       * sbom_name not match to searched package name
# Find        # 871 sbom =  @esbuild/darwin-x64 ( npm ) Repository(full_name="evanw/esbuild")
#       * sbom_name not match to searched package name
# Find        # 872 sbom =  @esbuild/freebsd-arm64 ( npm ) Repository(full_name="evanw/esbuild")
#       * npm.io search nothing
# Find        # 873 sbom =  @esbuild/freebsd-x64 ( npm ) Repository(full_name="evanw/esbuild")
#       * sbom_name not match to searched package name
# Find        # 874 sbom =  @esbuild/linux-arm ( npm ) Repository(full_name="evanw/esbuild")
#       * sbom_name not match to searched package name
# Find        # 875 sbom =  @esbuild/linux-arm64 ( npm ) Repository(full_name="evanw/esbuild")
#       * npm.io search nothing
# Find        # 876 sbom =  @esbuild/linux-ia32 ( npm ) Repository(full_name="evanw/esbuild")
#       * npm.io search nothing
# Find        # 877 sbom =  @esbuild/linux-loong64 ( npm ) Repository(full_name="evanw/esbuild")
#       * npm.io search nothing
# Find        # 878 sbom =  @esbuild/linux-mips64el ( npm ) Repository(full_name="evanw/esbuild")
#       * npm.io search nothing
#       * Cannot find repository tag
# Cannot find # 879 sbom =  @esbuild/linux-ppc64 ( npm )
#       * sbom_name not match to searched package name
#       * Cannot find repository tag
# Cannot find # 880 sbom =  @esbuild/linux-riscv64 ( npm )
#       * sbom_name not match to searched package name
#       * Cannot find repository tag
# Cannot find # 881 sbom =  @esbuild/linux-s390x ( npm )
#       * sbom_name not match to searched package name
# Find        # 882 sbom =  @esbuild/linux-x64 ( npm ) Repository(full_name="evanw/esbuild")
#       * npm.io search nothing
#       * Cannot find repository tag
# Cannot find # 883 sbom =  @esbuild/netbsd-x64 ( npm )
#       * npm.io search nothing
#       * Cannot find repository tag
# Cannot find # 884 sbom =  @esbuild/openbsd-x64 ( npm )
#       * npm.io search nothing
#       * Cannot find repository tag
# Cannot find # 885 sbom =  @esbuild/sunos-x64 ( npm )
#       * sbom_name not match to searched package name
#       * Cannot find repository tag
# Cannot find # 886 sbom =  @esbuild/win32-arm64 ( npm )
#       * npm.io search nothing
#       * Cannot find repository tag
# Cannot find # 887 sbom =  @esbuild/win32-ia32 ( npm )
#       * First search result doesn't contain 'package'
# Find        # 888 sbom =  @types/mdast ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 889 sbom =  @docusaurus/plugin-content-docs ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 890 sbom =  @docusaurus/plugin-content-pages ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 891 sbom =  @docusaurus/plugin-debug ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 892 sbom =  @docusaurus/plugin-google-analytics ( npm )
#       * sbom_name not match to searched package name
#       * Cannot find repository tag
# Cannot find # 893 sbom =  @docusaurus/plugin-google-tag-manager ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 894 sbom =  @types/react-router-config ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 895 sbom =  @types/sax ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 896 sbom =  cssnano-preset-advanced ( npm )
#       * First search result doesn't contain 'package'
# Following Github server redirection from /repos/facebook/flux to /repositories/22046023
# Find        # 897 sbom =  flux ( npm ) Repository(full_name="facebookarchive/flux")
#       * First search result doesn't contain 'package'
# Find        # 898 sbom =  unist-util-generated ( npm ) Repository(full_name="syntax-tree/unist-util-generated")
#       * First search result doesn't contain 'package'
# Find        # 899 sbom =  @types/hast ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 900 sbom =  @types/tough-cookie ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 901 sbom =  @types/node-fetch ( npm )
#       * First search result doesn't contain 'package'
# Find        # 902 sbom =  @types/js-cookie ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * npm.io search nothing
#       * Cannot find repository tag
# Cannot find # 903 sbom =  @atlaskit/platform-feature-flags ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 904 sbom =  @types/which ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 905 sbom =  combine-promises ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 906 sbom =  @types/filewriter ( npm )
#       * sbom_name not match to searched package name
#       * Cannot find repository tag
# Cannot find # 907 sbom =  is-network-error ( npm )
#       * npm.io search nothing
#       * Cannot find repository tag
# Cannot find # 908 sbom =  @octokit/plugin-paginate-graphql ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 909 sbom =  @types/btoa-lite ( npm )
#       * repo_url doesn't contain https://github.com/
#       * Cannot find repository tag
# Cannot find # 910 sbom =  @atlaskit/analytics-next-stable-react-context ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 911 sbom =  @atlaskit/codemod-utils ( npm )
#       * repo_url doesn't contain https://github.com/
#       * Cannot find repository tag
# Cannot find # 912 sbom =  @atlaskit/ds-lib ( npm )
#       * npm.io search nothing
#       * Cannot find repository tag
# Cannot find # 913 sbom =  @atlaskit/interaction-context ( npm )
#       * repo_url doesn't contain https://github.com/
#       * Cannot find repository tag
# Cannot find # 914 sbom =  @atlaskit/motion ( npm )
#       * repo_url doesn't contain https://github.com/
#       * Cannot find repository tag
# Cannot find # 915 sbom =  @atlaskit/visually-hidden ( npm )
#       * sbom_name not match to searched package name
#       * Cannot find repository tag
# Cannot find # 916 sbom =  eslint-plugin-i ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 917 sbom =  @atlaskit/spinner ( npm )
#       * repo_url doesn't contain https://github.com/
#       * Cannot find repository tag
# Cannot find # 918 sbom =  @atlaskit/analytics-next ( npm )
#       * npm.io search nothing
#       * Cannot find repository tag
# Cannot find # 919 sbom =  @atlaskit/ds-explorations ( npm )
#       * repo_url doesn't contain https://github.com/
#       * Cannot find repository tag
# Cannot find # 920 sbom =  @atlaskit/in-product-testing ( npm )
#       * repo_url doesn't contain https://github.com/
#       * Cannot find repository tag
# Cannot find # 921 sbom =  @atlaskit/popper ( npm )
#       * npm.io search nothing
#       * cannot access ' atlassian/atlassian-frontend-mirror '
# Cannot find # 922 sbom =  @atlaskit/layering ( npm )
#       * repo_url doesn't contain https://github.com/
#       * Cannot find repository tag
# Cannot find # 923 sbom =  @atlaskit/focus-ring ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 924 sbom =  @atlaskit/inline-dialog ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 925 sbom =  @atlaskit/blanket ( npm )
#       * npm.io search nothing
#       * Cannot find repository tag
# Cannot find # 926 sbom =  @atlaskit/primitives ( npm )
#       * npm.io search nothing
#       * Cannot find repository tag
# ...
# Cannot find # 2476 sbom =  schannel ( cargo )
# Cannot find # 2477 sbom =  try-lock ( cargo )
# Cannot find # 2478 sbom =  bytes-utils ( cargo )
# Cannot find # 2479 sbom =  fs-err ( cargo )
# Cannot find # 2480 sbom =  derive-where ( cargo )
# Cannot find # 2481 sbom =  dataview ( cargo )
# Cannot find # 2482 sbom =  pelite ( cargo )
# Cannot find # 2483 sbom =  lexpr-macros ( cargo )
# Cannot find # 2484 sbom =  native-windows-gui ( cargo )
# Cannot find # 2485 sbom =  cpufeatures ( cargo )
# Cannot find # 2486 sbom =  octocrab ( cargo )
# Cannot find # 2487 sbom =  wasm-streams ( cargo )
# Cannot find # 2488 sbom =  crossbeam-deque ( cargo )
# Cannot find # 2489 sbom =  crossbeam-epoch ( cargo )
# Cannot find # 2490 sbom =  crossbeam-queue ( cargo )
# Cannot find # 2491 sbom =  crossbeam ( cargo )
# Cannot find # 2492 sbom =  console ( cargo )
# Cannot find # 2493 sbom =  termcolor ( cargo )
# Cannot find # 2494 sbom =  xattr ( cargo )
# Cannot find # 2495 sbom =  rayon-core ( cargo )
# Cannot find # 2496 sbom =  unicode-bidi ( cargo )
# Cannot find # 2497 sbom =  shlex ( cargo )
# Cannot find # 2498 sbom =  num-conv ( cargo )
# Cannot find # 2499 sbom =  itertools ( cargo )
# Cannot find # 2500 sbom =  webpki-roots ( cargo )
# Cannot find # 2501 sbom =  iana-time-zone ( cargo )
# Cannot find # 2502 sbom =  unicode-segmentation ( cargo )
# Cannot find # 2503 sbom =  num-integer ( cargo )
# Cannot find # 2504 sbom =  indicatif ( cargo )
# Cannot find # 2505 sbom =  pkg-config ( cargo )
# Cannot find # 2506 sbom =  textwrap ( cargo )
# Cannot find # 2507 sbom =  unicode-normalization ( cargo )
# Cannot find # 2508 sbom =  thread_local ( cargo )
# Cannot find # 2509 sbom =  futures-timer ( cargo )
# Cannot find # 2510 sbom =  ahash ( cargo )
# Cannot find # 2511 sbom =  h2 ( cargo )
# Cannot find # 2512 sbom =  http ( cargo )
# Cannot find # 2513 sbom =  js-sys ( cargo )
# Cannot find # 2514 sbom =  pin-project ( cargo )
# Cannot find # 2515 sbom =  pin-project-internal ( cargo )
# Cannot find # 2516 sbom =  quote ( cargo )
# Cannot find # 2517 sbom =  time-macros ( cargo )
# Cannot find # 2518 sbom =  wasm-bindgen ( cargo )
# Cannot find # 2519 sbom =  wasm-bindgen-backend ( cargo )
# Cannot find # 2520 sbom =  wasm-bindgen-futures ( cargo )
# Cannot find # 2521 sbom =  wasm-bindgen-macro ( cargo )
# Cannot find # 2522 sbom =  wasm-bindgen-macro-support ( cargo )
# Cannot find # 2523 sbom =  wasm-bindgen-shared ( cargo )
# Cannot find # 2524 sbom =  web-sys ( cargo )
# Cannot find # 2525 sbom =  aho-corasick ( cargo )
# Cannot find # 2526 sbom =  reqwest ( cargo )
# Cannot find # 2527 sbom =  smallvec ( cargo )
# Cannot find # 2528 sbom =  walkdir ( cargo )
# Cannot find # 2529 sbom =  itoa ( cargo )
# Cannot find # 2530 sbom =  pin-project-lite ( cargo )
# Cannot find # 2531 sbom =  wasm-bindgen-test ( cargo )
# Cannot find # 2532 sbom =  wasm-bindgen-test-macro ( cargo )
# Cannot find # 2533 sbom =  chrono ( cargo )
# Cannot find # 2534 sbom =  allocator-api2 ( cargo )
# Cannot find # 2535 sbom =  bumpalo ( cargo )
# Cannot find # 2536 sbom =  combine ( cargo )
# Cannot find # 2537 sbom =  encoding_rs ( cargo )
# Cannot find # 2538 sbom =  libredox ( cargo )
# Cannot find # 2539 sbom =  rayon ( cargo )
# Cannot find # 2540 sbom =  redox_users ( cargo )
# Cannot find # 2541 sbom =  serde_yaml ( cargo )
# Cannot find # 2542 sbom =  unsafe-libyaml ( cargo )
# Cannot find # 2543 sbom =  serde_path_to_error ( cargo )
# Cannot find # 2544 sbom =  arc-swap ( cargo )
# Cannot find # 2545 sbom =  addr2line ( cargo )
# Cannot find # 2546 sbom =  gimli ( cargo )
# Cannot find # 2547 sbom =  utf8parse ( cargo )
# Cannot find # 2548 sbom =  signal-hook-registry ( cargo )
# Cannot find # 2549 sbom =  rustix ( cargo )
# Cannot find # 2550 sbom =  lock_api ( cargo )
# Cannot find # 2551 sbom =  parking_lot_core ( cargo )
# Cannot find # 2552 sbom =  concurrent-queue ( cargo )
# Cannot find # 2553 sbom =  socket2 ( cargo )
# Cannot find # 2554 sbom =  autocfg ( cargo )
# Cannot find # 2555 sbom =  num-traits ( cargo )
# Cannot find # 2556 sbom =  deadpool-runtime ( cargo )
# Cannot find # 2557 sbom =  tokio-util ( cargo )
# Cannot find # 2558 sbom =  ryu ( cargo )
# Cannot find # 2559 sbom =  semver ( cargo )
# Cannot find # 2560 sbom =  rustc-demangle ( cargo )
# Cannot find # 2561 sbom =  errno ( cargo )
# Cannot find # 2562 sbom =  instant ( cargo )
# Cannot find # 2563 sbom =  waker-fn ( cargo )
# Cannot find # 2564 sbom =  rustversion ( cargo )
# Cannot find # 2565 sbom =  linux-raw-sys ( cargo )
# Cannot find # 2566 sbom =  libc ( cargo )
# Cannot find # 2567 sbom =  anyhow ( cargo )
# Cannot find # 2568 sbom =  crossbeam-utils ( cargo )
# Cannot find # 2569 sbom =  crossbeam-channel ( cargo )
# Cannot find # 2570 sbom =  crc32fast ( cargo )
# Cannot find # 2571 sbom =  plotters ( cargo )
# Cannot find # 2572 sbom =  plotters-backend ( cargo )
# Cannot find # 2573 sbom =  parking_lot ( cargo )
# Cannot find # 2574 sbom =  zeroize ( cargo )
# Cannot find # 2575 sbom =  native-tls ( cargo )
# Cannot find # 2576 sbom =  unicode-width ( cargo )
# Cannot find # 2577 sbom =  tar ( cargo )
# Cannot find # 2578 sbom =  strum_macros ( cargo )
# Cannot find # 2579 sbom =  windows-result ( cargo )
# Cannot find # 2580 sbom =  vte_generate_state_changes ( cargo )
# Cannot find # 2581 sbom =  crc32c ( cargo )
# Cannot find # 2582 sbom =  backtrace ( cargo )
# Cannot find # 2583 sbom =  memchr ( cargo )
# Cannot find # 2584 sbom =  httparse ( cargo )
# Cannot find # 2585 sbom =  miniz_oxide ( cargo )
# Cannot find # 2586 sbom =  proc-macro2 ( cargo )
# Cannot find # 2587 sbom =  strum ( cargo )
# Cannot find # 2588 sbom =  num-bigint ( cargo )
# Cannot find # 2589 sbom =  log ( cargo )
# Cannot find # 2590 sbom =  pest ( cargo )
# Cannot find # 2591 sbom =  pest_derive ( cargo )
# Cannot find # 2592 sbom =  pest_generator ( cargo )
# Cannot find # 2593 sbom =  pest_meta ( cargo )
# Cannot find # 2594 sbom =  zerocopy ( cargo )
# Cannot find # 2595 sbom =  zerocopy-derive ( cargo )
# Cannot find # 2596 sbom =  windows_i686_gnullvm ( cargo )
# Cannot find # 2597 sbom =  tinyvec ( cargo )
# Cannot find # 2598 sbom =  sysinfo ( cargo )
# Cannot find # 2599 sbom =  hyper ( cargo )
# Cannot find # 2600 sbom =  security-framework ( cargo )
# Cannot find # 2601 sbom =  security-framework-sys ( cargo )
# Cannot find # 2602 sbom =  redox_syscall ( cargo )
# Cannot find # 2603 sbom =  thiserror-impl ( cargo )
# Cannot find # 2604 sbom =  thiserror ( cargo )
# Cannot find # 2605 sbom =  portable-atomic ( cargo )
# Cannot find # 2606 sbom =  openssl-sys ( cargo )
# Cannot find # 2607 sbom =  openssl ( cargo )
# Cannot find # 2608 sbom =  sha1_smol ( cargo )
# Cannot find # 2609 sbom =  tokio-macros ( cargo )
# Cannot find # 2610 sbom =  anstream ( cargo )
# Cannot find # 2611 sbom =  anstyle ( cargo )
# Cannot find # 2612 sbom =  anstyle-parse ( cargo )
# Cannot find # 2613 sbom =  anstyle-query ( cargo )
# Cannot find # 2614 sbom =  anstyle-wincon ( cargo )
# Cannot find # 2615 sbom =  colorchoice ( cargo )
# Cannot find # 2616 sbom =  is_terminal_polyfill ( cargo )
# Cannot find # 2617 sbom =  serde_spanned ( cargo )
# Cannot find # 2618 sbom =  version_check ( cargo )
# Cannot find # 2619 sbom =  tokio ( cargo )
# Cannot find # 2620 sbom =  toml_datetime ( cargo )
# Cannot find # 2621 sbom =  winnow ( cargo )
# Cannot find # 2622 sbom =  toml_edit ( cargo )
# Cannot find # 2623 sbom =  clap_derive ( cargo )
# Cannot find # 2624 sbom =  regex ( cargo )
# Cannot find # 2625 sbom =  winapi-util ( cargo )
# Cannot find # 2626 sbom =  ppv-lite86 ( cargo )
# Cannot find # 2627 sbom =  flate2 ( cargo )
# Cannot find # 2628 sbom =  object ( cargo )
# Cannot find # 2629 sbom =  derive_more-impl ( cargo )
# Cannot find # 2630 sbom =  derive_more ( cargo )
# Cannot find # 2631 sbom =  new_mime_guess ( cargo )
# Cannot find # 2632 sbom =  filetime ( cargo )
# Cannot find # 2633 sbom =  clap_builder ( cargo )
# Cannot find # 2634 sbom =  core-foundation-sys ( cargo )
# Cannot find # 2635 sbom =  cc ( cargo )
# Cannot find # 2636 sbom =  serde_derive ( cargo )
# Cannot find # 2637 sbom =  serde ( cargo )
# Cannot find # 2638 sbom =  serde_json ( cargo )
# Cannot find # 2639 sbom =  mio ( cargo )
# Find        # 2640 sbom =  actions/checkout ( githubactions ) Repository(full_name="actions/checkout")
# Find        # 2641 sbom =  jetli/wasm-pack-action ( githubactions ) Repository(full_name="jetli/wasm-pack-action")
# Find        # 2642 sbom =  actions/github-script ( githubactions ) Repository(full_name="actions/github-script")
# Find        # 2643 sbom =  dorny/test-reporter ( githubactions ) Repository(full_name="dorny/test-reporter")
# Find        # 2644 sbom =  actions/upload-artifact ( githubactions ) Repository(full_name="actions/upload-artifact")
# Find        # 2645 sbom =  actions/download-artifact ( githubactions ) Repository(full_name="actions/download-artifact")
# Find        # 2646 sbom =  graalvm/setup-graalvm ( githubactions ) Repository(full_name="graalvm/setup-graalvm")
# Find        # 2647 sbom =  styfle/cancel-workflow-action ( githubactions ) Repository(full_name="styfle/cancel-workflow-action")
#       * npm.io search nothing
# Find        # 2648 sbom =  @humanwhocodes/module-importer ( npm ) Repository(full_name="humanwhocodes/module-importer")
#       * npm.io search nothing
# Find        # 2649 sbom =  @isaacs/cliui ( npm ) Repository(full_name="yargs/cliui")
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 2650 sbom =  d3-drag ( npm )
#       * First search result doesn't contain 'package'
# Find        # 2651 sbom =  fast-levenshtein ( npm ) Repository(full_name="hiddentao/fast-levenshtein")
#       * First search result doesn't contain 'package'
# Find        # 2652 sbom =  header-case ( npm ) Repository(full_name="blakeembrey/change-case")
#       * First search result doesn't contain 'package'
# Find        # 2653 sbom =  is-boolean-object ( npm ) Repository(full_name="inspect-js/is-boolean-object")
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 2654 sbom =  is-callable ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 2655 sbom =  is-number-object ( npm )
#       * sbom_name not match to searched package name
# Find        # 2656 sbom =  iterator.prototype ( npm ) Repository(full_name="ljharb/Iterator.prototype")
#       * cannot access ' substack/text-table '
#       * cannot access ' substack/text-table '
# Cannot find # 2657 sbom =  text-table ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 2658 sbom =  use-sync-external-store ( npm )
#       * First search result doesn't contain 'package'
# Find        # 2659 sbom =  @types/istanbul-reports ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 2660 sbom =  archiver-utils ( npm )
#       * First search result doesn't contain 'package'
# Find        # 2661 sbom =  har-validator ( npm ) Repository(full_name="ahmadnassri/node-har-validator")
#       * First search result doesn't contain 'package'
# Find        # 2662 sbom =  isstream ( npm ) Repository(full_name="rvagg/isstream")
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 2663 sbom =  validate-npm-package-license ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 2664 sbom =  @types/cacheable-request ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 2665 sbom =  @types/keyv ( npm )
#       * First search result doesn't contain 'package'
# Find        # 2666 sbom =  rw ( npm ) Repository(full_name="mbostock/rw")
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 2667 sbom =  @types/babel__template ( npm )
#       * First search result doesn't contain 'package'
# Find        # 2668 sbom =  @types/istanbul-lib-coverage ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
# Find        # 2669 sbom =  @types/istanbul-lib-report ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 2670 sbom =  @types/tough-cookie ( npm )
#       * First search result doesn't contain 'package'
# Find        # 2671 sbom =  archiver ( npm ) Repository(full_name="archiverjs/node-archiver")
#       * First search result doesn't contain 'package'
# Find        # 2672 sbom =  @types/node-fetch ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * sbom_name not match to searched package name
#       * Cannot find repository tag
# Cannot find # 2673 sbom =  client-only ( npm )
#       * cannot access ' substack/semver-compare '
#       * Cannot find repository tag
# Cannot find # 2674 sbom =  semver-compare ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 2675 sbom =  @types/ms ( npm )
#       * First search result doesn't contain 'package'
# Find        # 2676 sbom =  @types/markdown-it ( npm ) Repository(full_name="DefinitelyTyped/DefinitelyTyped")
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 2677 sbom =  @types/d3-geo ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 2678 sbom =  d3-dispatch ( npm )
#       * First search result doesn't contain 'package'
# Following Github server redirection from /repos/dominictarr/config-chain to /repositories/2301184
# Find        # 2679 sbom =  config-chain ( npm ) Repository(full_name="dawsbot/config-chain")
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 2680 sbom =  @types/d3-color ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 2681 sbom =  @types/d3-interpolate ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 2682 sbom =  @types/d3-time ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 2683 sbom =  @types/d3-timer ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 2684 sbom =  @types/http-cache-semantics ( npm )
#       * cannot access ' thenativeweb/boolean '
#       * Cannot find repository tag
# Cannot find # 2685 sbom =  boolean ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 2686 sbom =  @types/cookie ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 2687 sbom =  @types/d3-axis ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 2688 sbom =  @types/d3-brush ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 2689 sbom =  @types/d3-chord ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 2690 sbom =  @types/d3-contour ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 2691 sbom =  @types/d3-delaunay ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 2692 sbom =  @types/d3-dispatch ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 2693 sbom =  @types/d3-drag ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 2694 sbom =  @types/d3-dsv ( npm )
#       * First search result doesn't contain 'package'
#       * Cannot find repository tag
# Cannot find # 2695 sbom =  @types/d3-fetch ( npm )
#       * First search result doesn't contain 'package'

# %%
def merge_mapping(src_list, merge_filename):
    
    output = {}
    
    # Let record overwrite if sbom_name already exist
    for src in src_list:
        raw = pd.read_csv(src)
        
        for index, row in raw.iterrows():
            output[row["sbom_name"]] = {"repo": row["repo"], "map_by": row["map_by"]}
            
    # Write output to csv file
    with open(merge_filename, "w") as f:
        # header
        f.write("sbom_name,repo,map_by,\n")
        
        for sbom_name in output.keys():
            f.write(str(sbom_name))
            f.write(",")
            f.write(output[sbom_name]["repo"])
            f.write(",")
            if isinstance(output[sbom_name]["map_by"], float):
                f.write("npm")
            else:
                f.write(output[sbom_name]["map_by"])
            f.write(",\n")

# %%
merge_mapping(["csv/metastep/map_sbom_name_to_repo_full_name.csv", 
               "csv/metastep/map_sbom_name_to_repo_full_name-1.csv"],
              "csv/metastep/map_sbom_name_to_repo_full_name-merged.csv")

# %% [markdown]
# ### HAS_LICENSE
#
# - Using id to match.

# %%
has_license_properties = {
    "repo": "repo",      # repo.full_name
    "license": "spdx_id" # repo.license.spdx_id
}

has_license_filename = "has_license.csv"

# %%
full_file_name = "csv/{}".format(has_license_filename)
write_headers(full_file_name, has_license_properties)

with open(full_file_name, "a") as f:
    for repo in target_repos:
        # get the repo
        g = Github()
        repo_info = g.get_repo(full_name_or_id=repo)
        
        f.write(repo)
        f.write(",")
        f.write(repo_info.license.spdx_id)
        f.write(",")
        f.write("\n")

# %% [markdown]
# ### IN_TOPIC
#
# - Using id to match

# %%
in_topic_properties = {
    "repo": "repo", 
    "topic": "topic"
}

in_topic_filename = "in_topic.csv"

# %%
full_file_name = "csv/{}".format(in_topic_filename)
write_headers(full_file_name, in_topic_properties)

with open(full_file_name, "a") as f:
    for repo in target_repos:
        # get the repo and topics
        g = Github()
        repo_info = g.get_repo(full_name_or_id=repo)
        topics = repo_info.topics
        
        for t in topics:
            temp = t.replace("-", "").replace(" ", "")
            
            f.write(repo)
            f.write(",")
            f.write(temp)
            f.write(",")
            f.write("\n")
