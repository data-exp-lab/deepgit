# %% [markdown]
# # DeepGit: Building Edges one Tag

# %% [markdown]
# ## Preparation
# ### Package Import

# %%
import requests
import pandas as pd
from datetime import datetime, timezone
import os
from dotenv import load_dotenv
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
from collections import Counter

# %%
load_dotenv()
# Out:
# True

# %% [markdown]
# ### GitHub Authenticate Setup

# %% [markdown]
# Create a `.env` file in the root directory and add the line `GITHUB_TOKEN = "your_token"`.

# %%
def authenticate_github(token):
    """
    Returns headers required for GitHub API requests.
    The Accept header includes the preview for topics.
    """
    return {
        'Authorization': f'token {token}',
        'Accept': 'application/vnd.github.mercy-preview+json'
    }
token = os.getenv("GITHUB_TOKEN")
headers = authenticate_github(token)

# %% [markdown]
# ## Function Definition

# %% [markdown]
# ### GitHub Extraction

# %%
def search_github_repos_by_topic(tag, headers):
    """
    Searches GitHub repositories that have the specified topic (tag) and over 100 stars.
    Handles pagination and returns a list of dictionaries containing only the repository name and repo id.
    """
    repos = []
    page = 1
    per_page = 100
    query = f"topic:{tag} stars:>5"
    
    while True:
        url = (
            f"https://api.github.com/search/repositories?q={query}"
            f"&sort=stars&order=desc&per_page={per_page}&page={page}"
        )
        response = requests.get(url, headers=headers)
        if response.status_code != 200:
            print(f"Error fetching repositories for tag '{tag}': {response.status_code}")
            break

        data = response.json()
        items = data.get('items', [])
        if not items:
            break

        for item in items:
            repos.append(
                 item.get("full_name")
            )

        # Break if fewer than 'per_page' items were returned (i.e. last page)
        if len(items) < per_page:
            break

        page += 1

    return repos

def get_repo_topics(full_name, headers):
    """
    Fetches the topics (tags) of a repository given its full name.
    """
    url = f"https://api.github.com/repos/{full_name}/topics"
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        return response.json().get('names', [])
    return []

# %% [markdown]
# ### Tag Similarity

# %%
def compute_topic_similarities(model_name: str, given_topic: str, topic_pool: list, threshold: float = 0.8):
    """
    Compute cosine similarity between a given topic and a pool of topics, filtering by a threshold.

    Args:
        model_name (str): Name of the SentenceTransformer model (e.g., 'all-MiniLM-L6-v2').
        given_topic (str): The topic to compare against the pool.
        topic_pool (list): List of topics to compare.
        threshold (float): Minimum similarity score to be included in the results (default: 0.8).

    Returns:
        list: Sorted list of (topic, similarity) tuples in descending order of similarity.
    """
    # Load model
    model = SentenceTransformer(model_name)
    
    # Encode the given topic and the pool of topics
    given_embedding = model.encode([given_topic])
    pool_embeddings = model.encode(topic_pool)
    
    # Compute cosine similarities
    similarities = cosine_similarity(given_embedding, pool_embeddings)[0]
    
    # Pair topics with their similarity scores
    topic_similarity_pairs = [topic for topic, sim in zip(topic_pool, similarities) if sim >= threshold]
    
    # Sort topics by similarity (higher is better)
    topic_similarity_pairs.sort(key=lambda x: x[1], reverse=True)

    return topic_similarity_pairs

# %% [markdown]
# ### Temp Store

# %%
def write_list_to_file(data_list, file_address):
    """
    Writes each item of the given list to a new line in a text file.

    :param data_list: List of elements to write to the file.
    :param file_address: Path to the file where the list should be saved.
    """
    try:
        with open(file_address, 'w', encoding='utf-8') as file:
            for item in data_list:
                file.write(f"{item}\n")
        print(f"List successfully written to {file_address}")
    except Exception as e:
        print(f"Error writing to file: {e}")

# %% [markdown]
# ## Demonstration

# %% [markdown]
# ### Input Tag(Topic)

# %% [markdown]
# Suppose we have a topic `llm`

# %%
input_topic = "large-language-model"

# %% [markdown]
# ### Git the Initial Repos

# %% [markdown]
# **Note**: for demonstration Purpose, we only extract repos have more than 10 stars

# %%
repos_with_input_topic = search_github_repos_by_topic(input_topic, headers)

# %%
len(repos_with_input_topic)
# Out:
# 185

# %%
repos_with_input_topic
# Out:
# ['jingyaogong/minimind',
#  'InternLM/InternLM',
#  'OpenSPG/KAG',
#  'gluonfield/enchanted',
#  'open-compass/opencompass',
#  '0xPlaygrounds/rig',
#  'verazuo/jailbreak_llms',
#  'ridgerchu/matmulfreellm',
#  'BrainBlend-AI/atomic-agents',
#  'InternLM/InternLM-XComposer',
#  'RManLuo/Awesome-LLM-KG',
#  'intel/intel-extension-for-transformers',
#  'dvlab-research/LISA',
#  'samchon/nestia',
#  'hyp1231/awesome-llm-powered-agent',
#  'EgoAlpha/prompt-in-context-learning',
#  'coderonion/awesome-yolo-object-detection',
#  'starpig1129/DATAGEN',
#  'zchoi/Awesome-Embodied-Agent-with-LLMs',
#  'llm-jp/awesome-japanese-llm',
#  'Tebmer/Awesome-Knowledge-Distillation-of-LLMs',
#  'acon96/home-llm',
#  'X-LANCE/SLAM-LLM',
#  'EasyJailbreak/EasyJailbreak',
#  'zhanshijinwat/Steel-LLM',
#  'showlab/VLog',
#  'onejune2018/Awesome-LLM-Eval',
#  'Kenza-AI/sagify',
#  'Paranioar/Awesome_Matching_Pretraining_Transfering',
#  'zchuz/CoT-Reasoning-Survey',
#  'dvlab-research/LLMGA',
#  'dylanhogg/llmgraph',
#  'yingpengma/Awesome-Story-Generation',
#  'SuperMedIntel/Medical-Graph-RAG',
#  'Wang-ML-Lab/llm-continual-learning-survey',
#  'InternLM/Agent-FLAN',
#  'westlake-repl/Recommendation-Systems-without-Explicit-ID-Features-A-Literature-Review',
#  'archersama/awesome-recommend-system-pretraining-papers',
#  'chrisliu298/awesome-llm-unlearning',
#  'zju-vipa/Odyssey',
#  'wyu97/GenRead',
#  'SAILResearch/awesome-foundation-model-leaderboards',
#  'zjysteven/lmms-finetune',
#  'Ledzy/BAdam',
#  'JinjieNi/MixEval',
#  'microsoft/multilspy',
#  'JayZhang42/FederatedGPT-Shepherd',
#  'yuhangzang/ContextDET',
#  'Picovoice/picollm',
#  'lxa9867/ImageFolder',
#  'RyanLiu112/compute-optimal-tts',
#  'BradMoonUESTC/finite-monkey-engine',
#  'nikolaydubina/llama2.go',
#  'Lichang-Chen/InstructZero',
#  'austin-starks/Promptimizer',
#  'rainym00d/LLM4RS',
#  'IAAR-Shanghai/ICSFSurvey',
#  'serp-ai/LLaMA-8bit-LoRA',
#  'westlake-repl/IDvs.MoRec',
#  'xrsrke/toolformer',
#  'westlake-repl/PixelRec',
#  'PKU-Alignment/beavertails',
#  'xNul/chat-llama-discord-bot',
#  'cnzzx/VSA',
#  'Sreyan88/GAMA',
#  'pillowsofwind/Knowledge-Conflicts-Survey',
#  'chrisliu298/awesome-representation-engineering',
#  'RManLuo/graph-constrained-reasoning',
#  'YZ-Cai/SimGRAG',
#  'Event-AHU/Medical_Image_Analysis',
#  'ravenSanstete/Obsidian-MantouAI',
#  'leduckhai/wav2graph',
#  'bilalonur/awesome-llm-os',
#  'asukaminato0721/telegram-summary-bot',
#  'starmpcc/CAMEL',
#  'nick7nlp/Counting-Stars',
#  'leezythu/FlexKBQA',
#  'ymcui/ChatGPT-in-Academia',
#  'mikahama/uralicNLP',
#  'WadeYin9712/Dynosaur',
#  'sean-t-smith/pwned-by-passgpt',
#  'Jacob-Zhou/simple-csc',
#  'HIT-SCIR/Abacus',
#  'OSU-NLP-Group/AttrScore',
#  'snwfdhmp/llm',
#  'chao1224/ProteinDT',
#  'pbhu1024/awesome-augmented-language-model',
#  'azminewasi/Awesome-LLMs-ICLR-24',
#  'quolo-ai/quolo',
#  'chenshuang-zhang/imagenet_d',
#  'themaximalist/llm.js',
#  'ritaranx/ClinGen',
#  'PeterH0323/ancient-chat-llm',
#  'Wangjw6/LLMob',
#  'Bruce-Lee-LY/flash_attention_inference',
#  'yang-su2000/Voice2Action',
#  'HRI-EU/tulip_agent',
#  'anseryuer/Local_LLM_Deployment_Guide_Chinese',
#  'RUC-GSAI/Llama-3-SynE',
#  'Zhuofeng-Li/TEG-Benchmark',
#  'see-say-segment/sesame',
#  'LlmKira/novelai-python',
#  'VinAIResearch/RecGPT',
#  'Baizhige/EEGUnity',
#  'ParthaPRay/LLM-Learning-Sources',
#  'Bruce-Lee-LY/decoding_attention',
#  'kkyuhun94/dalda',
#  'westlake-repl/Adapter4Rec',
#  'mytechnotalent/rea',
#  'mytechnotalent/pa',
#  'microsoft/synthetic-rag-index',
#  'zjunlp/InstructCell',
#  'HRI-EU/AttentiveSupport',
#  'liunian-Jay/Awesome-RAG',
#  'RainBowLuoCS/OpenOmni',
#  'jxhuang0508/Awesome-LLM-Reasoning-OpenAI-o1',
#  'tsinghua-fib-lab/SmartAgent',
#  'SALT-NLP/PrivacyLens',
#  'appier-research/structure-gen',
#  'thekevinscott/vicuna-7b',
#  'egeozsoy/ORacle',
#  'TsingmaoAI/MI-optimize',
#  'MarkLee131/PatchFinder',
#  'codezakh/DataEnvGym',
#  'zzz47zzz/spurious-forgetting',
#  'raymond0208/CashCatalyst',
#  'ICTMCG/POGER',
#  'quanshr/AugCon',
#  'kingnobro/Chat2SVG',
#  'DaoyuanLi2816/Kaggle-Eedi-Mining-Misconceptions-in-Mathematics-Silver-Medal',
#  'hesamsheikh/llm-mechanics',
#  'quanshr/DMoERM',
#  'zabir-nabil/awesome-multilingual-large-language-models',
#  'AmirMotefaker/Create-your-own-ChatGPT',
#  'dsdanielpark/all-about-llm',
#  'AI4Finance-Foundation/FinRAG',
#  'BARUDA-AI/Awesome-Medical-LLM',
#  'Nerif-AI/Nerif',
#  'daviden1013/llm-ie',
#  'iakashpaul/Portal',
#  'KID-22/Cocktail',
#  'sahilichake/Document-Summarization-App-using-LLM',
#  'KID-22/Source-Bias',
#  'Ask-Sage/AskSage-Open-Source-Community',
#  'Ashot72/AI-Chatbot',
#  'tsinghua-fib-lab/AgentMove',
#  'JinjieNi/MixEval-X',
#  'SuperBruceJia/Awesome-Mixture-of-Experts',
#  'THU-ESIS/GEOSatDB',
#  'shamspias/chatwithDB',
#  'tshu-w/ComEM',
#  'ntt-dkiku/route-explainer',
#  'samhoooo/chatapp-ollama',
#  'blakeb211/billcat-local-llm',
#  'constantjxyz/PromptLink',
#  'jparkerweb/llm-distillery',
#  'LDexter/DavinCC',
#  'gmp007/PropertyExtractor',
#  'genia-dev/vibraniumdome',
#  'Ne0bliviscaris/Ollama-SQLite-RAG',
#  'zhiao777774/awesome-personalized-lm',
#  'rhubarbwu/linguistic-collapse',
#  'xyproto/describeimage',
#  'answers111/OpenCarbonEval',
#  'R-D-BioTech-Alaska/Qelm',
#  'research-outcome/LLM-Game-Benchmark',
#  'jiangnanboy/Image_KIE_LLM',
#  'mzattera/predictive-powers',
#  'LazerLambda/Promptzl',
#  'lirenhao1997/CoEvol',
#  'pittisl/mPnP-LLM',
#  'mahsasheikh/DrugGen',
#  'analyticsinmotion/integrate-palm-into-word',
#  'mrseanryan/gpt-multi-atomic-agents',
#  'telalabs/thor',
#  'doccstat/llm-watermark-cpd',
#  'kapshaul/LLM-finetune-vuln-detection',
#  'fiorino-ai/fiorino-ai',
#  'chrisliu298/awesome-sparse-autoencoders',
#  'MySong7NLPer/ChatGPT_as_Keyphrase_Generator',
#  'FudanSELab/LISP',
#  'tsinghua-fib-lab/LIMP',
#  'mehrdad-dev/Battle-of-the-Wordsmiths',
#  'telalabs/loki',
#  'jpcadena/ice-breaker']

# %%
write_list_to_file(repos_with_input_topic, "./temp/llm_R.txt")
# Out:
# List successfully written to ./temp/llm_R.txt

# %% [markdown]
# ### Get the Pool of Topics
#
# Now we have a set of repos and we can extract the pool of topics from these repos

# %%
topic_pool = []
for full_name in repos_with_input_topic:
    topic_pool = topic_pool + get_repo_topics(full_name, headers)

# %%
len(topic_pool)
# Out:
# 1691

# %%
topic_pool_rm_dup = list(set(topic_pool))

# %%
topic_pool_rm_dup[0:10]
# Out:
# ['multi-modal-llms',
#  'in-context-learning',
#  'video',
#  'fine-tuning',
#  'generative-pretraining',
#  'camel',
#  'data',
#  'music-processing',
#  'scene-graph',
#  'llm-recommendation']

# %%
write_list_to_file(topic_pool_rm_dup, "./temp/llm_T.txt")
# Out:
# List successfully written to ./temp/llm_T.txt

# %% [markdown]
# ### Further Process the Topics

# %% [markdown]
# Note:We probably should do this again and again to ensure that the list of tags is thorough

# %% [markdown]
# **Step1: Frequency Fiter**

# %%
topic_counts = Counter(topic_pool)

# %%
filtered_topic_counts = {topic: count for topic, count in topic_counts.items() if count >= 5}

# %%
list(filtered_topic_counts.keys())
# Out:
# ['artificial-intelligence',
#  'large-language-model',
#  'chatbot',
#  'gpt',
#  'llm',
#  'knowledge-graph',
#  'llama',
#  'llama2',
#  'evaluation',
#  'benchmark',
#  'chatgpt',
#  'openai',
#  'ai',
#  'agent',
#  'generative-ai',
#  'large-language-models',
#  'llms',
#  'openai-api',
#  'gpt-4',
#  'multimodal',
#  'vision-language-model',
#  'language-model',
#  'llm-inference',
#  'rag',
#  'retrieval-augmented-generation',
#  'awesome-list',
#  'foundation-model',
#  'foundation-models',
#  'chain-of-thought',
#  'prompt-engineering',
#  'langchain',
#  'python',
#  'awesome',
#  'multimodal-large-language-models',
#  'dataset',
#  'machine-learning',
#  'nlp',
#  'deep-learning',
#  'image-generation',
#  'natural-language-processing',
#  'llm-agent',
#  'fine-tuning',
#  'large-multimodal-models',
#  'ml',
#  'reasoning']

# %% [markdown]
# **Step2: Similarity Filter**

# %%
model_name = "all-MiniLM-L6-v2"
similar_topics = compute_topic_similarities(model_name, input_topic, list(filtered_topic_counts.keys()), 0.5)

# %%
len(similar_topics)
# Out:
# 6

# %%
similar_topics
# Out:
# ['multimodal-large-language-models',
#  'vision-language-model',
#  'large-language-model',
#  'large-language-models',
#  'language-model',
#  'large-multimodal-models']

# %% [markdown]
# Meanwhile, I am using this prompt in o3-mini
# `return me relevant tags to {topic}`

# %% [markdown]
# **Step3: Mannually Craft(Human in the Loop)**

# %%
# with the help of OpenAI O3-Mini
similar_topics = [
    "large-language-models",
    "large-language-model",
    "llm",
    "llms",
    "foundation-model",
    "foundation-models",
    "generative-ai",
    "language-model",
    "llm-inference",
    "multimodal-large-language-models",
    'gpt',
    'llama',
    'llama2',
    'openai',
    'chatgpt',
    'generative-ai',
    'multimodal',
    'gpt-4',
    'retrieval-augmented-generation',
    'chain-of-thought',
    'prompt-engineering',
    'langchain',
    'llm-agent'
]

# %% [markdown]
# ### Get All Possible Repos

# %% [markdown]
# **"422" error means it exceed the GitHub API Rate Limits**

# %%
final_list_repos = [ ]
for topic in similar_topics:
    ls_repos = search_github_repos_by_topic(topic, headers)
    final_list_repos = final_list_repos + ls_repos
# Out:
# Error fetching repositories for tag 'large-language-models': 422
# Error fetching repositories for tag 'llm': 422
# Error fetching repositories for tag 'llms': 422
# Error fetching repositories for tag 'generative-ai': 422
# Error fetching repositories for tag 'gpt': 422
# Error fetching repositories for tag 'openai': 422
# Error fetching repositories for tag 'chatgpt': 422
# Error fetching repositories for tag 'generative-ai': 422
# Error fetching repositories for tag 'gpt-4': 422
# Error fetching repositories for tag 'langchain': 422

# %%
final_list_rm_dup = list(set(final_list_repos))

# %%
len(final_list_rm_dup)
# Out:
# 9367

# %% [markdown]
# ### Extract All Possible Information for a Repo

# %%
# Function to fetch repository details
def get_repo_data(repo_name, headers):
    url = f"https://api.github.com/repos/{repo_name}"
    response = requests.get(url, headers=headers)

    if response.status_code == 200:
        return response.json()
    else:
        print(f"Error fetching repo {repo_name}: {response.status_code}")
        return None

# List of repositories (ensure full names: 'owner/repo')
repo_data = []
for repo in final_list_rm_dup:
    repo_info = get_repo_data(repo, headers)
    if repo_info:
        repo_data.append(repo_info)  # Stores full JSON response

# Convert list of dictionaries into DataFrame
df_repos = pd.DataFrame(repo_data)
# Out:
# Error fetching repo irgolic/AutoPR: 403
# Error fetching repo fluxninja/aperture: 403
# Error fetching repo itsOwen/CyberScraper-2077: 403
# Error fetching repo Alab-NII/Awesome-SciLM: 403
# Error fetching repo YJiangcm/Lion: 403
# Error fetching repo mccaffary/GPT-4-ChatGPT-Project-Euler: 403
# Error fetching repo BiomedSciAI/gene-benchmark: 403
# Error fetching repo association-rosia/flair-2: 403
# Error fetching repo rryam/LumoKit: 403
# Error fetching repo taichengguo/LLM_MultiAgents_Survey_Papers: 403
# Error fetching repo michaelfeil/infinity: 403
# Error fetching repo business-science/ai-data-science-team: 403
# Error fetching repo xiangsx/gpt4free-ts: 403
# Error fetching repo xebia-functional/xef: 403
# Error fetching repo yunwei37/Awesome-Prompt-Engineering-ZH-CN: 403
# Error fetching repo build-on-aws/gen-ai-workshop: 403
# Error fetching repo adrianhajdin/project_ai_mern_image_generation: 403
# Error fetching repo autowarefoundation/autoware.privately-owned-vehicles: 403
# Error fetching repo hanbyel0105/Diff-HMR: 403
# Error fetching repo InternLM/xtuner: 403
# Error fetching repo MLT-OSS/samepage: 403
# Error fetching repo vivekuppal/transcribe: 403
# Error fetching repo xuyuan23/operateGPT: 403
# Error fetching repo blotterfyi/velocity: 403
# Error fetching repo depromeet/Swimie-server: 403
# Error fetching repo reichenbch/RAG-examples: 403
# Error fetching repo nandxorandor/chatbot_VS_chatbot: 403
# Error fetching repo LinkScapeOfficial/Ollmao: 403
# Error fetching repo nathanfhh/Digital-Form-with-GPT4-Vision-API: 403
# Error fetching repo zyushun/Adam-mini: 403
# Error fetching repo lopuhin/transformer-lm: 403
# Error fetching repo RaptorMai/CompBench: 403
# Error fetching repo Rishang/heygpt: 403
# Error fetching repo Azzedde/brainstormers: 403
# Error fetching repo BradMoonUESTC/finite-monkey-engine: 403
# Error fetching repo matthaigh27/ChatGPT-android-app: 403
# Error fetching repo bigai-nlco/CREAM: 403
# Error fetching repo sinanuozdemir/quick-start-guide-to-llms: 403
# Error fetching repo go2coding/go2coding.github.io: 403
# Error fetching repo EvolvingLMMs-Lab/Otter: 403
# Error fetching repo mesutdmn/Autonomous-Multi-Agent-Systems-with-CrewAI-Essay-Writer: 403
# Error fetching repo longyuewangdcu/Chinese-Llama-2: 403
# Error fetching repo DAMO-NLP-SG/Video-LLaMA: 403
# Error fetching repo NirDiamant/Controllable-RAG-Agent: 403
# Error fetching repo locuslab/massive-activations: 403
# Error fetching repo gentaiscool/multi-task-cs-lm: 403
# Error fetching repo om-ai-lab/RS5M: 403
# Error fetching repo yinzhangyue/SelfAware: 403
# Error fetching repo shamspias/gpt-document-trained-chatbot-builder: 403
# Error fetching repo Brutuski/hal2023-cli: 403
# Error fetching repo AdamG012/moe-paper-models: 403
# Error fetching repo mscheong01/interfAIce: 403
# Error fetching repo microsoft/Tokenizer: 403
# Error fetching repo JieyuZ2/EcoAssistant: 403
# Error fetching repo Intelligent-CAT-Lab/PLTranslationEmpirical: 403
# Error fetching repo rodyherrera/Lovelace: 403
# Error fetching repo Paranioar/Awesome_Matching_Pretraining_Transfering: 403
# Error fetching repo Nota-NetsPresso/shortened-llm: 403
# Error fetching repo reasoning-machines/CoCoGen: 403
# Error fetching repo riverscuomo/social: 403
# Error fetching repo XduSyL/EventGPT: 403
# Error fetching repo NeumTry/NeumAI: 403
# Error fetching repo snowby666/poe-api-wrapper: 403
# Error fetching repo devhub-ai/devhub: 403
# Error fetching repo flepied/second-brain-agent: 403
# Error fetching repo dKosarevsky/AI-Talks: 403
# Error fetching repo Nokia-Bell-Labs/papagei-foundation-model: 403
# Error fetching repo raphaelmansuy/code2prompt: 403
# Error fetching repo zjohn77/lightning-mlflow-hf: 403
# Error fetching repo Ransaka/daily-llama: 403
# Error fetching repo gabeur/mmt: 403
# Error fetching repo loretoparisi/bert-movie-reviews-sentiment-classifier: 403
# Error fetching repo baixianghuang/HalluEditBench: 403
# Error fetching repo BurakAhmet/DeepLearning.AI-TensorFlow-Advanced-Techniques-Specialization: 403
# Error fetching repo bloomberg/dataless-model-merging: 403
# Error fetching repo PromptlyCode/PromptlyCode: 403
# Error fetching repo CAOANJIA/image-caption: 403
# Error fetching repo jianglongye/featurenerf: 403
# Error fetching repo BlackHC/llm-strategy: 403
# Error fetching repo MarvinJWendt/promptbuilder.dev: 403
# Error fetching repo wgryc/emerging-trajectories: 403
# Error fetching repo rese1f/STEVE: 403
# Error fetching repo BlueBash/postgres-chatbot: 403
# Error fetching repo debnsuma/fcc-ai-engineering-aws: 403
# Error fetching repo kingnobro/Chat2SVG: 403
# Error fetching repo tensorzero/tensorzero: 403
# Error fetching repo atef-ataya/Large-Language-Models-Tutorial: 403
# Error fetching repo receyuki/stable-diffusion-prompt-reader: 403
# Error fetching repo belladoreai/llama-tokenizer-js: 403
# Error fetching repo grasses/PoisonPrompt: 403
# Error fetching repo cupybara/java-langchains: 403
# Error fetching repo danny-avila/LibreChat: 403
# Error fetching repo visual-haystacks/mirage: 403
# Error fetching repo Adnan9011/github-search: 403
# Error fetching repo superagent-ai/superagent-py: 403
# Error fetching repo TheHormat/ChessCast: 403
# Error fetching repo weavel-ai/promptmodel-python: 403
# Error fetching repo pooya-mohammadi/easy_image_inpainting: 403
# Error fetching repo PKU-Alignment/align-anything: 403
# Error fetching repo buaacyw/GaussianEditor: 403
# Error fetching repo nicrusso7/rex-gym: 403
# Error fetching repo josStorer/chatGPT-search-engine-extension: 403
# Error fetching repo axflow/axflow: 403
# Error fetching repo zjunlp/WKM: 403
# Error fetching repo yaohui-wyh/ctoc: 403
# Error fetching repo iltoga/WebSummarizer: 403
# Error fetching repo fardjad/node-llmatic: 403
# Error fetching repo ikechan8370/chatgpt-plugin: 403
# Error fetching repo vectornguyen76/resume-ranking: 403
# Error fetching repo braindler/Braindler: 403
# Error fetching repo Alibaba-NLP/KB-NER: 403
# Error fetching repo mickymultani/RAG-with-Cross-Encoder-Reranker: 403
# Error fetching repo liucongg/ChatGLM-Finetuning: 403
# Error fetching repo cheahjs/free-llm-api-resources: 403
# Error fetching repo jiacai2050/shellgpt: 403
# Error fetching repo vndee/local-talking-llm: 403
# Error fetching repo RahulSChand/llama2.c-for-dummies: 403
# Error fetching repo milojeBtc/ai-mental-agent: 403
# Error fetching repo AdirthaBorgohain/reportAI: 403
# Error fetching repo getAsterisk/deepclaude: 403
# Error fetching repo Gitax18/ReadMeAI: 403
# Error fetching repo clchinkc/stockchat: 403
# Error fetching repo BaiTheBest/SparseLLM: 403
# Error fetching repo GoogleCloudPlatform/generative-ai: 403
# Error fetching repo Zai-Kun/reverse-engineered-chatgpt: 403
# Error fetching repo enoche/MultimodalRecSys: 403
# Error fetching repo pkdindustries/soulshack: 403
# Error fetching repo texttron/hyde: 403
# Error fetching repo rajveersinghcse/PetCare-AI-Chatbot: 403
# Error fetching repo DataEval/dingo: 403
# Error fetching repo iAmmarTahir/KnowledgeGraphGPT: 403
# Error fetching repo szczyglis-dev/py-gpt: 403
# Error fetching repo mhaowork/amblegpt: 403
# Error fetching repo steel-dev/steel-cookbook: 403
# Error fetching repo sail-sg/sailor-llm: 403
# Error fetching repo Azure-Samples/rag-postgres-openai-python: 403
# Error fetching repo mgilangjanuar/agentify: 403
# Error fetching repo Muhtasham/simulator: 403
# Error fetching repo amazon-science/synthesizrr: 403
# Error fetching repo y9tr3ble/AIAssistantBot: 403
# Error fetching repo fedebotu/Green-Planet-Transformers-3: 403
# Error fetching repo Protosec-Research/AutoGDB: 403
# Error fetching repo ztjhz/BetterChatGPT: 403
# Error fetching repo Yuan-ManX/ai-multimodal-timeline: 403
# Error fetching repo MaxiDonkey/DelphiGroqCloud: 403
# Error fetching repo seandearnaley/reddit-gpt-summarizer: 403
# Error fetching repo 1arry1iu/archetype: 403
# Error fetching repo jmaczan/gdansk-ai: 403
# Error fetching repo nlp-uoregon/trankit: 403
# Error fetching repo activeloopai/deeplake: 403
# Error fetching repo labteral/chatgpt-python: 403
# Error fetching repo withcatai/node-llama-cpp: 403
# Error fetching repo declare-lab/Emma-X: 403
# Error fetching repo Azure-Samples/AI-Gateway: 403
# Error fetching repo XiaomingX/indie-hacker-tools-plus: 403
# Error fetching repo diStyApps/seait: 403
# Error fetching repo falcon-xu/early-exit-papers: 403
# Error fetching repo betmoar/ai-dev-guides: 403
# Error fetching repo intitni/CopilotForXcode: 403
# Error fetching repo Pro-GenAI/AutoPureData: 403
# Error fetching repo tsujuifu/pytorch_mgie: 403
# Error fetching repo weimin17/Multimodal_Transformer: 403
# Error fetching repo TilmanGriesel/chipper: 403
# Error fetching repo Yushi-Hu/tifa: 403
# Error fetching repo HamaWhiteGG/langchain-java: 403
# Error fetching repo VITA-Group/o1-planning: 403
# Error fetching repo lopinx/serverless-api-proxy: 403
# Error fetching repo zjunlp/knowledge-rumination: 403
# Error fetching repo p208p2002/albert-zh-for-pytorch-transformers: 403
# Error fetching repo shamspias/langchain-chat: 403
# Error fetching repo wil3/gymfc: 403
# Error fetching repo TonyLianLong/LLM-groundedDiffusion: 403
# Error fetching repo josStorer/RWKV-Runner: 403
# Error fetching repo ruisizhang123/REMARK-LLM: 403
# Error fetching repo chand1012/git2gpt: 403
# Error fetching repo deanpeters/product-manager-prompts: 403
# Error fetching repo nezort11/chatgpt-mobile: 403
# Error fetching repo robert-mcdermott/LLM-Image-Classification: 403
# Error fetching repo santoshdkolur/LLM-Runner: 403
# Error fetching repo fbaldassarri/llama-cpp-container: 403
# Error fetching repo xmindflow/Awesome_Mamba: 403
# Error fetching repo samchon/nestia: 403
# Error fetching repo LangbaseInc/langui: 403
# Error fetching repo kyegomez/ScreenAI: 403
# Error fetching repo leeh2213/MB2C: 403
# Error fetching repo sshh12/llm_oracle: 403
# Error fetching repo weanalyze/workcell: 403
# Error fetching repo tanalpha-aditya/Prompt-Engineering-BERT-NLP: 403
# Error fetching repo aws-solutions-library-samples/guidance-for-digital-thread-using-graph-and-generative-ai-on-aws: 403
# Error fetching repo vlarine/ruGPT2: 403
# Error fetching repo YangLing0818/RPG-DiffusionMaster: 403
# Error fetching repo robotology-legacy/gym-ignition: 403
# Error fetching repo Curated-Awesome-Lists/Awesome-Google-Gemini-AI: 403
# Error fetching repo CeMOS-IS/GenFormer: 403
# Error fetching repo jabberjabberjabber/LLavaImageTagger: 403
# Error fetching repo praj2408/Realtime-Document-Chat-System: 403
# Error fetching repo phospho-app/phospho: 403
# Error fetching repo FreedomIntelligence/TRIM: 403
# Error fetching repo chatbotkit/example-nextjs-ai-forms: 403
# Error fetching repo TobiasHeOl/AbLang2: 403
# Error fetching repo litanlitudan/skyagi: 403
# Error fetching repo hitz-zentroa/latxa: 403
# Error fetching repo navid-matinmo/utilityai: 403
# Error fetching repo benjaminnNgo/ScalingTGNs: 403
# Error fetching repo debanjum/ai-wallpaper: 403
# Error fetching repo HanaokaYuzu/NovelAI-API: 403
# Error fetching repo nrimsky/LM-exp: 403
# Error fetching repo tryanything-ai/agent_marketplace: 403
# Error fetching repo EricLBuehler/mistral.rs: 403
# Error fetching repo nohairblingbling/Interview-Assistant: 403
# Error fetching repo sendbird/sendbird-chat-sample-ios: 403
# Error fetching repo PacoVK/ollama-deep-researcher-ts: 403
# Error fetching repo MantisAI/prompt_engineering: 403
# Error fetching repo awwkl/brain_language_summarization: 403
# Error fetching repo HKUDS/GraphGPT: 403
# Error fetching repo lukehinds/fastllm: 403
# Error fetching repo Zakk-Yang/nexusync: 403
# Error fetching repo GanjinZero/KeBioLM: 403
# Error fetching repo build-on-aws/rag-golang-postgresql-langchain: 403
# Error fetching repo gannonh/chatgpt-pgvector: 403
# Error fetching repo AMAAI-Lab/mustango: 403
# Error fetching repo linkedin/QuantEase: 403
# Error fetching repo joannahong/AV-RelScore: 403
# Error fetching repo android-com-pl/wp-ai-alt-generator: 403
# Error fetching repo jankais3r/LLaMA_MPS: 403
# Error fetching repo AGIUI/Local-LLM: 403
# Error fetching repo kanugurajesh/RAG-Gemini: 403
# Error fetching repo robindekoster/chatgpt-custom-knowledge-chatbot: 403
# Error fetching repo pikho/ppromptor: 403
# Error fetching repo fuzz4all/fuzz4all: 403
# Error fetching repo fjrdomingues/autopilot: 403
# Error fetching repo chenhunghan/ialacol: 403
# Error fetching repo pegasi-ai/feather: 403
# Error fetching repo badripatro/Visual_Question_Generation: 403
# Error fetching repo AIOS-club/aios.chat: 403
# Error fetching repo microsoft/MSVBASE: 403
# Error fetching repo umair-nasir14/Word2World: 403
# Error fetching repo dappros/ethora: 403
# Error fetching repo momegas/megabots: 403
# Error fetching repo leftthomas/Tutorials: 403
# Error fetching repo jantrienes/InfoLossQA: 403
# Error fetching repo CoderSJX/AI-Resources-Central: 403
# Error fetching repo NotShrirang/LoomRAG: 403
# Error fetching repo suggest-go/suggest: 403
# Error fetching repo noahvelasco/AVA-Advanced-Virtual-Agent: 403
# Error fetching repo OcularEngineering/ocular: 403
# Error fetching repo JerryYin777/Awesome-MLSys-Blogger: 403
# Error fetching repo yyaadet/autosrt_page: 403
# Error fetching repo different-ai/obsidian-ava: 403
# Error fetching repo invictus717/MetaTransformer: 403
# Error fetching repo gyunggyung/AGI-Papers: 403
# Error fetching repo lucidrains/MaMMUT-pytorch: 403
# Error fetching repo crazycloud/data-analysis-llm-agent: 403
# Error fetching repo deep-symbolic-mathematics/LLM-SR: 403
# Error fetching repo AI-Prompt-Engineering-Wiki/ai-prompt-tutorial: 403
# Error fetching repo PragmaticMachineLearning/probly: 403
# Error fetching repo RahulSChand/gpu_poor: 403
# Error fetching repo vectice/GettingStarted: 403
# Error fetching repo zekaouinoureddine/Adding-Private-Data-to-LLMs: 403
# Error fetching repo GaoxiangLuo/LLM-BioMed-NER-RE: 403
# Error fetching repo iut62elec/Soccer-Highlight-Generator-with-GenAI: 403
# Error fetching repo WANGXinyiLinda/concept-based-demonstration-selection: 403
# Error fetching repo eduagarcia/roberta-legal-portuguese: 403
# Error fetching repo maxi-w/llama2-chat-interface: 403
# Error fetching repo Soulter/AstrBot: 403
# Error fetching repo pillowsofwind/Knowledge-Conflicts-Survey: 403
# Error fetching repo LexiestLeszek/namegen: 403
# Error fetching repo phanxuanquang/AskDB: 403
# Error fetching repo pchunduri6/rag-demystified: 403
# Error fetching repo pd3f/pd3f: 403
# Error fetching repo denniszielke/sql-ai-agents: 403
# Error fetching repo nrl-ai/pautobot: 403
# Error fetching repo jucasoliveira/terminalGPT: 403
# Error fetching repo johnmai-dev/TypeChat-Go: 403
# Error fetching repo michca07/Generating-Books-with-LLMs: 403
# Error fetching repo kyegomez/Algorithm-Of-Thoughts: 403
# Error fetching repo Gen-Verse/ReasonFlux: 403
# Error fetching repo apocas/restai: 403
# Error fetching repo prakhar21/Writing-with-BERT: 403
# Error fetching repo infiniflow/ragflow: 403
# Error fetching repo Squarific/gpt-cobuilder: 403
# Error fetching repo marcominerva/KernelMemoryService: 403
# Error fetching repo hal9ai/hal9: 403
# Error fetching repo ramon-victor/freegpt-webui: 403
# Error fetching repo CambioML/pykoi-rlhf-finetuned-transformers: 403
# Error fetching repo ggml-org/llama.vscode: 403
# Error fetching repo tarampampam/describe-commit: 403
# Error fetching repo SoftCreatR/php-mistral-ai-sdk: 403
# Error fetching repo whyiyhw/chatgpt-wechat: 403
# Error fetching repo amazon-science/factual-confidence-of-llms: 403
# Error fetching repo gnehs/subtitle-translator-electron: 403
# Error fetching repo inst-it/inst-it: 403
# Error fetching repo NeurAI-Lab/G2S: 403
# Error fetching repo Qiyuan-Ge/OpenAssistant: 403
# Error fetching repo lakeraai/chainguard: 403
# Error fetching repo autograder-org/autoGrader-frontend: 403
# Error fetching repo Stry233/Visual-Story-Generation-Based-on-Emotional-and-Keyword-Scheme: 403
# Error fetching repo Riccorl/transformers-embedder: 403
# Error fetching repo ZeldaFan0225/ChatGPT-Discord-Bot: 403
# Error fetching repo huggingface/pytorch-openai-transformer-lm: 403
# Error fetching repo Logisx/AI-Senior: 403
# Error fetching repo harry0703/MoneyPrinterTurbo: 403
# Error fetching repo brainlid/langchain: 403
# Error fetching repo svilupp/AIHelpMe.jl: 403
# Error fetching repo sail-sg/sdft: 403
# Error fetching repo Furyton/awesome-language-model-analysis: 403
# Error fetching repo LeeSinLiang/microGPT: 403
# Error fetching repo mobarski/ask-my-pdf: 403
# Error fetching repo redis-developer/gcp-redis-llm-stack: 403
# Error fetching repo zzstoatzz/raggy: 403
# Error fetching repo kom-senapati/talk-to-page: 403
# Error fetching repo YiVal/YiVal: 403
# Error fetching repo teftef6220/Local_LLM_bot: 403
# Error fetching repo azkadev/speech_to_text_telegram_bot_dart: 403
# Error fetching repo Victarry/awesome-poe-bots: 403
# Error fetching repo aliyeysides/prisma-gpt: 403
# Error fetching repo LHRLAB/ChatKBQA: 403
# Error fetching repo devlinb/arcadia: 403
# Error fetching repo i-dot-ai/redbox: 403
# Error fetching repo LLukas22/llm-rs-python: 403
# Error fetching repo Slaymish/ArticulateAI: 403
# Error fetching repo xu-song/bert-as-language-model: 403
# Error fetching repo jshuadvd/LongRoPE: 403
# Error fetching repo sozercan/aikit: 403
# Error fetching repo THUMNLab/awesome-large-graph-model: 403
# Error fetching repo AmberSahdev/Open-Interface: 403
# Error fetching repo betalgo/openai: 403
# Error fetching repo robjsliwa/llama-agent: 403
# Error fetching repo voytas75/GPTprompts: 403
# Error fetching repo Denis2054/RAG-Driven-Generative-AI: 403
# Error fetching repo sahilg06/EmoGen: 403
# Error fetching repo deeepsig/tokviz: 403
# Error fetching repo coderonion/awesome-llm-and-aigc: 403
# Error fetching repo Lupin1998/Awesome-MIM: 403
# Error fetching repo yuezk/chatgpt-mirror: 403
# Error fetching repo kyegomez/Gen2: 403
# Error fetching repo langgptai/awesome-claude-prompts: 403
# Error fetching repo xutongbao/learn-chatgpt: 403
# Error fetching repo techcow2/Tips-Tricks-for-AI-Coder: 403
# Error fetching repo techcow2/lmsa: 403
# Error fetching repo santosomar/RAG-for-cybersecurity: 403
# Error fetching repo eddieoz/reels-clips-automator: 403
# Error fetching repo mehdihadeli/AIAssist: 403
# Error fetching repo RageAgainstThePixel/com.openai.unity: 403
# Error fetching repo babaniyi/LLMs-for-RecSys: 403
# Error fetching repo cyberark/FuzzyAI: 403
# Error fetching repo tbckr/sgpt: 403
# Error fetching repo simonmysun/ell: 403
# Error fetching repo anyks/asc: 403
# Error fetching repo sammcj/llm-templates: 403
# Error fetching repo Tab-SE/tableau_langchain: 403
# Error fetching repo lollipopkit/flutter_gpt_box: 403
# Error fetching repo Yazdi9/Stable-DreamFusion-NeRF: 403
# Error fetching repo tonyzdev/eecs-resume-gpt_prompt: 403
# Error fetching repo AdityaLab/Samay: 403
# Error fetching repo PeterWang512/AttributeByUnlearning: 403
# Error fetching repo Yue-Yang/ChatGPT-Siri: 403
# Error fetching repo pleisto/yuren-13b: 403
# Error fetching repo Eurus-Holmes/Awesome-Multimodal-Research: 403
# Error fetching repo enricoros/big-AGI: 403
# Error fetching repo IvanAer/G-Universal-CLIP: 403
# Error fetching repo harishdeivanayagam/rowfill: 403
# Error fetching repo Dicklesworthstone/fast_vector_similarity: 403
# Error fetching repo vxcontrol/pentagi: 403
# Error fetching repo timescale/pgai: 403
# Error fetching repo gtreshchev/RuntimeSpeechRecognizer: 403
# Error fetching repo kalaspuff/ai-assisted-task-executor: 403
# Error fetching repo lucasm/findto: 403
# Error fetching repo daodao97/chatdoc: 403
# Error fetching repo alibaba/GraphTranslator: 403
# Error fetching repo eric-ai-lab/MSSBench: 403
# Error fetching repo ottobjorkland/SmartVoiceAssistant: 403
# Error fetching repo cyanheads/obsidian-mcp-server: 403
# Error fetching repo Docta-ai/docta: 403
# Error fetching repo OpenGVLab/MM-NIAH: 403
# Error fetching repo dasher-project/dasher-web: 403
# Error fetching repo oneil512/INSIGHT: 403
# Error fetching repo wrk226/pytorch-multimodal_sarcasm_detection: 403
# Error fetching repo SpazioDati/llm-elasticsearch-cache: 403
# Error fetching repo miurla/morphic: 403
# Error fetching repo eastriverlee/LLM.swift: 403
# Error fetching repo amazon-science/auto-cot: 403
# Error fetching repo receyuki/comfyui-prompt-reader-node: 403
# Error fetching repo sean-t-smith/pwned-by-passgpt: 403
# Error fetching repo HumanCompatibleAI/tensor-trust: 403
# Error fetching repo yashsmehta/personality-prediction: 403
# Error fetching repo idreesshaikh/Autonomous-Driving-in-Carla-using-Deep-Reinforcement-Learning: 403
# Error fetching repo missuo/OpenAI-Checker: 403
# Error fetching repo cortecs-ai/cortecs-py: 403
# Error fetching repo zjysteven/mink-plus-plus: 403
# Error fetching repo whiai/translate-hokkien: 403
# Error fetching repo haozheji/exact-optimization: 403
# Error fetching repo llmbev/talk2bev: 403
# Error fetching repo SwindleA/LLMCodeObfuscation: 403
# Error fetching repo openai/chatgpt-retrieval-plugin: 403
# Error fetching repo peterdresslar/vercel-ai-sdk-examples: 403
# Error fetching repo graphsignal/graphsignal-python: 403
# Error fetching repo Denis2054/Transformers-for-NLP-and-Computer-Vision-3rd-Edition: 403
# Error fetching repo KartikeyMish/RepoSavant: 403
# Error fetching repo Abraxas-365/langchain-rust: 403
# Error fetching repo friendliai/FAI-Model: 403
# Error fetching repo towardsai/ai-tutor-rag-system: 403
# Error fetching repo mapluisch/GPT-4-Vision-for-HoloLens: 403
# Error fetching repo pescheckit/python-gpt-po: 403
# Error fetching repo jakobdylanc/llmcord: 403
# Error fetching repo mantreshkhurana/Google-Bard-electron: 403
# Error fetching repo zacfrulloni/Prompt-Engineering-Holy-Grail: 403
# Error fetching repo yello-xyz/playfetch: 403
# Error fetching repo kyegomez/KosmosG: 403
# Error fetching repo apple/ml-slowfast-llava: 403
# Error fetching repo jerry1993-tech/Cornucopia-LLaMA-Fin-Chinese: 403
# Error fetching repo andrey-okhotin/star-shaped: 403
# Error fetching repo Ramseths/app-llama2: 403
# Error fetching repo foyer-work/merlin-node: 403
# Error fetching repo transitive-bullshit/OpenOpenAI: 403
# Error fetching repo bz-lab/AUITestAgent: 403
# Error fetching repo SaberaTalukder/TOTEM: 403
# Error fetching repo agentsea/surfkit: 403
# Error fetching repo StructuredLabs/preswald: 403
# Error fetching repo icebaker/nano-bots-spec: 403
# Error fetching repo RenqiChen/Virtual-Scientists: 403
# Error fetching repo eliotjlee/holmes: 403
# Error fetching repo amanvirparhar/weebo: 403
# Error fetching repo CompEpigen/methylbert: 403
# Error fetching repo dobriban/Principles-of-AI-LLMs: 403
# Error fetching repo C-Loftus/talon-ai-tools: 403
# Error fetching repo alchaplinsky/gen-ai: 403
# Error fetching repo vearch/vearch: 403
# Error fetching repo SinclairCoder/Instruction-Tuning-Papers: 403
# Error fetching repo langgptai/awesome-gemini-prompts: 403
# Error fetching repo risabhmishra/algotrading-sentimentanalysis-genai: 403
# Error fetching repo AI-Prompt-Genius/AI-Prompt-Genius: 403
# Error fetching repo SAILResearch/awesome-foundation-model-leaderboards: 403
# Error fetching repo ThomasVitale/llm-apps-java-langchain4j: 403
# Error fetching repo thrivewithai/NinjaSearchWithHumanGPT: 403
# Error fetching repo Zackriya-Solutions/meeting-minutes: 403
# Error fetching repo glb400/Toy-RecLM: 403
# Error fetching repo CogitoNTNU/TutorAI: 403
# Error fetching repo morpheuslord/GPT_Vuln-analyzer: 403
# Error fetching repo aborroy/llama2-docker-multiarch: 403
# Error fetching repo awaescher/llmaid: 403
# Error fetching repo MikeWangWZHL/EEG-To-Text: 403
# Error fetching repo shamantechnology/RedAGPT: 403
# Error fetching repo bobo0810/LearnDeepSpeed: 403
# Error fetching repo doccstat/llm-watermark-cpd: 403
# Error fetching repo KoljaB/Linguflex: 403
# Error fetching repo akanyaani/gpt-2-tensorflow2.0: 403
# Error fetching repo octotools/octotools: 403
# Error fetching repo cleissonbarbosa/article-generator: 403
# Error fetching repo jusiro/FLAIR: 403
# Error fetching repo AmourWaltz/BayesLMs: 403
# Error fetching repo KCaverly/cog-models: 403
# Error fetching repo Sets88/sets88_telegram_bot: 403
# Error fetching repo MySong7NLPer/ChatGPT_as_Keyphrase_Generator: 403
# Error fetching repo RainEggplant/chatgpt-telegram-bot: 403
# Error fetching repo LeonEricsson/llmjudge: 403
# Error fetching repo XL2248/SOV-MAS: 403
# Error fetching repo mlc-ai/web-llm: 403
# Error fetching repo VectorInstitute/vectorlm: 403
# Error fetching repo iblai/ibl-slack-chatgpt-langchain: 403
# Error fetching repo zhangzibin/char-rnn-chinese: 403
# Error fetching repo git-disl/PokeLLMon: 403
# Error fetching repo sagentic-ai/sagentic-af: 403
# Error fetching repo KVignesh122/AssetNewsSentimentAnalyzer: 403
# Error fetching repo MrXandbadas/MrX_OAI_Assistant_Manager: 403
# Error fetching repo FasterDecoding/TEAL: 403
# Error fetching repo Qrange-group/SUR-adapter: 403
# Error fetching repo ahmedbesbes/cowriter: 403
# Error fetching repo RockChinQ/LangBot: 403
# Error fetching repo liguodongiot/llm-resource: 403
# Error fetching repo HybridRobotics/prompt2walk: 403
# Error fetching repo HillZhang1999/ICD: 403
# Error fetching repo rdspring1/Count-Sketch-Optimizers: 403
# Error fetching repo TirendazAcademy/LangChain-Tutorials: 403
# Error fetching repo VITA-Group/4DGen: 403
# Error fetching repo WHU-ZQH/ChatGPT-vs.-BERT: 403
# Error fetching repo puyuan1996/ZeroPal: 403
# Error fetching repo huggingface/llm_training_handbook: 403
# Error fetching repo zeus-12/uxie: 403
# Error fetching repo ParthSareen/obsidian-rag: 403
# Error fetching repo SillyTavern/SillyTavern: 403
# Error fetching repo yokoffing/ChatGPT-Prompts: 403
# Error fetching repo playht/pyht: 403
# Error fetching repo fresh-creations/tammy: 403
# Error fetching repo KennethEnevoldsen/spacy-wrap: 403
# Error fetching repo DLR-RM/stable-baselines3: 403
# Error fetching repo birkhoffkiki/GPFM: 403
# Error fetching repo Guru322/GURU-Ai: 403
# Error fetching repo vsolina/tabby-backend-py: 403
# Error fetching repo jackaduma/Vicuna-LoRA-RLHF-PyTorch: 403
# Error fetching repo myscience/retnet-pytorch: 403
# Error fetching repo zjunlp/MKG_Analogy: 403
# Error fetching repo Maknee/minigpt4.cpp: 403
# Error fetching repo CaptainE/RNN-LSTM-in-numpy: 403
# Error fetching repo stippi/voice-assistant: 403
# Error fetching repo ShubhamMandowara/Text_summarization: 403
# Error fetching repo camenduru/alpaca-lora-colab: 403
# Error fetching repo Hellisotherpeople/Language-games: 403
# Error fetching repo aws-samples/advanced-rag-router-with-amazon-bedrock: 403
# Error fetching repo ntropy-network/enrichment_models: 403
# Error fetching repo fla-org/flame: 403
# Error fetching repo EmbraceAGI/Awesome-AI-GPTs: 403
# Error fetching repo k8sgpt-ai/k8sgpt-operator: 403
# Error fetching repo pipixin321/HolmesVAU: 403
# Error fetching repo Baizhige/EEGUnity: 403
# Error fetching repo dsdanielpark/Bard-API: 403
# Error fetching repo hasinhayder/PromptFiller: 403
# Error fetching repo imabutahersiddik/Ultimate-ChatGPT: 403
# Error fetching repo X-D-Lab/Sunsimiao: 403
# Error fetching repo princeton-nlp/LLM-Shearing: 403
# Error fetching repo gfargo/coco: 403
# Error fetching repo declare-lab/TangoFlux: 403
# Error fetching repo RabeaWahab/promptman: 403
# Error fetching repo jiggy-ai/pair: 403
# Error fetching repo instructor-ai/instructor-rb: 403
# Error fetching repo friendliai/friendli-client: 403
# Error fetching repo langchain-ai/langchain-extract: 403
# Error fetching repo strickvl/awesome-balochi-nlp: 403
# Error fetching repo Azure/azure-openai-workshop: 403
# Error fetching repo dulaiduwang003/super: 403
# Error fetching repo Caellwyn/long-memory-character-chat: 403
# Error fetching repo camilo-cf/llm-url_video-rag: 403
# Error fetching repo IDinsight/ask-a-question: 403
# Error fetching repo terminalcommandnewsletter/everything-chatgpt: 403
# Error fetching repo OpenAutoCoder/Agentless: 403
# Error fetching repo refuel-ai/autolabel: 403
# Error fetching repo microsoft/COCO-LM: 403
# Error fetching repo andrewkchan/deepseek.cpp: 403
# Error fetching repo Avaiga/demo-chatbot: 403
# Error fetching repo OpenDeepLearningAI/OpenDeepLearning: 403
# Error fetching repo anyscale/ray-summit-2023-training: 403
# Error fetching repo ajikan/ScribeAI: 403
# Error fetching repo nick7nlp/Counting-Stars: 403
# Error fetching repo DeadmanAbir/AgentGenesis: 403
# Error fetching repo darvin/Holodeck: 403
# Error fetching repo kserve/kserve: 403
# Error fetching repo SeungyounShin/Llama2-Code-Interpreter: 403
# Error fetching repo ardha27/AI-Waifu-Vtuber: 403
# Error fetching repo azkadev/llama: 403
# Error fetching repo Addepto/contextcheck: 403
# Error fetching repo nathanlesage/local-chat: 403
# Error fetching repo christinakim/scaling-laws-for-language-transfer: 403
# Error fetching repo gabrielhuang/reptile-pytorch: 403
# Error fetching repo CRIPAC-DIG/tgm-dlm: 403
# Error fetching repo Robitx/gp.nvim: 403
# Error fetching repo VITA-Group/llm-kick: 403
# Error fetching repo garystafford/genai_fiction_summary: 403
# Error fetching repo google-marketing-solutions/vigenair: 403
# Error fetching repo eosphoros-ai/DB-GPT: 403
# Error fetching repo michalkrawczyk/LLM_ask_papers: 403
# Error fetching repo Vokturz/LLM-slackbot-channels: 403
# Error fetching repo desilinguist/swig-srilm: 403
# Error fetching repo Gamma-Software/llm_qualitative_data_analysis: 403
# Error fetching repo morpheuslord/HackBot: 403
# Error fetching repo SynaLinks/HybridAGI: 403
# Error fetching repo mouredev/tggenerator: 403
# Error fetching repo yesbhautik/Whatsapp-Ai-BOT: 403
# Error fetching repo alan-ai/alan-sdk-ionic: 403
# Error fetching repo amazon-science/mix-generation: 403
# Error fetching repo Anil-matcha/GPT-4-Vision-Chatbot: 403
# Error fetching repo The-Swarm-Corporation/Multi-Agent-RAG-Template: 403
# Error fetching repo wearedevx/llm-together: 403
# Error fetching repo hk3427/RAG-KnowledgeLLM-LlamaIndex-BOT: 403
# Error fetching repo cambridgeltl/prompt4bli: 403
# Error fetching repo unit-mesh/choco-builder: 403
# Error fetching repo xuanlinli17/autoregressive_inference: 403
# Error fetching repo bobz25/chat-simplifier: 403
# Error fetching repo neuml/ragdata: 403
# Error fetching repo mustvlad/ChatGPT-System-Prompts: 403
# Error fetching repo HansalShah007/semroute: 403
# Error fetching repo Zalexanninev15/AI-ChatGPT: 403
# Error fetching repo build-on-aws/building-gen-ai-apps-with-found-models-workshop: 403
# Error fetching repo kilkelly/nanogptjs: 403
# Error fetching repo craigmayhew/pipe-gpt: 403
# Error fetching repo SteveKGYang/MetaAligner: 403
# Error fetching repo alinourian/Fine-tuning-Mistral-7b-QA: 403
# Error fetching repo weekend-project-space/bootstrap-gpt: 403
# Error fetching repo DefTruth/Awesome-LLM-Inference: 403
# Error fetching repo richardgill/llm-ui: 403
# Error fetching repo kyopark2014/llama3-langchain-kor: 403
# Error fetching repo ZhengxiangShi/InstructionModelling: 403
# Error fetching repo satellitecomponent/Neurite: 403
# Error fetching repo THUNLP-MT/MEAN: 403
# Error fetching repo Tudor44/sentiment-analysis-with-LLM: 403
# Error fetching repo donwany/gpt3datagen: 403
# Error fetching repo ziwang-com/comfyui-deepseek-r1: 403
# Error fetching repo xmindflow/Awesome-Foundation-Models-in-Medical-Imaging: 403
# Error fetching repo DeepTecher/awesome-ChatGPT-resource-zh: 403
# Error fetching repo yudataguy/RawRAG: 403
# Error fetching repo knowledge-ukraine/OntoChatGPT: 403
# Error fetching repo firelink-data/drive: 403
# Error fetching repo zjunlp/MKGformer: 403
# Error fetching repo knowsuchagency/promptic: 403
# Error fetching repo ciuzaak/Claude-Telegram-Bot: 403
# Error fetching repo AINativeLab/top-500-best-gpts: 403
# Error fetching repo Shaun-le/ViQAG: 403
# Error fetching repo Extensible-AI/DAGent: 403
# Error fetching repo lastmile-ai/aiconfig: 403
# Error fetching repo miroslavpejic85/mirotalksfu: 403
# Error fetching repo xrsrke/toolformer: 403
# Error fetching repo shrutisaxena51/Artificial-Intelligence-in-Compiler-Optimization: 403
# Error fetching repo epfml/llm-baselines: 403
# Error fetching repo AspadaX/Thinker: 403
# Error fetching repo AndersonBY/vector-vein: 403
# Error fetching repo yuhuixu1993/qa-lora: 403
# Error fetching repo SoraFlows/SoraFlows: 403
# Error fetching repo CognitiveCodes/NeuralGPT: 403
# Error fetching repo MatthewZMD/aidermacs: 403
# Error fetching repo stackwiseai/stackwise: 403
# Error fetching repo FunAudioLLM/SenseVoice: 403
# Error fetching repo AmpereComputingAI/ampere_model_library: 403
# Error fetching repo DrDataYE/DrGPT: 403
# Error fetching repo mikeffendii/Building-Systems-with-the-ChatGPT-API: 403
# Error fetching repo princeton-nlp/TRIME: 403
# Error fetching repo kakaobrain/kogpt: 403
# Error fetching repo build-on-aws/dotnet-fm-playground: 403
# Error fetching repo varunshenoy/honestgpt: 403
# Error fetching repo navamai/navamai: 403
# Error fetching repo supabase-community/database-build: 403
# Error fetching repo xmed-lab/FDDM: 403
# Error fetching repo sendbird/sendbird-uikit-react: 403
# Error fetching repo RareMojo/discord-ai: 403
# Error fetching repo leetcode-mafia/cheetah: 403
# Error fetching repo normal-computing/branches: 403
# Error fetching repo manthan89-py/Real-Time-Social-Media-Content-Retrievel-System: 403
# Error fetching repo OpenCSGs/llm-inference: 403
# Error fetching repo jordanvolz/lolpop: 403
# Error fetching repo cheshire-cat-ai/core: 403
# Error fetching repo pew/slack-workers-ai: 403
# Error fetching repo nawnoes/pytorch-meena: 403
# Error fetching repo PJLab-ADG/awesome-knowledge-driven-AD: 403
# Error fetching repo procesaur/Scratch2LM: 403
# Error fetching repo OpenRobotLab/VLM-Grounder: 403
# Error fetching repo varunshenoy/coauthor: 403
# Error fetching repo nvwa-project/nvwa-vine: 403
# Error fetching repo xiaoming2028/Chatgpt-Makes-Money: 403
# Error fetching repo KarelDO/xmc.dspy: 403
# Error fetching repo IlyasMoutawwakil/py-txi: 403
# Error fetching repo kongpf8848/azure-openai-proxy: 403
# Error fetching repo logikon-ai/logikon: 403
# Error fetching repo immex-tech/decor8ai-sdk: 403
# Error fetching repo ha0z1/New-Bing-Anywhere: 403
# Error fetching repo Yangyi-Chen/CoTConsistency: 403
# Error fetching repo naskio/mergeui: 403
# Error fetching repo intel/neural-compressor: 403
# Error fetching repo protectai/rebuff: 403
# Error fetching repo Moataz-Elmesmary/Data-Science-Roadmap: 403
# Error fetching repo QwenLM/Qwen: 403
# Error fetching repo SwiftBeta/SwiftOpenAI: 403
# Error fetching repo moabarar/nemar: 403
# Error fetching repo liyupi/ai-guide: 403
# Error fetching repo blakeb211/billcat-local-llm: 403
# Error fetching repo lyndonzheng/Pluralistic-Inpainting: 403
# Error fetching repo Danielskry/Awesome-RAG: 403
# Error fetching repo tbepler/prose: 403
# Error fetching repo thu-coai/Safety-Prompts: 403
# Error fetching repo ztjhz/miniLM: 403
# Error fetching repo StanfordSpezi/SpeziLLM: 403
# Error fetching repo andrewnguonly/Lumos: 403
# Error fetching repo yinizhilian/ICLR2024-Papers-with-Code: 403
# Error fetching repo superlinked/VectorHub: 403
# Error fetching repo abhineetgupta/ai-resume-builder: 403
# Error fetching repo Grt1228/chatgpt-steam-output: 403
# Error fetching repo BrainBlend-AI/atomic-agents: 403
# Error fetching repo Refaat-alktifan/CodeRanedeer: 403
# Error fetching repo deepset-ai/haystack-rag-app: 403
# Error fetching repo CVHub520/X-AnyLabeling: 403
# Error fetching repo mh-ka/ai-stuff: 403
# Error fetching repo emilamaj/bookwriter: 403
# Error fetching repo kyopark2014/llm-voicebot: 403
# Error fetching repo seukgcode/MELBench: 403
# Error fetching repo iSiddharth20/Generative-AI-Based-Spatio-Temporal-Fusion: 403
# Error fetching repo jan-janssen/LangSim: 403
# Error fetching repo offline-ai/cli: 403
# Error fetching repo successfulstudy/jailbreakprompt: 403
# Error fetching repo devoxx/DevoxxGenieIDEAPlugin: 403
# Error fetching repo anse-app/anse: 403
# Error fetching repo OFA-Sys/OFA: 403
# Error fetching repo foldl/chatllm.cpp: 403
# Error fetching repo GeorgeVern/AFTERV1.0: 403
# Error fetching repo PointsCoder/GPT-Driver: 403
# Error fetching repo Zaki-1052/GPTPortal: 403
# Error fetching repo meta-prompting/meta-prompting: 403
# Error fetching repo AshishKumar4/FlaxDiff: 403
# Error fetching repo chtmp223/topicGPT: 403
# Error fetching repo AIxHunter/FileWizardAI: 403
# Error fetching repo microsoft/genaiscript: 403
# Error fetching repo basicv8vc/chinese-instruction-datasets-for-llms: 403
# Error fetching repo SubstrateLabs/substrate-python: 403
# Error fetching repo pgryko/django-llama2-chat-pdf: 403
# Error fetching repo BastinFlorian/RAG-Chatbot-with-Confluence: 403
# Error fetching repo davendw49/k2: 403
# Error fetching repo jac99/MinkLocMultimodal: 403
# Error fetching repo THUDM/ChatGLM2-6B: 403
# Error fetching repo SingularityLabs-ai/MultiGPT-mini: 403
# Error fetching repo HKUDS/UrbanGPT: 403
# Error fetching repo ECNU-ICALK/EduChat: 403
# Error fetching repo ScaledFoundations/GRID-playground: 403
# Error fetching repo XiaomingX/Improve-Your-Prompt: 403
# Error fetching repo lean-dojo/LeanCopilot: 403
# Error fetching repo iiis-ai/cumulative-reasoning: 403
# Error fetching repo bzluan/TextCoT: 403
# Error fetching repo viniciusarruda/chatpdf: 403
# Error fetching repo RobotecAI/rai: 403
# Error fetching repo sonnhfit/SonAgent: 403
# Error fetching repo harleyszhang/llm_note: 403
# Error fetching repo jasonvanf/llama-trl: 403
# Error fetching repo jieyilong/tree-of-thought-puzzle-solver: 403
# Error fetching repo xenodium/chatgpt-shell: 403
# Error fetching repo cilabuniba/i-dream-my-painting: 403
# Error fetching repo farhan0167/otto-m8: 403
# Error fetching repo ItsPi3141/alpaca-electron: 403
# Error fetching repo b9software/B9ChatAI: 403
# Error fetching repo Allyson-AI/FuncMaster: 403
# Error fetching repo GaiZhenbiao/ChuanhuChatGPT: 403
# Error fetching repo atfortes/LLMSymbolicReasoningBench: 403
# Error fetching repo gitHBDX/TransfoRNA: 403
# Error fetching repo thunlp/SDLM-pytorch: 403
# Error fetching repo kyegomez/Med-PaLM: 403
# Error fetching repo yangjianxin1/Firefly: 403
# Error fetching repo JeffreyYH/Awesome-Generalist-Robots-via-Foundation-Models: 403
# Error fetching repo 3eeps/llmon-py: 403
# Error fetching repo DavidUdell/sparse_circuit_discovery: 403
# Error fetching repo KaiyangZhou/CoOp: 403
# Error fetching repo ritaranx/ClinGen: 403
# Error fetching repo blinko-space/blinko: 403
# Error fetching repo shroominic/funcchain: 403
# Error fetching repo Pro-GenAI/LML-DAP: 403
# Error fetching repo llmadd/code_using_GPT: 403
# Error fetching repo Upsonic/Upsonic: 403
# Error fetching repo PromptMixerDev/prompt-mixer-app-ce: 403
# Error fetching repo Pawandeep-prog/finetune-llm-lora-guide: 403
# Error fetching repo antoinejaussoin/retro-board: 403
# Error fetching repo g023/superez-gpt-builder: 403
# Error fetching repo NisaarAgharia/Indian-LawyerGPT: 403
# Error fetching repo mapluisch/LLaVA-CLI-with-multiple-images: 403
# Error fetching repo AutoGPTQ/AutoGPTQ: 403
# Error fetching repo openai/openai-openapi: 403
# Error fetching repo OSU-NLP-Group/ChemAgent: 403
# Error fetching repo km1994/llms_paper: 403
# Error fetching repo brightmart/nlp_chinese_corpus: 403
# Error fetching repo SwaggyMacro/BarrageGPT: 403
# Error fetching repo dense-analysis/neural: 403
# Error fetching repo wang2226/Awesome-LLM-Decoding: 403
# Error fetching repo victorharry/zap-gpt: 403
# Error fetching repo Yifan-Song793/ETO: 403
# Error fetching repo substratusai/runbooks: 403
# Error fetching repo ludwig-ai/ludwig: 403
# Error fetching repo zaixizhang/FLAG: 403
# Error fetching repo fajieyuan/IDforRec: 403
# Error fetching repo 79E/ChatGpt-Web: 403
# Error fetching repo MQEnergy/chatcat: 403
# Error fetching repo wikit-ai/awesome-llm-courses: 403
# Error fetching repo kyegomez/dev-swarm: 403
# Error fetching repo bigai-nlco/VideoTGB: 403
# Error fetching repo ImKeTT/ZeroGen: 403
# Error fetching repo LostOxygen/llm-confidentiality: 403
# Error fetching repo rvanasa/pandas-gpt: 403
# Error fetching repo Govind-S-B/ppt_generator: 403
# Error fetching repo odynvolk/jensen: 403
# Error fetching repo THU-KEG/EvaluationPapers4ChatGPT: 403
# Error fetching repo baaivision/Uni3D: 403
# Error fetching repo AiGptCode/AskyourDocuments: 403
# Error fetching repo SylphAI-Inc/AdalFlow: 403
# Error fetching repo wangcx18/llm-vscode-inference-server: 403
# Error fetching repo TIGER-AI-Lab/VideoGenHub: 403
# Error fetching repo eeeXun/gtt: 403
# Error fetching repo kozistr/semantic-search-rs: 403
# Error fetching repo promptable/gpt3-interview-bot: 403
# Error fetching repo lupantech/MathVista: 403
# Error fetching repo LiangYang666/ChatGPT-Web: 403
# Error fetching repo avastmick/google-generative-ai-rs: 403
# Error fetching repo yoannchb-pro/MoodleGPT: 403
# Error fetching repo Heidelberg-NLP/counting-probe: 403
# Error fetching repo alexandrevl/pyscreen: 403
# Error fetching repo deeppowers/deeppowers: 403
# Error fetching repo tianyi-lab/HallusionBench: 403
# Error fetching repo euclaise/SlimTrainer: 403
# Error fetching repo msoedov/langcorn: 403
# Error fetching repo WooooDyy/AgentGym: 403
# Error fetching repo s-nagaev/chibi: 403
# Error fetching repo codertimo/BERT-pytorch: 403
# Error fetching repo microsoft/Trace: 403
# Error fetching repo semperai/amica: 403
# Error fetching repo goodatlas/zeroth: 403
# Error fetching repo PacktPublishing/LLM-Engineers-Handbook: 403
# Error fetching repo mfmezger/ollama-rag-chainlit: 403
# Error fetching repo wkentaro/osam: 403
# Error fetching repo myscience/open-genie: 403
# Error fetching repo projectdiscovery/openrisk: 403
# Error fetching repo zjukg/KnowPAT: 403
# Error fetching repo rentruewang/bocoel: 403
# Error fetching repo Chenyme/Chenyme-AAVT: 403
# Error fetching repo anchen1011/chatgpt-finetune-ui: 403
# Error fetching repo chewxy/lingo: 403
# Error fetching repo amosjyng/vcr-langchain: 403
# Error fetching repo anc95/ChatGPT-CodeReview: 403
# Error fetching repo ai-update/bing-chat-prompts: 403
# Error fetching repo mksshare/mksshare.github.io: 403
# Error fetching repo nusnlp/S2T2: 403
# Error fetching repo wzdavid/ThinkRAG: 403
# Error fetching repo bytefer/ollama-ocr: 403
# Error fetching repo nianhua99/PandoraHelper: 403
# Error fetching repo arc53/DocsGPT: 403
# Error fetching repo SmallDoges/small-doge: 403
# Error fetching repo genieincodebottle/genaicodelab: 403
# Error fetching repo EDAPINENUT/ppflow: 403
# Error fetching repo zhihu/ZhiLight: 403
# Error fetching repo jeffdapaz/VisualChatGPTStudio: 403
# Error fetching repo kampersanda/tongrams-rs: 403
# Error fetching repo wozeparrot/tinyrwkv: 403
# Error fetching repo RUCAIBox/LLMSurvey: 403
# Error fetching repo spark-engine-opensource-projects/fullstack-nextjs-app-generator: 403
# Error fetching repo levitation-opensource/Manipulative-Expression-Recognition: 403
# Error fetching repo CameLLM/CameLLM: 403
# Error fetching repo moucheng2017/SOP-LVM-ICL-Ensemble: 403
# Error fetching repo fabriziosalmi/DevGPT: 403
# Error fetching repo AnotiaWang/deep-research-web-ui: 403
# Error fetching repo Aavache/LLMWebCrawler: 403
# Error fetching repo and-mill/Awesome-GenAI-Watermarking: 403
# Error fetching repo video-db/StreamRAG: 403
# Error fetching repo 4as/ChatGPT-DeMod: 403
# Error fetching repo alan-ai/alan-sdk-pcf: 403
# Error fetching repo teilomillet/gollm: 403
# Error fetching repo kyegomez/Gamba: 403
# Error fetching repo idearibosome/embracenet: 403
# Error fetching repo yao8839836/cp: 403
# Error fetching repo ray-project/ray-educational-materials: 403
# Error fetching repo cambridgeltl/visual-med-alpaca: 403
# Error fetching repo nrl-ai/llama-assistant: 403
# Error fetching repo DWCTOD/CVPR2024-Papers-with-Code-Demo: 403
# Error fetching repo leonid20000/odin-slides: 403
# Error fetching repo pampanic/pam_panic: 403
# Error fetching repo josephrocca/OpenCharacters: 403
# Error fetching repo ridgerchu/matmulfreellm: 403
# Error fetching repo sinnedpenguin/dennx: 403
# Error fetching repo m-a-n-i-f-e-s-t/power-attention: 403
# Error fetching repo mahmoodlab/UNI: 403
# Error fetching repo jw782cn/RepoChat-200k: 403
# Error fetching repo KudoAI/chatgpt.js-chrome-starter: 403
# Error fetching repo Aegis1863/LLMs-Distillation-Quantification: 403
# Error fetching repo iboing/CorDA: 403
# Error fetching repo woheller69/gpt4all-TK-CHAT: 403
# Error fetching repo jiangnanboy/Image_KIE_LLM: 403
# Error fetching repo guolinke/TUPE: 403
# Error fetching repo SkalskiP/sports: 403
# Error fetching repo SqueezeAILab/LLMCompiler: 403
# Error fetching repo easonlai/chatbot_with_pdf_streamlit: 403
# Error fetching repo MikeWangWZHL/Solo-Performance-Prompting: 403
# Error fetching repo llmapi-io/llmapi-chat: 403
# Error fetching repo xNul/code-llama-for-vscode: 403
# Error fetching repo adamlui/userscripts: 403
# Error fetching repo usesecond/aigate: 403
# Error fetching repo build-on-aws/agentic-workshop: 403
# Error fetching repo gyxxyg/TRACE: 403
# Error fetching repo magichub-opensource/CLAM-Conversational-Language-AI-from-MagicData: 403
# Error fetching repo e2b-dev/ai-developer-with-sandbox: 403
# Error fetching repo rese1f/aurora: 403
# Error fetching repo RageAgainstThePixel/com.rest.blockadelabs: 403
# Error fetching repo kanugurajesh/SmartDoc: 403
# Error fetching repo bwnyasse/aroma-journey-app: 403
# Error fetching repo ziwang-com/zero-lora: 403
# Error fetching repo goruck/home-generative-agent: 403
# Error fetching repo Picsart-AI-Research/Zero-Painter: 403
# Error fetching repo constantjxyz/PromptLink: 403
# Error fetching repo kylejtobin/langchain_search_bot: 403
# Error fetching repo X-PLUG/MobileAgent: 403
# Error fetching repo Fisseha-Estifanos/LLM-API: 403
# Error fetching repo ben-ogden/pinecone-rag: 403
# Error fetching repo junyu-w/gptc: 403
# Error fetching repo jgravelle/AutoGroq: 403
# Error fetching repo davide-coccomini/Deepfake-Detection-Challenge-DFAD2023: 403
# Error fetching repo aniketwdubey/chatpdf: 403
# Error fetching repo nomic-ai/gpt4all: 403
# Error fetching repo THUDM/LongCite: 403
# Error fetching repo DemoGit4LIANG/Chat2Anything: 403
# Error fetching repo Bessouat40/RAGLight: 403
# Error fetching repo mindspore-courses/step_into_llm: 403
# Error fetching repo wwbin2017/bailing: 403
# Error fetching repo OpenGVLab/InternGPT: 403
# Error fetching repo chriscrcodes/talk-to-your-factory: 403
# Error fetching repo zjunlp/Deco: 403
# Error fetching repo kyegomez/PALI3: 403
# Error fetching repo GURPREETKAURJETHRA/LLM-SECURITY: 403
# Error fetching repo tigerlab-ai/tiger: 403
# Error fetching repo Troyanovsky/Local-LLM-Comparison-Colab-UI: 403
# Error fetching repo Cybonto/OllaDeck: 403
# Error fetching repo alanqrwang/keymorph: 403
# Error fetching repo thu-ml/SageAttention: 403
# Error fetching repo rbourgeat/llm-rp: 403
# Error fetching repo jtsang4/bob-plugin-claude-translator: 403
# Error fetching repo StonyBrookNLP/ircot: 403
# Error fetching repo modelscope/dash-infer: 403
# Error fetching repo sunzeyeah/RLHF: 403
# Error fetching repo bravekingzhang/flutter_chat_box: 403
# Error fetching repo iimeta/iim-client: 403
# Error fetching repo lastmile-ai/mcp-agent: 403
# Error fetching repo burglarhobbit/Awesome-Medical-Large-Language-Models: 403
# Error fetching repo hahahumble/speechgpt: 403
# Error fetching repo asahi417/tner: 403
# Error fetching repo Hyk260/PureChat: 403
# Error fetching repo firebase/genkit: 403
# Error fetching repo Praveen76/LLMs-Interview-Prep-Guide: 403
# Error fetching repo DriesFaems/LeanStartUp-GPT-Agent: 403
# Error fetching repo 0xTheProDev/Spell-Checker: 403
# Error fetching repo grafana/vectorapi: 403
# Error fetching repo artemnefedov/JavaAI: 403
# Error fetching repo sozercan/kubectl-ai: 403
# Error fetching repo aws-samples/lm-gvp: 403
# Error fetching repo keith2018/TinyGPT: 403
# Error fetching repo BoxcarsAI/boxcars: 403
# Error fetching repo purvaten/FLEX: 403
# Error fetching repo clidey/whodb: 403
# Error fetching repo yaseenmustapha/nextjs14-app: 403
# Error fetching repo MuhangTian/TimeDiff: 403
# Error fetching repo huggingface/chat-ui: 403
# Error fetching repo LiyuanLucasLiu/LD-Net: 403
# Error fetching repo jalvarezz13/prompt.fail: 403
# Error fetching repo chicks2014/SQLGPT: 403
# Error fetching repo xingxin666/chatgpt-nodejs-web: 403
# Error fetching repo ParthSareen/simple-rag: 403
# Error fetching repo S1M0N38/dspy-arxiv: 403
# Error fetching repo sutdcv/SUTD-TrafficQA: 403
# Error fetching repo kyegomez/Progen: 403
# Error fetching repo build-on-aws/amazon-bedrock-custom-langchain-agent: 403
# Error fetching repo arekusandr/last_layer: 403
# Error fetching repo mala-lab/NegPrompt: 403
# Error fetching repo georgekhananaev/PyNextStack: 403
# Error fetching repo sunnweiwei/RankGPT: 403
# Error fetching repo VisualBoy/AI-Bots-Prompt-Collection: 403
# Error fetching repo Lokeshwaran-M/jam-gpt: 403
# Error fetching repo laelhalawani/gguf_llama: 403
# Error fetching repo toverainc/willow-inference-server: 403
# Error fetching repo The-Swarm-Corporation/FluidAPI: 403
# Error fetching repo tencentmusic/cube-studio: 403
# Error fetching repo Calvin-LL/is-even-ai: 403
# Error fetching repo nicolodiamante/chatty: 403
# Error fetching repo davidADSP/Generative_Deep_Learning_2nd_Edition: 403
# Error fetching repo knuddelsgmbh/jtokkit: 403
# Error fetching repo aihpi/ragsst: 403
# Error fetching repo neuralwork/sd-interior-design: 403
# Error fetching repo explosion/curated-transformers: 403
# Error fetching repo IngestAI/deepmark: 403
# Error fetching repo google/paxml: 403
# Error fetching repo Jenqyang/LLM-Powered-RAG-System: 403
# Error fetching repo DavideWiest/ContextFlow: 403
# ...
# Error fetching repo mmhamdy/open-language-models: 403
# Error fetching repo microsoft/RecAI: 403
# Error fetching repo mrmps/SMRY: 403
# Error fetching repo jamesturk/scrapeghost: 403
# Error fetching repo superlinked/superlinked: 403
# Error fetching repo Sven-Bo/Integrate-GPT4-in-Excel-using-VBA: 403
# Error fetching repo MainakVerse/sartaaj-ai-bio-generator: 403
# Error fetching repo omeregev/click2mask: 403
# Error fetching repo alisafaya/mukayese: 403
# Error fetching repo jpcadena/ice-breaker: 403
# Error fetching repo VinAIResearch/RecGPT: 403
# Error fetching repo EvelynFan/AWESOME-MER: 403
# Error fetching repo IbrahimSobh/llms: 403
# Error fetching repo RishiHazra/saycanpay: 403
# Error fetching repo PankajBarai/ChatGPT_Prompt_Engineering: 403
# Error fetching repo ClarkCGA/multi-temporal-crop-classification-training-data: 403
# Error fetching repo csinva/interpretable-embeddings: 403
# Error fetching repo smxl/500: 403
# Error fetching repo FudanSELab/LISP: 403
# Error fetching repo zchoi/Awesome-Embodied-Agent-with-LLMs: 403
# Error fetching repo Stylsheets/TaskEaseGPT: 403
# Error fetching repo 0w9/langchain-discord: 403
# Error fetching repo ddh0/easy-llama: 403
# Error fetching repo tensorgi/T6: 403
# Error fetching repo l294265421/my-llm: 403
# Error fetching repo BoevaLab/CancerFoundation: 403
# Error fetching repo quack-ai/companion: 403
# Error fetching repo TobyYang7/Llava_Qwen2: 403
# Error fetching repo microsoft/DeBERTa: 403
# Error fetching repo Dataherald/dataherald: 403
# Error fetching repo Azure-Samples/contoso-creative-writer: 403
# Error fetching repo ai919/Awesome-ChatGPT: 403
# Error fetching repo OpenGVLab/Instruct2Act: 403
# Error fetching repo olivierDuchenne/LLM_json_schema: 403
# Error fetching repo prajwalshettydev/UnrealGenAISupport: 403
# Error fetching repo OxWearables/ssl-wearables: 403
# Error fetching repo CyberZHG/torch-gpt-2: 403
# Error fetching repo HydroXai/pii-masker: 403
# Error fetching repo mala-lab/SIC-CADS: 403
# Error fetching repo biocypher/biocypher: 403
# Error fetching repo railsjazz/ask_chatgpt: 403
# Error fetching repo ChenWu98/agent-attack: 403
# Error fetching repo trypromptly/LLMStack: 403
# Error fetching repo solliancenet/foundationallm: 403
# Error fetching repo EmbraceAGI/AIGC_Interview: 403
# Error fetching repo pnborchert/BusinessBERT: 403
# Error fetching repo janbanot/personal_assistant: 403
# Error fetching repo richardadonnell/AI-Prompts-Tools-and-More: 403
# Error fetching repo gensx-inc/gensx: 403
# Error fetching repo nitanmarcel/sydney-telegram: 403
# Error fetching repo VITA-Group/LiGO: 403
# Error fetching repo nigel-daniels/openai: 403
# Error fetching repo milvus-io/milvus: 403
# Error fetching repo nathanborror/Heat: 403
# Error fetching repo femnn/Chatgpt-Create-fun-gameplay: 403
# Error fetching repo iimeta/fastapi-web: 403
# Error fetching repo scraperai/scraperai: 403
# Error fetching repo falcondai/lm-steganography: 403
# Error fetching repo weekend-project-space/moon-note: 403
# Error fetching repo marqo-ai/marqo-ecommerce-embeddings: 403
# Error fetching repo PKU-Alignment/beavertails: 403
# Error fetching repo DevEmperor/WristAssist: 403
# Error fetching repo APIParkLab/APIPark: 403
# Error fetching repo mishushakov/ai-fun: 403
# Error fetching repo jaredpalmer/nextjs-langchain-example: 403
# Error fetching repo sungnyun/diffblender: 403
# Error fetching repo curiousily/tweetcrafter: 403
# Error fetching repo discourse/discourse-ai: 403
# Error fetching repo TsinghuaC3I/MedXpertQA: 403
# Error fetching repo di37/youtube-notes-generator: 403
# Error fetching repo CyberDefend3r/stutterAI: 403
# Error fetching repo tychozzz/gpt-web-terminal: 403
# Error fetching repo pawamoy/mkdocs-llmstxt: 403
# Error fetching repo boschresearch/ALDM: 403
# Error fetching repo ehsanghaffar/llm-practice: 403
# Error fetching repo mongodb-developer/Google-Cloud-RAG-Langchain: 403
# Error fetching repo aehrc/cvt2distilgpt2: 403
# Error fetching repo McGill-NLP/weblinx: 403
# Error fetching repo crazyofapple/Reading_groups: 403
# Error fetching repo changwookjun/nlp-paper: 403
# Error fetching repo substratusai/kubeai: 403
# Error fetching repo rostyslavshovak/RAG-Retrieval-Augmented-Generation: 403
# Error fetching repo EdoardoBotta/RQ-VAE-Recommender: 403
# Error fetching repo webhiveos/WebHive: 403
# Error fetching repo caspianmoon/memoripy: 403
# Error fetching repo NitroRCr/AIaW: 403
# Error fetching repo changwoolee/BLAST: 403
# Error fetching repo noarche/AutoPrompt: 403
# Error fetching repo taranjeet/awesome-gpts: 403
# Error fetching repo antonio-f/Orca2: 403
# Error fetching repo viczommers/CentralBank-LLM: 403
# Error fetching repo gaomingzhao666/AI-Prompts: 403
# Error fetching repo abshare/abshare.github.io: 403
# Error fetching repo simoncragg/synth-gpt: 403
# Error fetching repo sStonemason/RET-CLIP: 403
# Error fetching repo Nithin-GK/UniteandConquer: 403
# Error fetching repo isaiahbjork/Auto-GPT-MetaTrader-Plugin: 403
# Error fetching repo mehrdad-dev/Battle-of-the-Wordsmiths: 403
# Error fetching repo cogentapps/chat-with-gpt: 403
# Error fetching repo takashiishida/cleanprompt: 403
# Error fetching repo mbarinov/repogpt: 403
# Error fetching repo SciPhi-AI/agent-search: 403
# Error fetching repo pingcap/LinguFlow: 403
# Error fetching repo kimtth/awesome-azure-openai-llm: 403
# Error fetching repo AtakanTekparmak/tiny_fnc_engine: 403
# Error fetching repo ggerganov/whisper.cpp: 403
# Error fetching repo lishenghui/awesome-fm-fl: 403
# Error fetching repo MineDojo/Voyager: 403
# Error fetching repo imoneoi/openchat: 403
# Error fetching repo pjlab-sys4nlp/llama-moe: 403
# Error fetching repo index-labs/readpilot: 403
# Error fetching repo JSv4/Delphic: 403
# Error fetching repo discus-labs/discus: 403
# Error fetching repo Colin-XKL/FeedCraft: 403
# Error fetching repo theodo-group/GenossGPT: 403
# Error fetching repo pratyushasharma/laser: 403
# Error fetching repo Miraclemarvel55/LLaMA-MOSS-RLHF-LoRA: 403
# Error fetching repo nlkitai/nlux: 403
# Error fetching repo Gamma-Software/AppifyAi: 403
# Error fetching repo motis-project/motis: 403
# Error fetching repo Oneirocom/Magick: 403
# Error fetching repo steinathan/reelsmaker: 403
# Error fetching repo blib-la/captain: 403
# Error fetching repo kohjingyu/search-agents: 403
# Error fetching repo Eurus-Holmes/MNMT: 403
# Error fetching repo mbzuai-oryx/VideoGLaMM: 403
# Error fetching repo DeNA/dify-google-cloud-terraform: 403
# Error fetching repo automorphic-ai/trex: 403
# Error fetching repo FrozenBurning/PrimDiffusion: 403
# Error fetching repo SamurAIGPT/langchain-course: 403
# Error fetching repo cure-lab/MotionCraft: 403
# Error fetching repo CLUEbenchmark/SuperCLUE: 403
# Error fetching repo artitw/text2text: 403
# Error fetching repo mattmireles/Flatty: 403
# Error fetching repo kyegomez/OpenR1: 403
# Error fetching repo jbuckman/boilerplate-dynet-rnn-lm: 403
# Error fetching repo thongekchakrit/ChartAI: 403
# Error fetching repo DreamLoom-AI/prompt-ez: 403
# Error fetching repo kkdai/linebot-langchain: 403
# Error fetching repo godaai/llm-table-survey: 403
# Error fetching repo jndiogo/sibila: 403
# Error fetching repo DoodleJZ/LIMIT-BERT: 403
# Error fetching repo EleutherAI/DALLE-mtf: 403
# Error fetching repo UIC-InDeXLab/Needle: 403
# Error fetching repo rubenselander/openai-function-tokens: 403
# Error fetching repo alberto-solano/open-source-LLM-translation-tool: 403
# Error fetching repo RManLuo/Awesome-LLM-KG: 403
# Error fetching repo open-compass/ANAH: 403
# Error fetching repo microsoft/TypeChat: 403
# Error fetching repo lorniu/go-translate: 403
# Error fetching repo madaan/pie-perf: 403
# Error fetching repo aimhubio/aim: 403
# Error fetching repo mbzuai-oryx/Video-ChatGPT: 403
# Error fetching repo Nkluge-correa/Aira: 403
# Error fetching repo Pavansomisetty21/Text-to-Images-Leveraging-Flux-AI-for-Text-to-Image-Generation: 403
# Error fetching repo OpenDriveLab/OpenScene: 403
# Error fetching repo rozek/node-red-flow-openai-api: 403
# Error fetching repo lmstudio-ai/lms: 403
# Error fetching repo NVIDIA/DeepLearningExamples: 403
# Error fetching repo kalavai-net/kalavai-client: 403
# Error fetching repo ahmedbesbes/media-agent: 403
# Error fetching repo 360CVGroup/OVD_Contest: 403
# Error fetching repo hyp1231/awesome-llm-powered-agent: 403
# Error fetching repo mlsanigeria/speak-to-docs: 403
# Error fetching repo bhattbhavesh91/pdf-q-a-llamaindex-llama2: 403
# Error fetching repo skywalker023/sodaverse: 403
# Error fetching repo electricpipelines/barq: 403
# Error fetching repo janhq/jan: 403
# Error fetching repo m1guelpf/yt-whisper: 403
# Error fetching repo katanemo/archgw: 403
# Error fetching repo zzw922cn/awesome-speech-recognition-speech-synthesis-papers: 403
# Error fetching repo Aesthetikx/openai_pipe: 403
# Error fetching repo gustavoeenriquez/MakerAi: 403
# Error fetching repo yaroslavyaroslav/OpenAI-sublime-text: 403
# Error fetching repo seyf1elislam/LocalLLM_OneClick_Colab: 403
# Error fetching repo SiyuanYan1/PanDerm: 403
# Error fetching repo iimeta/fastapi-admin: 403
# Error fetching repo jellydn/gpt4all-cli: 403
# Error fetching repo jmont-dev/ollama-hpp: 403
# Error fetching repo GerevAI/gerev: 403
# Error fetching repo mishushakov/llm-scraper: 403
# Error fetching repo worldbank/llm4data: 403
# Error fetching repo zhenye234/LLaSA_training: 403
# Error fetching repo hymie122/RAG-Survey: 403
# Error fetching repo Joyce94/LLM-RLHF-Tuning: 403
# Error fetching repo codekansas/keras-language-modeling: 403
# Error fetching repo 3Alan/chatpdf-demo: 403
# Error fetching repo Storia-AI/sage: 403
# Error fetching repo chrislemke/ChatFred: 403
# Error fetching repo geeker-ai/geek_chat: 403
# Error fetching repo mjunaidca/travel-ai-service: 403
# Error fetching repo EdVince/CLIP-ImageSearch-NCNN: 403
# Error fetching repo zenoverflow/omnichain: 403
# Error fetching repo Azure/GPT-RAG: 403
# Error fetching repo mala-lab/InCTRL: 403
# Error fetching repo Zaechus/artix-installer: 403
# Error fetching repo Ahmet-Dedeler/ai-llm-comparison: 403
# Error fetching repo cycneuramus/signal-aichat: 403
# Error fetching repo IST-DASLab/marlin: 403
# Error fetching repo devscast/lugha: 403
# Error fetching repo vxsahu/gitagpt: 403
# Error fetching repo robatwilliams/openai-excel-functions: 403
# Error fetching repo logankilpatrick/ChatGPT-Simple: 403
# Error fetching repo EmbeddedLLM/JamAIBase: 403
# Error fetching repo zilliztech/deep-searcher: 403
# Error fetching repo suncloudsmoon/TextCraft: 403
# Error fetching repo blankenshipz/clerk: 403
# Error fetching repo ccallazans/ai-video-generator: 403
# Error fetching repo OpenBGBenchmark/OpenBG-IMG: 403
# Error fetching repo ayushidalmia/Phrase-Based-Model: 403
# Error fetching repo daver987/nuxt-docu-search-ai: 403
# Error fetching repo elder-plinius/L1B3RT4S: 403
# Error fetching repo ToxyBorg/llama_langchain_documents_embeddings: 403
# Error fetching repo kamalkraj/minGPT-TF: 403
# Error fetching repo d-f/llm-summarization: 403
# Error fetching repo Text2TCS/Towards-Learning-Terminological-Concept-Systems: 403
# Error fetching repo xieyuquanxx/awesome-Large-MultiModal-Hallucination: 403
# Error fetching repo zukixa/cool-ai-stuff: 403
# Error fetching repo web-infra-dev/midscene: 403
# Error fetching repo ggml-org/llama.vim: 403
# Error fetching repo kanishkamisra/minicons: 403
# Error fetching repo ai-forever/DataProcessingFramework: 403
# Error fetching repo hiyouga/FastEdit: 403
# Error fetching repo vicgalle/awesome-rlaif: 403
# Error fetching repo cognano/AVIDa-SARS-CoV-2: 403
# Error fetching repo kyegomez/LongNet: 403
# Error fetching repo Shou-Hsu/Report.ai: 403
# Error fetching repo user1342/Oversight: 403
# Error fetching repo bapaws/answer: 403
# Error fetching repo pitmonticone/RedditTextClassification: 403
# Error fetching repo Olanetsoft/article-idea-generator: 403
# Error fetching repo tshu-w/ComEM: 403
# Error fetching repo JHubi1/ollama-app: 403
# Error fetching repo HowieHwong/TrustLLM: 403
# Error fetching repo salesforce/DialogStudio: 403
# Error fetching repo djrecipe/SlackAI: 403
# Error fetching repo INK-USC/RobustLR: 403
# Error fetching repo zjunlp/KnowAgent: 403
# Error fetching repo svilupp/awesome-generative-ai-meets-julia-language: 403
# Error fetching repo deepsense-ai/ds-pycontain: 403
# Error fetching repo jondot/awesome-rust-llm: 403
# Error fetching repo chaoswork/sft_datasets: 403
# Error fetching repo CMKRG/QiZhenGPT: 403
# Error fetching repo CyberAlbSecOP/Awesome_GPT_Super_Prompting: 403
# Error fetching repo decisionfacts/semantic-ai: 403
# Error fetching repo orhanerday/open-ai: 403
# Error fetching repo sinanuozdemir/oreilly-ai-agents: 403
# Error fetching repo showlab/Awesome-GUI-Agent: 403
# Error fetching repo tatsu-lab/alpaca_farm: 403
# Error fetching repo adamrushy/OpenAISwift: 403
# Error fetching repo Prographers/Slack-GPT: 403
# Error fetching repo tmlr-group/DeepInception: 403
# Error fetching repo tuananhbui89/Erasing-Adversarial-Preservation: 403
# Error fetching repo ashishpatel26/AIAgentWorkshop: 403
# Error fetching repo jina-ai/agentchain: 403
# Error fetching repo IuriiD/ai24support-openai-pinecone-rag: 403
# Error fetching repo talperetz/browsegraph: 403
# Error fetching repo CameLLM/CameLLM-Llama: 403
# Error fetching repo LetterLiGo/SafeGen_CCS2024: 403
# Error fetching repo rizerphe/local-llm-function-calling: 403
# Error fetching repo dabit3/gpt-travel-advisor: 403
# Error fetching repo yokingma/search_with_ai: 403
# Error fetching repo instructor-ai/instructor: 403
# Error fetching repo will-thompson-k/tldr-transformers: 403
# Error fetching repo doutv/Auto-GPT-Notion: 403
# Error fetching repo stephanj/Scheduling-using-GPT4: 403
# Error fetching repo SignitDoc/semantic-file-retrieval: 403
# Error fetching repo sozercan/guac-ai-mole: 403
# Error fetching repo microsoft/HydraLab: 403
# Error fetching repo akl7777777/bob-plugin-akl-chatgpt-free-translate: 403
# Error fetching repo bhattbhavesh91/pdf-qa-astradb-langchain: 403
# Error fetching repo ricardobalk/HackGPT: 403
# Error fetching repo aymenfurter/smartrag: 403
# Error fetching repo dotvignesh/PDFChat: 403
# Error fetching repo AIDC-AI/Parrot: 403
# Error fetching repo franalgaba/chatgpt-telegram-bot-serverless: 403
# Error fetching repo chg0901/Public_QiDiHui: 403
# Error fetching repo 101dotxyz/GPTeam: 403
# Error fetching repo chanpreet3000/amazon-hackon: 403
# Error fetching repo zAlweNy26/ts-cat: 403
# Error fetching repo deepflowio/deepflow: 403
# Error fetching repo jdh-algo/JoyVASA: 403
# Error fetching repo jaychempan/Awesome-LWMs: 403
# Error fetching repo TIGER-AI-Lab/LongICLBench: 403
# Error fetching repo arthur-ai/bench: 403
# Error fetching repo inferflow/inferflow: 403
# Error fetching repo voidful/awesome-chatgpt-dataset: 403
# Error fetching repo Ravi-Teja-konda/Surveillance_Video_Summarizer: 403
# Error fetching repo hkust-nlp/deita: 403
# Error fetching repo stableagents/stableagents: 403
# Error fetching repo yxuansu/MAGIC: 403
# Error fetching repo smol-ai/GodMode: 403
# Error fetching repo three-bee/triplane_edit: 403
# Error fetching repo awslabs/mlm-scoring: 403
# Error fetching repo hhstore/blog: 403
# Error fetching repo nodetool-ai/nodetool: 403
# Error fetching repo IDEA-CCNL/Fengshenbang-LM: 403
# Error fetching repo logancyang/obsidian-copilot: 403
# Error fetching repo ParisNeo/lollms-webui: 403
# Error fetching repo ai4co/routefinder: 403
# Error fetching repo nociza/Bimg: 403
# Error fetching repo horseee/LLaMA-Pruning: 403
# Error fetching repo jackMort/ChatGPT.nvim: 403
# Error fetching repo cosin2077/chaty: 403
# Error fetching repo kennethleungty/Generative-AI-Pharmacist: 403
# Error fetching repo olimorris/codecompanion.nvim: 403
# Error fetching repo jasonaidm/ai_webui: 403
# Error fetching repo docarray/docarray: 403
# Error fetching repo WLiK/LLM4Rec-Awesome-Papers: 403
# Error fetching repo microsoft/generative-ai-for-beginners: 403
# Error fetching repo kinsta/hello-world-langchain: 403
# Error fetching repo vdutts7/ai-mreflow: 403
# Error fetching repo ioannis-papadimitriou/rag-playground: 403
# Error fetching repo raunak-agarwal/instruction-datasets: 403
# Error fetching repo microsoft/typechat.net: 403
# Error fetching repo GeneralBots/BotServer: 403
# Error fetching repo pluja/maestro: 403
# Error fetching repo pd3f/pd3f-core: 403
# Error fetching repo artmatsak/horace: 403
# Error fetching repo alon-albalak/data-selection-survey: 403
# Error fetching repo kardolus/chatgpt-cli: 403
# Error fetching repo langgptai/Top-GPTs-Prompts: 403

# %%
df_repos.to_csv("./temp/llm_kb.csv")
